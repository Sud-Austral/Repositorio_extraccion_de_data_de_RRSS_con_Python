# %% [markdown]
# # Minería de datos sobre Twitter con Python
# ### 13 de Marzo

# %% [markdown]
# ### Insumos útiles que resultan de la minería de datos sobre twitter:
#     1. Obtener los tweets que incluyan el nombre una empresa o producto y posteriormente hacer un análisis de sentimientos sobre los tweets que contengan el o los términos seleccionados y saber si los usuarios tienen una apreciación positiva o negativa de una empresa o producto.
#     2. Crear un gráfico social de los usuarios más populares (influencers) que mencionan a nuestro producto o empresa en Twitter.
#     3. Recopilar datos en tiempo real de un evento como por ejemplo el lanzamiento de producto para su análisis.
#     4. Identificar los lugares, ciudades y/o países en los cuales nuestra empresa o producto son mencionados.
#     5. Analizar los datos de usuarios específicos y su interacción con otros usuarios en Twitter.
#     6. Hacer un Monitoreo de los seguidores y usuarios a los que sigue un usuario.
#     7. Encontrar influenciadores en Twitter y la tendencia en el crecimiento de sus seguidores.

# %% [markdown]
# ## 1. Construir una cuenta de desarrollador en Twitter
#
# Ingresando a https://apps.twitter.com/. debemos llegar a esta URL: https://developer.twitter.com/en/apps y donde nos registraremos como desarrollador. Una vez registrados, debemos esperar un momento a que nuestra cuenta sea creada y ya podemos construir una app.
#
# Primero debemos instalar desde Anaconda prompt tweepy: pip install tweepy

# %% [markdown]
# La mineria de datos sobre twitter incluye dos pasos:
#     1. Configurar una cuenta de desarrollador en Twitter y
#     2. Analizar con Python
#
#
#     1 primero analisis del lenguaje natural
#     2 integrar un conteo de tweets en la misma linea que indica si no existen, en cuyo caso que indique cero.
#     2 luego el analisis de sentimientos

# %%
import tweepy
from tweepy import OAuthHandler

api_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
api_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'
access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
auth = OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
#api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Código que establece un radio y guarda en CSV

# agregar el despliegue de un mensaje en el caso de no 
# encontrar tweets según los para metros especificados

import datetime
import csv
csvFile = open('tweets.csv', 'a')

filename = 'e001_'+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search , 
                   since='2020-01-01', q = 'seguridad',
                               geocode="-33.622096,-70.592343,4.5km").items():
        print ([tweet.created_at, tweet.text.encode('utf-8'), tweet.id, tweet.place])
        
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), 
                            tweet.id, tweet.place])
# Out:
# [datetime.datetime(2020, 3, 12, 15, 32, 51), b'@supereduc_cl @alvarado_edo Me preocupa la continuidad de las clases y la seguridad de  mis hijos antes las manifes\xe2\x80\xa6 https://t.co/iChZVNpKEv', 1238125812613812225, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 12, 13, 2, 18), b'@Neninogarcia @meganoticiascl @chilevision @CNNChile @germancodina @HolaChileLaRed nefasta seguridad, mal trato a n\xe2\x80\xa6 https://t.co/UgkD3aMuwy', 1238087925990150147, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 11, 19, 53, 33), b'Muchas veces lo sospech\xc3\xa9 pero ahora ya estoy completamente seguro que Pi\xc3\xb1era no termina su gobierno. 100% de seguridad.', 1237829029585092610, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 10, 5, 47, 32), b'@Sara_Connorr @euge2145 Estos creen que nuestra FFAA, CARABINEROS Y PDI, Son Narcos??\nNO srs, son Patriotas Dem\xc3\xb3cra\xe2\x80\xa6 https://t.co/FW4vSNcQEx', 1237253736231288832, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 9, 17, 13, 43), b'A\xc3\xb1os atras robaron 6 millones de d\xc3\xb3lares del mismo aeropuerto \xc2\xbfno se hizo nada por mejorar la seguridad? \xc2\xbfQui\xc3\xa9n sab\xe2\x80\xa6 https://t.co/5m1dsD1asC', 1237064033259454464, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 8, 2, 7, 52), b'@The__OU_DMI De la Patria y ciudadanos trabajadores. Asegur\xc3\xa1ndonos La seguridad social, extirpando delincuencia y narco_terrorismo.', 1236473681158823939, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 6, 1, 1, 31), b'Intendencia y estadio seguro suspendieron el partido por "Falta de fuerzas de seguridad"\n\xc2\xbfque es lo que no se entie\xe2\x80\xa6 https://t.co/NZPCGzhztw', 1235732204757581831, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 5, 0, 40, 41), b'@PepeMon_ESPN Una eventual franquicia y la seguridad de ese pa\xc3\xads', 1235364577644339201, Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]

# %%
import datetime
import csv
csvFile = open('tweets.csv', 'a')

filename = 'ana444 '+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search ,  q = 'ambiente',geocode="-33.622096,-70.592343,4.5km").items():
        print ([tweet.text, tweet.created_at, tweet.text.encode('utf-8'), tweet.place])
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.place])
# Out:
# ['El @MMAChile lanzó Tarjeta Digital, que busca reemplazar a las antiguas tarjetas impresas de papel. ¡Hoy este desaf… https://t.co/tlnPQTI6PX', datetime.datetime(2020, 3, 10, 15, 7, 9), b'El @MMAChile lanz\xc3\xb3 Tarjeta Digital, que busca reemplazar a las antiguas tarjetas impresas de papel. \xc2\xa1Hoy este desaf\xe2\x80\xa6 https://t.co/tlnPQTI6PX', Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# ['@Mad_maxx83 @metrodesantiago No entiendes el punto. Si el ambiente no es seguro, simplemente se cierra, pero abrir… https://t.co/PfhIaSJEKR', datetime.datetime(2020, 3, 6, 1, 58, 56), b'@Mad_maxx83 @metrodesantiago No entiendes el punto. Si el ambiente no es seguro, simplemente se cierra, pero abrir\xe2\x80\xa6 https://t.co/PfhIaSJEKR', Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# ['@metrodesantiago En este momento hay fuego en runa de las entradas a plaza puente alto ....ojo con el ambiente..', datetime.datetime(2020, 3, 4, 23, 10, 30), b'@metrodesantiago En este momento hay fuego en runa de las entradas a plaza puente alto ....ojo con el ambiente..', Place(_api=<tweepy.api.API object at 0x000001570F9F0308>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001570F9F0308>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]

# %%
import datetime
import csv
csvFile = open('tweets.csv', 'a')

filename = 'anefef '+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search ,  q = 'medio ambiente',geocode="-33.365900,-70.513310,150km").items():
        print ([tweet.text, tweet.created_at, tweet.text.encode('utf-8')])
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# ['RT @MuniNunoa: ¿Qué materiales se pueden reciclar? 🤔\nAquí te lo contamos ☝\nSé parte de nuestro Programa de Reciclaje y toma acciones concre…', datetime.datetime(2020, 3, 13, 16, 33, 23), b'RT @MuniNunoa: \xc2\xbfQu\xc3\xa9 materiales se pueden reciclar? \xf0\x9f\xa4\x94\nAqu\xc3\xad te lo contamos \xe2\x98\x9d\nS\xc3\xa9 parte de nuestro Programa de Reciclaje y toma acciones concre\xe2\x80\xa6']
# ['RT @jcollinsrom: @patricionavia @Justiceandpace Este gobierno encéfalo, las FFEE, su constitución, la privatización de la educación, la sal…', datetime.datetime(2020, 3, 13, 16, 23, 6), b'RT @jcollinsrom: @patricionavia @Justiceandpace Este gobierno enc\xc3\xa9falo, las FFEE, su constituci\xc3\xb3n, la privatizaci\xc3\xb3n de la educaci\xc3\xb3n, la sal\xe2\x80\xa6']
# ['RT @MetroValpo: ¿Sabías que diariamente en nuestras cocheras se sanitizan y desinfectan los trenes de Metro Valparaíso? En el proceso se ut…', datetime.datetime(2020, 3, 13, 16, 10, 18), b'RT @MetroValpo: \xc2\xbfSab\xc3\xadas que diariamente en nuestras cocheras se sanitizan y desinfectan los trenes de Metro Valpara\xc3\xadso? En el proceso se ut\xe2\x80\xa6']
# ['RT @sergio_pena_v: @jtgazmuri Acá tenemos jóvenes del "Apruebo", ayudando al medio ambiente, vaciando el camión para que esté tenga menos p…', datetime.datetime(2020, 3, 13, 16, 8, 54), b'RT @sergio_pena_v: @jtgazmuri Ac\xc3\xa1 tenemos j\xc3\xb3venes del "Apruebo", ayudando al medio ambiente, vaciando el cami\xc3\xb3n para que est\xc3\xa9 tenga menos p\xe2\x80\xa6']
# ['RT @MuniNunoa: ¿Qué materiales se pueden reciclar? 🤔\nAquí te lo contamos ☝\nSé parte de nuestro Programa de Reciclaje y toma acciones concre…', datetime.datetime(2020, 3, 13, 16, 1, 18), b'RT @MuniNunoa: \xc2\xbfQu\xc3\xa9 materiales se pueden reciclar? \xf0\x9f\xa4\x94\nAqu\xc3\xad te lo contamos \xe2\x98\x9d\nS\xc3\xa9 parte de nuestro Programa de Reciclaje y toma acciones concre\xe2\x80\xa6']
# ['RT @MuniNunoa: ¿Qué materiales se pueden reciclar? 🤔\nAquí te lo contamos ☝\nSé parte de nuestro Programa de Reciclaje y toma acciones concre…', datetime.datetime(2020, 3, 13, 15, 59, 16), b'RT @MuniNunoa: \xc2\xbfQu\xc3\xa9 materiales se pueden reciclar? \xf0\x9f\xa4\x94\nAqu\xc3\xad te lo contamos \xe2\x98\x9d\nS\xc3\xa9 parte de nuestro Programa de Reciclaje y toma acciones concre\xe2\x80\xa6']
# ['14 formas de ahorrar siendo respetuosos con el medio ambiente https://t.co/aI6KxBnJy6 https://t.co/HBvQcR7UnQ', datetime.datetime(2020, 3, 13, 15, 50, 34), b'14 formas de ahorrar siendo respetuosos con el medio ambiente https://t.co/aI6KxBnJy6 https://t.co/HBvQcR7UnQ']
# ['RT @piensaverde_cl: 💚 Feliz día #8M a todas nuestras mujeres #ecologistas, porque así como la madre tierra tiene el don de dar vida, así la…', datetime.datetime(2020, 3, 8, 19, 33, 48), b'RT @piensaverde_cl: \xf0\x9f\x92\x9a Feliz d\xc3\xada #8M a todas nuestras mujeres #ecologistas, porque as\xc3\xad como la madre tierra tiene el don de dar vida, as\xc3\xad la\xe2\x80\xa6']
# ['💚 Feliz día #8M a todas nuestras mujeres #ecologistas, porque así como la madre tierra tiene el don de dar vida, as… https://t.co/D5zhk771i5', datetime.datetime(2020, 3, 8, 19, 33, 14), b'\xf0\x9f\x92\x9a Feliz d\xc3\xada #8M a todas nuestras mujeres #ecologistas, porque as\xc3\xad como la madre tierra tiene el don de dar vida, as\xe2\x80\xa6 https://t.co/D5zhk771i5']
# ['@MinagriCL @MMAChile @SMA_CL  Sigamos luchando como sea por nuestro medio ambiente aunque al gobierno no le interes… https://t.co/yDtQuLVwIm', datetime.datetime(2020, 3, 8, 19, 14, 3), b'@MinagriCL @MMAChile @SMA_CL  Sigamos luchando como sea por nuestro medio ambiente aunque al gobierno no le interes\xe2\x80\xa6 https://t.co/yDtQuLVwIm']
# ['Firma esta Alerta de Acción para instar a la Comisión de Medio Ambiente, Recursos Naturales y Cambio Climático, que… https://t.co/He7Ig5dmTs', datetime.datetime(2020, 3, 8, 18, 11, 3), b'Firma esta Alerta de Acci\xc3\xb3n para instar a la Comisi\xc3\xb3n de Medio Ambiente, Recursos Naturales y Cambio Clim\xc3\xa1tico, que\xe2\x80\xa6 https://t.co/He7Ig5dmTs']
# ['RT @bichocanasto_: dice guillermo andino que la #VendimiaSolidaria sirve para revertir los daños del medio ambiente.', datetime.datetime(2020, 3, 8, 17, 56, 31), b'RT @bichocanasto_: dice guillermo andino que la #VendimiaSolidaria sirve para revertir los da\xc3\xb1os del medio ambiente.']
# ['Esta señora si que cuida el medio ambiente... cero plastico... https://t.co/LYfe1w3CNz', datetime.datetime(2020, 3, 8, 17, 56, 6), b'Esta se\xc3\xb1ora si que cuida el medio ambiente... cero plastico... https://t.co/LYfe1w3CNz']
# ['Ahora hablan de medio ambiente!!! Que vergüenza!!! Devuelvan el Agua!!!', datetime.datetime(2020, 3, 8, 17, 48, 21), b'Ahora hablan de medio ambiente!!! Que verg\xc3\xbcenza!!! Devuelvan el Agua!!!']
# ['dice guillermo andino que la #VendimiaSolidaria sirve para revertir los daños del medio ambiente.', datetime.datetime(2020, 3, 8, 17, 48, 6), b'dice guillermo andino que la #VendimiaSolidaria sirve para revertir los da\xc3\xb1os del medio ambiente.']
# ['RT @PartidoVerdeMza: Felicitaciones @SilviaVazquez  nueva Directora Nacional de Medio Ambiente del Ministerio de Relaciones Exteriores Come…', datetime.datetime(2020, 3, 8, 17, 16, 21), b'RT @PartidoVerdeMza: Felicitaciones @SilviaVazquez  nueva Directora Nacional de Medio Ambiente del Ministerio de Relaciones Exteriores Come\xe2\x80\xa6']
# ['@cgajardop Desastroso para el medio ambiente, y pa el Sr. Carcamo tener 50 cámaras no le sirve, necesita piloto aut… https://t.co/C9O9pUKQRW', datetime.datetime(2020, 3, 8, 17, 14, 13), b'@cgajardop Desastroso para el medio ambiente, y pa el Sr. Carcamo tener 50 c\xc3\xa1maras no le sirve, necesita piloto aut\xe2\x80\xa6 https://t.co/C9O9pUKQRW']
# ['@chilevision informa sobre agresiones de manifestantes del Rechazo en Providencia, agregando que  sus camarógrafos… https://t.co/KoMzO0lU6I', datetime.datetime(2020, 3, 8, 0, 58, 43), b'@chilevision informa sobre agresiones de manifestantes del Rechazo en Providencia, agregando que  sus camar\xc3\xb3grafos\xe2\x80\xa6 https://t.co/KoMzO0lU6I']
# ['Y no les vamos a dar las gracias por sacar los neumáticos  y basura que ustedes mismos generaron y la @DIMAOIMSA ha… https://t.co/tBFOB3pFxE', datetime.datetime(2020, 3, 8, 0, 43, 7), b'Y no les vamos a dar las gracias por sacar los neum\xc3\xa1ticos  y basura que ustedes mismos generaron y la @DIMAOIMSA ha\xe2\x80\xa6 https://t.co/tBFOB3pFxE']
# ['RT @Naty_campusano: Estas prácticas políticas y empresariales que no pueden ser parte del Nuevo Chile. Basta de jugar con el medio ambiente…', datetime.datetime(2020, 3, 8, 0, 39, 41), b'RT @Naty_campusano: Estas pr\xc3\xa1cticas pol\xc3\xadticas y empresariales que no pueden ser parte del Nuevo Chile. Basta de jugar con el medio ambiente\xe2\x80\xa6']
# ['@hermanntertsch Una alarma que hemos venido denunciado y que no ha tenido eco en los centros de poder del medio amb… https://t.co/nmKVcC0ruZ', datetime.datetime(2020, 3, 8, 0, 34, 32), b'@hermanntertsch Una alarma que hemos venido denunciado y que no ha tenido eco en los centros de poder del medio amb\xe2\x80\xa6 https://t.co/nmKVcC0ruZ']
# ['No entiendo bien qué significa "contaminar". Antes era tirar desechos no biodegradables al medio ambiente. Ahora pa… https://t.co/TMTV15SVL1', datetime.datetime(2020, 3, 8, 0, 33, 55), b'No entiendo bien qu\xc3\xa9 significa "contaminar". Antes era tirar desechos no biodegradables al medio ambiente. Ahora pa\xe2\x80\xa6 https://t.co/TMTV15SVL1']
# ['En Chilevisión, seguramente para jugar al empate, después de informar sobre la cobarde agresión a Rafael Cavada por… https://t.co/CzN8hYkJy9', datetime.datetime(2020, 3, 8, 0, 25, 33), b'En Chilevisi\xc3\xb3n, seguramente para jugar al empate, despu\xc3\xa9s de informar sobre la cobarde agresi\xc3\xb3n a Rafael Cavada por\xe2\x80\xa6 https://t.co/CzN8hYkJy9']
# ['Te felicito amigo. En estos tiempos donde los weones buscan excusas del medio ambiente y un montón de weas más para… https://t.co/aDPyyi9pYH', datetime.datetime(2020, 3, 7, 23, 29, 7), b'Te felicito amigo. En estos tiempos donde los weones buscan excusas del medio ambiente y un mont\xc3\xb3n de weas m\xc3\xa1s para\xe2\x80\xa6 https://t.co/aDPyyi9pYH']

# %% [markdown]
# # Información extraíble de cada tweet:
# created_at: la fecha de creacion del tweet.
#
# text: el texto del tweet.
#
# id: El identificador del tweet.
#
# favorite_count: el número de favoritos.
#
# retweet_count: el número de retweets.
#
# favorited: los favoritos.
#
# retweeted: booleano que establece si el usuario esta autenticado.
#
# lang: acrónimo para el idioma.
#
# place, coordinates, geo: información de geolocalización si es que está disponble.
#
# user: el perfil completo del autor.
#
# ## Importante: razón para usar BdeD NoSQL:
# ### twitter no está estructurado, por lo que el excel no cargará si existe algún símbolo en él.
#
# entities: lista de entidades como URL, @ -menciones, hashtags y símbolos.
#
# in_reply_to_user_id: identificador de usuario si el tweet es una respuesta a un usuario específico.
#
# in_reply_to_status_id: identificador de estado si id el tweet es una respuesta a un estado específico.

# %% [markdown]
# ### Podemos identificar los últimos usuarios y su localización respecto a un tema específico
# #### Fuente: https://www.earthdatascience.org/courses/earth-analytics-python/using-apis-natural-language-processing-twitter/get-and-use-twitter-data-in-python/

# %%
import pandas as pd
search_words = "#wildfires"
date_since = "2018-11-16"
tweets = tweepy.Cursor(api.search, 
                           q = search_words,
                           #geocode="-33.365900,-70.513310,150km",
                           lang="es",
                           since=date_since).items(50)
users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs
# Out:
# [['racasant', 'Madrid'],
#  ['IngForestal50', ''],
#  ['rimasu3', 'Badajoz, España'],
#  ['DemontesOT', 'Sede Central en Madrid']]

# %% [markdown]
# #### y desplegar un dataframe:

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location"])
tweet_text
# Out:
#             user                location
# 0       racasant                  Madrid
# 1  IngForestal50
# 2        rimasu3         Badajoz, España
# 3     DemontesOT  Sede Central en Madrid

# %% [markdown]
# El parámetro until es específico y no se puede establecer para un periodo de tiempo que exceda los 7 días del momento actual.

# %% [markdown]
# <img src="tweet001.jpg">

# %%
new_search = "medio ambiente -filter:retweets"
import datetime

    
tweets = tweepy.Cursor(api.search,
                   q=new_search,
                   #geocode="-33.365900,-70.513310,5km",
                   lang="es",
                    
                # podemos obtener los tweets desde el 2020-03-10
                # hasta el 2020-03-11:
                   since='2020-03-10',
                   until = '2020-03-11').items(50)

all_tweets = [ tweet.created_at for tweet in tweets]
all_tweets[:50]
# Out:
# [datetime.datetime(2020, 3, 10, 23, 59, 11),
#  datetime.datetime(2020, 3, 10, 23, 58, 50),
#  datetime.datetime(2020, 3, 10, 23, 58, 9),
#  datetime.datetime(2020, 3, 10, 23, 58, 5),
#  datetime.datetime(2020, 3, 10, 23, 57, 54),
#  datetime.datetime(2020, 3, 10, 23, 55, 52),
#  datetime.datetime(2020, 3, 10, 23, 55, 44),
#  datetime.datetime(2020, 3, 10, 23, 53, 4),
#  datetime.datetime(2020, 3, 10, 23, 52, 5),
#  datetime.datetime(2020, 3, 10, 23, 51, 29),
#  datetime.datetime(2020, 3, 10, 23, 50, 51),
#  datetime.datetime(2020, 3, 10, 23, 47, 49),
#  datetime.datetime(2020, 3, 10, 23, 47, 20),
#  datetime.datetime(2020, 3, 10, 23, 46, 55),
#  datetime.datetime(2020, 3, 10, 23, 45, 10),
#  datetime.datetime(2020, 3, 10, 23, 44, 1),
#  datetime.datetime(2020, 3, 10, 23, 43, 58),
#  datetime.datetime(2020, 3, 10, 23, 43, 43),
#  datetime.datetime(2020, 3, 10, 23, 43, 36),
#  datetime.datetime(2020, 3, 10, 23, 41, 4),
#  datetime.datetime(2020, 3, 10, 23, 40, 44),
#  datetime.datetime(2020, 3, 10, 23, 40, 5),
#  datetime.datetime(2020, 3, 10, 23, 40),
#  datetime.datetime(2020, 3, 10, 23, 38, 49),
#  datetime.datetime(2020, 3, 10, 23, 37, 26),
#  datetime.datetime(2020, 3, 10, 23, 36, 51),
#  datetime.datetime(2020, 3, 10, 23, 34, 54),
#  datetime.datetime(2020, 3, 10, 23, 34, 36),
#  datetime.datetime(2020, 3, 10, 23, 33, 10),
#  datetime.datetime(2020, 3, 10, 23, 32, 29),
#  datetime.datetime(2020, 3, 10, 23, 31, 51),
#  datetime.datetime(2020, 3, 10, 23, 30, 33),
#  datetime.datetime(2020, 3, 10, 23, 30, 32),
#  datetime.datetime(2020, 3, 10, 23, 30, 4),
#  datetime.datetime(2020, 3, 10, 23, 30, 1),
#  datetime.datetime(2020, 3, 10, 23, 29, 53),
#  datetime.datetime(2020, 3, 10, 23, 29, 14),
#  datetime.datetime(2020, 3, 10, 23, 29, 8),
#  datetime.datetime(2020, 3, 10, 23, 28, 20),
#  datetime.datetime(2020, 3, 10, 23, 27, 59),
#  datetime.datetime(2020, 3, 10, 23, 27, 50),
#  datetime.datetime(2020, 3, 10, 23, 26, 48),
#  datetime.datetime(2020, 3, 10, 23, 26, 28),
#  datetime.datetime(2020, 3, 10, 23, 25, 45),
#  datetime.datetime(2020, 3, 10, 23, 24, 49),
#  datetime.datetime(2020, 3, 10, 23, 23, 49),
#  datetime.datetime(2020, 3, 10, 23, 22, 45),
#  datetime.datetime(2020, 3, 10, 23, 22, 5),
#  datetime.datetime(2020, 3, 10, 23, 21, 37),
#  datetime.datetime(2020, 3, 10, 23, 21, 13)]

# %% [markdown]
# ### Análisis de sentimientos

# %%
import textblob
import matplotlib.pyplot as plt

# %%
keyword=input('Que concepto quieres buscar?')
numberOfTweets=int(input('Ingresa el número de tweets'))

tweets = tweepy.Cursor(api.search, q=keyword, lang='es').items(numberOfTweets)


positive = 0
negative = 0
neutral = 0
polarity = 0

def calculatePercentage(a,b):
    return 100*float(a)/float(b)

for tweet in tweets:
    print(tweet.text)
    myAnalysis=textblob.TextBlob(tweet.text)
    polarity += myAnalysis.sentiment.polarity
    if myAnalysis.sentiment.polarity ==0:
        neutral+=1
    elif myAnalysis.sentiment.polarity > 0.00:
        positive+=1
    elif myAnalysis.sentiment.polarity < 0.00:
        negative+=1

positive=calculatePercentage(positive,numberOfTweets)
negative=calculatePercentage(negative,numberOfTweets)
neutral=calculatePercentage(neutral,numberOfTweets)

positive=format(positive,'.2f')
negative=format(negative,'.2f')
neutral=format(neutral,'.2f')

print('----------------------------------------------------------------------------')
if polarity>0:
    print('Positive')
elif polarity<0:
    print('Negative')
elif polarity==0:
    print('Neutral')

labels = ['Positive [' + str(positive) + '%]', 'Neutral [' + str(neutral) + '%]','Negative [' + str(negative) + '%]']
sizes=[positive,neutral,negative]
colors=['green','yellow','red']
patches,texts=plt.pie(sizes,colors=colors,startangle=90)
plt.legend(patches,labels,loc="best")
plt.title('Cómo las personas reaccionan a ' + keyword + ' analizando ' + str(numberOfTweets) + ' Tweets.')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# @melnicksergio Melnik hablando de defender la democracia, cuando este sanguinario tuvo activa participación en la dictadura de Pinochet 🤢
# RT @de_economicas: #Repostulación #FACSE #UCM #Talca
#
# Nuestro director Escuela de #Sociología  Dr. Marcelo Pinochet, invita a participar d…
# RT @SolesitaSunrise: #Viernes13 La figura de bienestar que más extrañamos en Chile desde el 18 de octubre es la de Augusto Pinochet. Entreg…
# RT @andres20ad: De joven apoyó un golpe de estado
# De adulto apoyó a un tirano
# De viejo quiere mantener la Constitución de Pinochet
#
# Tenemos…
# RT @edorobi73: Tellier participo en el atentado a Pinochet que dejo 5 escoltas muertos
# Quintana dio muerte a carabinero tras atropello y s…
# RT @michuuuub: VAMOS A CAMBIAR LA CONSTITUCIÓN DE GUZMÁN, SE VA A MORIR LA VIEJA RE CULIÁ, VAMOS A EXIGIR LA JUSTICIA QUE SE NEGÓ HACE 40 A…
# RT @guillier: Sergio, tú no estás en condiciones de defender la democracia. Fuiste ministro y cómplice activo de una Dictadura. Justificast…
# RT @antoniowalkerp: Participando de la #ExpoLoncoche junto al Subsecretario @Sub_Agricultura @JI_Pinochet y el Director de @INDAP_Chile @cr…
# ----------------------------------------------------------------------------
# Positive

# %% [markdown]
# Otra perspectiva:
#
# Obtengamos las últimas 100 publicaciones para el usuario de Twitter Bill Gates y mostremos sólo los primeros 5 tweets más recientes.
# Fuente:https://medium.com/@randerson112358/twitter-sentiment-analysis-15d8892c0082

# %%
# Extract 100 tweets from the twitter user
posts = api.user_timeline(screen_name="DanielJadue", 
                          count = 100, lang ="en", tweet_mode="extended")

#  Print the last 5 tweets
print("Show the 5 recent tweets:\n")
i=1
for tweet in posts[:5]:
    print(str(i) +') '+ tweet.full_text + '\n')
    i= i+1
# Out:
# Show the 5 recent tweets:
#
# 1) Hoy destacamos el libro “Obra Reunida” de Stella Díaz Varín, una antología que evoca tiempos de clandestinidad y poesía femenina que encontrarás en. Uretra librería popular @Recoletras a solo $9.360 pesos! https://t.co/CmCiXmKe9G
#
# 2) RT @oyenico: Momento exacto cuando Piñera dice que "supimos que IBAN a quemar las estaciones del Metro" en entrevista de @meganoticiascl #M…
#
# 3) Durante los últimos años se han profundizado las desigualdades y las injusticias a través de un modelo social que está absolutamente agotado. La salida a la crisis es solo con más democracia y nunca con menos democracia. #YoApruebo #ConvencionConstituyente https://t.co/VfgX1SKdxF
#
# 4) @gblumel y @sebastianpinera ? https://t.co/s6hqB6AV2g
#
# 5) @robertwatsonuc @sebastianpinera @gblumel de acuerdo

# %% [markdown]
# Creemos un dataframe con una columna llamada "Tweets" que contendrá las publicaciones del usuario de Twitter y que luego muestre las primeras 5 filas.

# %%
# Cree un marco de datos con una columna llamada Tweets:
df = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
# Mostrar las primeras 5 filas de datos:
df.head()
# Out:
#                                               Tweets
# 0  Hoy destacamos el libro “Obra Reunida” de Stel...
# 1  RT @oyenico: Momento exacto cuando Piñera dice...
# 2  Durante los últimos años se han profundizado l...
# 3  @gblumel y @sebastianpinera ? https://t.co/s6h...
# 4  @robertwatsonuc @sebastianpinera @gblumel de a...

# %% [markdown]
# Los datos están un poco sucios porque contienen el símbolo "@", hipervínculos, RT y pueden contener etiquetas hash "#", por lo que los limpiaremos creando una función para eliminar estos símbolos de los tweets. Luego aplicaremos esa función a los Tweets y mostraré los resultados.

# %%
# Creamos una función para limpiar los tweets
import re
def cleanTxt(text):
     text = re.sub('@[A-Za-z0–9]+', '', text) #Removing @mentions
     text = re.sub('#', '', text) # Removing '#' hash tag
     text = re.sub('RT[\s]+', '', text) # Removing RT
     text = re.sub('https?:\/\/\S+', '', text) # Removing hyperlink
     return text

# Limpiamos los tweets
df['Tweets'] = df['Tweets'].apply(cleanTxt)

# Mostramos los tweets limpios
df
# Out:
#                                                Tweets
# 0   Hoy destacamos el libro “Obra Reunida” de Stel...
# 1   : Momento exacto cuando Piñera dice que "supim...
# 2   Durante los últimos años se han profundizado l...
# 3                                               y  ?
# 4                                          de acuerdo
# ..                                                ...
# 95  :   Quiere escuchar, y desde ya moverse con la...
# 96                                      _D   si claro
# 97  Sara Correia, cantante de Fado, estará present...
# 98  A solo un día de comenzar nuestro festival  no...
# 99                  Que yo sepa, gobierna la derecha.
#
# [100 rows x 1 columns]

# %% [markdown]
# Queremos agregar la subjetividad y polaridad de los tweets al dataframe.
# Para hacer esto, crearemos dos funciones:
# 1. Una para obtener los tweets llamados subjetividad (cuán subjetivo u obstinado es el texto, un puntaje de 0 es un hecho y un puntaje de +1 es en gran medida una opinión) y
# 2. Otra para obtener el tweets llamados Polarity (qué tan positivo o negativo es el texto, un puntaje de -1 es el puntaje negativo más alto y un puntaje de +1 es el puntaje positivo más alto).
# A continuación, almacenaremos los resultados en dos columnas, una llamada "Subjetividad" y la otra llamada "Polaridad" y mostraremos los resultados.

# %%
from textblob import TextBlob

# Create a function to get the subjectivity
def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
   return  TextBlob(text).sentiment.polarity


# Create two new columns 'Subjectivity' & 'Polarity'
df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] = df['Tweets'].apply(getPolarity)

# Show the new dataframe with columns 'Subjectivity' & 'Polarity'
df
# Out:
#                                                Tweets  Subjectivity  Polarity
# 0   Hoy destacamos el libro “Obra Reunida” de Stel...      0.900000  0.750000
# 1   : Momento exacto cuando Piñera dice que "supim...      0.000000  0.000000
# 2   Durante los últimos años se han profundizado l...      0.066667  0.033333
# 3                                               y  ?       0.000000  0.000000
# 4                                          de acuerdo      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  :   Quiere escuchar, y desde ya moverse con la...      0.000000  0.000000
# 96                                      _D   si claro      0.000000  0.000000
# 97  Sara Correia, cantante de Fado, estará present...      0.000000  0.000000
# 98  A solo un día de comenzar nuestro festival  no...      0.000000  0.000000
# 99                  Que yo sepa, gobierna la derecha.      0.000000  0.000000
#
# [100 rows x 3 columns]

# %% [markdown]
# Veamos qué tan bien se distribuyen los sentimientos.
# Una buena manera de lograr esta tarea es entender las palabras comunes trazando
# nubes de palabras. Una nube de palabras (también conocida como nubes de texto o
# nubes de etiquetas) es una visualización, cuanto más aparece una palabra específica en el texto, más grande y más audaz aparece en la nube de palabras. Visualicemos todas las palabras en los datos usando el diagrama de nube de palabras. Parece que la palabra "salud" aparece mucho en los últimos 100 tweets de Bill Gates.

# %%
# visualización de la nube de palabras
from wordcloud import WordCloud
allWords = ' '.join([twts for twts in df['Tweets']])
wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size=110).generate(allWords)
plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Crearemos una función para calcular el análisis negativo (-1), neutral (0) y positivo (+1) y agregue la información a una nueva columna llamada Análisis, luego muestre los resultados.

# %%
# Create a function to compute negative (-1), neutral (0) and positive (+1) analysis
def getAnalysis(score):
 if score < 0:
  return 'Negative'
 elif score == 0:
  return 'Neutral'
 else:
  return 'Positive'


df['Analysis'] = df['Polarity'].apply(getAnalysis)

# Show the dataframe
df
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   Hoy destacamos el libro “Obra Reunida” de Stel...      0.900000  0.750000
# 1   : Momento exacto cuando Piñera dice que "supim...      0.000000  0.000000
# 2   Durante los últimos años se han profundizado l...      0.066667  0.033333
# 3                                               y  ?       0.000000  0.000000
# 4                                          de acuerdo      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  :   Quiere escuchar, y desde ya moverse con la...      0.000000  0.000000
# 96                                      _D   si claro      0.000000  0.000000
# 97  Sara Correia, cantante de Fado, estará present...      0.000000  0.000000
# 98  A solo un día de comenzar nuestro festival  no...      0.000000  0.000000
# 99                  Que yo sepa, gobierna la derecha.      0.000000  0.000000
#
#     Analysis
# 0   Positive
# 1    Neutral
# 2   Positive
# 3    Neutral
# 4    Neutral
# ..       ...
# 95   Neutral
# 96   Neutral
# 97   Neutral
# 98   Neutral
# 99   Neutral
#
# [100 rows x 4 columns]

# %% [markdown]
# Imprimamos los tweets positivos en orden ascendente. El tuit más positivo es el tuit # 1.

# %%
# Imprimimos los tweets positivos: 
print('Desplegamos los tweets positivos:\n')
j=1
sortedDF = df.sort_values(by=['Polarity']) # Ordenamos los tweets
for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Analysis'][i] == 'Positive'):
    print(str(j) + ') '+ sortedDF['Tweets'][i])
    print()
    j= j+1
# Out:
# Desplegamos los tweets positivos:
#
# 1) Hoy destacamos el libro “Obra Reunida” de Stella Díaz Varín, una antología que evoca tiempos de clandestinidad y poesía femenina que encontrarás en. Uretra librería popular  a solo $9.360 pesos!
#
# 2) Durante los últimos años se han profundizado las desigualdades y las injusticias a través de un modelo social que está absolutamente agotado. La salida a la crisis es solo con más democracia y nunca con menos democracia. YoApruebo ConvencionConstituyente
#
# 3) Marcha familiar en Melipilla cobardemente atacada por agentes del Estado. Gobierno de  y  nuevamente optan por la represión. La impunidad permite que los criminales sigan abusando contra un pueblo que solo pide justicia y dignidad! RenunciaPiñera
#
# 4) Orgullosos, satisfechos y contentos seguimosavanzando Escuela Popular de Teatro de Recoleta: Primera generación de egresados  vía _ciudadano
#
# 5) Agradezco invitación de organizaciones sociales de Ñuñoa para exponer acerca de “los gobiernos locales para un nuevo Chile” en la plaza Guillermo Franke. Notable convocatoria! SeguimosAvanzando
#
# 6) : Estamos celebrando un gran hito con la Escuela Popular de Teatro de Recoleta! La primera generación de egresados de la…
#
# 7) Las y los verdaderos protagonistas del cambio social en Chile deben tener su espacio.
#
# Desde el comando  se ha cedido la totalidad de los minutos de la franja a las organizaciones sociales, para construir una ‘Franja por la dignidad’. ¡Las y los esperamos mañana!
#
# 8) Este gobierno sigue sin entender nada y prisionero de un modelo fracasado / “Es lo que hay y no hay más”: la lapidaria determinación de La Moneda respecto de la agenda social
#
# 9) Comparto esta columna, indispensable para entender cómo llegamos a este punto y cuál es la responsabilidad de algunos que aparecen hoy defendiendo la democracia /Reformas constitucionales: el regalo de la mayoría parlamentaria en 1989

# %% [markdown]
# Imprimimos los tweets negativos en orden descendente. El tuit más negativo es el tuit # 1.

# %%
# Impresión de los tweets negativos
  
print('Impresión de los tweets negativos:\n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False) #Sort the tweets
for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Analysis'][i] == 'Negative'):
    print(str(j) + ') '+sortedDF['Tweets'][i])
    print()
    j=j+1
# Out:
# Impresión de los tweets negativos:

# %% [markdown]
# Trace la polaridad y la subjetividad como un diagrama de dispersión. Parece que la mayoría de los tweets son positivos, ya que muchos de los puntos están en el lado derecho de la polaridad en el valor 0.00.

# %%
# Plotting 
plt.figure(figsize=(8,6)) 
for i in range(0, df.shape[0]):
  plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color='Blue') # plt.scatter(x,y,color)   
plt.title('Sentiment Analysis') 
plt.xlabel('Polarity') 
plt.ylabel('Subjectivity') 
plt.show()

# %% [markdown]
# Imprimimos el porcentaje de tweets positivos. Alrededor de 81/100 de los tweets se consideran tweets positivos.

# %%
# Print the percentage of positive tweets
ptweets = df[df.Analysis == 'Positive']
ptweets = ptweets['Tweets']
ptweets

round( (ptweets.shape[0] / df.shape[0]) * 100 , 1)
# Out:
# 9.0

# %% [markdown]
# Imprime el porcentaje de tweets negativos. Alrededor de 9/100 tweets se consideran tweets negativos.

# %%
# Print the percentage of negative tweets
ntweets = df[df.Analysis == 'Negative']
ntweets = ntweets['Tweets']
ntweets

round( (ntweets.shape[0] / df.shape[0]) * 100, 1)
# Out:
# 0.0

# %% [markdown]
# Mostrar el valor cuenta. Ahora podemos ver que 81 tweets son positivos, 10 son neutrales y 9 son negativos.

# %%
# Show the value counts
df['Analysis'].value_counts()
# Out:
# Neutral     91
# Positive     9
# Name: Analysis, dtype: int64

# %% [markdown]
# Muestra visualmente el valor cuenta.

# %%
# Trazar y visualizar los recuentos
plt.title('Análisis de sentimientos')
plt.xlabel('Sentimiento')
plt.ylabel('Recuentos')
df['Analysis'].value_counts().plot(kind = 'bar')
plt.show()
