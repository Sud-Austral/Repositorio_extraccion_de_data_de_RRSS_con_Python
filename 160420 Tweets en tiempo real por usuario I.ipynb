# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-16
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
prompt = '> '
tweet=''
print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = input(prompt)

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:
# > ispch
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/OelxCGtAiI
#
# RT @ministeriosalud: Inicio de uso obligatorio de mascarillas | ¿En qué lugares?
#
# Conoce más sobre esta nueva medida que comienza a impleme…
#
# Si estás en aislamiento domiciliario, es muy importante mantener las medidas de prevención en el hogar.
#
# - Lávate l… https://t.co/CnP3HCxnZ8
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/RKI8QHFmVg
#
# RT @ministeriosalud: Conoce el detalle de la nueva medida que comienza hoy sobre el uso obligatorio de mascarillas, publicado en la edición…
#
# RT @ministeriosalud: Subsec @pdazan | Fiscalización
#
# "La autoridad sanitaria tiene todas las facultades para realizar la fiscalización corr…
#
# RT @ministeriosalud: "Esta medida se suma al resto de las que ya están implementadas en el país".
#
# "Llamamos a las personas a que mantengan…
#
# RT @ministeriosalud: Subsecretaria @pdazan | Sanciones
#
# - 2.5 millones de pesos de sanción
#
# "Esta medida es fundamental y obligatoria. Se d…
#
# RT @ministeriosalud: AHORA: Subsec @pdazan hace el llamado a respetar la medida de uso obligatorio de mascarilla en recintos cerrados, que…
#
# #CuidémonosEntreTodos y en especial si tienes un familiar en tu hogar diagnosticado con #COVID_19.
#
# Conoce los cons… https://t.co/TAPCEIN2hl

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  El uso correcto de la mascarilla es clave para...
# 1  RT @ministeriosalud: Inicio de uso obligatorio...
# 2  Si estás en aislamiento domiciliario, es muy i...
# 3  Temperatura actual, pronóstico del tiempo y ra...
# 4  RT @ministeriosalud: Conoce el detalle de la n...
# 5  RT @ministeriosalud: Subsec @pdazan | Fiscaliz...
# 6  RT @ministeriosalud: "Esta medida se suma al r...
# 7  RT @ministeriosalud: Subsecretaria @pdazan | S...
# 8  RT @ministeriosalud: AHORA: Subsec @pdazan hac...
# 9  #CuidémonosEntreTodos y en especial si tienes ...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251148409383378944
# 2020-04-17 14:00:00
# TweetDeck
# 4
# 4
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OelxCGtAiI', 'expanded_url': 'https://twitter.com/i/web/status/1251148409383378944', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  El uso correcto de la mascarilla es clave para...  1251148409383378944
# 1  RT @ministeriosalud: Inicio de uso obligatorio...  1251135627501940737
# 2  Si estás en aislamiento domiciliario, es muy i...  1251133312070008832
# 3  Temperatura actual, pronóstico del tiempo y ra...  1251131864104030209
# 4  RT @ministeriosalud: Conoce el detalle de la n...  1251129333504245762
# 5  RT @ministeriosalud: Subsec @pdazan | Fiscaliz...  1251129282279211019
# 6  RT @ministeriosalud: "Esta medida se suma al r...  1251129266344992772
# 7  RT @ministeriosalud: Subsecretaria @pdazan | S...  1251129248838045696
# 8  RT @ministeriosalud: AHORA: Subsec @pdazan hac...  1251129217682636801
# 9  #CuidémonosEntreTodos y en especial si tienes ...  1251118210495193088
#
#                  Date              Source  Likes  RTs
# 0 2020-04-17 14:00:00           TweetDeck      4    4
# 1 2020-04-17 13:09:13  Twitter for iPhone      0  252
# 2 2020-04-17 13:00:01           TweetDeck      1    2
# 3 2020-04-17 12:54:15  Twitter for iPhone      0    0
# 4 2020-04-17 12:44:12  Twitter for iPhone      0  100
# 5 2020-04-17 12:44:00  Twitter for iPhone      0   11
# 6 2020-04-17 12:43:56  Twitter for iPhone      0   12
# 7 2020-04-17 12:43:52  Twitter for iPhone      0   21
# 8 2020-04-17 12:43:45  Twitter for iPhone      0   49
# 9 2020-04-17 12:00:00           TweetDeck      0    0

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  El uso correcto de la mascarilla es clave para...
# 1  RT @ministeriosalud: Inicio de uso obligatorio...
# 2  Si estás en aislamiento domiciliario, es muy i...
# 3  Temperatura actual, pronóstico del tiempo y ra...
# 4  RT @ministeriosalud: Conoce el detalle de la n...
# 5  RT @ministeriosalud: Subsec @pdazan | Fiscaliz...
# 6  RT @ministeriosalud: "Esta medida se suma al r...
# 7  RT @ministeriosalud: Subsecretaria @pdazan | S...
# 8  RT @ministeriosalud: AHORA: Subsec @pdazan hac...
# 9  #CuidémonosEntreTodos y en especial si tienes ...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1251148409383... 2020-04-17 14:00:00
# 1  https://twitter.com/ispch/status/1251135627501... 2020-04-17 13:09:13
# 2  https://twitter.com/ispch/status/1251133312070... 2020-04-17 13:00:01
# 3  https://twitter.com/ispch/status/1251131864104... 2020-04-17 12:54:15
# 4  https://twitter.com/ispch/status/1251129333504... 2020-04-17 12:44:12
# 5  https://twitter.com/ispch/status/1251129282279... 2020-04-17 12:44:00
# 6  https://twitter.com/ispch/status/1251129266344... 2020-04-17 12:43:56
# 7  https://twitter.com/ispch/status/1251129248838... 2020-04-17 12:43:52
# 8  https://twitter.com/ispch/status/1251129217682... 2020-04-17 12:43:45
# 9  https://twitter.com/ispch/status/1251118210495... 2020-04-17 12:00:00
#
#                Source  Likes  RTs
# 0           TweetDeck      4    4
# 1  Twitter for iPhone      0  252
# 2           TweetDeck      1    2
# 3  Twitter for iPhone      0    0
# 4  Twitter for iPhone      0  100
# 5  Twitter for iPhone      0   11
# 6  Twitter for iPhone      0   12
# 7  Twitter for iPhone      0   21
# 8  Twitter for iPhone      0   49
# 9           TweetDeck      0    0

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
