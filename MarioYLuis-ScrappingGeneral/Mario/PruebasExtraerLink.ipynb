# %%
#Cargar librerias
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import sys



driver = webdriver.Firefox()
driver.set_page_load_timeout("60")
driver.get("https://www.facebook.com")

driver.find_element_by_name("email").send_keys("informaticasudaustral@gmail.com")
driver.find_element_by_name("pass").send_keys("Info.Sud91")

driver.find_element_by_id("loginbutton").click()
driver.set_page_load_timeout("60")

lugar = "isla de maipo"

lugar.replace(" ","%20")
driver.get("https://www.facebook.com/search/places/?q="+str(lugar)+"&epa=SERP_TAB")
driver.set_page_load_timeout("60")
#contador = 0
#paginas = 2

#while contador < paginas:
 #   driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
  #  time.sleep(5)
   # contador+=1

SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


flag  = 1
exit = ""
"""
while flag < 10:
#while exit == "Message: Unable to locate element: ._4sxc":
    try:
        driver.find_element_by_class_name("_4sxc _42ft").click()
        #driver.find_element_by_class_name("_5v47 fss").click()
        #print("Hola")
    except Exception as e:
        exit = e
        print(e)
        print("Oops! ",sys.exc_info()[0]," occured.")
        flag = flag + 1
        #print("termino")
        #flag = False
   """     


"""
css = "div.oh7imozk:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1) > div:nth-child(4) > div:nth-child(2) > ul:nth-child(5) > li:nth-child(36) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > span:nth-child(1) > div:nth-child(1) > div:nth-child(2) > a:nth-child(1)"
#         /html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li[11]/div[1]/div/div[2]/div/div[1]/div/div[1]/div/div/div[2]/span/div/div/a
xpath = "/html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li"
#xpath = "/html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li[36]/div[1]/div/div[2]/div/div[1]/div/div/div/div/div[2]/span/div/div/a"
#for i in driver.find_elements_by_xpath(xpath):
for i in driver.find_elements_by_css_selector(css):
    i.click()
    #print("hola")
time.sleep(5)
nombre = []
comentario = []
likes=[]
detalle = []
#driver.find_element_by_class_name
"""   
#xpath = "/html/body/div[1]/div[3]/div[1]/div/div[3]/div[2]/div/div/div[2]/div/div/div/div/div/div/ul/li"
#for i in driver.find_elements_by_xpath("/html/body/div[1]/div/   div/  div[2]/div/div   /div   /div/div   /div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li"):
#clase = find_element_by_class_name("_1wu_")

for i in driver.find_elements_by_class_name("_1wu_"):
    #maduro = i.find_element_by_class_name("_72vr")
    
    """
    try:
        maduro = i.find_element_by_class_name("_72vr")
        
        #maduro = i.find_element_by_tag_name("span")
        print(maduro.text)        
        try:
            likes = i.find_element_by_class_name("_1lld")
            print(likes.text)
        except:
            print("0")
    except:
        print("no hay texto")
    
    print("*****************************************************************************************")
        
   
   
    try:
        print(i.find_elements_by_class_name("lrazzd5p")[1].click())
        #print(i.find_element_by_xpath("a").text)
    except:
        print("Error")
    """
    
        
    #clase = i.find_element_by_class_name("_1wu_")
    tag = i.find_element_by_tag_name("a")
    salida = tag.get_attribute("href")
        
    
    #print(str(len(i.text.split("\n"))))
    #print(str(len(salida.split("\n"))))
    #for j in i.text.split("\n"):
    
    for j in salida.split("\n"):
        j = j.replace("Responder","").replace(" ·  · ","")
        j = j.replace("Escribe una respuesta...","")
        j = j.replace('Está seleccionada la opción "Más relevantes", por lo que es posible que algunas respuestas se hayan filtrado.',"")
        j = j.replace('Presiona "Enter" para publicar.',"")
        if(len(j) > 0):
            print(str(len(j)))
            
            print(j)
            print("*********************************************************************************************")
    print("--------------------------------------------------------------------------------------------------")
# Out:
# 41
# https://www.facebook.com/muniislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/IslaDeMaipoAtentos/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/muniislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 87
# https://www.facebook.com/pages/Isla-De-Maipo-Region-Metropolitana-Chile/108996172466853
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 57
# https://www.facebook.com/corporacionmunicipalislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 107
# https://www.facebook.com/Cesfam-Y-Postas-de-Salud-Corporaci%C3%B3n-Municipal-Isla-de-Maipo-535784159828059/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 45
# https://www.facebook.com/cultura.islademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/IBEMislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 38
# https://www.facebook.com/vinasantaema/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/BiblioIsladeMaipo196/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/campinglagunademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/campinglospuentes.cl/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 50
# https://www.facebook.com/campingeledenislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 54
# https://www.facebook.com/sibaritaygourmet.islademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 92
# https://www.facebook.com/Colegio-Mar%C3%ADa-Reina-Inmaculada-Isla-de-Maipo-1552666824998506/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 62
# https://www.facebook.com/Ajuvis-Isla-de-Maipo-694133307422592/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 35
# https://www.facebook.com/radioisla/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 40
# https://www.facebook.com/DeMartinoWines/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 61
# https://www.facebook.com/pages/Isla-De-Maipo/1171847276296252
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 74
# https://www.facebook.com/Colegio-Particular-leonardo-Da-Vinci-25917753913/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 45
# https://www.facebook.com/RestaurantZinFandel/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 43
# https://www.facebook.com/hostalnevadachile/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 35
# https://www.facebook.com/rekomaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 42
# https://www.facebook.com/patinislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 53
# https://www.facebook.com/tallerdecosturasislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 50
# https://www.facebook.com/centroveterinariocrubvet/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 51
# https://www.facebook.com/alcantarilladoislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 67
# https://www.facebook.com/ExpoCentro-Isla-de-Maipo-2321857901209537/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 51
# https://www.facebook.com/centroecuestreislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/nekosushiislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 36
# https://www.facebook.com/valtyer.cl/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 68
# https://www.facebook.com/pages/Subsole-Isla-De-Maipo/118406991644937
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/manoscreativas2018/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 95
# https://www.facebook.com/Isla-de-Maipo-Country-Home-Maipo-Valley-Country-Home-1612957042106041/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 47
# https://www.facebook.com/TerramaterIslaDeMaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 88
# https://www.facebook.com/Pizzas-y-churrascos-a-domicilio-isla-de-maipo--850333188426516/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
#