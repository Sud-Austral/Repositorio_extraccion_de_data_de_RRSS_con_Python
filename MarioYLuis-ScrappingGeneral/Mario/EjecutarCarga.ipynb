# %%
import cargaEnlaces as ce

# %%
listado = ce.cargarEnlacesLugar('isla de maipo')
# Out:
# 41
# https://www.facebook.com/muniislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/IslaDeMaipoAtentos/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/muniislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 57
# https://www.facebook.com/corporacionmunicipalislademaipo/
# *********************************************************************************************
# ...

# %%
print(listado)
# Out:
# ['https://www.facebook.com/muniislademaipo/', 'https://www.facebook.com/IslaDeMaipoAtentos/', 'https://www.facebook.com/muniislademaipo/', 'https://www.facebook.com/corporacionmunicipalislademaipo/', 'https://www.facebook.com/Cesfam-Y-Postas-de-Salud-Corporaci%C3%B3n-Municipal-Isla-de-Maipo-535784159828059/', 'https://www.facebook.com/cultura.islademaipo/', 'https://www.facebook.com/IBEMislademaipo/', 'https://www.facebook.com/vinasantaema/', 'https://www.facebook.com/campinglagunademaipo/', 'https://www.facebook.com/BiblioIsladeMaipo196/', 'https://www.facebook.com/campinglospuentes.cl/', 'https://www.facebook.com/Colegio-Mar%C3%ADa-Reina-Inmaculada-Isla-de-Maipo-1552666824998506/', 'https://www.facebook.com/Ajuvis-Isla-de-Maipo-694133307422592/', 'https://www.facebook.com/campingeledenislademaipo/', 'https://www.facebook.com/sibaritaygourmet.islademaipo/', 'https://www.facebook.com/DeMartinoWines/', 'https://www.facebook.com/rekomaipo/', 'https://www.facebook.com/patinislademaipo/'
# ...
