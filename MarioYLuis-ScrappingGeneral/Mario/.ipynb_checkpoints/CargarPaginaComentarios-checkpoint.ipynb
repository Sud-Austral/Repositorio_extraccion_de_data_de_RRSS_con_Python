# %%
import urllib.request

# %%
fp = urllib.request.urlopen("https://www.facebook.com/NintendoLatAm/posts/2482140828703889")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
print(mystr)
# Out:
# <!DOCTYPE html>
# <html lang="en" id="facebook" class="no_js">
# ...

# %%
import codecs
import itertools
import json
import re
import time
import warnings
from datetime import datetime
from urllib import parse as urlparse

from requests import RequestException
from requests_html import HTML, HTMLSession
_base_url = 'https://m.facebook.com'
_user_agent = ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
               "AppleWebKit/537.36 (KHTML, like Gecko) "
               "Chrome/76.0.3809.87 Safari/537.36")
_cookie = ('locale=en_US;')
_headers = {'User-Agent': _user_agent, 'Accept-Language': 'en-US,en;q=0.5', 'cookie': _cookie}

_session = None
_timeout = None

_likes_regex = re.compile(r'like_def[^>]*>([0-9,.]+)')
_comments_regex = re.compile(r'cmt_def[^>]*>([0-9,.]+)')
_shares_regex = re.compile(r'([0-9,.]+)\s+Shares', re.IGNORECASE)
_link_regex = re.compile(r"href=\"https:\/\/lm\.facebook\.com\/l\.php\?u=(.+?)\&amp;h=")

_cursor_regex = re.compile(r'href:"(/page_content[^"]+)"')  # First request
_cursor_regex_2 = re.compile(r'href":"(\\/page_content[^"]+)"')  # Other requests

_photo_link = re.compile(r"href=\"(/[^\"]+/photos/[^\"]+?)\"")
_image_regex = re.compile(r"<a href=\"([^\"]+?)\" target=\"_blank\" class=\"sec\">View Full Size<\/a>", re.IGNORECASE)
_image_regex_lq = re.compile(r"background-image: url\('(.+)'\)")
_post_url_regex = re.compile(r'/story.php\?story_fbid=')

_more_url_regex = re.compile(r'(?<=…\s)<a href="([^"]+)')
_post_story_regex = re.compile(r'href="(\/story[^"]+)" aria')

# %%
_session = HTMLSession()
response = _session.get("https://m.facebook.com/NintendoLatAm/posts/2482140828703889")
html = HTML(html=response.html.html.replace('<!--','').replace('-->',''))
cursor_blob = html.html
print(cursor_blob)
# Out:
# <!DOCTYPE html><html><head><title>Devuelve tiros a tus enemigos mientras vuelas por mundos llenos de color, vida y personajes divertidos en una aventura que mezcla los clásicos géneros de Shoot ’em Ups y Block Breakers para crear el primer &quot;Shmup Breaker&quot; del mundo.
#
# Sky Racket está disponible en eShop/Tienda Nintendo.
# México: https://www.nintendo.com/games/detail/sky-racket-switch/
# Argentina: https://store.nintendo.com.ar/sky-racket
# Colombia: https://store.nintendo.co/sky-racket
# Chile: https://store.nintendo.cl/sky-racket
# ...

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-14-ec48251f04f8> in <module>
# ----> 1 driver = webdriver.Chrome()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
# ...

# %%
import time
from selenium import webdriver

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://m.facebook.com/NintendoLatAm/posts/2482140828703889');
time.sleep(5) # Let the user actually see something!
search_box = driver.find_element_by_name('q')
search_box.send_keys('ChromeDriver')
search_box.submit()
time.sleep(5) # Let the user actually see something!
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-13-abd973e57713> in <module>
#       2 from selenium import webdriver
#       3
# ----> 4 driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
#       5 driver.get('http://www.google.com/');
#       6 time.sleep(5) # Let the user actually see something!
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox()
driver.get("https://www.facebook.com/NintendoLatAm/posts/2477630075821631")
#assert "Python" in driver.title
elem = driver.find_element_by_class_name("_3hg- _42ft")
print(elem)
#elem.clear()
#elem.send_keys("pycon")
#elem.send_keys(Keys.RETURN)
#assert "No results found." not in driver.page_source
#driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-20-123f7f2a5c7b> in <module>
#       5 driver.get("https://www.facebook.com/NintendoLatAm/posts/2477630075821631")
#       6 #assert "Python" in driver.title
# ----> 7 elem = driver.find_element_by_class_name("_3hg- _42ft")
#       8 print(elem)
#       9 #elem.clear()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Firefox()
driver.set_page_load_timeout("10")
driver.get("https://www.google.com")
#assert "Python" in driver.title
driver.find_element_by_name("q").send_keys("Automation Step by Step")
time.sleep(2)
driver.find_element_by_name("btnK").send_keys(Keys.ENTER)
#print(elem)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Firefox()
driver.set_page_load_timeout("60")
driver.get("https://www.facebook.com")
#assert "Python" in driver.title
driver.find_element_by_name("email").send_keys("informaticasudaustral@gmail.com")
driver.find_element_by_name("pass").send_keys("Info.Sud91")
driver.find_element_by_id("loginbutton").click()
#driver.get("https://www.facebook.com/NintendoLatAm/posts/2482140828703889")
#driver.get("https://m.facebook.com/story.php?story_fbid=10157415360825895&id=313191260894")
driver.set_page_load_timeout("60")
#driver.get("https://www.facebook.com/story.php?story_fbid=2482569281994377&id=1629107234007257")
driver.get("https://www.facebook.com/story.php?story_fbid=10157425418460895&id=313191260894")
driver.set_page_load_timeout("60")
#driver.find_element_by_name("btnK").send_keys(Keys.ENTER)
#driver.find_element_by_class_name("_3hg- _42ft").send_keys(Keys.ENTER)
#print(elem)
#texto = driver.find_elements_by_xpath("//div[@aria-label='Comentario']");
#texto = driver.find_element_by_xpath("//div[@aria-label='Comentario']");
#for i in texto:
#    print(i)
#for i in driver.find_elements_by_xpath("//*[@class='l9j0dhe7 ecm0bbzt hv4rvrfc qt6c0cv9 dati1w0a lzcic4wl btwxx1t3 j83agx80']"):
#    print("hola")
#print(hola)
#texto = driver.
#print(texto)
#l9j0dhe7.ecm0bbzt.hv4rvrfc.qt6c0cv9.dati1w0alzcic4wl btwxx1t3 j83agx80
#wd.
time.sleep(5)
#for i in driver.find_elements_by_xpath("/html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li[21]/div[1]/div"):
for i in driver.find_elements_by_xpath("/html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li"):
#for i in driver.find_element_by_css_selector("div.oh7imozk:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1) > div:nth-child(4) > div:nth-child(2) > ul:nth-child(5) > li:nth-child(1) > div:nth-child(1) > div:nth-child(1)"):
    #print(i.text)
    for j in i.text.split("\n"):
        print(j)
        print("*********************************************************************************************")
    #print(i)
    print("--------------------------------------------------------------------------------------------------")
#texto = driver.page_source
#print(texto.text)
# Out:
# Fan destacado
# *********************************************************************************************
# German Ramirez
# *********************************************************************************************
# Mientras no haya conciencia que " Mis negligentes actos, pueden causar muerte de un tercero, familiar incluido " esto no pinta bien. La irresponsabilidad del propio denunciante es criticable al salir de casa sin motivo urgente
# *********************************************************************************************
# 16
# *********************************************************************************************
# Me gusta
# *********************************************************************************************
#  · Responder · 30 min · Editado
# *********************************************************************************************
# 3 respuestas
# *********************************************************************************************
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-ffaf8fcf32d2> in <module>
#      29 #/html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]/ul/li[1]/div[1]/div
#      30 time.sleep(5)
# ---> 31 for i in driver.find_element_by_xpath("/html/body/div[1]/div/div/div[2]/div/div/div/div/div/div[4]/div[1]/div/div/div/div[3]/div/div[4]/div[2]"):
#      32 #for i in driver.find_element_by_css_selector("div.oh7imozk:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1) > div:nth-child(4) > div:nth-child(2) > ul:nth-child(5) > li:nth-child(1) > div:nth-child(1) > div:nth-child(1)"):
#      33     print(i.text)
#
# TypeError: 'FirefoxWebElement' object is not iterable
