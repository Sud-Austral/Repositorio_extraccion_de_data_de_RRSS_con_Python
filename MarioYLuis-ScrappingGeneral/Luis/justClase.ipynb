# %%
import scappingFacebook as sF
import pandas as pd

# %%
#data = sF.comentario("https://www.facebook.com/story.php?story_fbid=10157425418460895&id=313191260894")
#len(data)

# %%
#data.head()

# %%
#for i in data["id"]:
#    print(i)

# %%
print(sF.getPost("Cooperativa",4))
# Out:
# ['https://www.facebook.com/story.php?story_fbid=10157431002045895&id=313191260894', 'https://www.facebook.com/story.php?story_fbid=10157431647160895&id=313191260894', 'https://www.facebook.com/story.php?story_fbid=10157431669185895&id=313191260894', 'https://www.facebook.com/story.php?story_fbid=10157431629125895&id=313191260894']

# %%
salida = []
for i in sF.getPost("Cooperativa",99):
    salida.append(sF.comentario(i))

# %%
salida[0].head()
# Out:
#                                           comentario likes  id  id_padre  \
# 0  Maximiliano Daniel Baldárrago Medina Las vuelt...     1   1         0
#
#     hora
# 0  8 min

# %%
len(salida[1])
# Out:
# 11

# %%
for i in salida:
    print(str(len(i)))
# Out:
# 0
# 6
# 1
# 14
# 400
# 0
# 1
# 10
# 1
# 32
# 0
# 77
# 19
# 0
# 0
# 17
# 7
# 0
# 1
# 1
# 0
# 42
# 3
# 4
# 0
# 11
# 0
# 11
# 73
# 0
# 107
# 13
# 1
# 0
# 1
# 12
# 0
# 49
# 4
# 27
# 10
# 0
# 9
# 37
# 1
# 31
# 17
# 18
# 0
# 0
# 0
# 92
# 3
# 0
# 1
# 3
# 50
# 0
# 1
# 25
# 11
# 37
# 175
# 0
# 0
# 6
# 17
# 0
# 0
# 11
# 0
# 13
# 76
# 12
# 0
# 2
# 7
# 1
# 130
# 0
# 123
# 0
# 0
# 0
# 1
# 11
# 55
# 0
# 0
# 0
# 68
# 19
# 7
# 0
# 99
# 0
# 101
# 0
# 3

# %%
salida[4].head(50)
# Out:
#                                            comentario likes  id  id_padre  \
# 0   Angelica Muñoz Barrientos La felicito ya que e...    26   1         0
# 1   Gerardo Mardones Hay una gran diferencia entre...     2   2         0
# 2   Ariel Gálvez Buen gesto ... yo estaría muy agr...    36   3         0
# 3   Yuliana Guiselle Opino que ella dio la cara co...    63   4         0
# 4   Arturo Bugueño Yuliana Guiselle ,si te refiere...     1   5         4
# 5   Maria Eliana Sepulveda Increíble gesto de gene...   112   6         0
# 6   Danniela Campos Acuña Maria Eliana Sepulveda t...     1   7         6
# 7   Cecilia Echeverria Maria Eliana Sepulveda jaja ja     0   8         6
# 8   Alejandra Erika Rovirosa Era necesaria la foto...     0   9         6
# 9   Claudio Pizarro Es raro por un lado que empatí...     2  10         6
# 10  Constanza Olmeño Olmeño Habiendo consentimient...   115  11         0
# 11  Leslie Andrea Ponce Constanza Olmeño Olmeño pi...     4  12        11
# ...
