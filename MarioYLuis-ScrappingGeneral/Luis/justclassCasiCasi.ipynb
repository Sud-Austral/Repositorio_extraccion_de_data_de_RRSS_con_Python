# %%
import scappingFacebook as sF
import pandas as pd

# %%
data = sF.comentarioPorLugar("isla de maipo",2,10)
# Out:
# Se guardaron los datos en isla_de_maipo25-03-2020_15-59-14.csv

# %%
len(data)
# Out:
# 908

# %%
#data = pd.read_csv("isla de maipo25-03-2020_15-35-43.csv")
#data.head()
#len(data)

# %%
#data.head(54)

# %%
#for i in data["likes"].unique():
#    print(i)

# %%
#muniislademaipo
#from facebook_scraper import get_posts
#for post in get_posts("muniislademaipo", pages=3, credentials=("informaticasudaustral@gmail.com","Info.Sud91")):
#    print(post)

# %%
for i in sF.getPost("Cooperativa", 100):
    if(i["likes"] > 100):
        print("Hola")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9ecfd0e26861> in <module>
# ----> 1 for i in sF.getPost("Cooperativa", 1000):
#       2     if(i["likes"] > 100):
#       3         print("Hola")
#
# ~\Documents\Repositorio_extraccion_de_data_de_RRSS_con_Python\MarioYLuis-ScrappingGeneral\Luis\scappingFacebook.py in getPost(pagina, n)
#      36 def getPost(pagina, n):
#      37     salida = []
# ---> 38     for post in get_posts(pagina, pages=n, credentials=("informaticasudaustral@gmail.com","Info.Sud91")):
#      39         if type(post["post_url"]) == str:
#      40                 #print(type(post["post_url"]))
#
# C:\ProgramData\Anaconda3\lib\site-packages\facebook_scraper.py in _get_posts(path, pages, timeout, sleep, credentials)
#      73     while True:
#      74         for article in html.find('article'):
# ...

# %%
def getPostX(pagina, pages = 200):
    from facebook_scraper import get_posts
    salida =  get_posts(pagina, pages=pages)       
    return salida

# %%
for i in getPostX("Cooperativa"):
    print(str(i["likes"]))
# Out:
# 1
# 133
# 369
# 23
# 91
# 27
# 21
# 583
# 20
# 80
# 0
# 22
# 11
# 1242
# 0
# 39
# 340
# 5
# 0
# 5
# 15
# 541
# 7
# 42
# 925
# 6
# 4
# 1
# 25
# 3
# 805
# 53
# 13
# 11
# 1593
# 31
# 12
# 48
# 19
# 223
# 2
# 43
# 858
# 11
# 1078
# 1
# 3
# 18
# 0
# 6
# 156
# 4
# 2404
# 41
# 5
# 190
# 8
# 146
# 3
# 12
# 13
# 3
# 81
# 94
# 28
# 7
# 94
# 2
# 40
# 126
# 10
# 1301
# 6
# 404
# 14
# 31
# 222
# 58
# 31
# 301
# 12
# 111
# 4
# 58
# 4
# 896
# 7
# 202
# 313
# 85
# 1343
# 93
# 224
# 23
# 206
# 5
# 81
# 277
# 324
# 380
# 2015
# 100
# 68
# 4
# 2
# 24
# 28
# 736
# 144
# 12
# 74
# 83
# 11
# 218
# 20
# 731
# 348
# 32
# 30
# 14
# 10
# 160
# 12
# 104
# 2190
# 283
# 266
# 19
# 14
# 496
# 26
# 558
# 58
# 19
# 14
# 819
# 26
# 92
# 91
# 10
# 14
# 233
# 147
# 365
# 6
# 47
# 4
# 129
# 73
# 1
# 93
# 740
# 26
# 4
# 65
# 272
# 2
# 95
# 63
# 373
# 109
# 4
# 86
# 209
# 155
# 148
# 133
# 101
# 5
# 46
# 8
# 251
# 42
# 3
# 10
# 34
# 47
# 1
# 2
# 15
# 291
# 110
# 176
# 31
# 5
# 41
# 101
# 93
# 3
# 360
# 15
# 3
# 11
# ...

# %%
hola = getPostX("Cooperativa")

# %%
for i in hola:
    print(i)
# Out:
# {'post_id': '10157434749720895', 'text': 'La brasileña se fue a vivir a Nueva York por trabajo, pero pretende regresar a Chile lo antes posible. (Vía @M360cl)\nM360.CL\nMichelle Carvalho contó cómo pasa la cuarentena en su departamento en Nueva York', 'post_text': 'La brasileña se fue a vivir a Nueva York por trabajo, pero pretende regresar a Chile lo antes posible. (Vía @M360cl)', 'shared_text': 'M360.CL\nMichelle Carvalho contó cómo pasa la cuarentena en su departamento en Nueva York', 'time': datetime.datetime(2020, 3, 25, 17, 2, 21), 'image': 'https://external.fscl6-1.fna.fbcdn.net/safe_image.php?d=AQAarbRrzdb371HW&w=476&h=249&url=http%3A%2F%2Fwww.m360.cl%2Fnoticias%2Fsite%2Fartic%2F20200325%2Fimag%2Ffoto_0000000120200325132836.jpg&cfs=1&jq=75&ext=jpg&_nc_hash=AQDCO40EpLYT--M4', 'likes': 3, 'comments': 3, 'shares': 0, 'post_url': 'https://m.facebook.com/story.php?story_fbid=10157434749720895&id=313191260894', 'link': 'https://www.m360.cl/noticias/moda-estilo/famosos/michelle-carv
# ...

# %%
print(hola[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-6d466a64694a> in <module>
# ----> 1 print(hola[0])
#
# TypeError: 'generator' object is not subscriptable

# %%
hola2 = list(getPostX("Cooperativa"))

# %%
print(hola2[0])
# Out:
# {'post_id': '10157434749720895', 'text': 'La brasileña se fue a vivir a Nueva York por trabajo, pero pretende regresar a Chile lo antes posible. (Vía @M360cl)\nM360.CL\nMichelle Carvalho contó cómo pasa la cuarentena en su departamento en Nueva York', 'post_text': 'La brasileña se fue a vivir a Nueva York por trabajo, pero pretende regresar a Chile lo antes posible. (Vía @M360cl)', 'shared_text': 'M360.CL\nMichelle Carvalho contó cómo pasa la cuarentena en su departamento en Nueva York', 'time': datetime.datetime(2020, 3, 25, 17, 2, 21), 'image': 'https://external.fscl6-1.fna.fbcdn.net/safe_image.php?d=AQAarbRrzdb371HW&w=476&h=249&url=http%3A%2F%2Fwww.m360.cl%2Fnoticias%2Fsite%2Fartic%2F20200325%2Fimag%2Ffoto_0000000120200325132836.jpg&cfs=1&jq=75&ext=jpg&_nc_hash=AQDCO40EpLYT--M4', 'likes': 3, 'comments': 8, 'shares': 0, 'post_url': 'https://m.facebook.com/story.php?story_fbid=10157434749720895&id=313191260894', 'link': 'https://www.m360.cl/noticias/moda-estilo/famosos/michelle-carv
# ...

# %%
type(hola)
# Out:
# generator

# %%
type(hola2)
# Out:
# list

# %%
import pandas as pd
data = pd.DataFrame.from_dict(getPostX("Cooperativa"))
data
# Out:
#                post_id                                               text  \
# 0    10157434791450895  Bayern Munich bajó los sueldos de los futbolis...
# 1    10157434749720895  La brasileña se fue a vivir a Nueva York por t...
# 2    10157434704535895  Esto es muy lindo 😍\nCOOPERATIVA.CL\n[VIDEO 📹]...
# 3    10157434704605895  ¿Qué te parece?\nCOOPERATIVA.CL\nPresentan pro...
# 4    10157434651915895  "Lo que ocurre en el mundo es que es que el gr...
# ..                 ...                                                ...
# 797  10157395624445895  A tener en cuenta ⚽️👇\nALAIRELIBRE.CL\nEl llam...
# 798  10157395478505895  Se decretaron 180 días de investigación.\nCOOP...
# 799  10157395392795895  Además, lamentó que la posta en que se diagnos...
# 800  10157395387200895  Gran gesto 👏\nALAIRELIBRE.CL\nJosip Ilicic don...
# 801  10157395368810895  Hasta ahora hay once futbolistas profesionales...
#
#                                              post_text  \
# ...

# %%
# %matplotlib inline
#imagenes = data["image"]
image=io.imread("Temuco.ecw") #/255.0 # imread lee las imagenes con los pixeles codificados como enteros 
    # en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1

#print("- Dimensiones de la imagen:")
#print(image.shape)
#plt.imshow(image,vmin=0,vmax=1)
#print("***************************************************************************************")
#print(image)

#image2 = image
#plt.imshow(image2,vmin=0,vmax=1)


#print(image2[0][0][0])
#print(len(image2))
#print(len(image2[0]))
#print(len(image2[0][0]))
#image.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\imageio\plugins\gdal.py in load_lib()
#      16     try:
# ---> 17         import osgeo.gdal as _gdal
#      18     except ImportError:
#
# ModuleNotFoundError: No module named 'osgeo'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-79-14e4f6e18098> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 #imagenes = data["image"]
# ----> 3 image=io.imread("Temuco.ecw") #/255.0 # imread lee las imagenes con los pixeles codificados como enteros
#       4     # en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1
#       5
#
# ...

# %%
type(imagenes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-37022c5115a9> in <module>
# ----> 1 type(imagenes)
#
# NameError: name 'imagenes' is not defined

# %%
from PIL import Image

# %%
i = Image.open('https://www.adslzone.net/app/uploads/2019/04/borrar-fondo-imagen.jpg','r')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-53-8f76390b0e9f> in <module>
# ----> 1 i = Image.open('https://www.adslzone.net/app/uploads/2019/04/borrar-fondo-imagen.jpg','r')
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# OSError: [Errno 22] Invalid argument: 'https://www.adslzone.net/app/uploads/2019/04/borrar-fondo-imagen.jpg'

# %%
from skimage import io
import skimage

from PIL import Image
Image.MAX_IMAGE_PIXELS = 999999999
#516047500 
                         


image=io.imread("ejemplo.jpg")/255.0 # imread lee las imagenes con los pixeles codificados como enteros 
# en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1

print("- Dimensiones de la imagen:")
print(image.shape)
#plt.imshow(image,vmin=0,vmax=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-86-776b65872fce> in <module>
#       8
#       9
# ---> 10 image=io.imread("ejemplo.jpg")/255.0 # imread lee las imagenes con los pixeles codificados como enteros
#      11 # en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1
#      12
#
# MemoryError:
