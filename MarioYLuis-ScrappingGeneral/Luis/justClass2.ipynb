# %%
import scappingFacebook as sF
import pandas as pd

# %%
#print(str(contador["contador"]))
#data = sF.comentario2("https://www.facebook.com/story.php?story_fbid=10157425418460895&id=313191260894",sF.getDriver())
data = sF.comentarioPost2(sF.getDriver(),sF.getPost("Cooperativa",5)[4])
data.head()
# Out:
# Likes: 1
# Likes: 1
# Likes: 0
# Likes: 0
# Likes: 1
# Likes: 0
#                                           comentario likes    hora  \
# 0       Cecy Mora Y barrio alto, SIGUE CONTAMINANDO.     0  12 min
# 1  Jonathan Navarrete Sipu obvio si los dueños de...     2  22 min
# 2  Carolina Aburto Jonathan Navarrete adónde la v...     1  19 min
# 3  Marcela Alejandra Triviño Mayorga Carolina Abu...     1  16 min
# 4  Carolina Aburto Marcela Alejandra Triviño Mayo...     0  15 min
#
#              post_id                                         Texto post  \
# 0  10157433525645895  La más austral del mundo: La medida endurece l...
# 1  10157433525645895  La más austral del mundo: La medida endurece l...
# 2  10157433525645895  La más austral del mundo: La medida endurece l...
# 3  10157433525645895  La más austral del mundo: La medida endurece l...
# 4  10157433525645895  La más austral del mundo: La medida endurece l...
#
#                                         Texto post 2  \
# ...

# %%
len(data)
# Out:
# 8

# %%
#data.head(50)

# %%
#from selenium import webdriver
#from selenium.webdriver.common.keys import Keys

#driver = sF.getDriver()
#driver.get("https://github.com/harismuneer/Ultimate-Facebook-Scraper/blob/v2.0/setup.py")

# %%
#lista = sF.getPost("Cooperativa", 1)

# %%
#lista[0]

# %%
#post = sF.getPost("Cooperativa",10)[9]

# %%
#post["Nombre"] = "Nombre"

# %%
#print(post)

# %%
#data = sF.comentarioPost(sF.getDriver(),sF.getPost("Cooperativa",4)[3])
#data.head(20)

# %%
#len(data)
data
# Out:
#                                           comentario likes    hora  \
# 0       Cecy Mora Y barrio alto, SIGUE CONTAMINANDO.     0  12 min
# 1  Jonathan Navarrete Sipu obvio si los dueños de...     2  22 min
# 2  Carolina Aburto Jonathan Navarrete adónde la v...     1  19 min
# 3  Marcela Alejandra Triviño Mayorga Carolina Abu...     1  16 min
# 4  Carolina Aburto Marcela Alejandra Triviño Mayo...     0  15 min
# 5       Jonathan Navarrete Se juntaron los ermitaños     0  12 min
# 6  Kuwabatake Sanjuro Carolina Aburto mira Pajaro...     1  10 min
# 7  Jonathan Navarrete Kuwabatake Sanjuro demás so...     0   7 min
#
#              post_id                                         Texto post  \
# 0  10157433525645895  La más austral del mundo: La medida endurece l...
# 1  10157433525645895  La más austral del mundo: La medida endurece l...
# 2  10157433525645895  La más austral del mundo: La medida endurece l...
# 3  10157433525645895  La más austral del mundo: La medida endurece l...
# ...

# %%
columnas = data.columns.values

data_aux = pd.DataFrame(columns=columnas)

# %%
data2 = pd.concat([data,data_aux])

# %%
len(data2)
# Out:
# 8

# %%
datos = []
datos.append(data)
datos.append(data)
datos.append(data)
datos.append(data)
datos.append(data)
data3 = pd.concat(datos)
data3
# Out:
#                                           comentario likes    hora  \
# 0       Cecy Mora Y barrio alto, SIGUE CONTAMINANDO.     0  12 min
# 1  Jonathan Navarrete Sipu obvio si los dueños de...     2  22 min
# 2  Carolina Aburto Jonathan Navarrete adónde la v...     1  19 min
# 3  Marcela Alejandra Triviño Mayorga Carolina Abu...     1  16 min
# 4  Carolina Aburto Marcela Alejandra Triviño Mayo...     0  15 min
# 5       Jonathan Navarrete Se juntaron los ermitaños     0  12 min
# 6  Kuwabatake Sanjuro Carolina Aburto mira Pajaro...     1  10 min
# 7  Jonathan Navarrete Kuwabatake Sanjuro demás so...     0   7 min
# 0       Cecy Mora Y barrio alto, SIGUE CONTAMINANDO.     0  12 min
# 1  Jonathan Navarrete Sipu obvio si los dueños de...     2  22 min
# 2  Carolina Aburto Jonathan Navarrete adónde la v...     1  19 min
# 3  Marcela Alejandra Triviño Mayorga Carolina Abu...     1  16 min
# 4  Carolina Aburto Marcela Alejandra Triviño Mayo...     0  15 min
# ...

# %%
datos_aux = []
datos_aux.append(data3)
data4 = pd.concat(datos_aux)
data4
# Out:
#                                           comentario likes    hora  \
# 0       Cecy Mora Y barrio alto, SIGUE CONTAMINANDO.     0  12 min
# 1  Jonathan Navarrete Sipu obvio si los dueños de...     2  22 min
# 2  Carolina Aburto Jonathan Navarrete adónde la v...     1  19 min
# 3  Marcela Alejandra Triviño Mayorga Carolina Abu...     1  16 min
# 4  Carolina Aburto Marcela Alejandra Triviño Mayo...     0  15 min
# 5       Jonathan Navarrete Se juntaron los ermitaños     0  12 min
# 6  Kuwabatake Sanjuro Carolina Aburto mira Pajaro...     1  10 min
# 7  Jonathan Navarrete Kuwabatake Sanjuro demás so...     0   7 min
# 0       Cecy Mora Y barrio alto, SIGUE CONTAMINANDO.     0  12 min
# 1  Jonathan Navarrete Sipu obvio si los dueños de...     2  22 min
# 2  Carolina Aburto Jonathan Navarrete adónde la v...     1  19 min
# 3  Marcela Alejandra Triviño Mayorga Carolina Abu...     1  16 min
# 4  Carolina Aburto Marcela Alejandra Triviño Mayo...     0  15 min
# ...
