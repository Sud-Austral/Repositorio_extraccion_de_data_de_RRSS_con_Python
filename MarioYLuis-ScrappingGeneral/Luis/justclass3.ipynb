# %%
import scappingFacebook as sF
import pandas as pd

# %%
sF.Final("Cooperativa",10)
# Out:
# Se guardaron los datos en Cooperativa25-03-2020_13-02-41.csv
#                                            comentario likes    hora  \
# 0   Fabian Valderas Valderas Mañalich se irá del g...     0   1 min
# 0                            Mónica Pedemonte Sanchez     0   4 min
# 1                                  Irene Zuñiga Yañez     0   1 min
# 2               Rachel Vero Madrid Maravillosa !!! ❤🥰     0   4 min
# 3                          Daniela Hernández Aguilera     0   5 min
# ..                                                ...   ...     ...
# 37                                         Aury Sando     0  27 min
# 38                              Felipe Osses\n🤷🏼‍♂️🤢🤮     1  28 min
# 39                      Jacqueline Molina Chodil\n🤮🤮🤮     0  29 min
# 40    Lisandro Pinto Esta noticia la redacto mañalich     7  30 min
# 41  Michel Jr Olmedo Lisandro Pinto muto y se volv...     0  15 min
#
#               post_id                                         Texto post  \
# 0   10157433764735895  Hoy ingresó un segundo recurso, esta vez en co...
# 0   10157433734170895  😍 Santiago, un joven argentino, compartió en T...
# 1   10157433734170895  😍 Santiago, un joven argentino, compartió en T...
# 2   10157433734170895  😍 Santiago, un joven argentino, compartió en T...
# 3   10157433734170895  😍 Santiago, un joven argentino, compartió en T...
# ..                ...                                                ...
# 37  10157433665170895  La ex chica reality extraña a su pololo con el...
# 38  10157433665170895  La ex chica reality extraña a su pololo con el...
# 39  10157433665170895  La ex chica reality extraña a su pololo con el...
# 40  10157433665170895  La ex chica reality extraña a su pololo con el...
# 41  10157433665170895  La ex chica reality extraña a su pololo con el...
#
#                                          Texto post 2  \
# 0   Hoy ingresó un segundo recurso, esta vez en co...
# 0   😍 Santiago, un joven argentino, compartió en T...
# 1   😍 Santiago, un joven argentino, compartió en T...
# 2   😍 Santiago, un joven argentino, compartió en T...
# 3   😍 Santiago, un joven argentino, compartió en T...
# ..                                                ...
# 37  La ex chica reality extraña a su pololo con el...
# 38  La ex chica reality extraña a su pololo con el...
# 39  La ex chica reality extraña a su pololo con el...
# 40  La ex chica reality extraña a su pololo con el...
# 41  La ex chica reality extraña a su pololo con el...
#
#                                      Texto compartido      Hora de posteo  \
# 0   COOPERATIVA.CL\nCorte rechaza recurso contra M... 2020-03-25 12:59:34
# 0                                                     2020-03-25 12:50:14
# 1                                                     2020-03-25 12:50:14
# 2                                                     2020-03-25 12:50:14
# 3                                                     2020-03-25 12:50:14
# ..                                                ...                 ...
# 37  M360.CL\nLa pena de Angélica Sepúlveda por su ... 2020-03-25 12:29:47
# 38  M360.CL\nLa pena de Angélica Sepúlveda por su ... 2020-03-25 12:29:47
# 39  M360.CL\nLa pena de Angélica Sepúlveda por su ... 2020-03-25 12:29:47
# 40  M360.CL\nLa pena de Angélica Sepúlveda por su ... 2020-03-25 12:29:47
# 41  M360.CL\nLa pena de Angélica Sepúlveda por su ... 2020-03-25 12:29:47
#
#                                                Imagen  Likes del post  \
# 0   https://external.fscl6-1.fna.fbcdn.net/safe_im...               0
# 0                                                None             193
# 1                                                None             193
# 2                                                None             193
# 3                                                None             193
# ..                                                ...             ...
# 37  https://external.fscl6-1.fna.fbcdn.net/safe_im...              14
# 38  https://external.fscl6-1.fna.fbcdn.net/safe_im...              14
# 39  https://external.fscl6-1.fna.fbcdn.net/safe_im...              14
# 40  https://external.fscl6-1.fna.fbcdn.net/safe_im...              14
# 41  https://external.fscl6-1.fna.fbcdn.net/safe_im...              14
#
#     Comentarios del Post  Compartido  \
# 0                      0           0
# 0                     24           0
# 1                     24           0
# 2                     24           0
# 3                     24           0
# ..                   ...         ...
# 37                   145           4
# 38                   145           4
# 39                   145           4
# 40                   145           4
# 41                   145           4
#
#                                                   URL  \
# 0   https://m.facebook.com/story.php?story_fbid=10...
# 0   https://m.facebook.com/story.php?story_fbid=10...
# 1   https://m.facebook.com/story.php?story_fbid=10...
# 2   https://m.facebook.com/story.php?story_fbid=10...
# 3   https://m.facebook.com/story.php?story_fbid=10...
# ..                                                ...
# 37  https://m.facebook.com/story.php?story_fbid=10...
# 38  https://m.facebook.com/story.php?story_fbid=10...
# 39  https://m.facebook.com/story.php?story_fbid=10...
# 40  https://m.facebook.com/story.php?story_fbid=10...
# 41  https://m.facebook.com/story.php?story_fbid=10...
#
#                                                  Link  \
# 0   http://www.cooperativa.cl/noticias/sociedad/sa...
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# ..                                                ...
# 37  https://www.m360.cl/noticias/sexo-pareja/amor/...
# 38  https://www.m360.cl/noticias/sexo-pareja/amor/...
# 39  https://www.m360.cl/noticias/sexo-pareja/amor/...
# 40  https://www.m360.cl/noticias/sexo-pareja/amor/...
# 41  https://www.m360.cl/noticias/sexo-pareja/amor/...
#
#                 Hora consulta Nombre Facebook
# 0  2020-03-25 13:01:01.467710     Cooperativa
# 0  2020-03-25 13:01:38.312818     Cooperativa
# 1  2020-03-25 13:01:38.312818     Cooperativa
# 2  2020-03-25 13:01:38.312818     Cooperativa
# 3  2020-03-25 13:01:38.312818     Cooperativa
# ..                        ...             ...
# 37 2020-03-25 13:02:41.089491     Cooperativa
# 38 2020-03-25 13:02:41.089491     Cooperativa
# 39 2020-03-25 13:02:41.089491     Cooperativa
# 40 2020-03-25 13:02:41.089491     Cooperativa
# 41 2020-03-25 13:02:41.089491     Cooperativa
#
# [95 rows x 16 columns]

# %%
#data.head(10)

# %%
#len(data)

# %%
data.to_csv("Hola.csv", index=False)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import sys
from typing import List, Tuple, Dict, TextIO
import array
def filtrar(variable):
    filtro = ["/pages"]
    for palabra in filtro:
            if palabra in variable:
                return 1
            else:
                return 2
            
            

def cargarEnlacesLugar(lugar):
    driver = webdriver.Firefox()
    driver.set_page_load_timeout("60")
    driver.get("https://www.facebook.com")

    driver.find_element_by_name("email").send_keys("informaticasudaustral@gmail.com")
    driver.find_element_by_name("pass").send_keys("Info.Sud91")

    driver.find_element_by_id("loginbutton").click()
    driver.set_page_load_timeout("60")

    lugar.replace(" ","%20")
    driver.get("https://www.facebook.com/search/places/?q="+str(lugar)+"&epa=SERP_TAB")
    driver.set_page_load_timeout("60")
    #arr = array.array('i')
    listas = []
    
    #contador = 0
    #paginas = 2
    #while contador < paginas:
     #   driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
      #  time.sleep(5)
       # contador+=1

    SCROLL_PAUSE_TIME = 5

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height


    for i in driver.find_elements_by_class_name("_1wu_"):
        tag = i.find_element_by_tag_name("a")
        salida = tag.get_attribute("href")
        
        resultado = filtrar(salida)
        
        if resultado == 2:
            listas.append(str(salida))
        
    
            for j in salida.split("\n"):
                j = j.replace("Responder","").replace(" ·  · ","")
                j = j.replace("Escribe una respuesta...","")
                j = j.replace('Está seleccionada la opción "Más relevantes", por lo que es posible que algunas respuestas se hayan filtrado.',"")
                j = j.replace('Presiona "Enter" para publicar.',"")
                if(len(j) > 0):
                    print(str(len(j)))

                    print(j)
                    print("*********************************************************************************************")
            print("--------------------------------------------------------------------------------------------------")

    return listas

# %%
for i in cargarEnlacesLugar("isla de maipo"):
    print(i)
    print(len(i))
    print("***************************************************************************************")
# Out:
# 41
# https://www.facebook.com/muniislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/IslaDeMaipoAtentos/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/muniislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 57
# https://www.facebook.com/corporacionmunicipalislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 107
# https://www.facebook.com/Cesfam-Y-Postas-de-Salud-Corporaci%C3%B3n-Municipal-Isla-de-Maipo-535784159828059/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 45
# https://www.facebook.com/cultura.islademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/IBEMislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 38
# https://www.facebook.com/vinasantaema/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/campinglagunademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/campinglospuentes.cl/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/BiblioIsladeMaipo196/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 74
# https://www.facebook.com/Colegio-Particular-leonardo-Da-Vinci-25917753913/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 40
# https://www.facebook.com/DeMartinoWines/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 92
# https://www.facebook.com/Colegio-Mar%C3%ADa-Reina-Inmaculada-Isla-de-Maipo-1552666824998506/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 50
# https://www.facebook.com/campingeledenislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 62
# https://www.facebook.com/Ajuvis-Isla-de-Maipo-694133307422592/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 54
# https://www.facebook.com/sibaritaygourmet.islademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 53
# https://www.facebook.com/tallerdecosturasislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 35
# https://www.facebook.com/radioisla/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 43
# https://www.facebook.com/hostalnevadachile/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 35
# https://www.facebook.com/rekomaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/manoscreativas2018/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 42
# https://www.facebook.com/patinislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 67
# https://www.facebook.com/ExpoCentro-Isla-de-Maipo-2321857901209537/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 50
# https://www.facebook.com/centroveterinariocrubvet/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/nekosushiislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 95
# https://www.facebook.com/Isla-de-Maipo-Country-Home-Maipo-Valley-Country-Home-1612957042106041/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 51
# https://www.facebook.com/centroecuestreislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 88
# https://www.facebook.com/Pizzas-y-churrascos-a-domicilio-isla-de-maipo--850333188426516/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 47
# https://www.facebook.com/TerramaterIslaDeMaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 63
# https://www.facebook.com/Turismo-Isla-de-Maipo-168449983499158/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 39
# https://www.facebook.com/psicologoidem/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 78
# https://www.facebook.com/Centro-Tur%C3%ADstico-Vista-al-Cerro-354325907990813/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 71
# https://www.facebook.com/Centro-de-Evento-El-Rosarito-1357763600980959/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 42
# https://www.facebook.com/jardinesdelaisla/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 54
# https://www.facebook.com/creacionescordovaislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 34
# https://www.facebook.com/ketychoc/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 62
# https://www.facebook.com/Vivero-Isla-de-Maipo-523990827686758/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 74
# https://www.facebook.com/Do%C3%B1a-chavita-isla-de-maipo-1505947562993567/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 82
# https://www.facebook.com/Arriendo-Parcela-Isla-de-Maipo-El-Romero-228025681418226/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 76
# https://www.facebook.com/Insumoman%C3%ADa-SpA-Isla-de-Maipo-308115449876462/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 66
# https://www.facebook.com/Camping-en-isla-de-Maipo-322292488457035/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 68
# https://www.facebook.com/Peluchemania-Isla-De-Maipo-252090785260641/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 50
# https://www.facebook.com/ventadeaguapurificada.cl/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 43
# https://www.facebook.com/laclaselapuntilla/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 71
# https://www.facebook.com/Centro-%C3%93ptico-de-la-Isla-104688710933227/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/libreriaisla376/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 33
# https://www.facebook.com/donyayo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 39
# https://www.facebook.com/mitosdelmaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 71
# https://www.facebook.com/Comida-Delivery-Isla-de-Maipo-224691158268966/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/FoodTrukLosPapitas/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 104
# https://www.facebook.com/Ramdasnivas-Isla-de-Maipo-Guru-Darshan-Singh-y-Shiv-Charn-Kaur-548941928600667/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 41
# https://www.facebook.com/ExpoIsladeMaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 61
# https://www.facebook.com/Camping-ElEd%C3%A9n-277529079408800/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 45
# https://www.facebook.com/RestaurantZinFandel/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 44
# https://www.facebook.com/centroarteyterapia/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 51
# https://www.facebook.com/alcantarilladoislademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/atabekho.islademaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 74
# https://www.facebook.com/Parcela-Privada-en-Isla-de-Maipo-822430257865360/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 36
# https://www.facebook.com/valtyer.cl/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 42
# https://www.facebook.com/amplusrestaurant/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 42
# https://www.facebook.com/LaCasonaDelConde/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/camping.vistaalcerro/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 76
# https://www.facebook.com/Centro-Tur%C3%ADstico-La-Herradura-218874901518201/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 65
# https://www.facebook.com/Comercial-ISLA-De-MAIPO-257710524813161/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 66
# https://www.facebook.com/Bomberos-Segunda-Islita-1888156761303121/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 37
# https://www.facebook.com/Campingel14/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 68
# https://www.facebook.com/Casa-Rustica-Isla-de-Maipo-100388784915434/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 70
# https://www.facebook.com/CP-Maria-Reina-Isla-de-Maipo-481792315499088/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 54
# https://www.facebook.com/AguasVertientesdeIsladeMaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 69
# https://www.facebook.com/Aluminios-SM-isla-de-Maipo-2221108121488842/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 57
# https://www.facebook.com/FiestaDeLaChilenidadIslaDeMaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 49
# https://www.facebook.com/SanIsidroAguaPurificada/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 87
# https://www.facebook.com/Estefany-Peluquer%C3%ADa-Canina-Isla-de-Maipo-158413631354314/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 65
# https://www.facebook.com/Ferreter%C3%ADa-Central-238959249562048/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 67
# https://www.facebook.com/Outlet-Bebe-Isla-de-Maipo-100319564779538/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 65
# https://www.facebook.com/Free-Bike-Pe%C3%B1aflor-558618117614197/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 46
# https://www.facebook.com/aguapurificadamalibu/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 86
# https://www.facebook.com/Comidas-preparadas-a-domicilio-isla-de-maipo-263370083870122/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 70
# https://www.facebook.com/Sabor-Natural-Isla-de-Maipo-1577714752483631/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 43
# https://www.facebook.com/detergentesimaipo/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 36
# https://www.facebook.com/riclalonso/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 68
# https://www.facebook.com/Turismo-Vivo-Isla-de-maipo-602393166565515/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 42
# https://www.facebook.com/jardinerarustica/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 31
# https://www.facebook.com/8kMAV/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 68
# https://www.facebook.com/Semilla-Azul-Isla-de-Maipo-292171561583252/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 68
# https://www.facebook.com/Guias-Scout-Isla-de-Maipo-1293018734060925/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 73
# https://www.facebook.com/Alimentos-Perros-Isla-de-Maipo-1455814654518301/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 73
# https://www.facebook.com/Escuela-Colo-Colo-Isla-de-Maipo-511992275656488/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 77
# https://www.facebook.com/Delicias-Artesanales-isla-de-Maipo-1248393528505539/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 75
# https://www.facebook.com/Clases-particulares-Isla-de-Maipo-548308705346228/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# 70
# https://www.facebook.com/Ruta-del-Vino-Isla-de-Maipo-1587530021467854/
# *********************************************************************************************
# --------------------------------------------------------------------------------------------------
# https://www.facebook.com/muniislademaipo/
# 41
# ***************************************************************************************
# https://www.facebook.com/IslaDeMaipoAtentos/
# 44
# ***************************************************************************************
# https://www.facebook.com/muniislademaipo/
# 41
# ***************************************************************************************
# https://www.facebook.com/corporacionmunicipalislademaipo/
# 57
# ***************************************************************************************
# https://www.facebook.com/Cesfam-Y-Postas-de-Salud-Corporaci%C3%B3n-Municipal-Isla-de-Maipo-535784159828059/
# 107
# ***************************************************************************************
# https://www.facebook.com/cultura.islademaipo/
# 45
# ***************************************************************************************
# https://www.facebook.com/IBEMislademaipo/
# 41
# ***************************************************************************************
# https://www.facebook.com/vinasantaema/
# 38
# ***************************************************************************************
# https://www.facebook.com/campinglagunademaipo/
# 46
# ***************************************************************************************
# https://www.facebook.com/campinglospuentes.cl/
# 46
# ***************************************************************************************
# https://www.facebook.com/BiblioIsladeMaipo196/
# 46
# ***************************************************************************************
# https://www.facebook.com/Colegio-Particular-leonardo-Da-Vinci-25917753913/
# 74
# ***************************************************************************************
# https://www.facebook.com/DeMartinoWines/
# 40
# ***************************************************************************************
# https://www.facebook.com/Colegio-Mar%C3%ADa-Reina-Inmaculada-Isla-de-Maipo-1552666824998506/
# 92
# ***************************************************************************************
# https://www.facebook.com/campingeledenislademaipo/
# 50
# ***************************************************************************************
# https://www.facebook.com/Ajuvis-Isla-de-Maipo-694133307422592/
# 62
# ***************************************************************************************
# https://www.facebook.com/sibaritaygourmet.islademaipo/
# 54
# ***************************************************************************************
# https://www.facebook.com/tallerdecosturasislademaipo/
# 53
# ***************************************************************************************
# https://www.facebook.com/radioisla/
# 35
# ***************************************************************************************
# https://www.facebook.com/hostalnevadachile/
# 43
# ***************************************************************************************
# https://www.facebook.com/rekomaipo/
# 35
# ***************************************************************************************
# https://www.facebook.com/manoscreativas2018/
# 44
# ***************************************************************************************
# https://www.facebook.com/patinislademaipo/
# 42
# ***************************************************************************************
# https://www.facebook.com/ExpoCentro-Isla-de-Maipo-2321857901209537/
# 67
# ***************************************************************************************
# https://www.facebook.com/centroveterinariocrubvet/
# 50
# ***************************************************************************************
# https://www.facebook.com/nekosushiislademaipo/
# 46
# ***************************************************************************************
# https://www.facebook.com/Isla-de-Maipo-Country-Home-Maipo-Valley-Country-Home-1612957042106041/
# 95
# ***************************************************************************************
# https://www.facebook.com/centroecuestreislademaipo/
# 51
# ***************************************************************************************
# https://www.facebook.com/Pizzas-y-churrascos-a-domicilio-isla-de-maipo--850333188426516/
# 88
# ***************************************************************************************
# https://www.facebook.com/TerramaterIslaDeMaipo/
# 47
# ***************************************************************************************
# https://www.facebook.com/Turismo-Isla-de-Maipo-168449983499158/
# 63
# ***************************************************************************************
# https://www.facebook.com/psicologoidem/
# 39
# ***************************************************************************************
# https://www.facebook.com/Centro-Tur%C3%ADstico-Vista-al-Cerro-354325907990813/
# 78
# ***************************************************************************************
# https://www.facebook.com/Centro-de-Evento-El-Rosarito-1357763600980959/
# 71
# ***************************************************************************************
# https://www.facebook.com/jardinesdelaisla/
# 42
# ***************************************************************************************
# https://www.facebook.com/creacionescordovaislademaipo/
# 54
# ***************************************************************************************
# https://www.facebook.com/ketychoc/
# 34
# ***************************************************************************************
# https://www.facebook.com/Vivero-Isla-de-Maipo-523990827686758/
# 62
# ***************************************************************************************
# https://www.facebook.com/Do%C3%B1a-chavita-isla-de-maipo-1505947562993567/
# 74
# ***************************************************************************************
# https://www.facebook.com/Arriendo-Parcela-Isla-de-Maipo-El-Romero-228025681418226/
# 82
# ***************************************************************************************
# https://www.facebook.com/Insumoman%C3%ADa-SpA-Isla-de-Maipo-308115449876462/
# 76
# ***************************************************************************************
# https://www.facebook.com/Camping-en-isla-de-Maipo-322292488457035/
# 66
# ***************************************************************************************
# https://www.facebook.com/Peluchemania-Isla-De-Maipo-252090785260641/
# 68
# ***************************************************************************************
# https://www.facebook.com/ventadeaguapurificada.cl/
# 50
# ***************************************************************************************
# https://www.facebook.com/laclaselapuntilla/
# 43
# ***************************************************************************************
# https://www.facebook.com/Centro-%C3%93ptico-de-la-Isla-104688710933227/
# 71
# ***************************************************************************************
# https://www.facebook.com/libreriaisla376/
# 41
# ***************************************************************************************
# https://www.facebook.com/donyayo/
# 33
# ***************************************************************************************
# https://www.facebook.com/mitosdelmaipo/
# 39
# ***************************************************************************************
# https://www.facebook.com/Comida-Delivery-Isla-de-Maipo-224691158268966/
# 71
# ***************************************************************************************
# https://www.facebook.com/FoodTrukLosPapitas/
# 44
# ***************************************************************************************
# https://www.facebook.com/Ramdasnivas-Isla-de-Maipo-Guru-Darshan-Singh-y-Shiv-Charn-Kaur-548941928600667/
# 104
# ***************************************************************************************
# https://www.facebook.com/ExpoIsladeMaipo/
# 41
# ***************************************************************************************
# https://www.facebook.com/Camping-ElEd%C3%A9n-277529079408800/
# 61
# ***************************************************************************************
# https://www.facebook.com/RestaurantZinFandel/
# 45
# ***************************************************************************************
# https://www.facebook.com/centroarteyterapia/
# 44
# ***************************************************************************************
# https://www.facebook.com/alcantarilladoislademaipo/
# 51
# ***************************************************************************************
# https://www.facebook.com/atabekho.islademaipo/
# 46
# ***************************************************************************************
# https://www.facebook.com/Parcela-Privada-en-Isla-de-Maipo-822430257865360/
# 74
# ***************************************************************************************
# https://www.facebook.com/valtyer.cl/
# 36
# ***************************************************************************************
# https://www.facebook.com/amplusrestaurant/
# 42
# ***************************************************************************************
# https://www.facebook.com/LaCasonaDelConde/
# 42
# ***************************************************************************************
# https://www.facebook.com/camping.vistaalcerro/
# 46
# ***************************************************************************************
# https://www.facebook.com/Centro-Tur%C3%ADstico-La-Herradura-218874901518201/
# 76
# ***************************************************************************************
# https://www.facebook.com/Comercial-ISLA-De-MAIPO-257710524813161/
# 65
# ***************************************************************************************
# https://www.facebook.com/Bomberos-Segunda-Islita-1888156761303121/
# 66
# ***************************************************************************************
# https://www.facebook.com/Campingel14/
# 37
# ***************************************************************************************
# https://www.facebook.com/Casa-Rustica-Isla-de-Maipo-100388784915434/
# 68
# ***************************************************************************************
# https://www.facebook.com/CP-Maria-Reina-Isla-de-Maipo-481792315499088/
# 70
# ***************************************************************************************
# https://www.facebook.com/AguasVertientesdeIsladeMaipo/
# 54
# ***************************************************************************************
# https://www.facebook.com/Aluminios-SM-isla-de-Maipo-2221108121488842/
# 69
# ***************************************************************************************
# https://www.facebook.com/FiestaDeLaChilenidadIslaDeMaipo/
# 57
# ***************************************************************************************
# https://www.facebook.com/SanIsidroAguaPurificada/
# 49
# ***************************************************************************************
# https://www.facebook.com/Estefany-Peluquer%C3%ADa-Canina-Isla-de-Maipo-158413631354314/
# 87
# ***************************************************************************************
# https://www.facebook.com/Ferreter%C3%ADa-Central-238959249562048/
# 65
# ***************************************************************************************
# https://www.facebook.com/Outlet-Bebe-Isla-de-Maipo-100319564779538/
# 67
# ***************************************************************************************
# https://www.facebook.com/Free-Bike-Pe%C3%B1aflor-558618117614197/
# 65
# ***************************************************************************************
# https://www.facebook.com/aguapurificadamalibu/
# 46
# ***************************************************************************************
# https://www.facebook.com/Comidas-preparadas-a-domicilio-isla-de-maipo-263370083870122/
# 86
# ***************************************************************************************
# https://www.facebook.com/Sabor-Natural-Isla-de-Maipo-1577714752483631/
# 70
# ***************************************************************************************
# https://www.facebook.com/detergentesimaipo/
# 43
# ***************************************************************************************
# https://www.facebook.com/riclalonso/
# 36
# ***************************************************************************************
# https://www.facebook.com/Turismo-Vivo-Isla-de-maipo-602393166565515/
# 68
# ***************************************************************************************
# https://www.facebook.com/jardinerarustica/
# 42
# ***************************************************************************************
# https://www.facebook.com/8kMAV/
# 31
# ***************************************************************************************
# https://www.facebook.com/Semilla-Azul-Isla-de-Maipo-292171561583252/
# 68
# ***************************************************************************************
# https://www.facebook.com/Guias-Scout-Isla-de-Maipo-1293018734060925/
# 68
# ***************************************************************************************
# https://www.facebook.com/Alimentos-Perros-Isla-de-Maipo-1455814654518301/
# 73
# ***************************************************************************************
# https://www.facebook.com/Escuela-Colo-Colo-Isla-de-Maipo-511992275656488/
# 73
# ***************************************************************************************
# https://www.facebook.com/Delicias-Artesanales-isla-de-Maipo-1248393528505539/
# 77
# ***************************************************************************************
# https://www.facebook.com/Clases-particulares-Isla-de-Maipo-548308705346228/
# 75
# ***************************************************************************************
# https://www.facebook.com/Ruta-del-Vino-Isla-de-Maipo-1587530021467854/
# 70
# ***************************************************************************************
