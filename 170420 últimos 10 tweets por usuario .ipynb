# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'SuperDeSalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# [ACTUALIZACIÓN]
# Reporte diario #Covid_19 por parte del Ministerio de Salud:
#
# 🔹10.088 casos totales.
# 🔹358 casos nuev… https://t.co/dhlM0lOujy
#
# RT @ministeriosalud: [EN VIVO] Subsecretaria @pdazan entrega balance diario de #COVID_19 en nuestro país. https://t.co/29fl6gzZMQ
#
# RT @ministeriosalud: 🏥Hoy seguimos con el traslado del @FelixHfb a su nueva casa, esta vez fueron 3 pacientes de la UTI adulto que llegaron…
#
# RT @ministeriosalud: Es muy importante seguir todos los consejos y recomendaciones para evitar contagios de enfermedades respiratorias y en…
#
# RT @ministeriosalud: ¿Sabes qué es una Residencia Sanitaria?
# El subsecretario @arturozunigaj nos cuenta todo sobre ellas.
# Dale▶️ al video y…
#
# RT @ministeriosalud: Sigue estos consejos si un miembro del hogar es diagnosticado con #COVID_19 y es enviado a cuarentena a la casa:
#
# #Cu…
#
# #CuidémonosEntreTodos  en especial si tienes a alguien en tu hogar diagnosticado con #COVID_19
#
# Infórmate siempre e… https://t.co/zK63BUerjz
#
# RT @ministeriosalud: Hoy presentamos la Guía Práctica de la Salud en Personas Mayores, en este video te mostramos pequeños ejemplos de cómo…
#
# Al salir de tu casa mantén siempre, al menos, un metro de distancia con las demás personas
# 🚶‍♂️|---------|🚶‍♀️
#
# El… https://t.co/6S6QJot7Cm
#
# RT @ministeriosalud: Las Residencias Sanitarias son establecimientos que cuentan con habitaciones individuales, baños privados, servicio de…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  [ACTUALIZACIÓN]\nReporte diario #Covid_19 por ...
# 1  RT @ministeriosalud: [EN VIVO] Subsecretaria @...
# 2  RT @ministeriosalud: 🏥Hoy seguimos con el tras...
# 3  RT @ministeriosalud: Es muy importante seguir ...
# 4  RT @ministeriosalud: ¿Sabes qué es una Residen...
# 5  RT @ministeriosalud: Sigue estos consejos si u...
# 6  #CuidémonosEntreTodos  en especial si tienes a...
# 7  RT @ministeriosalud: Hoy presentamos la Guía P...
# 8  Al salir de tu casa mantén siempre, al menos, ...
# 9  RT @ministeriosalud: Las Residencias Sanitaria...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251892221311361026
# 2020-04-19 15:15:39
# Twitter for iPhone
# 1
# 1
# None
# None
# {'hashtags': [{'text': 'Covid_19', 'indices': [31, 40]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/dhlM0lOujy', 'expanded_url': 'https://twitter.com/i/web/status/1251892221311361026', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  [ACTUALIZACIÓN]\nReporte diario #Covid_19 por ...  1251892221311361026
# 1  RT @ministeriosalud: [EN VIVO] Subsecretaria @...  1251891434539683840
# 2  RT @ministeriosalud: 🏥Hoy seguimos con el tras...  1251883882993070083
# 3  RT @ministeriosalud: Es muy importante seguir ...  1251881250958303234
# 4  RT @ministeriosalud: ¿Sabes qué es una Residen...  1251713942344392705
# 5  RT @ministeriosalud: Sigue estos consejos si u...  1251679501639200774
# 6  #CuidémonosEntreTodos  en especial si tienes a...  1251652985282859009
# 7  RT @ministeriosalud: Hoy presentamos la Guía P...  1251621363988738050
# 8  Al salir de tu casa mantén siempre, al menos, ...  1251598403492024321
# 9  RT @ministeriosalud: Las Residencias Sanitaria...  1251585818117931008
#
#                  Date              Source  Likes  RTs
# 0 2020-04-19 15:15:39  Twitter for iPhone      1    1
# 1 2020-04-19 15:12:31  Twitter for iPhone      0   98
# 2 2020-04-19 14:42:31  Twitter for iPhone      0   15
# 3 2020-04-19 14:32:03  Twitter for iPhone      0   18
# 4 2020-04-19 03:27:14  Twitter for iPhone      0   47
# 5 2020-04-19 01:10:22  Twitter for iPhone      0   47
# 6 2020-04-18 23:25:00  Twitter for iPhone      0    1
# 7 2020-04-18 21:19:21  Twitter for iPhone      0   23
# 8 2020-04-18 19:48:07  Twitter for iPhone      2    1
# 9 2020-04-18 18:58:07  Twitter for iPhone      0   71

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  [ACTUALIZACIÓN]\nReporte diario #Covid_19 por ...
# 1  RT @ministeriosalud: [EN VIVO] Subsecretaria @...
# 2  RT @ministeriosalud: 🏥Hoy seguimos con el tras...
# 3  RT @ministeriosalud: Es muy importante seguir ...
# 4  RT @ministeriosalud: ¿Sabes qué es una Residen...
# 5  RT @ministeriosalud: Sigue estos consejos si u...
# 6  #CuidémonosEntreTodos  en especial si tienes a...
# 7  RT @ministeriosalud: Hoy presentamos la Guía P...
# 8  Al salir de tu casa mantén siempre, al menos, ...
# 9  RT @ministeriosalud: Las Residencias Sanitaria...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125189... 2020-04-19 15:15:39
# 1  https://twitter.com/SuperDeSalud/status/125189... 2020-04-19 15:12:31
# 2  https://twitter.com/SuperDeSalud/status/125188... 2020-04-19 14:42:31
# 3  https://twitter.com/SuperDeSalud/status/125188... 2020-04-19 14:32:03
# 4  https://twitter.com/SuperDeSalud/status/125171... 2020-04-19 03:27:14
# 5  https://twitter.com/SuperDeSalud/status/125167... 2020-04-19 01:10:22
# 6  https://twitter.com/SuperDeSalud/status/125165... 2020-04-18 23:25:00
# 7  https://twitter.com/SuperDeSalud/status/125162... 2020-04-18 21:19:21
# 8  https://twitter.com/SuperDeSalud/status/125159... 2020-04-18 19:48:07
# 9  https://twitter.com/SuperDeSalud/status/125158... 2020-04-18 18:58:07
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      1    1
# 1  Twitter for iPhone      0   98
# 2  Twitter for iPhone      0   15
# 3  Twitter for iPhone      0   18
# 4  Twitter for iPhone      0   47
# 5  Twitter for iPhone      0   47
# 6  Twitter for iPhone      0    1
# 7  Twitter for iPhone      0   23
# 8  Twitter for iPhone      2    1
# 9  Twitter for iPhone      0   71

# %%
import csv
data.to_csv(r'tweets_super_de_salud.csv', index = False)
