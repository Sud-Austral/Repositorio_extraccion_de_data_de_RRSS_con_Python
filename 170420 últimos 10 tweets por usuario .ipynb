# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Si estás en aislamiento domiciliario, es muy importante mantener las medidas de prevención en el hogar.
#
# - Lávate l… https://t.co/9kSQ0PPBEg
#
# #VacúnateAhora contra la influenza. Recuerda que es además gratuita para personas mayores de 65 años, niños y niñas… https://t.co/JIzzaAm59I
#
# Inicio de uso obligatorio de mascarillas | ¿En qué lugares?
#
# Conoce más sobre esta nueva medida que comienza a impl… https://t.co/wAsZuR68cb
#
# Donar sangre es donar vida.
# Si vas a salir, haz que valga la pena. Si tu comuna está en cuarentena puedes pedir tu… https://t.co/vgWowymv7Q
#
# RT @jmanalich: ¿Cuál es el sentido esencial del uso de la mascarilla? Es un acto de responsabilidad para que quien puede infectar a otro, n…
#
# RT @ministeriosalud: [Actualización] Ministerio de Salud informa 9.252 casos confirmados de #COVID_19 en Chile.
#
# Revisa el detalle completo…
#
# RT @arturozunigaj: Como cada día en el reporte diario #pandemia en La Moneda, mi agradecimiento a la labor que están desempeñando los #trab…
#
# RT @pdazan: Desde hoy comienza a regir la medida de uso obligatorio de mascarilla en recintos cerrados que aglomeren a más de 10 personas y…
#
# Si no tienes mascarillas, crea la tuya en simples pasos con una polera.
# #CuidémonosEntreTodos https://t.co/Ji25MNxMXo
#
# Si tienes a un miembro del hogar  diagnosticado con COVID 19, es muy importante que adoptes las siguientes medidas:… https://t.co/lfmbJPRzhx

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Si estás en aislamiento domiciliario, es muy i...
# 1  #VacúnateAhora contra la influenza. Recuerda q...
# 2  Inicio de uso obligatorio de mascarillas | ¿En...
# 3  Donar sangre es donar vida.\nSi vas a salir, h...
# 4  RT @jmanalich: ¿Cuál es el sentido esencial de...
# 5  RT @ministeriosalud: [Actualización] Ministeri...
# 6  RT @arturozunigaj: Como cada día en el reporte...
# 7  RT @pdazan: Desde hoy comienza a regir la medi...
# 8  Si no tienes mascarillas, crea la tuya en simp...
# 9  Si tienes a un miembro del hogar  diagnosticad...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251239008975245312
# 2020-04-17 20:00:01
# TweetDeck
# 1
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/9kSQ0PPBEg', 'expanded_url': 'https://twitter.com/i/web/status/1251239008975245312', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Si estás en aislamiento domiciliario, es muy i...  1251239008975245312
# 1  #VacúnateAhora contra la influenza. Recuerda q...  1251223905546629120
# 2  Inicio de uso obligatorio de mascarillas | ¿En...  1251208809076240384
# 3  Donar sangre es donar vida.\nSi vas a salir, h...  1251193710374772737
# 4  RT @jmanalich: ¿Cuál es el sentido esencial de...  1251182250068185090
# 5  RT @ministeriosalud: [Actualización] Ministeri...  1251182085529907200
# 6  RT @arturozunigaj: Como cada día en el reporte...  1251182076151377920
# 7  RT @pdazan: Desde hoy comienza a regir la medi...  1251182066911322112
# 8  Si no tienes mascarillas, crea la tuya en simp...  1251178606946062336
# 9  Si tienes a un miembro del hogar  diagnosticad...  1251163509322383360
#
#                  Date              Source  Likes  RTs
# 0 2020-04-17 20:00:01           TweetDeck      1    0
# 1 2020-04-17 19:00:00           TweetDeck      0    0
# 2 2020-04-17 18:00:01           TweetDeck      9    8
# 3 2020-04-17 17:00:01           TweetDeck      0    1
# 4 2020-04-17 16:14:28  Twitter for iPhone      0  627
# 5 2020-04-17 16:13:49  Twitter for iPhone      0   35
# 6 2020-04-17 16:13:47  Twitter for iPhone      0   58
# 7 2020-04-17 16:13:45  Twitter for iPhone      0   67
# 8 2020-04-17 16:00:00           TweetDeck      0    0
# 9 2020-04-17 15:00:00           TweetDeck      2    2

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Si estás en aislamiento domiciliario, es muy i...
# 1  #VacúnateAhora contra la influenza. Recuerda q...
# 2  Inicio de uso obligatorio de mascarillas | ¿En...
# 3  Donar sangre es donar vida.\nSi vas a salir, h...
# 4  RT @jmanalich: ¿Cuál es el sentido esencial de...
# 5  RT @ministeriosalud: [Actualización] Ministeri...
# 6  RT @arturozunigaj: Como cada día en el reporte...
# 7  RT @pdazan: Desde hoy comienza a regir la medi...
# 8  Si no tienes mascarillas, crea la tuya en simp...
# 9  Si tienes a un miembro del hogar  diagnosticad...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1251239008975... 2020-04-17 20:00:01
# 1  https://twitter.com/ispch/status/1251223905546... 2020-04-17 19:00:00
# 2  https://twitter.com/ispch/status/1251208809076... 2020-04-17 18:00:01
# 3  https://twitter.com/ispch/status/1251193710374... 2020-04-17 17:00:01
# 4  https://twitter.com/ispch/status/1251182250068... 2020-04-17 16:14:28
# 5  https://twitter.com/ispch/status/1251182085529... 2020-04-17 16:13:49
# 6  https://twitter.com/ispch/status/1251182076151... 2020-04-17 16:13:47
# 7  https://twitter.com/ispch/status/1251182066911... 2020-04-17 16:13:45
# 8  https://twitter.com/ispch/status/1251178606946... 2020-04-17 16:00:00
# 9  https://twitter.com/ispch/status/1251163509322... 2020-04-17 15:00:00
#
#                Source  Likes  RTs
# 0           TweetDeck      1    0
# 1           TweetDeck      0    0
# 2           TweetDeck      9    8
# 3           TweetDeck      0    1
# 4  Twitter for iPhone      0  627
# 5  Twitter for iPhone      0   35
# 6  Twitter for iPhone      0   58
# 7  Twitter for iPhone      0   67
# 8           TweetDeck      0    0
# 9           TweetDeck      2    2

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
