# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'opsoms'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Ante el miedo 😟, preocupación 😳 y estrés 😰 que la pandemia por #COVID19 puede generar en muchas personas, este vide… https://t.co/e3CCGUsTsH
#
# RT @PAHOemergencies: #COVID19 ¿Te sientes aislado 😔 porque no puedes visitar a tus amigos y familiares?
#
# ¡Conéctate 📞📱 🖥️ con ellos a diar…
#
# RT @opsomsuruguay: 👉🏽 Conversa acerca de la #COVID19 con tus hijos 👦🏻 👧🏾
#
# De seguro ellos ya habrán escuchado algo. El silencio y los secr…
#
# RT @opsargentina: #COVID19 #QuedateEnCasa https://t.co/Zxhpm8Lz2m
#
# RT @opsomsels: COVID-19 👉🏽 ¿Extrañas a tus amigos? 😞
# El distanciamiento físico no es aislamiento social.
#
# Mantenernos seguros y conectados…
#
# RT @opscuba: Los medios de comunicación pueden
# contribuir a un cambio de comportamientos que
# ayude a disminuir la propagación de la COVID-1…
#
# RT @opscuba: ¿Cómo cubrir tu tos para evitar que otras personas se enfermen? #COVID19 https://t.co/5rCs0JM4QM
#
# RT @opscuba: ¿Cómo se organiza en Cuba el proceso asistencial en los centros de aislamiento?
#
# El #MINSAP nos comenta paso a paso cómo es es…
#
# RT @OPSGuate: #COVID19 El distanciamiento físico no es aislamiento social.
#
# Utiliza la tecnología para mantenerte en contacto 💻📱☎️ https:/…
#
# RT @opsomsuruguay: 10 formas de ayudar a las personas mayores y/o enfermedades subyacentes que viven con usted
#
# 🌡️ Controle su salud diaria…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Ante el miedo 😟, preocupación 😳 y estrés 😰 que...
# 1  RT @PAHOemergencies: #COVID19 ¿Te sientes aisl...
# 2  RT @opsomsuruguay: 👉🏽 Conversa acerca de la #C...
# 3  RT @opsargentina: #COVID19 #QuedateEnCasa http...
# 4  RT @opsomsels: COVID-19 👉🏽 ¿Extrañas a tus ami...
# 5  RT @opscuba: Los medios de comunicación pueden...
# 6  RT @opscuba: ¿Cómo cubrir tu tos para evitar q...
# 7  RT @opscuba: ¿Cómo se organiza en Cuba el proc...
# 8  RT @OPSGuate: #COVID19 El distanciamiento físi...
# 9  RT @opsomsuruguay: 10 formas de ayudar a las p...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252241313904328704
# 2020-04-20 14:22:49
# Twitter Web App
# 124
# 124
# None
# None
# {'hashtags': [{'text': 'COVID19', 'indices': [63, 71]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/e3CCGUsTsH', 'expanded_url': 'https://twitter.com/i/web/status/1252241313904328704', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Ante el miedo 😟, preocupación 😳 y estrés 😰 que...  1252241313904328704
# 1  RT @PAHOemergencies: #COVID19 ¿Te sientes aisl...  1252238435831566336
# 2  RT @opsomsuruguay: 👉🏽 Conversa acerca de la #C...  1252238053957083139
# 3  RT @opsargentina: #COVID19 #QuedateEnCasa http...  1252238024613789697
# 4  RT @opsomsels: COVID-19 👉🏽 ¿Extrañas a tus ami...  1252238009673699328
# 5  RT @opscuba: Los medios de comunicación pueden...  1252237968468783105
# 6  RT @opscuba: ¿Cómo cubrir tu tos para evitar q...  1252237870288506882
# 7  RT @opscuba: ¿Cómo se organiza en Cuba el proc...  1252237840458477571
# 8  RT @OPSGuate: #COVID19 El distanciamiento físi...  1252237806547714054
# 9  RT @opsomsuruguay: 10 formas de ayudar a las p...  1252237781918560258
#
#                  Date              Source  Likes  RTs
# 0 2020-04-20 14:22:49     Twitter Web App    124  124
# 1 2020-04-20 14:11:23  Twitter for iPhone      0    5
# 2 2020-04-20 14:09:52  Twitter for iPhone      0    8
# 3 2020-04-20 14:09:45  Twitter for iPhone      0   18
# 4 2020-04-20 14:09:41  Twitter for iPhone      0   35
# 5 2020-04-20 14:09:31  Twitter for iPhone      0    7
# 6 2020-04-20 14:09:08  Twitter for iPhone      0    8
# 7 2020-04-20 14:09:01  Twitter for iPhone      0   26
# 8 2020-04-20 14:08:53  Twitter for iPhone      0   10
# 9 2020-04-20 14:08:47  Twitter for iPhone      0   10

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Ante el miedo 😟, preocupación 😳 y estrés 😰 que...
# 1  RT @PAHOemergencies: #COVID19 ¿Te sientes aisl...
# 2  RT @opsomsuruguay: 👉🏽 Conversa acerca de la #C...
# 3  RT @opsargentina: #COVID19 #QuedateEnCasa http...
# 4  RT @opsomsels: COVID-19 👉🏽 ¿Extrañas a tus ami...
# 5  RT @opscuba: Los medios de comunicación pueden...
# 6  RT @opscuba: ¿Cómo cubrir tu tos para evitar q...
# 7  RT @opscuba: ¿Cómo se organiza en Cuba el proc...
# 8  RT @OPSGuate: #COVID19 El distanciamiento físi...
# 9  RT @opsomsuruguay: 10 formas de ayudar a las p...
#
#                                                   ID                Date  \
# 0  https://twitter.com/opsoms/status/125224131390... 2020-04-20 14:22:49
# 1  https://twitter.com/opsoms/status/125223843583... 2020-04-20 14:11:23
# 2  https://twitter.com/opsoms/status/125223805395... 2020-04-20 14:09:52
# 3  https://twitter.com/opsoms/status/125223802461... 2020-04-20 14:09:45
# 4  https://twitter.com/opsoms/status/125223800967... 2020-04-20 14:09:41
# 5  https://twitter.com/opsoms/status/125223796846... 2020-04-20 14:09:31
# 6  https://twitter.com/opsoms/status/125223787028... 2020-04-20 14:09:08
# 7  https://twitter.com/opsoms/status/125223784045... 2020-04-20 14:09:01
# 8  https://twitter.com/opsoms/status/125223780654... 2020-04-20 14:08:53
# 9  https://twitter.com/opsoms/status/125223778191... 2020-04-20 14:08:47
#
#                Source  Likes  RTs
# 0     Twitter Web App    124  124
# 1  Twitter for iPhone      0    5
# 2  Twitter for iPhone      0    8
# 3  Twitter for iPhone      0   18
# 4  Twitter for iPhone      0   35
# 5  Twitter for iPhone      0    7
# 6  Twitter for iPhone      0    8
# 7  Twitter for iPhone      0   26
# 8  Twitter for iPhone      0   10
# 9  Twitter for iPhone      0   10

# %%
import csv
data.to_csv(r'tweets_opsoms.csv', index = False)
