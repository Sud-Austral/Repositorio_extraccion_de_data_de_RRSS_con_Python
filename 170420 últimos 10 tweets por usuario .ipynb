# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'SuperDeSalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Desde hoy 17 de abril, y por tiempo indefinido, comienza el uso obligatorio de mascarillas... 😷
#
# ¿Sabes dónde debes… https://t.co/fGrEx5bkB1
#
# RT @sebastianpinera: [EN VIVO] Iniciamos entrega de #BonoCovid19 que beneficiará a 2.7 millones de personas https://t.co/8xIVEdLM0h
#
# RT @SENAMAGOB: Ante la emergencia del COVID-19 organicémonos para ayudar a quienes más lo necesitan. Únete a #CuentaConmigo donde podrás en…
#
# RT @ministeriosalud: Ministro @jmanalich | Testeo
#
# Existen 3 tipos de exámenes por coronavirus:
# - PCR (presencia del virus)
# - De Antígeno…
#
# RT @ministeriosalud: "Examen de anticuerpo será gratuito por indagación epidemiológica".
#
# "Costo del test de anticuerpos será codificado po…
#
# RT @ministeriosalud: Ministro @jmanalich | Carnet #COVID_19
#
# "Es un documento que va acreditar que la persona se diagnosticó con coronaviru…
#
# [ACTUALIZACIÓN]
# Reporte diario #Covid_19 por parte del Ministerio de Salud:
#
# 🔹9.252 casos totales.
# 🔹445 casos nuevo… https://t.co/kZz2MICO3d
#
# RT @ministeriosalud: [EN VIVO] Autoridades de Salud entregan balance diario de #COVID_19 en nuestro país. https://t.co/gSEcBByQI3
#
# RT @ministeriosalud: #CuidémonosEntreTodos y en especial si tienes un familiar en tu hogar diagnosticado con #COVID_19.
#
# Conoce los consejo…
#
# RT @Cenabast: Más de un millón de pacientes crónicos se verán beneficiados del retiro anticipado de medicamentos por hasta 3 meses, lo que…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Desde hoy 17 de abril, y por tiempo indefinido...
# 1  RT @sebastianpinera: [EN VIVO] Iniciamos entre...
# 2  RT @SENAMAGOB: Ante la emergencia del COVID-19...
# 3  RT @ministeriosalud: Ministro @jmanalich | Tes...
# 4  RT @ministeriosalud: "Examen de anticuerpo ser...
# 5  RT @ministeriosalud: Ministro @jmanalich | Car...
# 6  [ACTUALIZACIÓN]\nReporte diario #Covid_19 por ...
# 7  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 8  RT @ministeriosalud: #CuidémonosEntreTodos y e...
# 9  RT @Cenabast: Más de un millón de pacientes cr...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251179809167769602
# 2020-04-17 16:04:46
# Twitter Web App
# 1
# 2
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/fGrEx5bkB1', 'expanded_url': 'https://twitter.com/i/web/status/1251179809167769602', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Desde hoy 17 de abril, y por tiempo indefinido...  1251179809167769602
# 1  RT @sebastianpinera: [EN VIVO] Iniciamos entre...  1251174506258931712
# 2  RT @SENAMAGOB: Ante la emergencia del COVID-19...  1251165894895480833
# 3  RT @ministeriosalud: Ministro @jmanalich | Tes...  1251161134624727041
# 4  RT @ministeriosalud: "Examen de anticuerpo ser...  1251161105558196229
# 5  RT @ministeriosalud: Ministro @jmanalich | Car...  1251154056082419717
# 6  [ACTUALIZACIÓN]\nReporte diario #Covid_19 por ...  1251153921126486018
# 7  RT @ministeriosalud: [EN VIVO] Autoridades de ...  1251150844470325252
# 8  RT @ministeriosalud: #CuidémonosEntreTodos y e...  1251145564248367111
# 9  RT @Cenabast: Más de un millón de pacientes cr...  1251142411817848835
#
#                  Date              Source  Likes  RTs
# 0 2020-04-17 16:04:46     Twitter Web App      1    2
# 1 2020-04-17 15:43:42  Twitter for iPhone      0  229
# 2 2020-04-17 15:09:29  Twitter for iPhone      0   13
# 3 2020-04-17 14:50:34     Twitter Web App      0   54
# 4 2020-04-17 14:50:27     Twitter Web App      0   31
# 5 2020-04-17 14:22:26     Twitter Web App      0   32
# 6 2020-04-17 14:21:54     Twitter Web App      0    1
# 7 2020-04-17 14:09:41     Twitter Web App      0  142
# 8 2020-04-17 13:48:42     Twitter Web App      0   13
# 9 2020-04-17 13:36:10     Twitter Web App      0   32

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Desde hoy 17 de abril, y por tiempo indefinido...
# 1  RT @sebastianpinera: [EN VIVO] Iniciamos entre...
# 2  RT @SENAMAGOB: Ante la emergencia del COVID-19...
# 3  RT @ministeriosalud: Ministro @jmanalich | Tes...
# 4  RT @ministeriosalud: "Examen de anticuerpo ser...
# 5  RT @ministeriosalud: Ministro @jmanalich | Car...
# 6  [ACTUALIZACIÓN]\nReporte diario #Covid_19 por ...
# 7  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 8  RT @ministeriosalud: #CuidémonosEntreTodos y e...
# 9  RT @Cenabast: Más de un millón de pacientes cr...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125117... 2020-04-17 16:04:46
# 1  https://twitter.com/SuperDeSalud/status/125117... 2020-04-17 15:43:42
# 2  https://twitter.com/SuperDeSalud/status/125116... 2020-04-17 15:09:29
# 3  https://twitter.com/SuperDeSalud/status/125116... 2020-04-17 14:50:34
# 4  https://twitter.com/SuperDeSalud/status/125116... 2020-04-17 14:50:27
# 5  https://twitter.com/SuperDeSalud/status/125115... 2020-04-17 14:22:26
# 6  https://twitter.com/SuperDeSalud/status/125115... 2020-04-17 14:21:54
# 7  https://twitter.com/SuperDeSalud/status/125115... 2020-04-17 14:09:41
# 8  https://twitter.com/SuperDeSalud/status/125114... 2020-04-17 13:48:42
# 9  https://twitter.com/SuperDeSalud/status/125114... 2020-04-17 13:36:10
#
#                Source  Likes  RTs
# 0     Twitter Web App      1    2
# 1  Twitter for iPhone      0  229
# 2  Twitter for iPhone      0   13
# 3     Twitter Web App      0   54
# 4     Twitter Web App      0   31
# 5     Twitter Web App      0   32
# 6     Twitter Web App      0    1
# 7     Twitter Web App      0  142
# 8     Twitter Web App      0   13
# 9     Twitter Web App      0   32

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
