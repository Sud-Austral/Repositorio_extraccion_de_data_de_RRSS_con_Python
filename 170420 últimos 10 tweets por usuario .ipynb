# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'SuperDeSalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# ¿Sabes cómo se decretan las cuarentenas y cuáles los criterios para determinar estas medidas?… https://t.co/hhsYtrwbrj
#
# RT @pdazan: No olvides la obligatoriedad del uso de la mascarilla en ascensores, el transporte público, el tranporte privado pagado y en re…
#
# RT @jmanalich: El rol del estudio de anticuerpos será crucial para el entendimiento y manejo de COVD-19.: Antibody tests suggest that coron…
#
# RT @24HorasTVN: Coronavirus en la región de Aysén: Cero casos activos gracias a estrictas medidas sanitarias.
#
# Señal en vivo #24Play #24Hor…
#
# RT @ministeriosalud: ¿Sabes cómo se decretan las cuarentenas?
#
# Existe una serie de criterios para determinar esta medida en una zona, comun…
#
# RT @ministeriosalud: La limpieza en tu hogar, o en tu lugar de trabajo, es clave para evitar enfermedades como el #COVID_19.
#
# Encuentra má…
#
# Les dejamos la entrevista al Superintendente, Patricio Fernández, en la edición de hoy domingo de @ElMercurio_cl.… https://t.co/GU4WXOD6tL
#
# La @SuperDeSalud  busca profesional  para el Departamento de Administración y Finanzas.
#
# El cierre de la postulació… https://t.co/oSBO8P3XUO
#
# RT @ministeriosalud: Ministro @jmanalich en #MesaCentral de @T13: “Lo que se propone es una vuelta gradual, para los funcionarios públicos,…
#
# Ahora el ministro @jmanalich en vivo en @T13 https://t.co/2xeKT80b0w

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  ¿Sabes cómo se decretan las cuarentenas y cuál...
# 1  RT @pdazan: No olvides la obligatoriedad del u...
# 2  RT @jmanalich: El rol del estudio de anticuerp...
# 3  RT @24HorasTVN: Coronavirus en la región de Ay...
# 4  RT @ministeriosalud: ¿Sabes cómo se decretan l...
# 5  RT @ministeriosalud: La limpieza en tu hogar, ...
# 6  Les dejamos la entrevista al Superintendente, ...
# 7  La @SuperDeSalud  busca profesional  para el D...
# 8  RT @ministeriosalud: Ministro @jmanalich en #M...
# 9  Ahora el ministro @jmanalich en vivo en @T13 h...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252223317416837122
# 2020-04-20 13:11:18
# Twitter Web App
# 0
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hhsYtrwbrj', 'expanded_url': 'https://twitter.com/i/web/status/1252223317416837122', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [95, 118]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  ¿Sabes cómo se decretan las cuarentenas y cuál...  1252223317416837122
# 1  RT @pdazan: No olvides la obligatoriedad del u...  1252214845597941763
# 2  RT @jmanalich: El rol del estudio de anticuerp...  1252205762174124032
# 3  RT @24HorasTVN: Coronavirus en la región de Ay...  1252047365000888322
# 4  RT @ministeriosalud: ¿Sabes cómo se decretan l...  1252026392293900292
# 5  RT @ministeriosalud: La limpieza en tu hogar, ...  1251996589247397889
# 6  Les dejamos la entrevista al Superintendente, ...  1251957872382160896
# 7  La @SuperDeSalud  busca profesional  para el D...  1251938912462868480
# 8  RT @ministeriosalud: Ministro @jmanalich en #M...  1251920626975154176
# 9  Ahora el ministro @jmanalich en vivo en @T13 h...  1251914408256823298
#
#                  Date              Source  Likes  RTs
# 0 2020-04-20 13:11:18     Twitter Web App      0    0
# 1 2020-04-20 12:37:38     Twitter Web App      0   43
# 2 2020-04-20 12:01:33     Twitter Web App      0  241
# 3 2020-04-20 01:32:08  Twitter for iPhone      0   64
# 4 2020-04-20 00:08:48  Twitter for iPhone      0   41
# 5 2020-04-19 22:10:22  Twitter for iPhone      0   54
# 6 2020-04-19 19:36:31     Twitter Web App     18   13
# 7 2020-04-19 18:21:11  Twitter for iPhone      0    1
# 8 2020-04-19 17:08:31  Twitter for iPhone      0   50
# 9 2020-04-19 16:43:49  Twitter for iPhone      1    0

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  ¿Sabes cómo se decretan las cuarentenas y cuál...
# 1  RT @pdazan: No olvides la obligatoriedad del u...
# 2  RT @jmanalich: El rol del estudio de anticuerp...
# 3  RT @24HorasTVN: Coronavirus en la región de Ay...
# 4  RT @ministeriosalud: ¿Sabes cómo se decretan l...
# 5  RT @ministeriosalud: La limpieza en tu hogar, ...
# 6  Les dejamos la entrevista al Superintendente, ...
# 7  La @SuperDeSalud  busca profesional  para el D...
# 8  RT @ministeriosalud: Ministro @jmanalich en #M...
# 9  Ahora el ministro @jmanalich en vivo en @T13 h...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125222... 2020-04-20 13:11:18
# 1  https://twitter.com/SuperDeSalud/status/125221... 2020-04-20 12:37:38
# 2  https://twitter.com/SuperDeSalud/status/125220... 2020-04-20 12:01:33
# 3  https://twitter.com/SuperDeSalud/status/125204... 2020-04-20 01:32:08
# 4  https://twitter.com/SuperDeSalud/status/125202... 2020-04-20 00:08:48
# 5  https://twitter.com/SuperDeSalud/status/125199... 2020-04-19 22:10:22
# 6  https://twitter.com/SuperDeSalud/status/125195... 2020-04-19 19:36:31
# 7  https://twitter.com/SuperDeSalud/status/125193... 2020-04-19 18:21:11
# 8  https://twitter.com/SuperDeSalud/status/125192... 2020-04-19 17:08:31
# 9  https://twitter.com/SuperDeSalud/status/125191... 2020-04-19 16:43:49
#
#                Source  Likes  RTs
# 0     Twitter Web App      0    0
# 1     Twitter Web App      0   43
# 2     Twitter Web App      0  241
# 3  Twitter for iPhone      0   64
# 4  Twitter for iPhone      0   41
# 5  Twitter for iPhone      0   54
# 6     Twitter Web App     18   13
# 7  Twitter for iPhone      0    1
# 8  Twitter for iPhone      0   50
# 9  Twitter for iPhone      1    0

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
