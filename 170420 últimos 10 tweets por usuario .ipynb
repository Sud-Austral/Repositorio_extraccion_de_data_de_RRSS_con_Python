# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Conoce más sobre esta nueva medida que comienza a implementarse y encuentra más información en… https://t.co/vLtvpoGKnT
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/5q5vHKAhYs
#
# Es obligatorio el uso de mascarillas en medios de transporte públicos y privados remunerados.
#
# Si no cuentas con un… https://t.co/hXb8HVLeia
#
# Si tienes un pañuelo en tu hogar, puedes convertirlo en una mascarilla.
#
# Sigue estos pasos y #CuidémonosEntreTodos https://t.co/hdN6FvAe9l
#
# Inicio de uso obligatorio de mascarillas | ¿En qué lugares?
#
# Conoce más sobre esta nueva medida y encuentra más inf… https://t.co/CdgMO5ox6M
#
# Conoce más sobre esta nueva medida que comienza a implementarse y encuentra más información en… https://t.co/2m8zNj3wCU
#
# Es obligatorio el uso de mascarillas en medios de transporte públicos y privados remunerados.
#
# Si no cuentas con un… https://t.co/XrRebds06m
#
# Si tienes un pañuelo en tu hogar, puedes convertirlo en una mascarilla.
#
# Sigue estos pasos y #CuidémonosEntreTodos https://t.co/cIz7cDuoh8
#
# #VacúnateAhora contra la influenza. Recuerda que es además gratuita para personas mayores de 65 años, niños y niñas… https://t.co/Wyo6qQiPTr
#
# RT @ministeriosalud: Subsecretaria @pdazan: “todas las semanas se toman las medidas y si es necesario se evalúan cierres de nuevas comunas…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Conoce más sobre esta nueva medida que comienz...
# 1  Temperatura actual, pronóstico del tiempo y ra...
# 2  Es obligatorio el uso de mascarillas en medios...
# 3  Si tienes un pañuelo en tu hogar, puedes conve...
# 4  Inicio de uso obligatorio de mascarillas | ¿En...
# 5  Conoce más sobre esta nueva medida que comienz...
# 6  Es obligatorio el uso de mascarillas en medios...
# 7  Si tienes un pañuelo en tu hogar, puedes conve...
# 8  #VacúnateAhora contra la influenza. Recuerda q...
# 9  RT @ministeriosalud: Subsecretaria @pdazan: “t...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252220472000798720
# 2020-04-20 13:00:00
# TweetDeck
# 1
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vLtvpoGKnT', 'expanded_url': 'https://twitter.com/i/web/status/1252220472000798720', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [96, 119]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Conoce más sobre esta nueva medida que comienz...  1252220472000798720
# 1  Temperatura actual, pronóstico del tiempo y ra...  1252215165531144194
# 2  Es obligatorio el uso de mascarillas en medios...  1252205372158341128
# 3  Si tienes un pañuelo en tu hogar, puedes conve...  1252039277778788352
# 4  Inicio de uso obligatorio de mascarillas | ¿En...  1252009080127922178
# 5  Conoce más sobre esta nueva medida que comienz...  1251978879637442561
# 6  Es obligatorio el uso de mascarillas en medios...  1251948683102425091
# 7  Si tienes un pañuelo en tu hogar, puedes conve...  1251918484373553154
# 8  #VacúnateAhora contra la influenza. Recuerda q...  1251903383981744128
# 9  RT @ministeriosalud: Subsecretaria @pdazan: “t...  1251897824171745282
#
#                  Date              Source  Likes  RTs
# 0 2020-04-20 13:00:00           TweetDeck      1    0
# 1 2020-04-20 12:38:55  Twitter for iPhone      0    0
# 2 2020-04-20 12:00:00           TweetDeck      1    0
# 3 2020-04-20 01:00:00           TweetDeck      1    2
# 4 2020-04-19 23:00:00           TweetDeck      3    3
# 5 2020-04-19 21:00:00           TweetDeck      1    0
# 6 2020-04-19 19:00:00           TweetDeck      6    2
# 7 2020-04-19 17:00:00           TweetDeck      2    1
# 8 2020-04-19 16:00:00           TweetDeck      2    0
# 9 2020-04-19 15:37:55  Twitter for iPhone      0   21

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Conoce más sobre esta nueva medida que comienz...
# 1  Temperatura actual, pronóstico del tiempo y ra...
# 2  Es obligatorio el uso de mascarillas en medios...
# 3  Si tienes un pañuelo en tu hogar, puedes conve...
# 4  Inicio de uso obligatorio de mascarillas | ¿En...
# 5  Conoce más sobre esta nueva medida que comienz...
# 6  Es obligatorio el uso de mascarillas en medios...
# 7  Si tienes un pañuelo en tu hogar, puedes conve...
# 8  #VacúnateAhora contra la influenza. Recuerda q...
# 9  RT @ministeriosalud: Subsecretaria @pdazan: “t...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1252220472000... 2020-04-20 13:00:00
# 1  https://twitter.com/ispch/status/1252215165531... 2020-04-20 12:38:55
# 2  https://twitter.com/ispch/status/1252205372158... 2020-04-20 12:00:00
# 3  https://twitter.com/ispch/status/1252039277778... 2020-04-20 01:00:00
# 4  https://twitter.com/ispch/status/1252009080127... 2020-04-19 23:00:00
# 5  https://twitter.com/ispch/status/1251978879637... 2020-04-19 21:00:00
# 6  https://twitter.com/ispch/status/1251948683102... 2020-04-19 19:00:00
# 7  https://twitter.com/ispch/status/1251918484373... 2020-04-19 17:00:00
# 8  https://twitter.com/ispch/status/1251903383981... 2020-04-19 16:00:00
# 9  https://twitter.com/ispch/status/1251897824171... 2020-04-19 15:37:55
#
#                Source  Likes  RTs
# 0           TweetDeck      1    0
# 1  Twitter for iPhone      0    0
# 2           TweetDeck      1    0
# 3           TweetDeck      1    2
# 4           TweetDeck      3    3
# 5           TweetDeck      1    0
# 6           TweetDeck      6    2
# 7           TweetDeck      2    1
# 8           TweetDeck      2    0
# 9  Twitter for iPhone      0   21

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
