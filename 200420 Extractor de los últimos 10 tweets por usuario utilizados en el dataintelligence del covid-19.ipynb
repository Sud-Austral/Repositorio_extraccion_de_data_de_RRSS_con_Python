# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/99W47OImYz
#
# Prefiere medicamentos #bioequivalentes.
# El @ispch garantiza su calidad, seguridad y eficacia.
# #ExigeElAmarillo https://t.co/KYohZBk7GW
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOlnhQ7… https://t.co/mqGlZKLnig
#
# Si tienes un pañuelo en tu hogar, puedes convertirlo en una mascarilla.
#
# Sigue estos pasos y #CuidémonosEntreTodos https://t.co/iiIEzJofK0
#
# RT @ministeriosalud: [VIDEO] El Director de Emergencias de @WHO, Mike Ryan, se refirió a sus declaraciones sobre el tipo de examen para dec…
#
# Conoce más sobre esta nueva medida que comienza a implementarse y encuentra más información en… https://t.co/RYXffYu9Eq
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOlnhQ7… https://t.co/35rtG2lOSP
#
# Prefiere medicamentos #bioequivalentes.
# El @ispch garantiza su calidad, seguridad y eficacia.
# #ExigeElAmarillo https://t.co/mdYqDMzI4j
#
# Si estás en aislamiento domiciliario, es muy importante mantener las medidas de prevención en el hogar.
#
# - Lávate l… https://t.co/gXIrCQM76M
#
# Si no tienes mascarillas, crea la tuya en simples pasos con una polera.
# #CuidémonosEntreTodos https://t.co/pEDCBn7rCk

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Temperatura actual, pronóstico del tiempo y ra...
# 1  Prefiere medicamentos #bioequivalentes. \nEl @...
# 2  Protégete contra el nuevo Coronavirus COVID-19...
# 3  Si tienes un pañuelo en tu hogar, puedes conve...
# 4  RT @ministeriosalud: [VIDEO] El Director de Em...
# 5  Conoce más sobre esta nueva medida que comienz...
# 6  Protégete contra el nuevo Coronavirus COVID-19...
# 7  Prefiere medicamentos #bioequivalentes. \nEl @...
# 8  Si estás en aislamiento domiciliario, es muy i...
# 9  Si no tienes mascarillas, crea la tuya en simp...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'extended_entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252588068848222208
# 2020-04-21 13:20:42
# Twitter for iPhone
# 0
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1252588062300872705, 'id_str': '1252588062300872705', 'indices': [102, 125], 'media_url': 'http://pbs.twimg.com/media/EWIWNMdWoAERqsq.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EWIWNMdWoAERqsq.jpg', 'url': 'https://t.co/99W47OImYz', 'display_url': 'pic.twitter.com/99W47OImYz', 'expanded_url': 'https://twitter.com/ispch/status/1252588068848222208/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 717, 'h': 1200, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 828, 'h': 1385, 'resize': 'fit'}, 'small': {'w': 407, 'h': 680, 'resize': 'fit'}}}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Temperatura actual, pronóstico del tiempo y ra...  1252588068848222208
# 1  Prefiere medicamentos #bioequivalentes. \nEl @...  1252582860143448065
# 2  Protégete contra el nuevo Coronavirus COVID-19...  1252567760229498881
# 3  Si tienes un pañuelo en tu hogar, puedes conve...  1252416767575511053
# 4  RT @ministeriosalud: [VIDEO] El Director de Em...  1252404027628740609
# 5  Conoce más sobre esta nueva medida que comienz...  1252401666462085127
# 6  Protégete contra el nuevo Coronavirus COVID-19...  1252371468337496064
# 7  Prefiere medicamentos #bioequivalentes. \nEl @...  1252356369002328065
# 8  Si estás en aislamiento domiciliario, es muy i...  1252341268870361088
# 9  Si no tienes mascarillas, crea la tuya en simp...  1252326172039319552
#
#                  Date              Source  Likes  RTs
# 0 2020-04-21 13:20:42  Twitter for iPhone      0    0
# 1 2020-04-21 13:00:00           TweetDeck      0    0
# 2 2020-04-21 12:00:00           TweetDeck      2    1
# 3 2020-04-21 02:00:00           TweetDeck      5    1
# 4 2020-04-21 01:09:23  Twitter for iPhone      0  497
# 5 2020-04-21 01:00:00           TweetDeck      3    3
# 6 2020-04-20 23:00:00           TweetDeck      0    0
# 7 2020-04-20 22:00:00           TweetDeck      2    1
# 8 2020-04-20 21:00:00           TweetDeck      2    2
# 9 2020-04-20 20:00:01           TweetDeck      3    2

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Temperatura actual, pronóstico del tiempo y ra...
# 1  Prefiere medicamentos #bioequivalentes. \nEl @...
# 2  Protégete contra el nuevo Coronavirus COVID-19...
# 3  Si tienes un pañuelo en tu hogar, puedes conve...
# 4  RT @ministeriosalud: [VIDEO] El Director de Em...
# 5  Conoce más sobre esta nueva medida que comienz...
# 6  Protégete contra el nuevo Coronavirus COVID-19...
# 7  Prefiere medicamentos #bioequivalentes. \nEl @...
# 8  Si estás en aislamiento domiciliario, es muy i...
# 9  Si no tienes mascarillas, crea la tuya en simp...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1252588068848... 2020-04-21 13:20:42
# 1  https://twitter.com/ispch/status/1252582860143... 2020-04-21 13:00:00
# 2  https://twitter.com/ispch/status/1252567760229... 2020-04-21 12:00:00
# 3  https://twitter.com/ispch/status/1252416767575... 2020-04-21 02:00:00
# 4  https://twitter.com/ispch/status/1252404027628... 2020-04-21 01:09:23
# 5  https://twitter.com/ispch/status/1252401666462... 2020-04-21 01:00:00
# 6  https://twitter.com/ispch/status/1252371468337... 2020-04-20 23:00:00
# 7  https://twitter.com/ispch/status/1252356369002... 2020-04-20 22:00:00
# 8  https://twitter.com/ispch/status/1252341268870... 2020-04-20 21:00:00
# 9  https://twitter.com/ispch/status/1252326172039... 2020-04-20 20:00:01
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0    0
# 1           TweetDeck      0    0
# 2           TweetDeck      2    1
# 3           TweetDeck      5    1
# 4  Twitter for iPhone      0  497
# 5           TweetDeck      3    3
# 6           TweetDeck      0    0
# 7           TweetDeck      2    1
# 8           TweetDeck      2    2
# 9           TweetDeck      3    2

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
