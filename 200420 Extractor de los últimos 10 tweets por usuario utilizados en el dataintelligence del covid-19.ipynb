# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ministeriosalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Cuando salgas, hazlo sólo si es necesario y usando siempre una mascarilla si estás en un ascensor, comercio, espaci… https://t.co/Ohkqpp70Tr
#
# Subsecretario de Redes Asistenciales @arturozunigaj inspecciona Residencia Sanitaria y llama a hacer uso de este be… https://t.co/meosxPkIuV
#
# RT @arturozunigaj: Trabajo de equipo!bien @SSDelReloncavi
#
# RT @24HorasTVN: 🔍 #24Data | Este martes el ministerio de Salud publicó el décimo informe epidemiológico de COVID-19. https://t.co/7mtpwbkFmW
#
# RT @FelixHfb: Directora @DraMoroni agradece a todos los funcionari@s por haber realizado un traslado impecable, con estándares de seguridad…
#
# #CuidémonosEntreTodos y en especial a nuestras personas mayores.
# Conoce las medidas implementadas para los Establec… https://t.co/joPeq2B4xH
#
# RT @pdazan: Recuerda que este jueves entra en cuarentena, por siete días, parte de la comuna de Independencia. https://t.co/5BHWsRAURT
#
# RT @SSMaule: Empresarios realizaron significativo aporte al Hospital de Constitución, se trata de monitores de multiparámetro para la obser…
#
# RT @SaludChiloe: #PlanCoronavirus. Por unanimidad @goreloslagos asignara 652 millones para habilitación de un Hospital de campaña en #Castr…
#
# RT @jmanalich: Debería haberse demorado 15 días, para completar vacunación. En ese momento la circulación viral era mínima.

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Cuando salgas, hazlo sólo si es necesario y us...
# 1  Subsecretario de Redes Asistenciales @arturozu...
# 2  RT @arturozunigaj: Trabajo de equipo!bien @SSD...
# 3  RT @24HorasTVN: 🔍 #24Data | Este martes el min...
# 4  RT @FelixHfb: Directora @DraMoroni agradece a ...
# 5  #CuidémonosEntreTodos y en especial a nuestras...
# 6  RT @pdazan: Recuerda que este jueves entra en ...
# 7  RT @SSMaule: Empresarios realizaron significat...
# 8  RT @SaludChiloe: #PlanCoronavirus. Por unanimi...
# 9  RT @jmanalich: Debería haberse demorado 15 día...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252764053350559746
# 2020-04-22 01:00:00
# Twitter Media Studio
# 8
# 10
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Ohkqpp70Tr', 'expanded_url': 'https://twitter.com/i/web/status/1252764053350559746', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Cuando salgas, hazlo sólo si es necesario y us...  1252764053350559746
# 1  Subsecretario de Redes Asistenciales @arturozu...  1252760666122977282
# 2  RT @arturozunigaj: Trabajo de equipo!bien @SSD...  1252755510757072896
# 3  RT @24HorasTVN: 🔍 #24Data | Este martes el min...  1252753387747192832
# 4  RT @FelixHfb: Directora @DraMoroni agradece a ...  1252749698529705985
# 5  #CuidémonosEntreTodos y en especial a nuestras...  1252748954959097856
# 6  RT @pdazan: Recuerda que este jueves entra en ...  1252742169657516032
# 7  RT @SSMaule: Empresarios realizaron significat...  1252740916084948992
# 8  RT @SaludChiloe: #PlanCoronavirus. Por unanimi...  1252740871205924865
# 9  RT @jmanalich: Debería haberse demorado 15 día...  1252740799567220737
#
#                  Date                Source  Likes  RTs
# 0 2020-04-22 01:00:00  Twitter Media Studio      8   10
# 1 2020-04-22 00:46:32    Twitter Web Client      2    2
# 2 2020-04-22 00:26:03    Twitter for iPhone      0    5
# 3 2020-04-22 00:17:37    Twitter for iPhone      0   14
# 4 2020-04-22 00:02:57    Twitter for iPhone      0   38
# 5 2020-04-22 00:00:00  Twitter Media Studio      6    6
# 6 2020-04-21 23:33:02    Twitter for iPhone      0   19
# 7 2020-04-21 23:28:03    Twitter for iPhone      0   14
# 8 2020-04-21 23:27:53    Twitter for iPhone      0    8
# 9 2020-04-21 23:27:36    Twitter for iPhone      0  354

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Cuando salgas, hazlo sólo si es necesario y us...
# 1  Subsecretario de Redes Asistenciales @arturozu...
# 2  RT @arturozunigaj: Trabajo de equipo!bien @SSD...
# 3  RT @24HorasTVN: 🔍 #24Data | Este martes el min...
# 4  RT @FelixHfb: Directora @DraMoroni agradece a ...
# 5  #CuidémonosEntreTodos y en especial a nuestras...
# 6  RT @pdazan: Recuerda que este jueves entra en ...
# 7  RT @SSMaule: Empresarios realizaron significat...
# 8  RT @SaludChiloe: #PlanCoronavirus. Por unanimi...
# 9  RT @jmanalich: Debería haberse demorado 15 día...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ministeriosalud/status/125... 2020-04-22 01:00:00
# 1  https://twitter.com/ministeriosalud/status/125... 2020-04-22 00:46:32
# 2  https://twitter.com/ministeriosalud/status/125... 2020-04-22 00:26:03
# 3  https://twitter.com/ministeriosalud/status/125... 2020-04-22 00:17:37
# 4  https://twitter.com/ministeriosalud/status/125... 2020-04-22 00:02:57
# 5  https://twitter.com/ministeriosalud/status/125... 2020-04-22 00:00:00
# 6  https://twitter.com/ministeriosalud/status/125... 2020-04-21 23:33:02
# 7  https://twitter.com/ministeriosalud/status/125... 2020-04-21 23:28:03
# 8  https://twitter.com/ministeriosalud/status/125... 2020-04-21 23:27:53
# 9  https://twitter.com/ministeriosalud/status/125... 2020-04-21 23:27:36
#
#                  Source  Likes  RTs
# 0  Twitter Media Studio      8   10
# 1    Twitter Web Client      2    2
# 2    Twitter for iPhone      0    5
# 3    Twitter for iPhone      0   14
# 4    Twitter for iPhone      0   38
# 5  Twitter Media Studio      6    6
# 6    Twitter for iPhone      0   19
# 7    Twitter for iPhone      0   14
# 8    Twitter for iPhone      0    8
# 9    Twitter for iPhone      0  354

# %%
import csv
data.to_csv(r'tweets_opsoms.csv', index = False)
