# %% [markdown]
# # 200420 Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ministeriosalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @pdazan: Esta semana promovemos el autocuidado de las Personas Mayores en tiempos de cuarentena. Revisa y comparte estos consejos con tu…
#
# ¿Cómo podemos cuidar a nuestras personas mayores que están en aislamiento?
#
# Mantén contacto frecuente con ellos vía… https://t.co/UH4bV7NqHW
#
# RT @servsaludconce: 📍 Delegado del SS Concepción inició sus labores de supervisión en Sanatorio Alemán
# A las 10 de la mañana de hoy, 20 de…
#
# RT @T13: Director de emergencias de la OMS aborda controversia en torno a carnet COVID-19
#
# https://t.co/0GtwfknMcq
#
# RT @FelipeGuevaraSt: Durante el fin de semana 15 personas no cumplieron la cuarentena, iniciándose las sanciones correspondientes, es decir…
#
# Si alguien de mi familia está diagnosticado por #COVID_19, ¿qué debo hacer?
#
# Visita https://t.co/5dNEmjSLxo y en es… https://t.co/fZMEfy9eJF
#
# RT @SaludChiloe: LABORATORIO DE AQUACHILE REALIZA GRATIS PRUEBAS DIAGNÓSTICAS DE SARS COV-2 GRACIAS A CONVENIO FIRMADO CON EL SERVICIO DE S…
#
# RT @GobiernodeChile: El Proyecto de ley #IngresodeEmergencia, anunciado hoy por el Pdte. @sebastianpinera, beneficiará a familias perteneci…
#
# RT @TeodoroRiberaN: A esta hora 450 ciudadanos bolivianos se dirigen hacia la frontera para regresar a su país, tras ocho días de cuarenten…
#
# RT @SSBiobio: En Laja, el director del @SSBiobio visitó junto al gobernador de la provincia de Biobío @IgnacioFica1 y el alcalde de la comu…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @pdazan: Esta semana promovemos el autocuid...
# 1  ¿Cómo podemos cuidar a nuestras personas mayor...
# 2  RT @servsaludconce: 📍 Delegado del SS Concepci...
# 3  RT @T13: Director de emergencias de la OMS abo...
# 4  RT @FelipeGuevaraSt: Durante el fin de semana ...
# 5  Si alguien de mi familia está diagnosticado po...
# 6  RT @SaludChiloe: LABORATORIO DE AQUACHILE REAL...
# 7  RT @GobiernodeChile: El Proyecto de ley #Ingre...
# 8  RT @TeodoroRiberaN: A esta hora 450 ciudadanos...
# 9  RT @SSBiobio: En Laja, el director del @SSBiob...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252342767151312897
# 2020-04-20 21:05:57
# Twitter Web App
# 0
# 11
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'pdazan', 'name': 'Paula Daza', 'id': 2496588486, 'id_str': '2496588486', 'indices': [3, 10]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @pdazan: Esta semana promovemos el autocuid...  1252342767151312897
# 1  ¿Cómo podemos cuidar a nuestras personas mayor...  1252341269017137162
# 2  RT @servsaludconce: 📍 Delegado del SS Concepci...  1252340335218319360
# 3  RT @T13: Director de emergencias de la OMS abo...  1252340316423614471
# 4  RT @FelipeGuevaraSt: Durante el fin de semana ...  1252335142963568640
# 5  Si alguien de mi familia está diagnosticado po...  1252326171808849931
# 6  RT @SaludChiloe: LABORATORIO DE AQUACHILE REAL...  1252322143037083648
# 7  RT @GobiernodeChile: El Proyecto de ley #Ingre...  1252319817203421189
# 8  RT @TeodoroRiberaN: A esta hora 450 ciudadanos...  1252318667313840128
# 9  RT @SSBiobio: En Laja, el director del @SSBiob...  1252317497660829696
#
#                  Date                Source  Likes  RTs
# 0 2020-04-20 21:05:57       Twitter Web App      0   11
# 1 2020-04-20 21:00:00  Twitter Media Studio      8    9
# 2 2020-04-20 20:56:17       Twitter Web App      0    4
# 3 2020-04-20 20:56:13       Twitter Web App      0   11
# 4 2020-04-20 20:35:40       Twitter Web App      0   14
# 5 2020-04-20 20:00:01  Twitter Media Studio     18   18
# 6 2020-04-20 19:44:00       Twitter Web App      0   26
# 7 2020-04-20 19:34:46       Twitter Web App      0   36
# 8 2020-04-20 19:30:11       Twitter Web App      0   70
# 9 2020-04-20 19:25:33       Twitter Web App      0    9

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @pdazan: Esta semana promovemos el autocuid...
# 1  ¿Cómo podemos cuidar a nuestras personas mayor...
# 2  RT @servsaludconce: 📍 Delegado del SS Concepci...
# 3  RT @T13: Director de emergencias de la OMS abo...
# 4  RT @FelipeGuevaraSt: Durante el fin de semana ...
# 5  Si alguien de mi familia está diagnosticado po...
# 6  RT @SaludChiloe: LABORATORIO DE AQUACHILE REAL...
# 7  RT @GobiernodeChile: El Proyecto de ley #Ingre...
# 8  RT @TeodoroRiberaN: A esta hora 450 ciudadanos...
# 9  RT @SSBiobio: En Laja, el director del @SSBiob...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ministeriosalud/status/125... 2020-04-20 21:05:57
# 1  https://twitter.com/ministeriosalud/status/125... 2020-04-20 21:00:00
# 2  https://twitter.com/ministeriosalud/status/125... 2020-04-20 20:56:17
# 3  https://twitter.com/ministeriosalud/status/125... 2020-04-20 20:56:13
# 4  https://twitter.com/ministeriosalud/status/125... 2020-04-20 20:35:40
# 5  https://twitter.com/ministeriosalud/status/125... 2020-04-20 20:00:01
# 6  https://twitter.com/ministeriosalud/status/125... 2020-04-20 19:44:00
# 7  https://twitter.com/ministeriosalud/status/125... 2020-04-20 19:34:46
# 8  https://twitter.com/ministeriosalud/status/125... 2020-04-20 19:30:11
# 9  https://twitter.com/ministeriosalud/status/125... 2020-04-20 19:25:33
#
#                  Source  Likes  RTs
# 0       Twitter Web App      0   11
# 1  Twitter Media Studio      8    9
# 2       Twitter Web App      0    4
# 3       Twitter Web App      0   11
# 4       Twitter Web App      0   14
# 5  Twitter Media Studio     18   18
# 6       Twitter Web App      0   26
# 7       Twitter Web App      0   36
# 8       Twitter Web App      0   70
# 9       Twitter Web App      0    9

# %%
import csv
data.to_csv(r'tweets_opsoms.csv', index = False)
