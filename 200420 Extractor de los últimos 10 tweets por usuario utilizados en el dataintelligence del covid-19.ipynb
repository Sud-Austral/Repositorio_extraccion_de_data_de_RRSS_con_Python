# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ministeriosalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# "Estamos sacando adelante a nuestro país (del #COVID_19), y así ha sido reconocido internacionalmente".
#
# - Ministro… https://t.co/DiNn65vcwd
#
# Ministro @jmanalich | Grupos de importancia vacunación
#
# - Embarazadas, en cualquier momento de la edad gestacional… https://t.co/2AAgDnUkXT
#
# Ministro @jmanalich | Vacunas Influenza
#
# "Después de un mes, tenemos que decir con mucho orgullo que el 84% de la p… https://t.co/kToLOnU9FC
#
# Ministro @jmanalich:
#
# "La decisión de corte de asistencia a clases se tomó consultando y con los argumentos sobre l… https://t.co/5oisJmKcwk
#
# Subsec @arturozunigaj | Red Asistencial #COVID_19
#
# ▪️ 6.365 exámenes realizados
# ▪️ 128.722 exámenes totales
# ▪️ Tasa… https://t.co/SBGr3zbuqt
#
# Subsec @arturozunigaj | Reporte diario #COVID_19
#
# ▪️ 464 casos nuevos
# ▪️ 11.296 casos totales
# ▪️ 5.386 recuperados… https://t.co/RZyLfEzNwN
#
# Subsec @arturozunigaj | Nuevo @FelixHfb
#
# "Ayer se trasladó el último paciente al nuevo H. Félix Bulnes y que es un… https://t.co/DEetdQ7VN7
#
# [AHORA] Autoridades de Salud entregan balance diario de #COVID_19 en nuestro país. https://t.co/2mWUzdU5hQ
#
# RT @MMAChile: En el #DíaDeLaTierra queremos recordar algunos de los Objetivos de Desarrollo Sostenible (#ODS) que nos permitirán cuidar nue…
#
# RT @OPSOMSMexico: COVID19: El distanciamiento físico no es aislamiento social #SanaDistancia
#
# #OnuMxCOVID19
# #SaludParaTodos https://t.co/…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  "Estamos sacando adelante a nuestro país (del ...
# 1  Ministro @jmanalich | Grupos de importancia va...
# 2  Ministro @jmanalich | Vacunas Influenza\n\n"De...
# 3  Ministro @jmanalich:\n\n"La decisión de corte ...
# 4  Subsec @arturozunigaj | Red Asistencial #COVID...
# 5  Subsec @arturozunigaj | Reporte diario #COVID_...
# 6  Subsec @arturozunigaj | Nuevo @FelixHfb \n\n"A...
# 7  [AHORA] Autoridades de Salud entregan balance ...
# 8  RT @MMAChile: En el #DíaDeLaTierra queremos re...
# 9  RT @OPSOMSMexico: COVID19: El distanciamiento ...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252982386523947008
# 2020-04-22 15:27:34
# Twitter Web App
# 13
# 6
# None
# None
# {'hashtags': [{'text': 'COVID_19', 'indices': [46, 55]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DiNn65vcwd', 'expanded_url': 'https://twitter.com/i/web/status/1252982386523947008', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  "Estamos sacando adelante a nuestro país (del ...  1252982386523947008
# 1  Ministro @jmanalich | Grupos de importancia va...  1252980957767860229
# 2  Ministro @jmanalich | Vacunas Influenza\n\n"De...  1252980550937149442
# 3  Ministro @jmanalich:\n\n"La decisión de corte ...  1252980242487971840
# 4  Subsec @arturozunigaj | Red Asistencial #COVID...  1252979095593336845
# 5  Subsec @arturozunigaj | Reporte diario #COVID_...  1252978807352393740
# 6  Subsec @arturozunigaj | Nuevo @FelixHfb \n\n"A...  1252977792771219456
# 7  [AHORA] Autoridades de Salud entregan balance ...  1252976882389102593
# 8  RT @MMAChile: En el #DíaDeLaTierra queremos re...  1252969494009409541
# 9  RT @OPSOMSMexico: COVID19: El distanciamiento ...  1252965570753921029
#
#                  Date           Source  Likes  RTs
# 0 2020-04-22 15:27:34  Twitter Web App     13    6
# 1 2020-04-22 15:21:54  Twitter Web App      4    6
# 2 2020-04-22 15:20:17  Twitter Web App     13   11
# 3 2020-04-22 15:19:03  Twitter Web App      5   13
# 4 2020-04-22 15:14:30  Twitter Web App     21   43
# 5 2020-04-22 15:13:21  Twitter Web App     51  133
# 6 2020-04-22 15:09:19  Twitter Web App     13   16
# 7 2020-04-22 15:05:42        Periscope     66  129
# 8 2020-04-22 14:36:21  Twitter Web App      0   85
# 9 2020-04-22 14:20:45  Twitter Web App      0   32

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  "Estamos sacando adelante a nuestro país (del ...
# 1  Ministro @jmanalich | Grupos de importancia va...
# 2  Ministro @jmanalich | Vacunas Influenza\n\n"De...
# 3  Ministro @jmanalich:\n\n"La decisión de corte ...
# 4  Subsec @arturozunigaj | Red Asistencial #COVID...
# 5  Subsec @arturozunigaj | Reporte diario #COVID_...
# 6  Subsec @arturozunigaj | Nuevo @FelixHfb \n\n"A...
# 7  [AHORA] Autoridades de Salud entregan balance ...
# 8  RT @MMAChile: En el #DíaDeLaTierra queremos re...
# 9  RT @OPSOMSMexico: COVID19: El distanciamiento ...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:27:34
# 1  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:21:54
# 2  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:20:17
# 3  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:19:03
# 4  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:14:30
# 5  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:13:21
# 6  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:09:19
# 7  https://twitter.com/ministeriosalud/status/125... 2020-04-22 15:05:42
# 8  https://twitter.com/ministeriosalud/status/125... 2020-04-22 14:36:21
# 9  https://twitter.com/ministeriosalud/status/125... 2020-04-22 14:20:45
#
#             Source  Likes  RTs
# 0  Twitter Web App     13    6
# 1  Twitter Web App      4    6
# 2  Twitter Web App     13   11
# 3  Twitter Web App      5   13
# 4  Twitter Web App     21   43
# 5  Twitter Web App     51  133
# 6  Twitter Web App     13   16
# 7        Periscope     66  129
# 8  Twitter Web App      0   85
# 9  Twitter Web App      0   32

# %%
import csv
data.to_csv(r'tweets_min_sal.csv', index = False)
