# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'opsoms'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Sesión informativa #COVID19 con @DirOPSPAHO completa aquí👇👇
# https://t.co/WdTNn6uNaT
#
# RT @OPASOMSBrasil: “Em 20/4, houve 893.119 casos confirmados de #COVID19 e 42.686 pessoas perderam a vida nas 🌎. A pandemia continua a impa…
#
# RT @OPASOMSBrasil: “Cada morte por #COVID19 representa uma vida interrompida, uma família de luto. Sou solidária às famílias atingidas nest…
#
# RT @OPASOMSBrasil: “Estamos lutando contra um inimigo invisível, não apenas porque o vírus não pode ser visto a olho nu, mas porque não tem…
#
# RT @OPASOMSBrasil: “Isso deve mudar. Precisamos de uma visão mais clara de onde o vírus está circulando e quantas pessoas foram infectadas…
#
# RT @OPASOMSBrasil: Primeiro, expandam a capacidade dos laboratórios 🔬. Os países são incentivados a ampliar os testes para #COVID19 usando…
#
# RT @OPASOMSBrasil: #COVID19: Nessas circunstâncias desafiadoras, o que recomendamos aos países das Américas?
#
# RT @OPASOMSBrasil: Segundo, priorizem de acordo com a disponibilidade. Quando existem limitações, precisamos priorizar os pacientes com sin…
#
# RT @OPASOMSBrasil: Terceiro, garanta o acesso a todos. Os testes devem ser gratuitos para os pacientes. Os altos preços criam uma barreira…
#
# RT @OPASOMSBrasil: “Até o momento, a OPAS forneceu mais de 500 mil testes de PCR para 34 países e territórios, e trabalhamos com outros paí…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Sesión informativa #COVID19 con @DirOPSPAHO co...
# 1  RT @OPASOMSBrasil: “Em 20/4, houve 893.119 cas...
# 2  RT @OPASOMSBrasil: “Cada morte por #COVID19 re...
# 3  RT @OPASOMSBrasil: “Estamos lutando contra um ...
# 4  RT @OPASOMSBrasil: “Isso deve mudar. Precisamo...
# 5  RT @OPASOMSBrasil: Primeiro, expandam a capaci...
# 6  RT @OPASOMSBrasil: #COVID19: Nessas circunstân...
# 7  RT @OPASOMSBrasil: Segundo, priorizem de acord...
# 8  RT @OPASOMSBrasil: Terceiro, garanta o acesso ...
# 9  RT @OPASOMSBrasil: “Até o momento, a OPAS forn...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252670985200951300
# 2020-04-21 18:50:11
# Twitter Web App
# 18
# 13
# None
# None
# {'hashtags': [{'text': 'COVID19', 'indices': [19, 27]}], 'symbols': [], 'user_mentions': [{'screen_name': 'DirOPSPAHO', 'name': 'Carissa Etienne', 'id': 606480640, 'id_str': '606480640', 'indices': [32, 43]}], 'urls': [{'url': 'https://t.co/WdTNn6uNaT', 'expanded_url': 'https://www.youtube.com/watch?v=IVJMV9xw7i0', 'display_url': 'youtube.com/watch?v=IVJMV9…', 'indices': [60, 83]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Sesión informativa #COVID19 con @DirOPSPAHO co...  1252670985200951300
# 1  RT @OPASOMSBrasil: “Em 20/4, houve 893.119 cas...  1252652403519885312
# 2  RT @OPASOMSBrasil: “Cada morte por #COVID19 re...  1252652392891498500
# 3  RT @OPASOMSBrasil: “Estamos lutando contra um ...  1252652380467933184
# 4  RT @OPASOMSBrasil: “Isso deve mudar. Precisamo...  1252652361375535110
# 5  RT @OPASOMSBrasil: Primeiro, expandam a capaci...  1252652352114511874
# 6  RT @OPASOMSBrasil: #COVID19: Nessas circunstân...  1252652332489355272
# 7  RT @OPASOMSBrasil: Segundo, priorizem de acord...  1252652299366789120
# 8  RT @OPASOMSBrasil: Terceiro, garanta o acesso ...  1252652290055471105
# 9  RT @OPASOMSBrasil: “Até o momento, a OPAS forn...  1252652283004964866
#
#                  Date              Source  Likes  RTs
# 0 2020-04-21 18:50:11     Twitter Web App     18   13
# 1 2020-04-21 17:36:20  Twitter for iPhone      0   10
# 2 2020-04-21 17:36:18  Twitter for iPhone      0    4
# 3 2020-04-21 17:36:15  Twitter for iPhone      0    4
# 4 2020-04-21 17:36:10  Twitter for iPhone      0    5
# 5 2020-04-21 17:36:08  Twitter for iPhone      0    3
# 6 2020-04-21 17:36:03  Twitter for iPhone      0    2
# 7 2020-04-21 17:35:55  Twitter for iPhone      0    3
# 8 2020-04-21 17:35:53  Twitter for iPhone      0    3
# 9 2020-04-21 17:35:52  Twitter for iPhone      0    3

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Sesión informativa #COVID19 con @DirOPSPAHO co...
# 1  RT @OPASOMSBrasil: “Em 20/4, houve 893.119 cas...
# 2  RT @OPASOMSBrasil: “Cada morte por #COVID19 re...
# 3  RT @OPASOMSBrasil: “Estamos lutando contra um ...
# 4  RT @OPASOMSBrasil: “Isso deve mudar. Precisamo...
# 5  RT @OPASOMSBrasil: Primeiro, expandam a capaci...
# 6  RT @OPASOMSBrasil: #COVID19: Nessas circunstân...
# 7  RT @OPASOMSBrasil: Segundo, priorizem de acord...
# 8  RT @OPASOMSBrasil: Terceiro, garanta o acesso ...
# 9  RT @OPASOMSBrasil: “Até o momento, a OPAS forn...
#
#                                                   ID                Date  \
# 0  https://twitter.com/opsoms/status/125267098520... 2020-04-21 18:50:11
# 1  https://twitter.com/opsoms/status/125265240351... 2020-04-21 17:36:20
# 2  https://twitter.com/opsoms/status/125265239289... 2020-04-21 17:36:18
# 3  https://twitter.com/opsoms/status/125265238046... 2020-04-21 17:36:15
# 4  https://twitter.com/opsoms/status/125265236137... 2020-04-21 17:36:10
# 5  https://twitter.com/opsoms/status/125265235211... 2020-04-21 17:36:08
# 6  https://twitter.com/opsoms/status/125265233248... 2020-04-21 17:36:03
# 7  https://twitter.com/opsoms/status/125265229936... 2020-04-21 17:35:55
# 8  https://twitter.com/opsoms/status/125265229005... 2020-04-21 17:35:53
# 9  https://twitter.com/opsoms/status/125265228300... 2020-04-21 17:35:52
#
#                Source  Likes  RTs
# 0     Twitter Web App     18   13
# 1  Twitter for iPhone      0   10
# 2  Twitter for iPhone      0    4
# 3  Twitter for iPhone      0    4
# 4  Twitter for iPhone      0    5
# 5  Twitter for iPhone      0    3
# 6  Twitter for iPhone      0    2
# 7  Twitter for iPhone      0    3
# 8  Twitter for iPhone      0    3
# 9  Twitter for iPhone      0    3

# %%
import csv
data.to_csv(r'tweets_opsoms.csv', index = False)
