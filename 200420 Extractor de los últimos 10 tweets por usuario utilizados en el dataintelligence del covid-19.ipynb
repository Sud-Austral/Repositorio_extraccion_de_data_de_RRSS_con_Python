# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'SuperDeSalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Al salir de tu casa siempre mantén, como mínimo, un metro de distancia con los demás:
# 🚶‍♂️|----1mt-----|🚶‍♀️ |----1… https://t.co/U8jpIgA3vu
#
# RT @ministeriosalud: Salud dio a conocer el primer nacimiento del nuevo Hospital @FelixHfb https://t.co/44KYcvLtRh #PlanCoronavirus
#
# Con éxito se realizó la primera devolución de excedentes en efectivo, que instruyó la @SuperDeSalud a las Isapres.… https://t.co/FkU3eynJAl
#
# RT @ministeriosalud: Mañana jueves 23, a las 22:00 horas termina la cuarentena total en Chillán y Chillán Viejo, pero ¿sabes qué comunas se…
#
# @silvitamatrona Hola, buenas tardes.
# Le dejamos un mensaje directo.
#
# @kikavial @IsapreColmena Hola Francisca, si deseas ingresar un reclamo en contra de tu Isapre, puedes hacerlo en nu… https://t.co/6Yo2Uz20NJ
#
# En simples pasos puedes convertir un pañuelo en una mascarilla para protegerte y proteger al resto... no hay excusa… https://t.co/GyKPng50cP
#
# RT @MTTChile: #PlanCoronavirus ✈️Si necesitas viajar en avión dentro de Chile, deberás solicitar tu #PasaporteSanitario en https://t.co/68U…
#
# @rcovarru Hola Renato, buenas tardes! Te dejamos un mensaje directo.
#
# RT @MMAChile: En el #DíaDeLaTierra queremos recordar algunos de los Objetivos de Desarrollo Sostenible (#ODS) que nos permitirán cuidar nue…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Al salir de tu casa siempre mantén, como mínim...
# 1  RT @ministeriosalud: Salud dio a conocer el pr...
# 2  Con éxito se realizó la primera devolución de ...
# 3  RT @ministeriosalud: Mañana jueves 23, a las 2...
# 4  @silvitamatrona Hola, buenas tardes. \nLe deja...
# 5  @kikavial @IsapreColmena Hola Francisca, si de...
# 6  En simples pasos puedes convertir un pañuelo e...
# 7  RT @MTTChile: #PlanCoronavirus ✈️Si necesitas ...
# 8  @rcovarru Hola Renato, buenas tardes! Te dejam...
# 9  RT @MMAChile: En el #DíaDeLaTierra queremos re...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1253050173351215105
# 2020-04-22 19:56:56
# Twitter Web App
# 3
# 1
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/U8jpIgA3vu', 'expanded_url': 'https://twitter.com/i/web/status/1253050173351215105', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Al salir de tu casa siempre mantén, como mínim...  1253050173351215105
# 1  RT @ministeriosalud: Salud dio a conocer el pr...  1253037357240143872
# 2  Con éxito se realizó la primera devolución de ...  1253030481140035585
# 3  RT @ministeriosalud: Mañana jueves 23, a las 2...  1253024180527927300
# 4  @silvitamatrona Hola, buenas tardes. \nLe deja...  1253013868684722176
# 5  @kikavial @IsapreColmena Hola Francisca, si de...  1253011575524347905
# 6  En simples pasos puedes convertir un pañuelo e...  1253009137144823810
# 7  RT @MTTChile: #PlanCoronavirus ✈️Si necesitas ...  1253005431942844416
# 8  @rcovarru Hola Renato, buenas tardes! Te dejam...  1253002966308720640
# 9  RT @MMAChile: En el #DíaDeLaTierra queremos re...  1253001975790292995
#
#                  Date           Source  Likes  RTs
# 0 2020-04-22 19:56:56  Twitter Web App      3    1
# 1 2020-04-22 19:06:00  Twitter Web App      0    9
# 2 2020-04-22 18:38:41  Twitter Web App     22    9
# 3 2020-04-22 18:13:39  Twitter Web App      0   16
# 4 2020-04-22 17:32:40  Twitter Web App      0    0
# 5 2020-04-22 17:23:34  Twitter Web App      0    0
# 6 2020-04-22 17:13:52  Twitter Web App      0    0
# 7 2020-04-22 16:59:09  Twitter Web App      0   56
# 8 2020-04-22 16:49:21  Twitter Web App      1    0
# 9 2020-04-22 16:45:25  Twitter Web App      0  191

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Al salir de tu casa siempre mantén, como mínim...
# 1  RT @ministeriosalud: Salud dio a conocer el pr...
# 2  Con éxito se realizó la primera devolución de ...
# 3  RT @ministeriosalud: Mañana jueves 23, a las 2...
# 4  @silvitamatrona Hola, buenas tardes. \nLe deja...
# 5  @kikavial @IsapreColmena Hola Francisca, si de...
# 6  En simples pasos puedes convertir un pañuelo e...
# 7  RT @MTTChile: #PlanCoronavirus ✈️Si necesitas ...
# 8  @rcovarru Hola Renato, buenas tardes! Te dejam...
# 9  RT @MMAChile: En el #DíaDeLaTierra queremos re...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125305... 2020-04-22 19:56:56
# 1  https://twitter.com/SuperDeSalud/status/125303... 2020-04-22 19:06:00
# 2  https://twitter.com/SuperDeSalud/status/125303... 2020-04-22 18:38:41
# 3  https://twitter.com/SuperDeSalud/status/125302... 2020-04-22 18:13:39
# 4  https://twitter.com/SuperDeSalud/status/125301... 2020-04-22 17:32:40
# 5  https://twitter.com/SuperDeSalud/status/125301... 2020-04-22 17:23:34
# 6  https://twitter.com/SuperDeSalud/status/125300... 2020-04-22 17:13:52
# 7  https://twitter.com/SuperDeSalud/status/125300... 2020-04-22 16:59:09
# 8  https://twitter.com/SuperDeSalud/status/125300... 2020-04-22 16:49:21
# 9  https://twitter.com/SuperDeSalud/status/125300... 2020-04-22 16:45:25
#
#             Source  Likes  RTs
# 0  Twitter Web App      3    1
# 1  Twitter Web App      0    9
# 2  Twitter Web App     22    9
# 3  Twitter Web App      0   16
# 4  Twitter Web App      0    0
# 5  Twitter Web App      0    0
# 6  Twitter Web App      0    0
# 7  Twitter Web App      0   56
# 8  Twitter Web App      1    0
# 9  Twitter Web App      0  191

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
