# %% [markdown]
# # 140420 Tweets en tiempo real por usuario

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-11
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
# https://twitter.com/colmedchile/status/1249754648476516352
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing
import time
# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import csv
# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

def twi(num):

    if (num < 10):
    
        t=10
        time.sleep(t)
        def twitter_setup():

            auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
            auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

            api = tweepy.API(auth)
            return api

        prompt = '> '
        tweet=''

        usuario_de_consulta = 'realDonaldTrump' 

        extractor = twitter_setup()

        tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
        print("Number of tweets extracted: {}.\n".format(len(tweets)))

        print("10 recent tweets:\n")
        for tweet in tweets[:10]:
            print(tweet.text)
            print()

        data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

        display(data.head(10))

        data['ID'] = np.array([tweet.id for tweet in tweets])
        data['Date'] = np.array([tweet.created_at for tweet in tweets])
        data['Source'] = np.array([tweet.source for tweet in tweets])
        data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
        data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

        display(data.head(10))

        elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
        data['ID'] = elstringid + data['ID'].astype(str)
        display(data)
        
        
        return

twi(1)

#data.to_csv(r'wrrrr.csv', index = False)
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @WhiteHouse: President @realDonaldTrump is halting funding of the World Health Organization while a review is conducted to assess WHO's…
#
# https://t.co/KRxBA0OjpX
#
# White House news conference today at 5:45 P.M. Eastern. Thank you!
#
# My Administration is committed to protecting the Homeland from the scourge of narco-terrorists and traffickers seek… https://t.co/cnAPqQk19I
#
# Tell the Democrat Governors that “Mutiny On The Bounty” was one of my all time favorite movies. A good old fashione… https://t.co/AkL2j7upwF
#
# GET RID OF BALLOT HARVESTING, IT IS RAMPANT WITH FRAUD. THE USA MUST HAVE VOTER I.D., THE ONLY WAY TO GET AN HONEST COUNT!
#
# Cuomo’s been calling daily, even hourly, begging for everything, most of which should have been the state’s respons… https://t.co/eel2Fl1w2V
#
# The Democrats don’t want to approve more money for our great workers under the incredibly successful “Paycheck” plan. Replenish Account Now!
#
# https://t.co/DRVhpMCuAx
#
# https://t.co/ImJ7W5MACi
#                                               Tweets
# 0  RT @WhiteHouse: President @realDonaldTrump is ...
# 1                            https://t.co/KRxBA0OjpX
# 2  White House news conference today at 5:45 P.M....
# 3  My Administration is committed to protecting t...
# 4  Tell the Democrat Governors that “Mutiny On Th...
# 5  GET RID OF BALLOT HARVESTING, IT IS RAMPANT WI...
# 6  Cuomo’s been calling daily, even hourly, beggi...
# 7  The Democrats don’t want to approve more money...
# 8                            https://t.co/DRVhpMCuAx
# 9                            https://t.co/ImJ7W5MACi
#                                               Tweets                   ID  \
# 0  RT @WhiteHouse: President @realDonaldTrump is ...  1250203509296959488
# 1                            https://t.co/KRxBA0OjpX  1250203462555570176
# 2  White House news conference today at 5:45 P.M....  1250172326920040449
# 3  My Administration is committed to protecting t...  1250088893766078470
# 4  Tell the Democrat Governors that “Mutiny On Th...  1250075668282576898
# 5  GET RID OF BALLOT HARVESTING, IT IS RAMPANT WI...  1250067500190089217
# 6  Cuomo’s been calling daily, even hourly, beggi...  1250063051182747651
# 7  The Democrats don’t want to approve more money...  1250056263746162688
# 8                            https://t.co/DRVhpMCuAx  1249888406127153155
# 9                            https://t.co/ImJ7W5MACi  1249886901320011786
#
#                  Date                Source   Likes    RTs
# 0 2020-04-14 23:25:18    Twitter for iPhone       0   6057
# 1 2020-04-14 23:25:07    Twitter for iPhone   15035   3757
# 2 2020-04-14 21:21:24    Twitter for iPhone   60780  11032
# 3 2020-04-14 15:49:52    Twitter for iPhone   84471  24715
# 4 2020-04-14 14:57:19    Twitter for iPhone  120375  30632
# 5 2020-04-14 14:24:51    Twitter for iPhone  203516  51840
# 6 2020-04-14 14:07:11    Twitter for iPhone  144070  30078
# 7 2020-04-14 13:40:12    Twitter for iPhone  106383  26686
# 8 2020-04-14 02:33:12  Twitter Media Studio   72698  21520
# 9 2020-04-14 02:27:13  Twitter Media Studio   64419  18531
#                                               Tweets  \
# 0  RT @WhiteHouse: President @realDonaldTrump is ...
# 1                            https://t.co/KRxBA0OjpX
# 2  White House news conference today at 5:45 P.M....
# 3  My Administration is committed to protecting t...
# 4  Tell the Democrat Governors that “Mutiny On Th...
# 5  GET RID OF BALLOT HARVESTING, IT IS RAMPANT WI...
# 6  Cuomo’s been calling daily, even hourly, beggi...
# 7  The Democrats don’t want to approve more money...
# 8                            https://t.co/DRVhpMCuAx
# 9                            https://t.co/ImJ7W5MACi
#
#                                                   ID                Date  \
# 0  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 23:25:18
# 1  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 23:25:07
# 2  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 21:21:24
# 3  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 15:49:52
# 4  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 14:57:19
# 5  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 14:24:51
# 6  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 14:07:11
# 7  https://twitter.com/realDonaldTrump/status/125... 2020-04-14 13:40:12
# 8  https://twitter.com/realDonaldTrump/status/124... 2020-04-14 02:33:12
# 9  https://twitter.com/realDonaldTrump/status/124... 2020-04-14 02:27:13
#
#                  Source   Likes    RTs
# 0    Twitter for iPhone       0   6057
# 1    Twitter for iPhone   15035   3757
# 2    Twitter for iPhone   60780  11032
# 3    Twitter for iPhone   84471  24715
# 4    Twitter for iPhone  120375  30632
# 5    Twitter for iPhone  203516  51840
# 6    Twitter for iPhone  144070  30078
# 7    Twitter for iPhone  106383  26686
# 8  Twitter Media Studio   72698  21520
# 9  Twitter Media Studio   64419  18531
