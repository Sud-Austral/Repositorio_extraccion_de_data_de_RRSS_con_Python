# %% [markdown]
# # 110420 2 Tweets en tiempo real por usuario
#
# base excelente!

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-11
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1 tweets_who.csv
# tweets_colegio_medico.csv
# tweets_min_sal.csv
# tweets_sochimu.csv
#
# tweets_who.csv
# tweets_colegio_medico.csv
# tweets_min_sal.csv
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_who.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
#
# sochimu
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/reversed_tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/reversed_twitter_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/reversed_twitter_who.csv
# https:/

# %%
# Importamos las librerías necesarias:

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import re
import time

# Declaramos nuestras Twitter API Keys:
access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_token_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
consumer_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)
#api = tweepy.API(auth)

# Se debe utilizar apscheduler
# https://medium.com/better-programming/introduction-to-apscheduler-86337f3bb4a6
'''Advanced Python Scheduler (APScheduler) es una biblioteca de Python que te permite programar 
tu código de Python para que se ejecute más tarde, ya sea solo una vez o periódicamente. 
Puede agregar nuevos trabajos o eliminar los antiguos sobre la marcha, según lo desees. 
Si almacena sus trabajos en una base de datos, también sobrevivirán a los reinicios del planificador 
y mantendrán su estado. Cuando se reinicia el planificador, ejecutará todos los trabajos que debería 
haber ejecutado mientras estaba desconectado'''

#from apscheduler.schedulers.background import BackgroundScheduler

# Inicializamos la variable global: 
tweet_count = 0

# Ingresamos el número de tweets a ser descargados:
n_tweets = 10

# Crea la clase que manejará el stream de tweets:
class StdOutListener(StreamListener):
    
    #sched = BackgroundScheduler(daemon=True)
    #sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
    #sched.start()
    #sched.shutdown()

    def on_data(self, data):
            
            global tweet_count
            global n_tweets
            global stream
            if tweet_count < n_tweets:
            
            # Imprimimos en pantalla los tweets descargados:
                print(data)
                tweet_count += 1
            
            # Guardar el archivo data como txt:
            # el parámetro 'a' permite ir escribiendo debajo de lo ya existente en el txt:
            # https://www.geeksforgeeks.org/reading-writing-text-files-python/
                write_on_txt=open("twitter7.txt",'a')
                write_on_txt.write(data)
                write_on_txt.close()  

                return True
        
            else:
                stream.disconnect()
      
    def on_error(self, status):
        print(status)

# Manejamos la autenticación de Twitter y la conexión a la API de Streaming de Twitter:
l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)

# Integramos un flitro para que busque un usuario, en éste caso de la WHO:
# id del colegio_medico: 633098103
# id del usuario: Ministerio de salud: 153825949
# id del usuario: SOCHIMU medicina de urgencia: 2882584795
# id del usuario: WHO: 14499829
# id de Christian Castro: 1230251564616515586
usuario = ['633098103']
stream.filter(follow=usuario)
# Out:
# {"created_at":"Sun Apr 12 17:10:32 +0000 2020","id":1249384417040220160,"id_str":"1249384417040220160","text":"RT @colmedchile: \u00a1Atenci\u00f3n! Recuerda completar nuestro catastro de Elementos para Protecci\u00f3n Personal, ya que se va actualizando semana a s\u2026","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":129290464,"id_str":"129290464","name":"Valentina","screen_name":"Srta_Nauru","location":"Nauru","url":null,"description":"mujer sobrante","translator_type":"none","protected":false,"verified":false,"followers_count":1567,"friends_count":1107,"listed_count":20,"favourites_count":27544,"statuses_count":91934,"created_at":"Sat Apr 03 20:25:13 +0000 2010","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"1F76B8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme11\/bg.gif","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme11\/bg.gif","profile_background_tile":true,"profile_link_color":"F5ABB5","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"F2EDF2","profile_text_color":"FC780D","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1094734098726297602\/QSlr9OMX_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1094734098726297602\/QSlr9OMX_normal.jpg","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Sun Apr 12 16:20:21 +0000 2020","id":1249371788049596416,"id_str":"1249371788049596416","text":"\u00a1Atenci\u00f3n! Recuerda completar nuestro catastro de Elementos para Protecci\u00f3n Personal, ya que se va actualizando sem\u2026 https:\/\/t.co\/gimpLx2JnP","display_text_range":[0,140],"source":"\u003ca href=\"https:\/\/www.socialgest.net\" rel=\"nofollow\"\u003eSocialGest\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":633098103,"id_str":"633098103","name":"Colmed Chile","screen_name":"colmedchile","location":"Chile","url":"http:\/\/www.colegiomedico.cl","description":"Cuenta Oficial del Colegio M\u00e9dico de Chile \ud83d\udcccFacebook: Colegio M\u00e9dico de Chile \ud83d\udcccInstagram: @colmed_chile #colmed #colmedchile","translator_type":"none","protected":false,"verified":false,"followers_count":76275,"friends_count":1858,"listed_count":115,"favourites_count":6923,"statuses_count":17144,"created_at":"Wed Jul 11 16:14:38 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0000CC","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1245851467891736576\/TayMmMjI_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1245851467891736576\/TayMmMjI_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/633098103\/1584977450","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null ...

# %%
import json
import pandas as pd
tweets_data_path = "twitter7.txt"  


tweets_data = []  
tweets_file = open(tweets_data_path, "r")  
for line in tweets_file:  
    try:  
        tweet = json.loads(line)  
        tweets_data.append(tweet)  
    except:  
        continue
        
tweets = pd.DataFrame()

tweets['Texto del tweet'] = list(map(lambda tweet: tweet['text'], tweets_data))
tweets['Usuario'] = list(map(lambda tweet: tweet['user']['screen_name'], tweets_data))
tweets['Fecha'] = list(map(lambda tweet: tweet['created_at'], tweets_data))

#url = f"https://twitter.com/user/status/{tweet.id}"

#tweets['id'] = list(map(lambda tweet: tweet['id'], tweets_data))

# https://twitter.com/christi75367675/status/
    
tweets['id'] = list(map(lambda tweet: 'https://twitter.com/colmedchile/status/'+tweet['id_str'], tweets_data))

tweets
# Out:
#                                      Texto del tweet          Usuario  \
# 0  RT @UN: Now is the time for unity, for the int...          ManuCRC
# 1  @WHO @WHOThailand @WHOSEARO @WHOWPRO .@RepAdam...    ElenaFelicia4
# 2  @WHO @WHO_Europe @WHOEMRO @WHOAFRO @WHOSEARO @...          DPerz23
# 3                                               @WHO  kanasimidoukoku
# 4  RT @WHO: Preliminary investigations conducted ...  leduardoserrano
# 5  RT @UN: Now is the time for unity, for the int...   emocionycambio
# 6  RT @WHO: Praise is powerful.\n\nTry praising y...     YenL45676561
# 7  RT @WHO: Praise is powerful.\n\nTry praising y...     juliecookies
# 8  RT @WHO: Catch bad behaviour early and redirec...     juliecookies
# 9  RT @WHO: Exercise helps kids with a lot of ene...     juliecookies
#
#                             Fecha  \
# 0  Sun Apr 12 16:55:48 +0000 2020
# 1  Sun Apr 12 16:55:59 +0000 2020
# 2  Sun Apr 12 16:56:08 +0000 2020
# 3  Sun Apr 12 16:56:18 +0000 2020
# 4  Sun Apr 12 16:56:19 +0000 2020
# 5  Sun Apr 12 16:56:24 +0000 2020
# 6  Sun Apr 12 16:56:42 +0000 2020
# 7  Sun Apr 12 16:56:47 +0000 2020
# 8  Sun Apr 12 16:56:56 +0000 2020
# 9  Sun Apr 12 16:57:00 +0000 2020
#
#                                                   id
# 0  https://twitter.com/who/status/124938071226179...
# 1  https://twitter.com/who/status/124938075743012...
# 2  https://twitter.com/who/status/124938079422670...
# 3  https://twitter.com/who/status/124938083830890...
# 4  https://twitter.com/who/status/124938084088855...
# 5  https://twitter.com/who/status/124938086058923...
# 6  https://twitter.com/who/status/124938093681628...
# 7  https://twitter.com/who/status/124938095853437...
# 8  https://twitter.com/who/status/124938099773016...
# 9  https://twitter.com/who/status/124938101232218...

# %%
reversed_tweets = tweets.iloc[::-1]
reversed_tweets
# Out:
#                                      Texto del tweet          Usuario  \
# 9  RT @WHO: Exercise helps kids with a lot of ene...     juliecookies
# 8  RT @WHO: Catch bad behaviour early and redirec...     juliecookies
# 7  RT @WHO: Praise is powerful.\n\nTry praising y...     juliecookies
# 6  RT @WHO: Praise is powerful.\n\nTry praising y...     YenL45676561
# 5  RT @UN: Now is the time for unity, for the int...   emocionycambio
# 4  RT @WHO: Preliminary investigations conducted ...  leduardoserrano
# 3                                               @WHO  kanasimidoukoku
# 2  @WHO @WHO_Europe @WHOEMRO @WHOAFRO @WHOSEARO @...          DPerz23
# 1  @WHO @WHOThailand @WHOSEARO @WHOWPRO .@RepAdam...    ElenaFelicia4
# 0  RT @UN: Now is the time for unity, for the int...          ManuCRC
#
#                             Fecha  \
# 9  Sun Apr 12 16:57:00 +0000 2020
# 8  Sun Apr 12 16:56:56 +0000 2020
# 7  Sun Apr 12 16:56:47 +0000 2020
# 6  Sun Apr 12 16:56:42 +0000 2020
# 5  Sun Apr 12 16:56:24 +0000 2020
# 4  Sun Apr 12 16:56:19 +0000 2020
# 3  Sun Apr 12 16:56:18 +0000 2020
# 2  Sun Apr 12 16:56:08 +0000 2020
# 1  Sun Apr 12 16:55:59 +0000 2020
# 0  Sun Apr 12 16:55:48 +0000 2020
#
#                                                   id
# 9  https://twitter.com/who/status/124938101232218...
# 8  https://twitter.com/who/status/124938099773016...
# 7  https://twitter.com/who/status/124938095853437...
# 6  https://twitter.com/who/status/124938093681628...
# 5  https://twitter.com/who/status/124938086058923...
# 4  https://twitter.com/who/status/124938084088855...
# 3  https://twitter.com/who/status/124938083830890...
# 2  https://twitter.com/who/status/124938079422670...
# 1  https://twitter.com/who/status/124938075743012...
# 0  https://twitter.com/who/status/124938071226179...

# %%
import csv
#reversed_tweets.to_excel('reversed_tweets.csv', sheet_name='primera')
tweets.to_csv(r'tweets_colegio_medico.csv', index = False)

# %% [markdown]
# #### Ahora se debe borrar el contenido del txt:
