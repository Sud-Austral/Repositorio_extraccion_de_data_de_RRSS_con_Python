# %% [markdown]
# # 080420 Extracción en tiempo real de tweets por usuario V
# https://medium.com/@jaimezornoza/downloading-data-from-twitter-using-the-streaming-api-3ac6766ba96c

# %%
#%load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-09
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %%
# Importamos las librerías necesarias:

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import re
import time

# Declaramos nuestras Twitter API Keys:
access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_token_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
consumer_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'


#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)
#api = tweepy.API(auth)

# Se debe utilizar apscheduler
# https://medium.com/better-programming/introduction-to-apscheduler-86337f3bb4a6
'''Advanced Python Scheduler (APScheduler) es una biblioteca de Python que te permite programar 
tu código de Python para que se ejecute más tarde, ya sea solo una vez o periódicamente. 
Puede agregar nuevos trabajos o eliminar los antiguos sobre la marcha, según lo desees. 
Si almacena sus trabajos en una base de datos, también sobrevivirán a los reinicios del planificador 
y mantendrán su estado. Cuando se reinicia el planificador, ejecutará todos los trabajos que debería 
haber ejecutado mientras estaba desconectado'''

#from apscheduler.schedulers.background import BackgroundScheduler


# Inicializamos la variable global: 
tweet_count = 0

# Ingresamos el número de tweets a ser descargados:
n_tweets = 10



# Crea la clase que manejará el stream de tweets:
class StdOutListener(StreamListener):
    
    
    #sched = BackgroundScheduler(daemon=True)
    #sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
    #sched.start()
    #sched.shutdown()
    
    
    def on_data(self, data):
        global tweet_count
        global n_tweets
        global stream
        if tweet_count < n_tweets:
            
            # Imprimimos en pantalla los tweets descargados:
            print(data)
            tweet_count += 1
            
            # Guardar el archivo data como txt:
            # el parámetro 'a' permite ir escribiendo debajo de lo ya existente en el txt:
            # https://www.geeksforgeeks.org/reading-writing-text-files-python/
            write_on_txt=open("twitter_data.txt",'a')
            write_on_txt.write(data)
            write_on_txt.close()  

            return True
        
        else:
            stream.disconnect()
      
    def on_error(self, status):
        print(status)

# Manejamos la autenticación de Twitter y la conexión a la API de Streaming de Twitter:
l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)

# Integramos un flitro para que busque un usuario, en éste caso de la WHO:
# id del usuario: WHO: 14499829
usuario = ['14499829']
stream.filter(follow=usuario)
# Out:
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:21 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# {"created_at":"Thu Apr 09 19:29:14 +0000 2020","id":1248332161998094341,"id_str":"1248332161998094341","text":"RT @WHO: Grab your book and watch @HowardDonald reading \u201cMy Hero is You, How kids can fight #COVID19!\u201d\n\n\ud83d\udcda https:\/\/t.co\/L23wN2LZwB\n\n#coronav\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":432993640,"id_str":"432993640","name":"AJ Ashwaq, PhD","screen_name":"AshShosho","location":"Liverpool,UK Jeddah,KSA","url":"https:\/\/www.isntd.org\/dengue-advisory-group","description":"Employee @SaudiMOH,PhD @LSTMnews #Puplic_Health #vector_control #Dengue #Zika #Insecticde #resistance. Member @Dengue Advisory Group @ISNTD #CSR #TOT","translator_type":"none","protected":false,"verified":false,"followers_count":739,"friends_count":1994,"listed_count":5,"favourites_count":2108,"statuses_count":5014,"created_at":"Sat Dec 10 01:06:13 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1245985781035831296\/x-kENv26_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1245985781035831296\/x-kENv26_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/432993640\/1585901135","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Apr 09 17:22:21 +0000 2020","id":1248300228542939138,"id_str":"1248300228542939138","text":"Grab your book and watch @HowardDonald reading \u201cMy Hero is You, How kids can fight #COVID19!\u201d\n\n\ud83d\udcda\u2026 https:\/\/t.co\/PEPQ7NjmCF","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":1248293362135957505,"in_reply_to_status_id_str":"1248293362135957505","in_reply_to_user_id":14499829,"in_reply_to_user_id_str":"14499829","in_reply_to_screen_name":"WHO","user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7234264,"friends_count":1716,"listed_count":31679,"favourites_count":10599,"statuses_count":49783,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0396DB","profile_sidebar_border_color":"8C8C8C","profile_sidebar_fill_color":"D9D9D9","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.co ...
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:24 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:25 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:25 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:26 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:29 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:30 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:30 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:31 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:34 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:35 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:35 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:36 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# {"created_at":"Thu Apr 09 19:29:28 +0000 2020","id":1248332220030386176,"id_str":"1248332220030386176","text":"RT @WHO: Media briefing on #COVID19 with @DrTedros. #coronavirus https:\/\/t.co\/ZKy3OjKgBl","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":213400899,"id_str":"213400899","name":"American Observatory \ud83c\uddfa\ud83c\uddf8","screen_name":"AmericanObserva","location":"USA \ud83c\udf10 World Wide  ","url":"http:\/\/americanobservatory.blogspot.com?m=1","description":"@WHO \ud83d\ude37 American Observatory of Human Rights INGO NY \ud83c\uddfa\ud83c\uddf8 #Worldwide Humanitarian Mission in Defense of Human Rights \ud83c\uddfa\ud83c\uddf8 President  @ChMutuverria","translator_type":"none","protected":false,"verified":false,"followers_count":875,"friends_count":3239,"listed_count":87,"favourites_count":7644,"statuses_count":20812,"created_at":"Mon Nov 08 20:48:04 +0000 2010","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"0051B3","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1030948252865241090\/eXDCUXxz_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1030948252865241090\/eXDCUXxz_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/213400899\/1584995550","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Apr 08 15:43:35 +0000 2020","id":1247912987257491457,"id_str":"1247912987257491457","text":"Media briefing on #COVID19 with @DrTedros. #coronavirus https:\/\/t.co\/ZKy3OjKgBl","source":"\u003ca href=\"https:\/\/periscope.tv\" rel=\"nofollow\"\u003ePeriscope\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7234263,"friends_count":1716,"listed_count":31679,"favourites_count":10599,"statuses_count":49783,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0396DB","profile_sidebar_border_color":"8C8C8C","profile_sidebar_fill_color":"D9D9D9","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profi ...
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:39 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:40 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:40 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:41 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# {"created_at":"Thu Apr 09 19:29:34 +0000 2020","id":1248332245728927746,"id_str":"1248332245728927746","text":"RT @WHO: Kids, meet Ario - a kind, orange dragon with a horn like a unicorn, who will introduce you to #COVID19 and help you understand how\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1171565161536204800,"id_str":"1171565161536204800","name":"Joni_W5","screen_name":"joni_w5","location":"Massachusetts, USA","url":null,"description":"Retired from hospital lab, loving my family & friends, adoring my canines ... doodle & long haired chihuahua\u2764\ufe0f No DMs please","translator_type":"none","protected":false,"verified":false,"followers_count":464,"friends_count":1949,"listed_count":0,"favourites_count":43413,"statuses_count":3371,"created_at":"Tue Sep 10 23:25:02 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1179994472056344577\/lgCHhC3J_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1179994472056344577\/lgCHhC3J_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1171565161536204800\/1578126610","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Apr 08 22:48:26 +0000 2020","id":1248019902759186432,"id_str":"1248019902759186432","text":"Kids, meet Ario - a kind, orange dragon with a horn like a unicorn, who will introduce you to #COVID19 and help you\u2026 https:\/\/t.co\/54TmtZnNvy","display_text_range":[0,140],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7234268,"friends_count":1716,"listed_count":31679,"favourites_count":10599,"statuses_count":49783,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0396DB","profile_sidebar_border_color":"8C8C8C","profile_sidebar_fill_color":"D9D9D9","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/14499829\/1582794472","default_profile":false,"default_profile_image":fa ...
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:44 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:45 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:45 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# {"created_at":"Thu Apr 09 19:29:37 +0000 2020","id":1248332258324480000,"id_str":"1248332258324480000","text":"RT @WHO: Grab your book and watch @HowardDonald reading \u201cMy Hero is You, How kids can fight #COVID19!\u201d\n\n\ud83d\udcda https:\/\/t.co\/L23wN2LZwB\n\n#coronav\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":213400899,"id_str":"213400899","name":"American Observatory \ud83c\uddfa\ud83c\uddf8","screen_name":"AmericanObserva","location":"USA \ud83c\udf10 World Wide  ","url":"http:\/\/americanobservatory.blogspot.com?m=1","description":"@WHO \ud83d\ude37 American Observatory of Human Rights INGO NY \ud83c\uddfa\ud83c\uddf8 #Worldwide Humanitarian Mission in Defense of Human Rights \ud83c\uddfa\ud83c\uddf8 President  @ChMutuverria","translator_type":"none","protected":false,"verified":false,"followers_count":875,"friends_count":3239,"listed_count":87,"favourites_count":7644,"statuses_count":20813,"created_at":"Mon Nov 08 20:48:04 +0000 2010","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"0051B3","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1030948252865241090\/eXDCUXxz_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1030948252865241090\/eXDCUXxz_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/213400899\/1584995550","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Apr 09 17:22:21 +0000 2020","id":1248300228542939138,"id_str":"1248300228542939138","text":"Grab your book and watch @HowardDonald reading \u201cMy Hero is You, How kids can fight #COVID19!\u201d\n\n\ud83d\udcda\u2026 https:\/\/t.co\/PEPQ7NjmCF","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":1248293362135957505,"in_reply_to_status_id_str":"1248293362135957505","in_reply_to_user_id":14499829,"in_reply_to_user_id_str":"14499829","in_reply_to_screen_name":"WHO","user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7234270,"friends_count":1716,"listed_count":31679,"favourites_count":10599,"statuses_count":49783,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0396DB","profile_sidebar_border_color":"8C8C8C","profile_sidebar_fill_color":"D9D9D9","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_imag ...
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:46 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# {"created_at":"Thu Apr 09 19:29:38 +0000 2020","id":1248332261532921858,"id_str":"1248332261532921858","text":"@WHO @DrTedros I wouldn't sign anything with the WHO.  What consideration are you offering up?  Corrupt medicine mu\u2026 https:\/\/t.co\/ihdiV40rS6","display_text_range":[15,140],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":1247920386139881472,"in_reply_to_status_id_str":"1247920386139881472","in_reply_to_user_id":14499829,"in_reply_to_user_id_str":"14499829","in_reply_to_screen_name":"WHO","user":{"id":4847999295,"id_str":"4847999295","name":"HealthcareInsurance","screen_name":"HealthcareUS411","location":null,"url":null,"description":"God wants you to trust Him, but Satan wants you to panic.","translator_type":"none","protected":false,"verified":false,"followers_count":4,"friends_count":129,"listed_count":0,"favourites_count":420,"statuses_count":421,"created_at":"Tue Jan 26 03:33:50 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1241437741889413122\/cfnD_b8t_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1241437741889413122\/cfnD_b8t_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/4847999295\/1584762369","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"@WHO @DrTedros I wouldn't sign anything with the WHO.  What consideration are you offering up?  Corrupt medicine must end!  The @WHO is corrupt.  #FireTedros","display_text_range":[15,157],"entities":{"hashtags":[{"text":"FireTedros","indices":[146,157]}],"urls":[],"user_mentions":[{"screen_name":"WHO","name":"World Health Organization (WHO)","id":14499829,"id_str":"14499829","indices":[0,4]},{"screen_name":"DrTedros","name":"Tedros Adhanom Ghebreyesus","id":189868631,"id_str":"189868631","indices":[5,14]},{"screen_name":"WHO","name":"World Health Organization (WHO)","id":14499829,"id_str":"14499829","indices":[128,132]}],"symbols":[]}},"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[{"url":"https:\/\/t.co\/ihdiV40rS6","expanded_url":"https:\/\/twitter.com\/i\/web\/status\/1248332261532921858","display_url":"twitter.com\/i\/web\/status\/1\u2026","indices":[117,140]}],"user_mentions":[{"screen_name":"WHO","name":"World Health Organization (WHO)","id":14499829,"id_str":"14499829","indices":[0,4]},{"screen_name":"DrTedros","name":"Tedros Adhanom Ghebreyesus","id":189868631,"id_str":"189868631","indices":[5,14]}],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"en","timestamp_ms":"1586460578698"}
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:49 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:50 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:50 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:51 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:54 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:55 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:55 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:56 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:29:59 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:30:00 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:30:00 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:50], next run at: 2020-04-09 15:30:46 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-17-16ab1f570a18>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=50)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:30:01 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-29d067bfe3fb> in <module>
#      81 # id del usuario: WHO: 14499829
#      82 usuario = ['14499829']
# ---> 83 stream.filter(follow=usuario)
#      84
#      85
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %% [markdown]
# Llevamos ahora la data a un dataframe:

# %%
import json
import pandas as pd
tweets_data_path = "twitter_data.txt"  
tweets_data = []  
tweets_file = open(tweets_data_path, "r")  
for line in tweets_file:  
    try:  
        tweet = json.loads(line)  
        tweets_data.append(tweet)  
    except:  
        continue
        
tweets = pd.DataFrame()
tweets['Texto del tweet'] = list(map(lambda tweet: 
tweet['text'], tweets_data))
tweets['Usuario'] = list(map(lambda tweet:
tweet['user']['screen_name'], tweets_data))
tweets['Fecha'] = list(map(lambda tweet:
tweet['created_at'], tweets_data))

tweets
# Out:
#                                       Texto del tweet        Usuario  \
# 0   RT @WHO: We are grateful to @HowardDonald for ...      laralapsy
# 1   @WHO @DrTedros \n\n(cf) #WHO/ #OMS Trevor Jone...        SineBis
# 2   RT @WHO_Europe: #COVID19 virus causes some flu...   EMKA54116265
# 3   @WHO could declare #DRCongo ‘Ebola free’ as so...     Medair_DRC
# 4                 @WHO mean wuhan health organization     Amar704020
# ..                                                ...            ...
# 67  @WHO @DrTedros Wondering what real mandate of ...     wasouthere
# 68  @WHO @UNICEF @UN @hrw @HRC @OIC_OCI @IFJGlobal...  OfficialMohd1
# 69                         @WHO stop bullying Taiwan!    Jay_taiwan_
# 70  RT @DrTedros: .@WHO will be releasing an updat...   NiliMajumder
# 71             @WHO @DrTedros https://t.co/3Sy0Ey1ZFO     darshancrs
#
#                              Fecha
# 0   Thu Apr 09 14:01:45 +0000 2020
# 1   Thu Apr 09 14:12:53 +0000 2020
# 2   Thu Apr 09 14:12:54 +0000 2020
# 3   Thu Apr 09 14:12:57 +0000 2020
# 4   Thu Apr 09 14:13:06 +0000 2020
# ..                             ...
# 67  Thu Apr 09 18:58:01 +0000 2020
# 68  Thu Apr 09 18:58:03 +0000 2020
# 69  Thu Apr 09 18:58:43 +0000 2020
# 70  Thu Apr 09 19:02:59 +0000 2020
# 71  Thu Apr 09 19:03:03 +0000 2020
#
# [72 rows x 3 columns]
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:09 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:10 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:10 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:50], next run at: 2020-04-09 15:04:56 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-17-16ab1f570a18>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=50)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "StdOutListener.<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:11 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-20-a8075a2dadc9>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:14 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-16-6f160c3a2137>", line 30, in <lambda>
#     sched.add_job(lambda : sched.fun1(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'fun1'
# Job "<lambda> (trigger: interval[0:05:00], next run at: 2020-04-09 15:09:10 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-12-7f8f8bd0a843>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=300)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:15 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-13-ba25dcb3cee7>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:00:05], next run at: 2020-04-09 15:04:15 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-15-a15851a81cbf>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=5)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'

# %% [markdown]
# #### Invertimos su orden:

# %%
reversed_tweets = tweets.iloc[::-1]
reversed_tweets
# Out:
#                                       Texto del tweet        Usuario  \
# 10  RT @DrTedros: .@WHO's been working day &amp; n...     TaraMPaine
# 9   RT @DrTedros: .@WHO will be releasing an updat...  phillychris17
# 8   @WHO  Following Indian paid media spreading ha...    jahandad001
# 7   RT @DrTedros: For the past 100 days, our unwav...  LouisTrigardt
# 6   @WHO The most useless organization in the worl...    EEA_citizen
# 5   RT @WHO: "We play games, cook, spend time in o...     SolarisNGO
# 4                 @WHO mean wuhan health organization     Amar704020
# 3   @WHO could declare #DRCongo ‘Ebola free’ as so...     Medair_DRC
# 2   RT @WHO_Europe: #COVID19 virus causes some flu...   EMKA54116265
# 1   @WHO @DrTedros \n\n(cf) #WHO/ #OMS Trevor Jone...        SineBis
# 0   RT @WHO: We are grateful to @HowardDonald for ...      laralapsy
#
#                              Fecha
# 10  Thu Apr 09 14:13:57 +0000 2020
# 9   Thu Apr 09 14:13:35 +0000 2020
# 8   Thu Apr 09 14:13:28 +0000 2020
# 7   Thu Apr 09 14:13:26 +0000 2020
# 6   Thu Apr 09 14:13:23 +0000 2020
# 5   Thu Apr 09 14:13:18 +0000 2020
# 4   Thu Apr 09 14:13:06 +0000 2020
# 3   Thu Apr 09 14:12:57 +0000 2020
# 2   Thu Apr 09 14:12:54 +0000 2020
# 1   Thu Apr 09 14:12:53 +0000 2020
# 0   Thu Apr 09 14:01:45 +0000 2020

# %% [markdown]
# #### Llevamos el dataframe a un excel:

# %%
 reversed_tweets.to_excel('reversed_tweets.xlsx', sheet_name='primera')

# %% [markdown]
# #### Ahora se debe borrar el contenido del txt:
