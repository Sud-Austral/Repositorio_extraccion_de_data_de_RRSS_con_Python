# %% [markdown]
# # 140420 Tweets en tiempo real por usuario

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-11
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
# https://twitter.com/colmedchile/status/1249754648476516352
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
prompt = '> '
tweet=''
print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = input(prompt)

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
    
# realDonaldTrump
# Out:
# ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:
# > SuperDeSalud
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Acá una de las intervenciones del Superintendente, a través de videoconferencia. https://t.co/vAxlS5aiOe
#
# El Superintendente, Patricio Fernández, interviene ante la Comisión del Senado, en la discusión de la Ley de Isapre… https://t.co/glQ8yGwpI2
#
# RT @GobiernodeChile: [HILO] Nuevas medidas anunciadas hoy:
#
# 1) A partir del jueves 16 de abril a las 22 horas, se declara cuarentena total…
#
# RT @segegob: ¡🔴Atención📢! Ministra @KarlaEnAccion junto a @SubPrevDelito, @katymartorell, explican las nuevas medidas adoptadas por el @Gob…
#
# El Superintendente, Patricio Fernández, participando de la sesión especial del Senado (Ley de Isapres).… https://t.co/bmMiDq28Ej
#
# RT @ministeriosalud: Hoy, el ministro @jmanalich anunció nuevas zonas que tendrán cuarentena desde el 16 de abril.
#
# Revisa aquí cuáles ing…
#
# RT @SaludMagallanes: Hoy arribaron a #Puq dos ventiladores mecánicos adquiridos por @SaludMagallanes destinados a reforzar la Unidad de Pac…
#
# @ciberchilenos @NuevaMasvida_ Hola, nos sigues para solicitarte unos datos por interno?
#
# @sur_unplugged @SERNAC Hola Héctor, nos puedes seguir para enviarte un mensaje directo.
#
# RT @arturozunigaj: Excelente demostración de la Provincia del BioBio sobre cómo debemos trabajar para enfrentar esta Pandemia.
# Alcaldes, S…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Acá una de las intervenciones del Superintende...
# 1  El Superintendente, Patricio Fernández, interv...
# 2  RT @GobiernodeChile: [HILO] Nuevas medidas anu...
# 3  RT @segegob: ¡🔴Atención📢! Ministra @KarlaEnAcc...
# 4  El Superintendente, Patricio Fernández, partic...
# 5  RT @ministeriosalud: Hoy, el ministro @jmanali...
# 6  RT @SaludMagallanes: Hoy arribaron a #Puq dos ...
# 7  @ciberchilenos @NuevaMasvida_ Hola, nos sigues...
# 8  @sur_unplugged @SERNAC Hola Héctor, nos puedes...
# 9  RT @arturozunigaj: Excelente demostración de l...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'extended_entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1250183305422610437
# 2020-04-14 22:05:01
# Twitter Web App
# 0
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1250182828412854272, 'id_str': '1250182828412854272', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1250182828412854272/pu/img/Eyzh8HRsFSiR12xY.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1250182828412854272/pu/img/Eyzh8HRsFSiR12xY.jpg', 'url': 'https://t.co/vAxlS5aiOe', 'display_url': 'pic.twitter.com/vAxlS5aiOe', 'expanded_url': 'https://twitter.com/SuperDeSalud/status/1250183305422610437/video/1', 'type': 'photo', 'sizes': {'large': {'w': 352, 'h': 640, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 352, 'h': 640, 'resize': 'fit'}, 'medium': {'w': 352, 'h': 640, 'resize': 'fit'}}}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Acá una de las intervenciones del Superintende...  1250183305422610437
# 1  El Superintendente, Patricio Fernández, interv...  1250183301870112769
# 2  RT @GobiernodeChile: [HILO] Nuevas medidas anu...  1250179465222774784
# 3  RT @segegob: ¡🔴Atención📢! Ministra @KarlaEnAcc...  1250169148166078466
# 4  El Superintendente, Patricio Fernández, partic...  1250166000940650496
# 5  RT @ministeriosalud: Hoy, el ministro @jmanali...  1250159051947880448
# 6  RT @SaludMagallanes: Hoy arribaron a #Puq dos ...  1250138293058048002
# 7  @ciberchilenos @NuevaMasvida_ Hola, nos sigues...  1250106123711102978
# 8  @sur_unplugged @SERNAC Hola Héctor, nos puedes...  1250103865594253316
# 9  RT @arturozunigaj: Excelente demostración de l...  1250101139372216331
#
#                  Date              Source  Likes  RTs
# 0 2020-04-14 22:05:01     Twitter Web App      0    0
# 1 2020-04-14 22:05:01     Twitter Web App      0    1
# 2 2020-04-14 21:49:46  Twitter for iPhone      0   26
# 3 2020-04-14 21:08:46     Twitter Web App      0   28
# 4 2020-04-14 20:56:16     Twitter Web App      0    0
# 5 2020-04-14 20:28:39     Twitter Web App      0   52
# 6 2020-04-14 19:06:10     Twitter Web App      0   51
# 7 2020-04-14 16:58:20     Twitter Web App      0    0
# 8 2020-04-14 16:49:22     Twitter Web App      0    0
# 9 2020-04-14 16:38:32     Twitter Web App      0   37

# %% [markdown]
# ahora agregemos un string a la columna ID

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Acá una de las intervenciones del Superintende...
# 1  El Superintendente, Patricio Fernández, interv...
# 2  RT @GobiernodeChile: [HILO] Nuevas medidas anu...
# 3  RT @segegob: ¡🔴Atención📢! Ministra @KarlaEnAcc...
# 4  El Superintendente, Patricio Fernández, partic...
# 5  RT @ministeriosalud: Hoy, el ministro @jmanali...
# 6  RT @SaludMagallanes: Hoy arribaron a #Puq dos ...
# 7  @ciberchilenos @NuevaMasvida_ Hola, nos sigues...
# 8  @sur_unplugged @SERNAC Hola Héctor, nos puedes...
# 9  RT @arturozunigaj: Excelente demostración de l...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125018... 2020-04-14 22:05:01
# 1  https://twitter.com/SuperDeSalud/status/125018... 2020-04-14 22:05:01
# 2  https://twitter.com/SuperDeSalud/status/125017... 2020-04-14 21:49:46
# 3  https://twitter.com/SuperDeSalud/status/125016... 2020-04-14 21:08:46
# 4  https://twitter.com/SuperDeSalud/status/125016... 2020-04-14 20:56:16
# 5  https://twitter.com/SuperDeSalud/status/125015... 2020-04-14 20:28:39
# 6  https://twitter.com/SuperDeSalud/status/125013... 2020-04-14 19:06:10
# 7  https://twitter.com/SuperDeSalud/status/125010... 2020-04-14 16:58:20
# 8  https://twitter.com/SuperDeSalud/status/125010... 2020-04-14 16:49:22
# 9  https://twitter.com/SuperDeSalud/status/125010... 2020-04-14 16:38:32
#
#                Source  Likes  RTs
# 0     Twitter Web App      0    0
# 1     Twitter Web App      0    1
# 2  Twitter for iPhone      0   26
# 3     Twitter Web App      0   28
# 4     Twitter Web App      0    0
# 5     Twitter Web App      0   52
# 6     Twitter Web App      0   51
# 7     Twitter Web App      0    0
# 8     Twitter Web App      0    0
# 9     Twitter Web App      0   37

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)

# %% [markdown]
# #### Ahora se debe borrar el contenido del txt:
