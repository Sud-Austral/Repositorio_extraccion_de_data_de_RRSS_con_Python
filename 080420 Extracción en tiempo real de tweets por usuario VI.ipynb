# %% [markdown]
# # 080420 Extracción en tiempo real de tweets por usuario VI
#
# https://medium.com/better-programming/introduction-to-apscheduler-86337f3bb4a6

# %%
# Importamos las librerías necesarias:

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import re
import time

# Declaramos nuestras Twitter API Keys:
access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_token_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
consumer_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'


#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)
#api = tweepy.API(auth)

# Se debe utilizar apscheduler
'''Advanced Python Scheduler (APScheduler) es una biblioteca de Python que te permite programar 
tu código de Python para que se ejecute más tarde, ya sea solo una vez o periódicamente. 
Puede agregar nuevos trabajos o eliminar los antiguos sobre la marcha, según lo desees. 
Si almacena sus trabajos en una base de datos, también sobrevivirán a los reinicios del planificador 
y mantendrán su estado. Cuando se reinicia el planificador, ejecutará todos los trabajos que debería 
haber ejecutado mientras estaba desconectado'''

from apscheduler.schedulers.blocking import BackgroundScheduler


# Inicializamos la variable global: 
tweet_count = 0

# Ingresamos el número de tweets a ser descargados:
n_tweets = 10



# Crea la clase que manejará el stream de tweets:
class StdOutListener(StreamListener):
    
    sched = BlockingScheduler()


    
    @sched.scheduled_job('interval', minutes=10)
    def on_data(self, data):
        global tweet_count
        global n_tweets
        global stream
        if tweet_count < n_tweets:
            
            # Imprimimos en pantalla los tweets descargados:
            print(data)
            tweet_count += 1
            
            # Guardar el archivo data como txt:
            # el parámetro 'a' permite ir escribiendo debajo de lo ya existente en el txt:
            # https://www.geeksforgeeks.org/reading-writing-text-files-python/
            write_on_txt=open("twitter_data.txt",'a')
            write_on_txt.write(data)
            write_on_txt.close()  

            return True
        
        else:
            stream.disconnect()
      
    def on_error(self, status):
        print(status)

# Manejamos la autenticación de Twitter y la conexión a la API de Streaming de Twitter:
l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)

# Integramos un flitro para que busque un usuario, en éste caso de la WHO:
# id del usuario: WHO: 14499829
usuario = ['14499829']
stream.filter(follow=usuario)
sched.start()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-2742bae19600> in <module>
#      26 haber ejecutado mientras estaba desconectado'''
#      27
# ---> 28 from apscheduler.schedulers.blocking import BackgroundScheduler
#      29
#      30
#
# ImportError: cannot import name 'BackgroundScheduler' from 'apscheduler.schedulers.blocking' (C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\schedulers\blocking.py)
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:45:19 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:47:06 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:48:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:52:37 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-7-cbc3490aadb1>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:53:39 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:10:00], next run at: 2020-04-09 16:55:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-9-38224ddf91b3>", line 43, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=600)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:55:26 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 16:57:03 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:00:57 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-7-cbc3490aadb1>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:01:59 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:03:46 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:10:00], next run at: 2020-04-09 17:05:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-9-38224ddf91b3>", line 43, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=600)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:05:23 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:09:17 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-7-cbc3490aadb1>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:10:19 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:12:06 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:13:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:10:00], next run at: 2020-04-09 17:15:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-9-38224ddf91b3>", line 43, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=600)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:17:37 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-7-cbc3490aadb1>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:18:39 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:12:06 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:22:03 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:10:00], next run at: 2020-04-09 17:25:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-9-38224ddf91b3>", line 43, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=600)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:25:57 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-7-cbc3490aadb1>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:26:59 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:28:46 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:30:23 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:10:00], next run at: 2020-04-09 17:35:43 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-9-38224ddf91b3>", line 43, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=600)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:34:17 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-7-cbc3490aadb1>", line 30, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:35:19 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
# Job "StdOutListener.<lambda> (trigger: interval[0:08:20], next run at: 2020-04-09 17:37:06 -04)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\usuario\anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-6-ca8ee26d5a78>", line 44, in <lambda>
#     sched.add_job(lambda : sched.on_data(),'interval',seconds=500)
# AttributeError: 'BackgroundScheduler' object has no attribute 'on_data'
