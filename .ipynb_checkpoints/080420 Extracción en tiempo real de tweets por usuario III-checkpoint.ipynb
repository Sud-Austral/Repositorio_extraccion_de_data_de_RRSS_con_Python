# %% [markdown]
# # 080420 Extracción en tiempo real de tweets por usuario III
#
# https://www.storybench.org/how-to-collect-tweets-from-the-twitter-streaming-api-using-python/
#
#
# https://twitter.com/colmedchile
#
# Para obtener el id de un usuario:
#
# http://gettwitterid.com/
#
# Tweet objects:
#
# https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object

# %% [markdown]
# Filtros en Twitter:
#
# <img src="./filtros_en_tweeter.jpg" width="500" height="1000" >

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# Out:
# Christian Castro
# last updated: 2020-04-08
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3

# %%
import tweepy

# authorization tokens
consumer_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'
access_key = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
 
   
# Paso 2: Crea la clase StreamListener. En el mismo
# archivo, vamos a crear una nueva clase llamada
# StreamListener que hereda de la clase
# StreamListener de tweepy y anula los métodos
# on_status y on_error para que podamos personalizar
# lo que queremos hacer con cada tweet que
# encontremos. 

# La siguiente función limpia nuestros tweets y los separa con la función .split():
def remove_url(txt):
    return ' '.join(re.sub('([^0-9A-Za-z-áéíóúÁÉÍÓÚñÑ \t])|(\w+:\/\/\S+)', '', txt).split())    
    
# StreamListener class inherits from tweepy.StreamListener and overrides on_status/on_error methods.
class StreamListener(tweepy.StreamListener):

     
    
    def on_status(self, status):
        j=1
        print(str(j) +') '+ '\n' +
                'Texto del tweet: '+ status.text +' '+'\n' +
                'Creado en : '+str(status.created_at) +' '+'\n' +
                'Id del tweet: '+str(status.id) +' '+'\n' +
                'Número de favoritos: '+str(status.favorite_count) +' '+'\n' +
                'Número de retweets: '+str(status.retweet_count) +' '+'\n' +
                'Favoritos: '+str(status.favorited) +' '+'\n' +
                '¿Usuario autenticado?: '+str(status.retweeted) +' '+'\n' +
                'Idioma: '+str(status.lang) +' '+'\n' +
                'Lugar: '+str(status.place) +' '+'\n' +
                'Coordenadas: '+str(status.coordinates) +' '+'\n' +
                'Geolocalización: '+str(status.geo) +' '+'\n' +
                'Perfil completo del autor: '+str(status.user) +' '+ '\n'+ '\n')
    

        # si existe el atributo "retweeted_status", marque este tweet como un retweet:
        is_retweet = hasattr(status, "retweeted_status")

        # verificar si el texto ha sido truncado:
        if hasattr(status,"extended_tweet"):
            text = status.extended_tweet["full_text"]
        else:
            text = status.text

        # check if this is a quote tweet.
        is_quote = hasattr(status, "quoted_status")
        quoted_text = ""
        if is_quote:
            # check if quoted tweet's text has been truncated before recording it
            if hasattr(status.quoted_status,"extended_tweet"):
                quoted_text = status.quoted_status.extended_tweet["full_text"]
            else:
                quoted_text = status.quoted_status.text

        # remove characters that might cause problems with csv encoding
        remove_characters = [",","\n"]
        for c in remove_characters:
            text.replace(c," ")
            quoted_text.replace(c, " ")

        with open("out.csv", "a", encoding='utf-8') as f:
            f.write("%s,%s,%s,%s,%s,%s\n" % (status.created_at,status.user.screen_name,is_retweet,is_quote,text,quoted_text))
     
    def on_error(self, status_code):
        print("Encountered streaming error (", status_code, ")")
        sys.exit()
        
        j += 1  
# Programa principal#  
        
if __name__ == "__main__":
    
    # Paso 1: Configuramos el endpoint API tweeter con las clave que obtuvimos como desarrollador:   
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    # Instanciamos la clase StreamListener:
    streamListener = StreamListener()
    stream = tweepy.Stream(auth=api.auth, listener=streamListener, count=5, tweet_mode='extended')

    with open("out.csv", "w", encoding='utf-8') as f:
        f.write("date,user, is_retweet, is_quote, full_text, quoted_text\n")
    
    # Paso 3: Inicializamos el streaming con filtros para seguir a un usuario específico:
    # id del usuario: colegio médico: 633098103
    # usuario = ['633098103']
    
    # id del usuario: WHO: 14499829
    usuario = ['633098103']
    stream.filter(follow=usuario)
    
    # Construyamos un dataframe con pandas:
# Out:
# 1)
# Texto del tweet: @colmedchile #CoronaVirusEnChile
# #HoyEsNoticiaCNN
# @Cenabast @ispch
# ventiladores y profesional capacitado (y prot… https://t.co/EcnVmQjhwZ
# Creado en : 2020-04-09 02:51:49
# Id del tweet: 1248081152302354439
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 1200343618319462400, 'id_str': '1200343618319462400', 'name': 'justenjoint', 'screen_name': 'justenjoint', 'location': None, 'url': None, 'description': 'cumplí cuarentena obligatoria sola, no fui contactada por las autoridades.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 6, 'friends_count': 67, 'listed_count': 0, 'favourites_count': 82, 'statuses_count': 149, 'created_at': 'Fri Nov 29 09:20:01 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1242268578633711616/gqS6lmUw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242268578633711616/gqS6lmUw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1200343618319462400/1585015773', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1200343618319462400, id_str='1200343618319462400', name='justenjoint', screen_name='justenjoint', location=None, url=None, description='cumplí cuarentena obligatoria sola, no fui contactada por las autoridades.', translator_type='none', protected=False, verified=False, followers_count=6, friends_count=67, listed_count=0, favourites_count=82, statuses_count=149, created_at=datetime.datetime(2019, 11, 29, 9, 20, 1), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1242268578633711616/gqS6lmUw_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1242268578633711616/gqS6lmUw_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/1200343618319462400/1585015773', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @colmedchile @PublimetroChile @CHVNoticias @jmanalich @eldesconcierto @opsoms
# Creado en : 2020-04-09 02:52:41
# Id del tweet: 1248081371983200256
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: und
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 1247181736297074688, 'id_str': '1247181736297074688', 'name': 'Juani', 'screen_name': 'Juani87413200', 'location': None, 'url': None, 'description': 'vive para brillar', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 0, 'friends_count': 9, 'listed_count': 0, 'favourites_count': 33, 'statuses_count': 122, 'created_at': 'Mon Apr 06 15:18:12 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1247182224937664516/9MI77f4U_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247182224937664516/9MI77f4U_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1247181736297074688, id_str='1247181736297074688', name='Juani', screen_name='Juani87413200', location=None, url=None, description='vive para brillar', translator_type='none', protected=False, verified=False, followers_count=0, friends_count=9, listed_count=0, favourites_count=33, statuses_count=122, created_at=datetime.datetime(2020, 4, 6, 15, 18, 12), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1247182224937664516/9MI77f4U_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1247182224937664516/9MI77f4U_normal.jpg', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @colmedchile: Desde #Colmed rechazamos proyecto que busca suspender #EUNACOM por 2 https://t.co/20OIh7fhlR Emergencia Sanitaria permite…
# Creado en : 2020-04-09 02:54:01
# Id del tweet: 1248081705472348160
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 1245833720273211402, 'id_str': '1245833720273211402', 'name': 'Gemma trujillo', 'screen_name': 'Gemmatrujillo15', 'location': None, 'url': None, 'description': 'Madre de cinco , médico y muy buena para reír ....', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 4, 'friends_count': 68, 'listed_count': 0, 'favourites_count': 37, 'statuses_count': 48, 'created_at': 'Thu Apr 02 22:01:35 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1248079961598177281/xGEFhTbI_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1248079961598177281/xGEFhTbI_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1245833720273211402/1586400427', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1245833720273211402, id_str='1245833720273211402', name='Gemma trujillo', screen_name='Gemmatrujillo15', location=None, url=None, description='Madre de cinco , médico y muy buena para reír ....', translator_type='none', protected=False, verified=False, followers_count=4, friends_count=68, listed_count=0, favourites_count=37, statuses_count=48, created_at=datetime.datetime(2020, 4, 2, 22, 1, 35), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1248079961598177281/xGEFhTbI_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1248079961598177281/xGEFhTbI_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/1245833720273211402/1586400427', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# 1)
# Texto del tweet: RT @colmedchile: HOY! A las 19:30 hrs, nuestra Pdta. Dra. @izkia Siches conversará con @monicarincon2017 en #HoyEsNoticiaCNN de @CNNChile s…
# Creado en : 2020-04-09 02:54:40
# Id del tweet: 1248081869201170432
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 708434851200962560, 'id_str': '708434851200962560', 'name': 'Pamela Santibañez', 'screen_name': 'PameSantii78', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 155, 'friends_count': 117, 'listed_count': 7, 'favourites_count': 1739, 'statuses_count': 8407, 'created_at': 'Fri Mar 11 23:30:05 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1177615856571994112/fF5zEir__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1177615856571994112/fF5zEir__normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=708434851200962560, id_str='708434851200962560', name='Pamela Santibañez', screen_name='PameSantii78', location=None, url=None, description=None, translator_type='none', protected=False, verified=False, followers_count=155, friends_count=117, listed_count=7, favourites_count=1739, statuses_count=8407, created_at=datetime.datetime(2016, 3, 11, 23, 30, 5), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1177615856571994112/fF5zEir__normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1177615856571994112/fF5zEir__normal.jpg', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @colmedchile: Junto a nuestra Comisión de #MigrantesYSalud, invitamos a todos los migrantes que habitan en Chile a completar esta encues…
# Creado en : 2020-04-09 02:57:32
# Id del tweet: 1248082590445297664
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 911030124753117184, 'id_str': '911030124753117184', 'name': 'Cayo Cornelio Tácito', 'screen_name': 'CayoCornelio', 'location': None, 'url': None, 'description': 'Cuánto más corrupto el Estado, más leyes tiene', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2538, 'friends_count': 1694, 'listed_count': 4, 'favourites_count': 46690, 'statuses_count': 95841, 'created_at': 'Fri Sep 22 00:51:22 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/911030124753117184/1579300948', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=911030124753117184, id_str='911030124753117184', name='Cayo Cornelio Tácito', screen_name='CayoCornelio', location=None, url=None, description='Cuánto más corrupto el Estado, más leyes tiene', translator_type='none', protected=False, verified=False, followers_count=2538, friends_count=1694, listed_count=4, favourites_count=46690, statuses_count=95841, created_at=datetime.datetime(2017, 9, 22, 0, 51, 22), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/911030124753117184/1579300948', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @sochtx: Recomendaciones para trasplantados en época de Covid 19 https://t.co/KUBtCQsEIw
# Creado en : 2020-04-09 02:58:09
# Id del tweet: 1248082744057438208
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 911030124753117184, 'id_str': '911030124753117184', 'name': 'Cayo Cornelio Tácito', 'screen_name': 'CayoCornelio', 'location': None, 'url': None, 'description': 'Cuánto más corrupto el Estado, más leyes tiene', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2538, 'friends_count': 1694, 'listed_count': 4, 'favourites_count': 46690, 'statuses_count': 95843, 'created_at': 'Fri Sep 22 00:51:22 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/911030124753117184/1579300948', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=911030124753117184, id_str='911030124753117184', name='Cayo Cornelio Tácito', screen_name='CayoCornelio', location=None, url=None, description='Cuánto más corrupto el Estado, más leyes tiene', translator_type='none', protected=False, verified=False, followers_count=2538, friends_count=1694, listed_count=4, favourites_count=46690, statuses_count=95843, created_at=datetime.datetime(2017, 9, 22, 0, 51, 22), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1218301938770550785/EGc4KEEJ_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/911030124753117184/1579300948', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# 1)
# Texto del tweet: RT @colmedchile: [#PRENSA] Colegio Médico critica con dureza manejo del Minsal de  los funcionarios de la salud contagiados de coronavirus,…
# Creado en : 2020-04-09 02:58:39
# Id del tweet: 1248082872289853447
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 113044982, 'id_str': '113044982', 'name': 'También Opino', 'screen_name': 'tambienopino', 'location': 'chile', 'url': 'https://twitter.com/tambienopino', 'description': 'Mujer, que se aburrió del acoso. Abogo por la defensa de tus derechos mujer y niña. Azul ,Zurda, descendiente de mapuche y migrate.\nRegionalista.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1175, 'friends_count': 2021, 'listed_count': 19, 'favourites_count': 13588, 'statuses_count': 67684, 'created_at': 'Wed Feb 10 14:33:40 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1225124879571308544/L7V9RIvd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225124879571308544/L7V9RIvd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/113044982/1371583748', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=113044982, id_str='113044982', name='También Opino', screen_name='tambienopino', location='chile', url='https://twitter.com/tambienopino', description='Mujer, que se aburrió del acoso. Abogo por la defensa de tus derechos mujer y niña. Azul ,Zurda, descendiente de mapuche y migrate.\nRegionalista.', translator_type='none', protected=False, verified=False, followers_count=1175, friends_count=2021, listed_count=19, favourites_count=13588, statuses_count=67684, created_at=datetime.datetime(2010, 2, 10, 14, 33, 40), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1225124879571308544/L7V9RIvd_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1225124879571308544/L7V9RIvd_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/113044982/1371583748', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @colmedchile: [#PRENSA] En @EmolTV, Dra. @Izkia Siches se refirió a la #MesaSocial y la situación de la red por #COVID19 “Esperábamos qu…
# Creado en : 2020-04-09 03:00:54
# Id del tweet: 1248083436985876480
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 139984420, 'id_str': '139984420', 'name': '∆aváη Micaela #QuedateEnCasa', 'screen_name': 'DanaeMicaela', 'location': 'Stgo- Chile', 'url': None, 'description': 'depto DDHH Colmed stgo\nPsiquiatra', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2055, 'friends_count': 1805, 'listed_count': 20, 'favourites_count': 1501, 'statuses_count': 6887, 'created_at': 'Tue May 04 06:53:50 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '080808', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1241198972594724869/hz5BmpqZ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1241198972594724869/hz5BmpqZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/139984420/1572544501', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=139984420, id_str='139984420', name='∆aváη Micaela #QuedateEnCasa', screen_name='DanaeMicaela', location='Stgo- Chile', url=None, description='depto DDHH Colmed stgo\nPsiquiatra', translator_type='none', protected=False, verified=False, followers_count=2055, friends_count=1805, listed_count=20, favourites_count=1501, statuses_count=6887, created_at=datetime.datetime(2010, 5, 4, 6, 53, 50), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='1A1B1F', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='080808', profile_sidebar_border_color='000000', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1241198972594724869/hz5BmpqZ_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1241198972594724869/hz5BmpqZ_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/139984420/1572544501', default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @colmedchile: [#PRENSA] En @EmolTV, Dra. @Izkia Siches se refirió a la #MesaSocial y la situación de la red por #COVID19 “Esperábamos qu…
# Creado en : 2020-04-09 03:04:05
# Id del tweet: 1248084240761335808
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 96552992, 'id_str': '96552992', 'name': 'Luis Roberto', 'screen_name': 'luisrobertocl', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 209, 'friends_count': 273, 'listed_count': 1, 'favourites_count': 13970, 'statuses_count': 2697, 'created_at': 'Sun Dec 13 13:49:00 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'A8C7F7', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1242135906947141634/iPomGJs1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242135906947141634/iPomGJs1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/96552992/1584983384', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=96552992, id_str='96552992', name='Luis Roberto', screen_name='luisrobertocl', location=None, url=None, description=None, translator_type='none', protected=False, verified=False, followers_count=209, friends_count=273, listed_count=1, favourites_count=13970, statuses_count=2697, created_at=datetime.datetime(2009, 12, 13, 13, 49), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='022330', profile_background_image_url='http://abs.twimg.com/images/themes/theme15/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme15/bg.png', profile_background_tile=False, profile_link_color='0084B4', profile_sidebar_border_color='A8C7F7', profile_sidebar_fill_color='C0DFEC', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1242135906947141634/iPomGJs1_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1242135906947141634/iPomGJs1_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/96552992/1584983384', default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# 1)
# Texto del tweet: RT @colmedchile: Estamos muy preocupados por la situación de las cárceles de nuestro país, por eso nuestro Dpto. de DDHH ha visitado el CDP…
# Creado en : 2020-04-09 03:05:02
# Id del tweet: 1248084478276354051
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 39867550, 'id_str': '39867550', 'name': 'Kalma', 'screen_name': 'kmendoza53', 'location': 'Santiago, Chile', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2867, 'friends_count': 1137, 'listed_count': 30, 'favourites_count': 99706, 'statuses_count': 431890, 'created_at': 'Wed May 13 23:24:38 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'DD2E44', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_tile': True, 'profile_link_color': '4A913C', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFF7CC', 'profile_text_color': '9C9C2E', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1246529776296300545/20UkgDhc_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246529776296300545/20UkgDhc_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39867550/1585546051', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=39867550, id_str='39867550', name='Kalma', screen_name='kmendoza53', location='Santiago, Chile', url=None, description=None, translator_type='none', protected=False, verified=False, followers_count=2867, friends_count=1137, listed_count=30, favourites_count=99706, statuses_count=431890, created_at=datetime.datetime(2009, 5, 13, 23, 24, 38), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='DD2E44', profile_background_image_url='http://abs.twimg.com/images/themes/theme18/bg.gif', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme18/bg.gif', profile_background_tile=True, profile_link_color='4A913C', profile_sidebar_border_color='FFFFFF', profile_sidebar_fill_color='FFF7CC', profile_text_color='9C9C2E', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1246529776296300545/20UkgDhc_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1246529776296300545/20UkgDhc_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/39867550/1585546051', default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @colmedchile: Junto a nuestra Comisión de #MigrantesYSalud, invitamos a todos los migrantes que habitan en Chile a completar esta encues…
# Creado en : 2020-04-09 03:06:20
# Id del tweet: 1248084803481743360
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 50347559, 'id_str': '50347559', 'name': 'Adriana Goñi Godoy', 'screen_name': 'antropomemoria', 'location': 'Santiago', 'url': 'http://about.me/adrianagonigodoy', 'description': 'Antropologa-arqueóloga U Ch. Mesa Sitios de Memoria Colegio Arqueólogos CL. Directora Gral. de LA AGENCIA MUNDIAL DE PRENSA DE CHILE World Press Agency of Chile', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 8497, 'friends_count': 4150, 'listed_count': 133, 'favourites_count': 48738, 'statuses_count': 129832, 'created_at': 'Wed Jun 24 16:09:54 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'A9A4AB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '4A913C', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': 'A40000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1121851100460724224/g-jO1oZ6_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1121851100460724224/g-jO1oZ6_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50347559/1572204066', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=50347559, id_str='50347559', name='Adriana Goñi Godoy', screen_name='antropomemoria', location='Santiago', url='http://about.me/adrianagonigodoy', description='Antropologa-arqueóloga U Ch. Mesa Sitios de Memoria Colegio Arqueólogos CL. Directora Gral. de LA AGENCIA MUNDIAL DE PRENSA DE CHILE World Press Agency of Chile', translator_type='none', protected=False, verified=False, followers_count=8497, friends_count=4150, listed_count=133, favourites_count=48738, statuses_count=129832, created_at=datetime.datetime(2009, 6, 24, 16, 9, 54), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='A9A4AB', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='4A913C', profile_sidebar_border_color='000000', profile_sidebar_fill_color='000000', profile_text_color='A40000', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1121851100460724224/g-jO1oZ6_normal.png', profile_image_url_https='https://pbs.twimg.com/profile_images/1121851100460724224/g-jO1oZ6_normal.png', profile_banner_url='https://pbs.twimg.com/profile_banners/50347559/1572204066', default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: RT @colmedchile: [#PRENSA] Colegio Médico critica con dureza manejo del Minsal de  los funcionarios de la salud contagiados de coronavirus,…
# Creado en : 2020-04-09 03:08:00
# Id del tweet: 1248085224153546754
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 3333781205, 'id_str': '3333781205', 'name': 'Ⓜarcela Gp', 'screen_name': 'Marcelagp2', 'location': None, 'url': None, 'description': 'Chile', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2480, 'friends_count': 2576, 'listed_count': 27, 'favourites_count': 168328, 'statuses_count': 406053, 'created_at': 'Fri Jun 19 01:34:53 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1231776546513391617/Mrsn6-g7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1231776546513391617/Mrsn6-g7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3333781205/1571101813', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=3333781205, id_str='3333781205', name='Ⓜarcela Gp', screen_name='Marcelagp2', location=None, url=None, description='Chile', translator_type='none', protected=False, verified=False, followers_count=2480, friends_count=2576, listed_count=27, favourites_count=168328, statuses_count=406053, created_at=datetime.datetime(2015, 6, 19, 1, 34, 53), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1231776546513391617/Mrsn6-g7_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1231776546513391617/Mrsn6-g7_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/3333781205/1571101813', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# 1)
# Texto del tweet: RT @colmedchile: Estamos muy preocupados por la situación de las cárceles de nuestro país, por eso nuestro Dpto. de DDHH ha visitado el CDP…
# Creado en : 2020-04-09 03:09:19
# Id del tweet: 1248085554576711680
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 1328242728, 'id_str': '1328242728', 'name': '#APRUEBO 👍🏼💥', 'screen_name': 'NietaDeLiIith', 'location': 'Pandemonium, así pah!', 'url': 'https://youtu.be/kd_-ezWE4ZE', 'description': 'I’m in the ghetto. Rrrratatatá ••• Dale Bulla 🔴💙 🤘🏻🦉•••Fachos culiaos me los paseo ••', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 785, 'friends_count': 1057, 'listed_count': 1, 'favourites_count': 20975, 'statuses_count': 46292, 'created_at': 'Fri Apr 05 02:54:13 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'D3D9DB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '311B92', 'profile_sidebar_border_color': '5AC3E9', 'profile_sidebar_fill_color': '2D1E29', 'profile_text_color': 'DB6995', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1212039124690931712/_K1xrsuL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212039124690931712/_K1xrsuL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1328242728/1578335488', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1328242728, id_str='1328242728', name='#APRUEBO 👍🏼💥', screen_name='NietaDeLiIith', location='Pandemonium, así pah!', url='https://youtu.be/kd_-ezWE4ZE', description='I’m in the ghetto. Rrrratatatá ••• Dale Bulla 🔴💙 🤘🏻🦉•••Fachos culiaos me los paseo ••', translator_type='none', protected=False, verified=False, followers_count=785, friends_count=1057, listed_count=1, favourites_count=20975, statuses_count=46292, created_at=datetime.datetime(2013, 4, 5, 2, 54, 13), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='D3D9DB', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=True, profile_link_color='311B92', profile_sidebar_border_color='5AC3E9', profile_sidebar_fill_color='2D1E29', profile_text_color='DB6995', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1212039124690931712/_K1xrsuL_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1212039124690931712/_K1xrsuL_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/1328242728/1578335488', default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @colmedchile @izkia @CNNChile La dra. Que no es experta en nada,  y pretende dar cátedra en epidemias.
# Lo único que… https://t.co/er8mUeak9v
# Creado en : 2020-04-09 03:10:33
# Id del tweet: 1248085867811557377
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 179288631, 'id_str': '179288631', 'name': 'EL PILAR DE LA DEMOCRACIA ES LA LIBERTAD', 'screen_name': 'vocaciondeservi', 'location': None, 'url': None, 'description': 'AMANTE DE LA LIBERTAD', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2734, 'friends_count': 3907, 'listed_count': 1, 'favourites_count': 763, 'statuses_count': 7400, 'created_at': 'Mon Aug 16 23:43:11 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1203106869071556609/Lx2Uzwto_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1203106869071556609/Lx2Uzwto_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/179288631/1575689990', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=179288631, id_str='179288631', name='EL PILAR DE LA DEMOCRACIA ES LA LIBERTAD', screen_name='vocaciondeservi', location=None, url=None, description='AMANTE DE LA LIBERTAD', translator_type='none', protected=False, verified=False, followers_count=2734, friends_count=3907, listed_count=1, favourites_count=763, statuses_count=7400, created_at=datetime.datetime(2010, 8, 16, 23, 43, 11), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1203106869071556609/Lx2Uzwto_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1203106869071556609/Lx2Uzwto_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/179288631/1575689990', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @colmedchile que opinan????
# Creado en : 2020-04-09 03:10:55
# Id del tweet: 1248085959914205186
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 1196218453352468483, 'id_str': '1196218453352468483', 'name': 'José Fernández', 'screen_name': 'JosFern02517587', 'location': None, 'url': None, 'description': 'Jose fernandez\nMe gusta el futbol\n30 años\nMe apasiona nadar', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 52, 'friends_count': 134, 'listed_count': 0, 'favourites_count': 1596, 'statuses_count': 7143, 'created_at': 'Mon Nov 18 00:08:25 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1196226894666108928/tKzo8XU4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1196226894666108928/tKzo8XU4_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1196218453352468483, id_str='1196218453352468483', name='José Fernández', screen_name='JosFern02517587', location=None, url=None, description='Jose fernandez\nMe gusta el futbol\n30 años\nMe apasiona nadar', translator_type='none', protected=False, verified=False, followers_count=52, friends_count=134, listed_count=0, favourites_count=1596, statuses_count=7143, created_at=datetime.datetime(2019, 11, 18, 0, 8, 25), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/1196226894666108928/tKzo8XU4_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1196226894666108928/tKzo8XU4_normal.jpg', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# 1)
# Texto del tweet: @colmedchile @PublimetroChile AL COLEGIO MÉDICO
# Dudo mucho que las personas que critican al Minsal por la manera en… https://t.co/Xr6V8bHIJp
# Creado en : 2020-04-09 03:15:53
# Id del tweet: 1248087209397403648
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 2172754574, 'id_str': '2172754574', 'name': 'José Miguel Serrano', 'screen_name': 'SerranoRosselot', 'location': 'Chile', 'url': None, 'description': 'Economista University of Portland y Columbia University. Consultorías. Estudios en filosofía oriental/occidental, columnista La Tercera y diarios regionales.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 53, 'friends_count': 74, 'listed_count': 0, 'favourites_count': 51, 'statuses_count': 1682, 'created_at': 'Sun Nov 03 20:22:07 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000696138959/ed01d570f777e1df3e557982c8e2e49e_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000696138959/ed01d570f777e1df3e557982c8e2e49e_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=2172754574, id_str='2172754574', name='José Miguel Serrano', screen_name='SerranoRosselot', location='Chile', url=None, description='Economista University of Portland y Columbia University. Consultorías. Estudios en filosofía oriental/occidental, columnista La Tercera y diarios regionales.', translator_type='none', protected=False, verified=False, followers_count=53, friends_count=74, listed_count=0, favourites_count=51, statuses_count=1682, created_at=datetime.datetime(2013, 11, 3, 20, 22, 7), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/378800000696138959/ed01d570f777e1df3e557982c8e2e49e_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/378800000696138959/ed01d570f777e1df3e557982c8e2e49e_normal.jpeg', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @colmedchile @EmolTV @izkia Entonces, hay que retirarse.
# Creado en : 2020-04-09 03:18:56
# Id del tweet: 1248087976485302273
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: es
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000002A113F511C8>, _json={'id': 1229992406, 'id_str': '1229992406', 'name': 'Perdidaprobando', 'screen_name': 'perdidaenelnort', 'location': None, 'url': None, 'description': 'Feliz... Luchando día a día... Por los míos y por los que vendrán...', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 305, 'friends_count': 485, 'listed_count': 2, 'favourites_count': 47980, 'statuses_count': 19879, 'created_at': 'Fri Mar 01 14:40:17 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3699635893/9ad1e3d9038e1b380e4d6b8be84a9304_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3699635893/9ad1e3d9038e1b380e4d6b8be84a9304_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1229992406/1362150422', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1229992406, id_str='1229992406', name='Perdidaprobando', screen_name='perdidaenelnort', location=None, url=None, description='Feliz... Luchando día a día... Por los míos y por los que vendrán...', translator_type='none', protected=False, verified=False, followers_count=305, friends_count=485, listed_count=2, favourites_count=47980, statuses_count=19879, created_at=datetime.datetime(2013, 3, 1, 14, 40, 17), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/3699635893/9ad1e3d9038e1b380e4d6b8be84a9304_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/3699635893/9ad1e3d9038e1b380e4d6b8be84a9304_normal.jpeg', profile_banner_url='https://pbs.twimg.com/profile_banners/1229992406/1362150422', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-10078689a2bd> in <module>
#      97     # id del usuario: WHO: 14499829
#      98     usuario = ['633098103']
# ---> 99     stream.filter(follow=usuario)
#     100
#     101
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %% [markdown]
# #### 1 que el último tweet sea el primero en ser desplegado!

# %% [markdown]
# #### 2 la tarea es desplegar siempre los últimos 5 tweets siendo el último el primero de la lista
