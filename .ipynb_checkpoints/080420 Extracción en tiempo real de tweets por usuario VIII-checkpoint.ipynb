# %% [markdown]
# # 080420 Extracción en tiempo real de tweets por usuario VIII
#
# prueba 1
#
# https://medium.com/greedygame-engineering/an-elegant-way-to-run-periodic-tasks-in-python-61b7c477b679

# %%
#%load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-09
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %%
# Importamos las librerías necesarias:





from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import re


import time
import schedule

import sched

from timeloop import Timeloop
from datetime import timedelta

tl = Timeloop()




access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_token_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
consumer_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

tweet_count = 0
n_tweets = 10

class StdOutListener(StreamListener):

    def on_data(self, data):
        global tweet_count
        global n_tweets
        global stream
        if tweet_count < n_tweets:
            
            # Imprimimos en pantalla los tweets descargados:
            print(data)
            tweet_count += 1
            
            # Guardar el archivo data como txt:
            # el parámetro 'a' permite ir escribiendo debajo de lo ya existente en el txt:
            # https://www.geeksforgeeks.org/reading-writing-text-files-python/
            write_on_txt=open("twitter_data.txt",'a')
            write_on_txt.write(data)
            write_on_txt.close()  

            return True
        
        else:
            stream.disconnect()

    def on_error(self, status):
        print(status)
        

@tl.job(interval=timedelta(seconds=600))        
def func1():
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    l = StdOutListener()
    stream = Stream(auth, l)
    usuario = ['14499829']
    stream.filter(follow=usuario)    

func1()
# Out:
# {"created_at":"Fri Apr 10 04:25:42 +0000 2020","id":1248467166736707587,"id_str":"1248467166736707587","text":"@WHO WHO=Terrorist Organization. Your funding will be gone and hopefully your members imprisoned and executed. Asap.","display_text_range":[5,116],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":1248351120411496448,"in_reply_to_status_id_str":"1248351120411496448","in_reply_to_user_id":14499829,"in_reply_to_user_id_str":"14499829","in_reply_to_screen_name":"WHO","user":{"id":1219536807978770432,"id_str":"1219536807978770432","name":"Jack Dorsey","screen_name":"JackDor06668830","location":null,"url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":10,"friends_count":51,"listed_count":0,"favourites_count":2369,"statuses_count":635,"created_at":"Tue Jan 21 08:27:05 +0000 2020","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1219537760140304387\/TKKNj-oj_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1219537760140304387\/TKKNj-oj_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1219536807978770432\/1579595436","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[],"user_mentions":[{"screen_name":"WHO","name":"World Health Organization (WHO)","id":14499829,"id_str":"14499829","indices":[0,4]}],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"en","timestamp_ms":"1586492742605"}
#
# {"created_at":"Fri Apr 10 04:25:48 +0000 2020","id":1248467190682025996,"id_str":"1248467190682025996","text":"RT @WHO: As we mark 100 days since the first case of what we now call #COVID19 now was notified to WHO, here is the timeline of key events\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":234759009,"id_str":"234759009","name":"DRR","screen_name":"DhillonPPS","location":"Earth","url":null,"description":"#DisasterRiskReduction #DRR #DRM #Disaster #DisasterManagement #Emergency #Crises #Resilience #Climate #allhazards #BCM #Risk","translator_type":"none","protected":false,"verified":false,"followers_count":151,"friends_count":539,"listed_count":2,"favourites_count":498,"statuses_count":1193,"created_at":"Thu Jan 06 14:04:34 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/913481141310472192\/DDTZ8XDZ_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/913481141310472192\/DDTZ8XDZ_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/234759009\/1537520391","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Apr 09 20:44:35 +0000 2020","id":1248351120411496448,"id_str":"1248351120411496448","text":"As we mark 100 days since the first case of what we now call #COVID19 now was notified to WHO, here is the timeline\u2026 https:\/\/t.co\/A19ZmGlpk6","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7240011,"friends_count":1717,"listed_count":31684,"favourites_count":10600,"statuses_count":49835,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0396DB","profile_sidebar_border_color":"8C8C8C","profile_sidebar_fill_color":"D9D9D9","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/14499829\/1582794472","default_profile":false,"defa ...
# {"created_at":"Fri Apr 10 04:25:50 +0000 2020","id":1248467201369059334,"id_str":"1248467201369059334","text":"RT @WHO: \"I support this proposal, and we are working with #CostaRica to finalize the details.\nPoorer countries &amp; fragile economies stand t\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":825197306,"id_str":"825197306","name":"Miriam Cronkhite","screen_name":"MiriamCronkhite","location":"Fort Lauderdale, FL","url":"http:\/\/www.miriamcronkhite.com\/","description":"Digital diva. Content queen. Ethical journalist. Apple guru. Prince fan. Equality advocate. Animal lover. https:\/\/m.soundcloud.com\/cronkhitemedia","translator_type":"none","protected":false,"verified":false,"followers_count":233,"friends_count":1024,"listed_count":30,"favourites_count":6120,"statuses_count":7803,"created_at":"Sat Sep 15 12:47:38 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"800000","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/757787930198847488\/dC7L-j8I_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/757787930198847488\/dC7L-j8I_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/825197306\/1420333428","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Mon Apr 06 16:09:58 +0000 2020","id":1247194850266677248,"id_str":"1247194850266677248","text":"\"I support this proposal, and we are working with #CostaRica to finalize the details.\nPoorer countries &amp; fragile ec\u2026 https:\/\/t.co\/mkRJdkASHx","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":1247194642971529221,"in_reply_to_status_id_str":"1247194642971529221","in_reply_to_user_id":14499829,"in_reply_to_user_id_str":"14499829","in_reply_to_screen_name":"WHO","user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7240011,"friends_count":1717,"listed_count":31684,"favourites_count":10600,"statuses_count":49835,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":
profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1171089776256012288\/P-YlCPj__normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1171089776256012288\/P-YlCPj__normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Apr 09 08:24:42 +0000 2020","id":1248164925299720192,"id_str":"1248164925299720192","text":"FACT: #5G mobile networks DO NOT spread #COVID19 \n\nMore: https:\/\/t.co\/TdKoGmWrIr\n\n#coronavirus #KnowTheFacts https:\/\/t.co\/c56tToalZF","display_text_range":[0,108],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":1246836558138880001,"in_reply_to_status_id_str":"1246836558138880001","in_reply_to_user_id":14499829,"in_reply_to_user_id_str":"14499829","in_reply_to_screen_name":"WHO","user":{"id":14499829,"id_str":"14499829","name":"World Health Organization (WHO)","screen_name":"WHO","location":"Geneva, Switzerland","url":"http:\/\/www.who.int","description":"We are the #UnitedNations\u2019 health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll","translator_type":"regular","protected":false,"verified":true,"followers_count":7240022,"friends_count":1717,"listed_count":31684,"favourites_count":10600,"statuses_count":49835,"created_at":"Wed Apr 23 19:56:27 +0000 2008","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"D0ECF8","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"0396DB","profile_sidebar_border_color":"8C8C8C","profile_sidebar_fill_color":"D9D9D9","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/875476478988886016\/_l61qZdR_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/14499829\/1582794472","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status": ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-4ea33247bfa7> in <module>
#      69     stream.filter(follow=usuario)
#      70
# ---> 71 func1()
#      72
#      73
#
# <ipython-input-45-4ea33247bfa7> in func1()
#      67     stream = Stream(auth, l)
#      68     usuario = ['14499829']
# ---> 69     stream.filter(follow=usuario)
#      70
#      71 func1()
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %%
import json
import pandas as pd
tweets_data_path = "twitter_data.txt"  
tweets_data = []  
tweets_file = open(tweets_data_path, "r")  
for line in tweets_file:  
    try:  
        tweet = json.loads(line)  
        tweets_data.append(tweet)  
    except:  
        continue
        
tweets = pd.DataFrame()
tweets['Texto del tweet'] = list(map(lambda tweet: 
tweet['text'], tweets_data))
tweets['Usuario'] = list(map(lambda tweet:
tweet['user']['screen_name'], tweets_data))
tweets['Fecha'] = list(map(lambda tweet:
tweet['created_at'], tweets_data))

tweets
# Out:
#                                       Texto del tweet          Usuario  \
# 0   @WHO Propaganda to make @WHO look like they di...   LyndaMarie8888
# 1                      @WHO this is pretty accurate..        Hezander1
# 2   @WHO SUCKS &amp; is guilty of BS for the #Chin...         labachus
# 3   RT @WHO: You can catch #COVID19 no matter how ...       MrBazingga
# 4   @WHO Biggest event: WHO lied to the world that...      CrystalCar2
# 5                    @WHO \n\nhttps://t.co/hLzoPOWY1M     clover_lin39
# 6   RT @WHO: It usually takes several years to dev...       MrBazingga
# 7   @WHO should be totally defunded they are a was...      Lvstarlet64
# 8   @WHO \n@DrTedros \n1.Who will listen to these ...    sskbind_Ind15
# 9   RT @WHO: Preliminary investigations conducted ...      bmx71054548
# 10  @WHO You lying pieces of dogshit!  May you all...         enki0999
# 11  @WHO https://t.co/bZDPPfq8gD\n👆\nWhat is this ...   AnshumanPratik
# 12  RT @WHO: As we mark 100 days since the first c...  nadiahishamsaid
# 13  RT @WHO: The most common symptoms of #COVID19 ...   Palitodeazucar
# 14     @WHO how much those commie bastards payin you?     ryanwhelan22
# 15  RT @WHO: The most common symptoms of #COVID19 ...     akaMartchoin
# 16  @WHO Correction it was 102 days ago Taiwan ale...          bsa3977
# 17  @WHO @WHOThailand @WHOSEARO @WHOWPRO The world...   kofi_barcelona
# 18  @WHO @tonyashai @kavita_krishnan @ashoswai @ar...  rosemarykashmir
# 19  @WHO When will you mark the anniversary in whi...   chungkingxprez
# 20  RT @WHO: 📚 A new story book “My Hero is You, H...      AllenFinley
# 21  RT @WHO: Preliminary investigations conducted ...         PBardzik
# 22  RT @WHO: As we mark 100 days since the first c...           IXcatz
# 23  RT @WHO: "Our singular focus is on working to ...     NahalRashpal
# 24  @WHO  #LockThemAllUp racketeering + crimes aga...         NooneinH
# 25  @WHO Tienamen square Tienamen square Tienamen ...  thefirestarte10
# 26  @WHO situation could have been better if this ...     Rajantweets_
# 27             @WHO @DrTedros https://t.co/fihVCIwoaH        Nateel_29
# 28  @WHO You globalist losers fvcked up big. I’m s...    BeachBumLolly
# 29  RT @WHO: “Sometimes when we are feeling very a...        LuAnnWHNP
# 30  @WHO why #WHO silent on other pathy... is #WHO...         ajeydada
# 31  RT @WHO: As we mark 100 days since the first c...        92Rakesh2
# 32  @WHO said it the #USA is politicizing this vir...           cldlop
# 33  @WHO is as guilty as #China un spreading the #...           vks_27
#
#                              Fecha
# 0   Fri Apr 10 01:37:18 +0000 2020
# 1   Fri Apr 10 01:37:20 +0000 2020
# 2   Fri Apr 10 01:37:28 +0000 2020
# 3   Fri Apr 10 01:37:33 +0000 2020
# 4   Fri Apr 10 01:38:01 +0000 2020
# 5   Fri Apr 10 01:38:03 +0000 2020
# 6   Fri Apr 10 01:38:04 +0000 2020
# 7   Fri Apr 10 01:38:15 +0000 2020
# 8   Fri Apr 10 01:38:30 +0000 2020
# 9   Fri Apr 10 01:38:51 +0000 2020
# 10  Fri Apr 10 01:52:39 +0000 2020
# 11  Fri Apr 10 01:52:51 +0000 2020
# 12  Fri Apr 10 01:53:09 +0000 2020
# 13  Fri Apr 10 01:53:26 +0000 2020
# 14  Fri Apr 10 01:54:00 +0000 2020
# 15  Fri Apr 10 01:54:52 +0000 2020
# 16  Fri Apr 10 01:55:11 +0000 2020
# 17  Fri Apr 10 01:55:38 +0000 2020
# 18  Fri Apr 10 01:55:55 +0000 2020
# 19  Fri Apr 10 01:56:18 +0000 2020
# 20  Fri Apr 10 01:56:45 +0000 2020
# 21  Fri Apr 10 01:56:48 +0000 2020
# 22  Fri Apr 10 01:56:58 +0000 2020
# 23  Fri Apr 10 01:57:36 +0000 2020
# 24  Fri Apr 10 02:01:50 +0000 2020
# 25  Fri Apr 10 02:01:55 +0000 2020
# 26  Fri Apr 10 02:02:34 +0000 2020
# 27  Fri Apr 10 02:02:37 +0000 2020
# 28  Fri Apr 10 02:02:47 +0000 2020
# 29  Fri Apr 10 02:04:09 +0000 2020
# 30  Fri Apr 10 02:04:34 +0000 2020
# 31  Fri Apr 10 02:04:53 +0000 2020
# 32  Fri Apr 10 02:04:59 +0000 2020
# 33  Fri Apr 10 02:05:05 +0000 2020

# %%
reversed_tweets = tweets.iloc[::-1]
reversed_tweets
# Out:
#                                       Texto del tweet          Usuario  \
# 33  @WHO is as guilty as #China un spreading the #...           vks_27
# 32  @WHO said it the #USA is politicizing this vir...           cldlop
# 31  RT @WHO: As we mark 100 days since the first c...        92Rakesh2
# 30  @WHO why #WHO silent on other pathy... is #WHO...         ajeydada
# 29  RT @WHO: “Sometimes when we are feeling very a...        LuAnnWHNP
# 28  @WHO You globalist losers fvcked up big. I’m s...    BeachBumLolly
# 27             @WHO @DrTedros https://t.co/fihVCIwoaH        Nateel_29
# 26  @WHO situation could have been better if this ...     Rajantweets_
# 25  @WHO Tienamen square Tienamen square Tienamen ...  thefirestarte10
# 24  @WHO  #LockThemAllUp racketeering + crimes aga...         NooneinH
# 23  RT @WHO: "Our singular focus is on working to ...     NahalRashpal
# 22  RT @WHO: As we mark 100 days since the first c...           IXcatz
# 21  RT @WHO: Preliminary investigations conducted ...         PBardzik
# 20  RT @WHO: 📚 A new story book “My Hero is You, H...      AllenFinley
# 19  @WHO When will you mark the anniversary in whi...   chungkingxprez
# 18  @WHO @tonyashai @kavita_krishnan @ashoswai @ar...  rosemarykashmir
# 17  @WHO @WHOThailand @WHOSEARO @WHOWPRO The world...   kofi_barcelona
# 16  @WHO Correction it was 102 days ago Taiwan ale...          bsa3977
# 15  RT @WHO: The most common symptoms of #COVID19 ...     akaMartchoin
# 14     @WHO how much those commie bastards payin you?     ryanwhelan22
# 13  RT @WHO: The most common symptoms of #COVID19 ...   Palitodeazucar
# 12  RT @WHO: As we mark 100 days since the first c...  nadiahishamsaid
# 11  @WHO https://t.co/bZDPPfq8gD\n👆\nWhat is this ...   AnshumanPratik
# 10  @WHO You lying pieces of dogshit!  May you all...         enki0999
# 9   RT @WHO: Preliminary investigations conducted ...      bmx71054548
# 8   @WHO \n@DrTedros \n1.Who will listen to these ...    sskbind_Ind15
# 7   @WHO should be totally defunded they are a was...      Lvstarlet64
# 6   RT @WHO: It usually takes several years to dev...       MrBazingga
# 5                    @WHO \n\nhttps://t.co/hLzoPOWY1M     clover_lin39
# 4   @WHO Biggest event: WHO lied to the world that...      CrystalCar2
# 3   RT @WHO: You can catch #COVID19 no matter how ...       MrBazingga
# 2   @WHO SUCKS &amp; is guilty of BS for the #Chin...         labachus
# 1                      @WHO this is pretty accurate..        Hezander1
# 0   @WHO Propaganda to make @WHO look like they di...   LyndaMarie8888
#
#                              Fecha
# 33  Fri Apr 10 02:05:05 +0000 2020
# 32  Fri Apr 10 02:04:59 +0000 2020
# 31  Fri Apr 10 02:04:53 +0000 2020
# 30  Fri Apr 10 02:04:34 +0000 2020
# 29  Fri Apr 10 02:04:09 +0000 2020
# 28  Fri Apr 10 02:02:47 +0000 2020
# 27  Fri Apr 10 02:02:37 +0000 2020
# 26  Fri Apr 10 02:02:34 +0000 2020
# 25  Fri Apr 10 02:01:55 +0000 2020
# 24  Fri Apr 10 02:01:50 +0000 2020
# 23  Fri Apr 10 01:57:36 +0000 2020
# 22  Fri Apr 10 01:56:58 +0000 2020
# 21  Fri Apr 10 01:56:48 +0000 2020
# 20  Fri Apr 10 01:56:45 +0000 2020
# 19  Fri Apr 10 01:56:18 +0000 2020
# 18  Fri Apr 10 01:55:55 +0000 2020
# 17  Fri Apr 10 01:55:38 +0000 2020
# 16  Fri Apr 10 01:55:11 +0000 2020
# 15  Fri Apr 10 01:54:52 +0000 2020
# 14  Fri Apr 10 01:54:00 +0000 2020
# 13  Fri Apr 10 01:53:26 +0000 2020
# 12  Fri Apr 10 01:53:09 +0000 2020
# 11  Fri Apr 10 01:52:51 +0000 2020
# 10  Fri Apr 10 01:52:39 +0000 2020
# 9   Fri Apr 10 01:38:51 +0000 2020
# 8   Fri Apr 10 01:38:30 +0000 2020
# 7   Fri Apr 10 01:38:15 +0000 2020
# 6   Fri Apr 10 01:38:04 +0000 2020
# 5   Fri Apr 10 01:38:03 +0000 2020
# 4   Fri Apr 10 01:38:01 +0000 2020
# 3   Fri Apr 10 01:37:33 +0000 2020
# 2   Fri Apr 10 01:37:28 +0000 2020
# 1   Fri Apr 10 01:37:20 +0000 2020
# 0   Fri Apr 10 01:37:18 +0000 2020

# %%
 reversed_tweets.to_excel('reversed_tweets.xlsx', sheet_name='primera')

# %% [markdown]
# #### Ahora se debe borrar el contenido del txt:
