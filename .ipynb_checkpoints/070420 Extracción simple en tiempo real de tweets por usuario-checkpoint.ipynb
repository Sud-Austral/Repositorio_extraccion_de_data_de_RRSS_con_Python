# %% [markdown]
# # 070420 Extracción simple en tiempo real de tweets por usuario
#
# https://www.youtube.com/watch?v=wlnx-7cm4Gg
#
# https://github.com/vprusso/youtube_tutorials
#
# https://twitter.com/colmedchile
#
# http://gettwitterid.com/

# %%
ACCESS_TOKEN = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_TOKEN_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
CONSUMER_KEY = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# %%
# Éste es un código recursivo:
# Python soporta JSON ntivamente!
import json


import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
 
class TwitterStreamer():

    def __init__(self):
        pass

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        
        """
        Método que nos permitirá extraer tweets
        """
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
        auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
        api = tweepy.API(auth, wait_on_rate_limit=True)  
        
        
        stream = Stream(auth, listener)

        # stream.filter(track=hash_tag_list)
            
        stream.filter(follow=hash_tag_list)

class StdOutListener(StreamListener):
    """
    This is a basic listener that just prints received tweets to stdout.
    """
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    """
    Clase que nos permitirá imprimir tweets
    """
    def on_data(self, data):
        
        try:     
            j=1    
           # Esta línea de código imprime en pantalla cada tweet:
            # print(str(j) +')'+ data + '\n')

            # con este par de líneas analizamos la estructura del JSon:
           # parsed_json = (json.loads(data))
           # print(json.dumps(parsed_json, indent=4, sort_keys=True))
            
            with open(data) as json_file:
                data = json.load(json_file)
                print(data['created_at'])
            
            
            '''  with open(data) as json_file:
                data = json.load(json_file)
                for p in data['people']:
                    print('Name: ' + p['name'])
                    print('Website: ' + p['website'])
                    print('From: ' + p['from'])
                    print('')'''
            
            #student = json.loads(data)
            #print("After Converting JSON Data into Custom Python Object")
            #print(str(j) +')'+student)
            
            
            
          #  with open(data, 'r') as f:
          #      datas = json.load(f)

            #    for distro in datas:
               #     print(distro['text'])
            
            
            
            # Este par de líneas imprime cada tweet en un archivo txt:
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
                
                         
            return True
            j= j+1
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
       

    def on_error(self, status):
        print(status)

if __name__ == '__main__':
 
    # Authenticate using config.py and connect to Twitter Streaming API.
    hash_tag_list = ['633098103']
    fetched_tweets_filename = "colegio_medico_001.txt"

    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# Error on_data [Errno 22] Invalid argument: '{"created_at":"Wed Apr 08 01:22:59 +0000 2020","id":1247696410419572736,"id_str":"1247696410419572736","text":"RT @colmedchile: [#NOTICIAS] Colegio M\\u00e9dico solicita informaci\\u00f3n sobre estrategia gubernamental por COVID-19. Todos los detalles en https:\\/\\u2026","source":"\\u003ca href=\\"https:\\/\\/mobile.twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter
\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":396139406,"id_str":"396139406","name":"carolina castillo","screen_name":"caro18oct","location":"Santiago, Chile","url":null,"description":"seguir luchando...","translator_type":"none","protected":false,"verified":false,"followers_count":12,"friends_count":64,"listed_count":0,"favourites_count":384,"statuses_count":527,"created_at":"Sat Oct 22 20:17:26 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1240957063888502791\\/3A7AMdqw_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1240957063888502791\\/3A7AMdqw_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Apr 08 01:10:38 +0000 2020","id":1247693299588235269,"id_str":"1247693299588235269","text":"\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb \\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\ud83d\\udc4f\\ud83c\\udffb\\n\\u00a1Gracias a todos los trabajadores de la salud de Chile y el mundo por su trabajo frente a e\\u2026 https:\\/\\/t.co\\/6lmiIBMNYi","display_text_range":[0,140],"source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":633098103,"id_str":"633098103","name":"Colmed Chile","screen_name":"colmedchile","location":"Chile","url":"http:\\/\\/www.colegiomedico.cl","description":"Cuenta Oficial del Colegio M\\u00e9dico de Chile \\ud83d\\udcccFacebook: Colegio M\\u00e9dico de Chile \\ud83d\\udcccInstagram: @colmed_chile #colmed #colmedchile","translator_type":"none","protected":false,"verified":false,"followers_count":74291,"friends_count":1858,"listed_count":115,"favourites_count":6891,"statuses_count":17038,"created_at":"Wed Jul 11 16:14:38 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/ ...
# Error on_data [Errno 22] Invalid argument: '{"created_at":"Wed Apr 08 01:24:30 +0000 2020","id":1247696790637477894,"id_str":"1247696790637477894","text":"@colmedchile @izkia @GobiernodeChile Estimada la falta de elementos lo he escuchado siempre, el problema son ustede\\u2026 https:\\/\\/t.co\\/faxcmqsPBR","display_text_range":[37,140],"source":"\\u003ca href=\\"https:\\/\\/mobile.twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web App\\u003c\\/a\\u003e","truncated":true,"in_reply_to_status_id":1247658772069257217,"in_reply_to_status_id_str":"1247658772069257217","in_reply_to_user_id":633098103,"in_reply_to_user_id_str":"633098103","in_reply_to_screen_name":"colmedchile","user":{"id":1186001034725986307,"id_str":"1186001034725986307","name":"KOALA","screen_name":"andreagallegui9","location":"v regi\\u00f3n CHILE","url":null,"description":"El mejor bien com\\u00fan es la PAZ. \\nCon\\u00f3cete a ti mismo as\\u00ed conocer\\u00e1s el AMOR\\nMi partido CHILENISMO  Hacer el bien y no mirar a qui\\u00e9n\\nMascotas es Familia","translator_type":"none","protected":false,"verified":false,"followers_count":1274,"friends_count":2383,"listed_count":0,"favourites_count":7001,"statuses_count":19008,"created_at":"Sun Oct 20 19:27:47 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1193207010029899776\\/mX8H4e4L_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1193207010029899776\\/mX8H4e4L_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/1186001034725986307\\/1579300702","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"@colmedchile @izkia @GobiernodeChile Estimada la falta de elementos lo he escuchado siempre, el problema son ustedes como cabeza no ense\\u00f1an a llevar los controles,como se debe anotar los insumos,llevar cardex es decir lo que se pide sea destinado con un rut del usuario todo lo k se ocup\\u00f3.Para evitar robos internos","display_text_range":[37,315],"entities":{"hashtags":[],"urls":[],"user_mentions":[{"screen_name":"colmedchile","name":"Colmed Chile","id":633098103,"id_str":"633098103","indices":[0,12]},{"screen_name":"izkia","name":"Izkia","id":52534878,"id_str":"52534878","indices":[13,19]},{"screen_name":"GobiernodeChile","name":"Gobierno de Chile","id":42102939,"id_str":"42102939","indices":[20,36]}],"symbols":[]}},"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[{"url":"https:\\/\\/t.co\\/faxcmqsPBR","expanded_url":"https:\\/\\/twitter.com\\/i\\/web\\/status\\/1247696790637477894","display_url":"twitter.com\\/i\\/web\\/status\\/1\\u2026","indices":[117,140]}],"user_mentions":[{"screen_name":"colmedchile","name":"Colmed Chile","id":633098103,"id_str":"633098103","indices":[0,12]},{"screen_name":"izkia","name":"Izkia","id":52534878,"id_str":"52534878","indices":[13,19]},{"screen_name":"GobiernodeChile","name":"Gobierno de Chile","id":42102939,"id_str":"42102939","indices":[20,36]}],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":
"created_at":"Wed Jul 11 16:14:38 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C ...
# Error on_data [Errno 22] Invalid argument: '{"created_at":"Wed Apr 08 02:06:39 +0000 2020","id":1247707397923254273,"id_str":"1247707397923254273","text":"RT @colmedchile: Dra. @Izkia Siches, realiza balance tras culminar 6ta reuni\\u00f3n de la #MesaSocialCOVID19, en la que se entregaron propuestas\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1185862023827070977,"id_str":"1185862023827070977","name":"Teresa","screen_name":"Teresa48891263","location":"Vallenar, Chile","url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":70,"friends_count":167,"listed_count":0,"favourites_count":9563,"statuses_count":5621,"created_at":"Sun Oct 20 10:15:34 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1246514093575606273\\/YfhWlXvo_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1246514093575606273\\/YfhWlXvo_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Apr 08 00:34:53 +0000 2020","id":1247684303649222656,"id_str":"1247684303649222656","text":"Dra. @Izkia Siches, realiza balance tras culminar 6ta reuni\\u00f3n de la #MesaSocialCOVID19, en la que se entregaron pro\\u2026 https:\\/\\/t.co\\/meT5fCfdya","display_text_range":[0,140],"source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":633098103,"id_str":"633098103","name":"Colmed Chile","screen_name":"colmedchile","location":"Chile","url":"http:\\/\\/www.colegiomedico.cl","description":"Cuenta Oficial del Colegio M\\u00e9dico de Chile \\ud83d\\udcccFacebook: Colegio M\\u00e9dico de Chile \\ud83d\\udcccInstagram: @colmed_chile #colmed #colmedchile","translator_type":"none","protected":false,"verified":false,"followers_count":74321,"friends_count":1858,"listed_count":115,"favourites_count":6892,"statuses_count":17039,"created_at":"Wed Jul 11 16:14:38 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":true,"profile_link_color":"0000CC","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1245851467891736576\\/TayMmMjI_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1245851467891736576\\/TayMmMjI_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/633098103\\/1584977450","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo" ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-9154d4536263> in <module>
#     100
#     101     twitter_streamer = TwitterStreamer()
# --> 102     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#
# <ipython-input-161-9154d4536263> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      29         # stream.filter(track=hash_tag_list)
#      30
# ---> 31         stream.filter(follow=hash_tag_list)
#      32
#      33 class StdOutListener(StreamListener):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:
