# %% [markdown]
# # 2 Minería de datos sobre Twitter con Python
# ### 16 de Marzo

# %% [markdown]
# ### Insumos útiles que resultan de la minería de datos sobre twitter:
#     1. Obtener los tweets que incluyan el nombre una empresa o producto y posteriormente hacer un análisis de sentimientos sobre los tweets que contengan el o los términos seleccionados y saber si los usuarios tienen una apreciación positiva o negativa de una empresa o producto.
#     2. Crear un gráfico social de los usuarios más populares (influencers) que mencionan a nuestro producto o empresa en Twitter.
#     3. Recopilar datos en tiempo real de un evento como por ejemplo el lanzamiento de producto para su análisis.
#     4. Identificar los lugares, ciudades y/o países en los cuales nuestra empresa o producto son mencionados.
#     5. Analizar los datos de usuarios específicos y su interacción con otros usuarios en Twitter.
#     6. Hacer un Monitoreo de los seguidores y usuarios a los que sigue un usuario.
#     7. Encontrar influenciadores en Twitter y la tendencia en el crecimiento de sus seguidores.

# %% [markdown]
# ## 1. Construir una cuenta de desarrollador en Twitter
#
# Ingresando a https://apps.twitter.com/. debemos llegar a esta URL: https://developer.twitter.com/en/apps y donde nos registraremos como desarrollador. Una vez registrados, debemos esperar un momento a que nuestra cuenta sea creada y ya podemos construir una app.
#
# Primero debemos instalar desde Anaconda prompt tweepy: pip install tweepy

# %% [markdown]
# La mineria de datos sobre twitter incluye dos pasos:
#     1. Configurar una cuenta de desarrollador en Twitter y
#     2. Analizar con Python
#
#
#     1 primero analisis del lenguaje natural
#     2 integrar un conteo de tweets en la misma linea que indica si no existen, en cuyo caso que indique cero.
#     2 luego el analisis de sentimientos

# %%
import tweepy
from tweepy import OAuthHandler

api_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
api_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'
access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
auth = OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
#api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Código que establece un radio y guarda en CSV

# agregar el despliegue de un mensaje en el caso de no 
# encontrar tweets según los para metros especificados

import datetime
import csv
csvFile = open('tweet.csv', 'a')

filename = 'e00tt1_'+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search , 
                   since='2020-01-01', q = 'seguridad',
                               geocode="-33.622096,-70.592343,4.5km").items():
        print ([tweet.created_at, tweet.text.encode('utf-8'), tweet.id, tweet.place])
        
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), 
                            tweet.id, tweet.place])
# Out:
# [datetime.datetime(2020, 3, 16, 21, 24, 18), b'Estimados vecinos(as), con el prop\xc3\xb3sito de enfrentar adecuadamente la propagaci\xc3\xb3n del coronavirus, sumado al objeti\xe2\x80\xa6 https://t.co/xC0JwXogXy', 1239663808320282624, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 15, 22, 37, 30), b'Estimados vecinos(as), con el prop\xc3\xb3sito de enfrentar adecuadamente la propagaci\xc3\xb3n del COVID-19, sumado al objetivo\xe2\x80\xa6 https://t.co/8wijvZrvJA', 1239319841217093632, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 15, 9, 42, 16), b'Veo conocidos de la Esc. Militar que compiten en qui\xc3\xa9n sube m\xc3\xa1s fotos de copete a Instagram los fines de semana.\nLa\xe2\x80\xa6 https://t.co/DHF2qXjFRD', 1239124749902635008, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 14, 15, 36, 34), b'As\xc3\xad como va la cosa y de ganar el #apruebo a cargo del @PCdeChile y el @elfrente_amplio ..\nDespu\xc3\xa9s del 26 de Abril\xe2\x80\xa6 https://t.co/AOfbnQ0GV9', 1238851523515428865, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 14, 1, 58, 3), b'@ReporteraClau @borizfox @ALERTADESISMO Yo no lo hice porque al que lo hizo, le hicieron pebre el auto. Insisto no\xe2\x80\xa6 https://t.co/d3n9XAxLGr', 1238645536762277889, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 12, 15, 32, 51), b'@supereduc_cl @alvarado_edo Me preocupa la continuidad de las clases y la seguridad de  mis hijos antes las manifes\xe2\x80\xa6 https://t.co/iChZVNpKEv', 1238125812613812225, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 12, 13, 2, 18), b'@Neninogarcia @meganoticiascl @chilevision @CNNChile @germancodina @HolaChileLaRed nefasta seguridad, mal trato a n\xe2\x80\xa6 https://t.co/UgkD3aMuwy', 1238087925990150147, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 11, 19, 53, 33), b'Muchas veces lo sospech\xc3\xa9 pero ahora ya estoy completamente seguro que Pi\xc3\xb1era no termina su gobierno. 100% de seguridad.', 1237829029585092610, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 10, 5, 47, 32), b'@Sara_Connorr @euge2145 Estos creen que nuestra FFAA, CARABINEROS Y PDI, Son Narcos??\nNO srs, son Patriotas Dem\xc3\xb3cra\xe2\x80\xa6 https://t.co/FW4vSNcQEx', 1237253736231288832, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# [datetime.datetime(2020, 3, 9, 17, 13, 43), b'A\xc3\xb1os atras robaron 6 millones de d\xc3\xb3lares del mismo aeropuerto \xc2\xbfno se hizo nada por mejorar la seguridad? \xc2\xbfQui\xc3\xa9n sab\xe2\x80\xa6 https://t.co/5m1dsD1asC', 1237064033259454464, Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]

# %%
import datetime
import csv
csvFile = open('tweet.csv', 'a')

filename = 'anagreeecgrg444 '+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search ,  q = 'ambiente',geocode="-33.622096,-70.592343,4.5km").items():
        print ([tweet.text, tweet.created_at, tweet.text.encode('utf-8'), tweet.place])
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.place])
# Out:
# ['A la gente que usa mascarilla y que supuestamente sabe usarlas porfa cuiden el medio ambiente y no los dejen tirado… https://t.co/oPwpLvf8r6', datetime.datetime(2020, 3, 16, 20, 25, 14), b'A la gente que usa mascarilla y que supuestamente sabe usarlas porfa cuiden el medio ambiente y no los dejen tirado\xe2\x80\xa6 https://t.co/oPwpLvf8r6', Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]
# ['El @MMAChile lanzó Tarjeta Digital, que busca reemplazar a las antiguas tarjetas impresas de papel. ¡Hoy este desaf… https://t.co/tlnPQTI6PX', datetime.datetime(2020, 3, 10, 15, 7, 9), b'El @MMAChile lanz\xc3\xb3 Tarjeta Digital, que busca reemplazar a las antiguas tarjetas impresas de papel. \xc2\xa1Hoy este desaf\xe2\x80\xa6 https://t.co/tlnPQTI6PX', Place(_api=<tweepy.api.API object at 0x00000150766E39C8>, id='009bffed2486be17', url='https://api.twitter.com/1.1/geo/id/009bffed2486be17.json', place_type='city', name='Puente Alto', full_name='Puente Alto, Chile', country_code='CL', country='Chile', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x00000150766E39C8>, type='Polygon', coordinates=[[[-70.6319484, -33.6441471], [-70.4867352, -33.6441471], [-70.4867352, -33.542929], [-70.6319484, -33.542929]]]), attributes={})]

# %%
import datetime
import csv
csvFile = open('tweets.csv', 'a')

filename = 'anefef '+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search ,  q = 'medio ambiente',geocode="-33.365900,-70.513310,150km").items():
        print ([tweet.text, tweet.created_at, tweet.text.encode('utf-8')])
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# ['RT @RedPE_Chile: “Desigualdad de género y medio ambiente, oportunidad de transformación” reflexiona  Anahí Urquiza @anahiurquiza en @Cooper…', datetime.datetime(2020, 3, 16, 21, 30, 44), b'RT @RedPE_Chile: \xe2\x80\x9cDesigualdad de g\xc3\xa9nero y medio ambiente, oportunidad de transformaci\xc3\xb3n\xe2\x80\x9d reflexiona  Anah\xc3\xad Urquiza @anahiurquiza en @Cooper\xe2\x80\xa6']
# ['A la gente que usa mascarilla y que supuestamente sabe usarlas porfa cuiden el medio ambiente y no los dejen tirado… https://t.co/oPwpLvf8r6', datetime.datetime(2020, 3, 16, 20, 25, 14), b'A la gente que usa mascarilla y que supuestamente sabe usarlas porfa cuiden el medio ambiente y no los dejen tirado\xe2\x80\xa6 https://t.co/oPwpLvf8r6']
# ['@juanmi_garces Mentira porque nunca me respetaste como encargado de medio ambiente. Sos un puto. Pero con respeto 😘', datetime.datetime(2020, 3, 16, 20, 17, 4), b'@juanmi_garces Mentira porque nunca me respetaste como encargado de medio ambiente. Sos un puto. Pero con respeto \xf0\x9f\x98\x98']
# ['RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitización de trenes de Metro Valparaíso. En el proceso se util…', datetime.datetime(2020, 3, 16, 20, 13, 58), b'RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitizaci\xc3\xb3n de trenes de Metro Valpara\xc3\xadso. En el proceso se util\xe2\x80\xa6']
# ['Talleres sustentables enseñan a ser amigables con el medio ambiente » https://t.co/LwiaBpuPMW https://t.co/aNprsV4iLr', datetime.datetime(2020, 3, 16, 19, 0), b'Talleres sustentables ense\xc3\xb1an a ser amigables con el medio ambiente \xc2\xbb https://t.co/LwiaBpuPMW https://t.co/aNprsV4iLr']
# ['Esto es sorprendente, cinco billones de bolsas de plástico se utilizan cada año y casi 70% o más van al medio ambie… https://t.co/F3FnUcqJJQ', datetime.datetime(2020, 3, 16, 18, 43, 17), b'Esto es sorprendente, cinco billones de bolsas de pl\xc3\xa1stico se utilizan cada a\xc3\xb1o y casi 70% o m\xc3\xa1s van al medio ambie\xe2\x80\xa6 https://t.co/F3FnUcqJJQ']
# ['RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou…', datetime.datetime(2020, 3, 16, 18, 37, 10), b'RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou\xe2\x80\xa6']
# ['RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou…', datetime.datetime(2020, 3, 16, 18, 35, 36), b'RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou\xe2\x80\xa6']
# ['RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou…', datetime.datetime(2020, 3, 16, 18, 33), b'RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou\xe2\x80\xa6']
# ['RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitización de trenes de Metro Valparaíso. En el proceso se util…', datetime.datetime(2020, 3, 16,
# ['👉🏭El parón de actividad industrial tiene un inesperado efecto en el medio ambiente y la atmósfera. 🌎… https://t.co/DEfeybFIh2', datetime.datetime(2020, 3, 16, 15, 4, 26), b'\xf0\x9f\x91\x89\xf0\x9f\x8f\xadEl par\xc3\xb3n de actividad industrial tiene un inesperado efecto en el medio ambiente y la atm\xc3\xb3sfera. \xf0\x9f\x8c\x8e\xe2\x80\xa6 https://t.co/DEfeybFIh2']
# ['No soy experto en el tema, solo utilizando la lógica. Pero me imagino que salud no solamente juego un rol clave, me… https://t.co/u9mTPvaQRg', datetime.datetime(2020, 3, 16, 14, 10, 35), b'No soy experto en el tema, solo utilizando la l\xc3\xb3gica. Pero me imagino que salud no solamente juego un rol clave, me\xe2\x80\xa6 https://t.co/u9mTPvaQRg']
# ['RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitización de trenes de Metro Valparaíso. En el proceso se util…', datetime.datetime(2020, 3, 16, 13, 31, 13), b'RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitizaci\xc3\xb3n de trenes de Metro Valpara\xc3\xadso. En el proceso se util\xe2\x80\xa6']
# ['#AperturaSesionesGC. Estuvimos acompañando a @TadeoGZ en su valoración de gestión 2019 y  los desafíos para el 2020… https://t.co/VFWWpaxi7G', datetime.datetime(2020, 3, 16, 13, 18, 31), b'#AperturaSesionesGC. Estuvimos acompa\xc3\xb1ando a @TadeoGZ en su valoraci\xc3\xb3n de gesti\xc3\xb3n 2019 y  los desaf\xc3\xados para el 2020\xe2\x80\xa6 https://t.co/VFWWpaxi7G']
# ['RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou…', datetime.datetime(2020, 3, 16, 13, 9, 24), b'RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou\xe2\x80\xa6']
# ['RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou…', datetime.datetime(2020, 3, 16, 13, 1, 28), b'RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou\xe2\x80\xa6']
# ['RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitización de trenes de Metro Valparaíso. En el proceso se util…', datetime.datetime(2020, 3, 16, 12, 45, 11), b'RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitizaci\xc3\xb3n de trenes de Metro Valpara\xc3\xadso. En el proceso se util\xe2\x80\xa6']
# ['RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitización de trenes de Metro Valparaíso. En el proceso se util…', datetime.datetime(2020, 3, 16, 12, 42, 25), b'RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitizaci\xc3\xb3n de trenes de Metro Valpara\xc3\xadso. En el proceso se util\xe2\x80\xa6']
# ['RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou…', datetime.datetime(2020, 3, 16, 12, 35, 24), b'RT @FIMA_Chile: #JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fernando Dou\xe2\x80\xa6']
# ['#JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fern… https://t.co/btKyIwhc7K', datetime.datetime(2020, 3, 16, 12, 30, 32), b'#JusticiaAmbiental\n"REFLEXIONES SOBRE ALGUNOS PRINCIPIOS Y\nVALORES QUE REGULAN EL MEDIO AMBIENTE EN CHILE" Por Fern\xe2\x80\xa6 https://t.co/btKyIwhc7K']
# ['RT @JuntaCasino55: ⚠️ ATENCIÓN ⚠️\nDurante todo este fin de semana y hasta las 08:00 horas de este lunes contaremos con dos bateas para reci…', datetime.datetime(2020, 3, 16, 12, 15, 21), b'RT @JuntaCasino55: \xe2\x9a\xa0\xef\xb8\x8f ATENCI\xc3\x93N \xe2\x9a\xa0\xef\xb8\x8f\nDurante todo este fin de semana y hasta las 08:00 horas de este lunes contaremos con dos bateas para reci\xe2\x80\xa6']
# ['Por ahora, el @Senado_Chile suspendió las comisiones de Trabajo (Pensiones) y Medio Ambiente (Ley Marco Cambio Clim… https://t.co/IWWBiR6KC8', datetime.datetime(2020, 3, 16, 11, 59, 24), b'Por ahora, el @Senado_Chile suspendi\xc3\xb3 las comisiones de Trabajo (Pensiones) y Medio Ambiente (Ley Marco Cambio Clim\xe2\x80\xa6 https://t.co/IWWBiR6KC8']
# ['@carcamofelipe También existe la de áridos , glaciares, agua el extractivismo mata el hábitat y medio ambiente', datetime.datetime(2020, 3, 16, 11, 55, 20), b'@carcamofelipe Tambi\xc3\xa9n existe la de \xc3\xa1ridos , glaciares, agua el extractivismo mata el h\xc3\xa1bitat y medio ambiente']
# ['RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitización de trenes de Metro Valparaíso. En el proceso se util…', datetime.datetime(2020, 3, 16, 11, 55, 8), b'RT @MetroValpo: Diariamente en nuestras cocheras se realiza la limpieza y sanitizaci\xc3\xb3n de trenes de Metro Valpara\xc3\xadso. En el proceso se util\xe2\x80\xa6']
# 
# ['RT @PlasticOceansCL: 🔵AHORA🔵\n¡UN GRAN AVANCE EN LA PROTECCIÓN DE LOS OCÉANOS!\nComisión de Medio Ambiente del Senado despacha proyecto que b…', datetime.datetime(2020, 3, 10, 23, 1, 34), b'RT @PlasticOceansCL: \xf0\x9f\x94\xb5AHORA\xf0\x9f\x94\xb5\n\xc2\xa1UN GRAN AVANCE EN LA PROTECCI\xc3\x93N DE LOS OC\xc3\x89ANOS!\nComisi\xc3\xb3n de Medio Ambiente del Senado despacha proyecto que b\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 54, 41), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @Senado_Chile: ⭕️Fin a plásticos de un solo uso avanza en el Senado:\n\nMoción parlamentaria, aprobada por la comisión de Medio Ambiente,…', datetime.datetime(2020, 3, 10, 22, 53, 50), b'RT @Senado_Chile: \xe2\xad\x95\xef\xb8\x8fFin a pl\xc3\xa1sticos de un solo uso avanza en el Senado:\n\nMoci\xc3\xb3n parlamentaria, aprobada por la comisi\xc3\xb3n de Medio Ambiente,\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 51, 34), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @Senado_Chile: ⭕️Fin a plásticos de un solo uso avanza en el Senado:\n\nMoción parlamentaria, aprobada por la comisión de Medio Ambiente,…', datetime.datetime(2020, 3, 10, 22, 50, 13), b'RT @Senado_Chile: \xe2\xad\x95\xef\xb8\x8fFin a pl\xc3\xa1sticos de un solo uso avanza en el Senado:\n\nMoci\xc3\xb3n parlamentaria, aprobada por la comisi\xc3\xb3n de Medio Ambiente,\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 50, 11), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @GatosQls: Paso piola, pero el martes pasado la Comisión de Medio Ambiente, rechazó el proyecto de Ley que buscaba considerar al rodeo c…', datetime.datetime(2020, 3, 10, 22, 46, 18), b'RT @GatosQls: Paso piola, pero el martes pasado la Comisi\xc3\xb3n de Medio Ambiente, rechaz\xc3\xb3 el proyecto de Ley que buscaba considerar al rodeo c\xe2\x80\xa6']
# ['RT @GatosQls: Paso piola, pero el martes pasado la Comisión de Medio Ambiente, rechazó el proyecto de Ley que buscaba considerar al rodeo c…', datetime.datetime(2020, 3, 10, 22, 33, 52), b'RT @GatosQls: Paso piola, pero el martes pasado la Comisi\xc3\xb3n de Medio Ambiente, rechaz\xc3\xb3 el proyecto de Ley que buscaba considerar al rodeo c\xe2\x80\xa6']
# ['RT @GatosQls: Paso piola, pero el martes pasado la Comisión de Medio Ambiente, rechazó el proyecto de Ley que buscaba considerar al rodeo c…', datetime.datetime(2020, 3, 10, 22, 29, 28), b'RT @GatosQls: Paso piola, pero el martes pasado la Comisi\xc3\xb3n de Medio Ambiente, rechaz\xc3\xb3 el proyecto de Ley que buscaba considerar al rodeo c\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 28, 40), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 26, 8), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 25, 12), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 25, 2), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 24, 55), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @nicolasyanez: La Constitución también garantiza "el derecho a vivir en un medio ambiente libre de contaminación" pero sabemos que no se…', datetime.datetime(2020, 3, 10, 22, 24, 26), b'RT @nicolasyanez: La Constituci\xc3\xb3n tambi\xc3\xa9n garantiza "el derecho a vivir en un medio ambiente libre de contaminaci\xc3\xb3n" pero sabemos que no se\xe2\x80\xa6']
# ['RT @GatosQls: Paso piola, pero el martes pasado la Comisión de Medio Ambiente, rechazó el proyecto de Ley que buscaba considerar al rodeo c…', datetime.datetime(2020, 3, 10, 22, 24, 23), b'RT @GatosQls: Paso piola, pero el martes pasado la Comisi\xc3\xb3n de Medio Ambiente, rechaz\xc3\xb3 el proyecto de Ley que buscaba considerar al rodeo c\xe2\x80\xa6']
# ['RT @Senado_Chile: ⭕️Fin a plásticos de un solo uso avanza en el Senado:\n\nMoción parlamentaria, aprobada por la comisión de Medio Ambiente,…', datetime.datetime(2020, 3, 10, 22, 18, 44), b'RT @Senado_Chile: \xe2\xad\x95\xef\xb8\x8fFin a pl\xc3\xa1sticos de un solo uso avanza en el Senado:\n\nMoci\xc3\xb3n parlamentaria, aprobada por la comisi\xc3\xb3n de Medio Ambiente,\xe2\x80\xa6']
# ['RT @ElDescorcheNews: 🚴IMPORTANTE “BICICLETEADA” POR EL MEDIO AMBIENTE\n#Maipú #Mendoza \n.\nEn el día mundial de la Eficiencia Energética, un…', datetime.datetime(2020, 3, 10, 22, 18, 39), b'RT @ElDescorcheNews: \xf0\x9f\x9a\xb4IMPORTANTE \xe2\x80\x9cBICICLETEADA\xe2\x80\x9d POR EL MEDIO AMBIENTE\n#Maip\xc3\xba #Mendoza \n.\nEn el d\xc3\xada mundial de la Eficiencia Energ\xc3\xa9tica, un\xe2\x80\xa6']
# ['RT @PaisCircular: 👉Un smartphone 📱apenas contamina por sí mismo durante su vida útil. Su consumo energético a lo largo del año es anecdótic…', datetime.datetime(2020, 3, 10, 22, 12, 58), b'RT @PaisCircular: \xf0\x9f\x91\x89Un smartphone \xf0\x9f\x93\xb1apenas contamina por s\xc3\xad mismo durante su vida \xc3\xbatil. Su consumo energ\xc3\xa9tico a lo largo del a\xc3\xb1o es anecd\xc3\xb3tic\xe2\x80\xa6']
# ['RT @Senado_Chile: ⭕️Fin a plásticos de un solo uso avanza en el Senado:\n\nMoción parlamentaria, aprobada por la comisión de Medio Ambiente,…', datetime.datetime(2020, 3, 10, 22, 10, 27), b'RT @Senado_Chile: \xe2\xad\x95\xef\xb8\x8fFin a pl\xc3\xa1sticos de un solo uso avanza en el Senado:\n\nMoci\xc3\xb3n parlamentaria, aprobada por la comisi\xc3\xb3n de Medio Ambiente,\xe2\x80\xa6']
# ['RT @Senado_Chile: ⭕️Fin a plásticos de un solo uso avanza en el Senado:\n\nMoción parlamentaria, aprobada por la comisión de Medio Ambiente,…', datetime.datetime(2020, 3, 10, 22, 9, 16), b'RT @Senado_Chile: \xe2\xad\x95\xef\xb8\x8fFin a pl\xc3\xa1sticos de un solo uso avanza en el Senado:\n\nMoci\xc3\xb3n parlamentaria, aprobada por la comisi\xc3\xb3n de Medio Ambiente,\xe2\x80\xa6']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-142f6ab00734> in <module>
#       7 with open (filename, 'a+', newline='') as csvFile:
#       8     csvWriter = csv.writer(csvFile)
# ----> 9     for tweet in tweepy.Cursor(api.search ,  q = 'medio ambiente',geocode="-33.365900,-70.513310,150km").items():
#      10         print ([tweet.text, tweet.created_at, tweet.text.encode('utf-8')])
#      11         csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
#
# ~\Miniconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~\Miniconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~\Miniconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~\Miniconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\Miniconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %% [markdown]
# # Información extraíble de cada tweet:
# created_at: la fecha de creacion del tweet.
#
# text: el texto del tweet.
#
# id: El identificador del tweet.
#
# favorite_count: el número de favoritos.
#
# retweet_count: el número de retweets.
#
# favorited: los favoritos.
#
# retweeted: booleano que establece si el usuario esta autenticado.
#
# lang: acrónimo para el idioma.
#
# place, coordinates, geo: información de geolocalización si es que está disponble.
#
# user: el perfil completo del autor.
#
# ## Importante: razón para usar BdeD NoSQL:
# ### twitter no está estructurado, por lo que el excel no cargará si existe algún símbolo en él.
#
# entities: lista de entidades como URL, @ -menciones, hashtags y símbolos.
#
# in_reply_to_user_id: identificador de usuario si el tweet es una respuesta a un usuario específico.
#
# in_reply_to_status_id: identificador de estado si id el tweet es una respuesta a un estado específico.

# %% [markdown]
# ### Podemos identificar los últimos usuarios y su localización respecto a un tema específico
# #### Fuente: https://www.earthdatascience.org/courses/earth-analytics-python/using-apis-natural-language-processing-twitter/get-and-use-twitter-data-in-python/

# %%
import pandas as pd
search_words = "#wildfires"
date_since = "2018-11-16"
tweets = tweepy.Cursor(api.search, 
                           q = search_words,
                           #geocode="-33.365900,-70.513310,150km",
                           lang="es",
                           since=date_since).items(50)
users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs

# %% [markdown]
# #### y desplegar un dataframe:

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location"])
tweet_text
# Out:
#             user                location
# 0       racasant                  Madrid
# 1  IngForestal50
# 2        rimasu3         Badajoz, España
# 3     DemontesOT  Sede Central en Madrid

# %% [markdown]
# El parámetro until es específico y no se puede establecer para un periodo de tiempo que exceda los 7 días del momento actual.

# %% [markdown]
# <img src="tweet001.jpg">

# %%
new_search = "medio ambiente -filter:retweets"
import datetime

    
tweets = tweepy.Cursor(api.search,
                   q=new_search,
                   #geocode="-33.365900,-70.513310,5km",
                   lang="es",
                    
                # podemos obtener los tweets desde el 2020-03-10
                # hasta el 2020-03-11:
                   since='2020-03-10',
                   until = '2020-03-11').items(50)

all_tweets = [ tweet.created_at for tweet in tweets]
all_tweets[:50]
# Out:
# [datetime.datetime(2020, 3, 10, 23, 59, 11),
#  datetime.datetime(2020, 3, 10, 23, 58, 50),
#  datetime.datetime(2020, 3, 10, 23, 58, 9),
#  datetime.datetime(2020, 3, 10, 23, 58, 5),
#  datetime.datetime(2020, 3, 10, 23, 57, 54),
#  datetime.datetime(2020, 3, 10, 23, 55, 52),
#  datetime.datetime(2020, 3, 10, 23, 55, 44),
#  datetime.datetime(2020, 3, 10, 23, 53, 4),
#  datetime.datetime(2020, 3, 10, 23, 52, 5),
#  datetime.datetime(2020, 3, 10, 23, 51, 29),
#  datetime.datetime(2020, 3, 10, 23, 50, 51),
#  datetime.datetime(2020, 3, 10, 23, 47, 20),
#  datetime.datetime(2020, 3, 10, 23, 46, 55),
#  datetime.datetime(2020, 3, 10, 23, 45, 10),
#  datetime.datetime(2020, 3, 10, 23, 44, 1),
#  datetime.datetime(2020, 3, 10, 23, 43, 58),
#  datetime.datetime(2020, 3, 10, 23, 43, 43),
#  datetime.datetime(2020, 3, 10, 23, 43, 36),
#  datetime.datetime(2020, 3, 10, 23, 41, 4),
#  datetime.datetime(2020, 3, 10, 23, 40, 44),
#  datetime.datetime(2020, 3, 10, 23, 40, 5),
#  datetime.datetime(2020, 3, 10, 23, 40),
#  datetime.datetime(2020, 3, 10, 23, 38, 49),
#  datetime.datetime(2020, 3, 10, 23, 37, 26),
#  datetime.datetime(2020, 3, 10, 23, 36, 51),
#  datetime.datetime(2020, 3, 10, 23, 34, 54),
#  datetime.datetime(2020, 3, 10, 23, 34, 36),
#  datetime.datetime(2020, 3, 10, 23, 33, 10),
#  datetime.datetime(2020, 3, 10, 23, 32, 29),
#  datetime.datetime(2020, 3, 10, 23, 31, 51),
#  datetime.datetime(2020, 3, 10, 23, 30, 33),
#  datetime.datetime(2020, 3, 10, 23, 30, 32),
#  datetime.datetime(2020, 3, 10, 23, 30, 4),
#  datetime.datetime(2020, 3, 10, 23, 30, 1),
#  datetime.datetime(2020, 3, 10, 23, 29, 53),
#  datetime.datetime(2020, 3, 10, 23, 29, 14),
#  datetime.datetime(2020, 3, 10, 23, 29, 8),
#  datetime.datetime(2020, 3, 10, 23, 28, 20),
#  datetime.datetime(2020, 3, 10, 23, 27, 59),
#  datetime.datetime(2020, 3, 10, 23, 27, 50),
#  datetime.datetime(2020, 3, 10, 23, 26, 48),
#  datetime.datetime(2020, 3, 10, 23, 26, 28),
#  datetime.datetime(2020, 3, 10, 23, 25, 45),
#  datetime.datetime(2020, 3, 10, 23, 24, 49),
#  datetime.datetime(2020, 3, 10, 23, 23, 49),
#  datetime.datetime(2020, 3, 10, 23, 22, 45),
#  datetime.datetime(2020, 3, 10, 23, 22, 5),
#  datetime.datetime(2020, 3, 10, 23, 21, 37),
#  datetime.datetime(2020, 3, 10, 23, 21, 13),
#  datetime.datetime(2020, 3, 10, 23, 20, 11)]

# %% [markdown]
# ### Análisis de sentimientos

# %%
import textblob
import matplotlib.pyplot as plt

# %%
keyword=input('Que concepto quieres buscar?')
numberOfTweets=int(input('Ingresa el número de tweets'))

tweets = tweepy.Cursor(api.search, q=keyword, lang='es').items(numberOfTweets)


positive = 0
negative = 0
neutral = 0
polarity = 0

def calculatePercentage(a,b):
    return 100*float(a)/float(b)

for tweet in tweets:
    print(tweet.text)
    myAnalysis=textblob.TextBlob(tweet.text)
    polarity += myAnalysis.sentiment.polarity
    if myAnalysis.sentiment.polarity ==0:
        neutral+=1
    elif myAnalysis.sentiment.polarity > 0.00:
        positive+=1
    elif myAnalysis.sentiment.polarity < 0.00:
        negative+=1

positive=calculatePercentage(positive,numberOfTweets)
negative=calculatePercentage(negative,numberOfTweets)
neutral=calculatePercentage(neutral,numberOfTweets)

positive=format(positive,'.2f')
negative=format(negative,'.2f')
neutral=format(neutral,'.2f')

print('----------------------------------------------------------------------------')
if polarity>0:
    print('Positive')
elif polarity<0:
    print('Negative')
elif polarity==0:
    print('Neutral')

labels = ['Positive [' + str(positive) + '%]', 'Neutral [' + str(neutral) + '%]','Negative [' + str(negative) + '%]']
sizes=[positive,neutral,negative]
colors=['green','yellow','red']
patches,texts=plt.pie(sizes,colors=colors,startangle=90)
plt.legend(patches,labels,loc="best")
plt.title('Cómo las personas reaccionan a ' + keyword + ' analizando ' + str(numberOfTweets) + ' Tweets.')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Que concepto quieres buscar?medio ambiente
# Ingresa el número de tweets50
# RT @floraim40: ...¡ ¡ QUÉ CRIMINALES TAN SALVAJES , ASESINOS DEL MEDIO AMBIENTE , BRUTOS , DIGNOS DEL PEOR CASTIGO !
# RT @CNNChile: #DesafíoTierra | Se ven los peces en Venecia: El impacto inesperado de una pandemia en el medio ambiente https://t.co/sy3REuO…
# RT @Ahoztar1972: HILO
#
# El fallido pelotazo en el barrio Txonta de Eibar está vinculado a las carreras de varios cargos de la Consejería de…
# RT @ballenablanca_: Ahora mismo solo nos importa el coronavirus, pero no podemos dejar caer todo lo demás https://t.co/o2789odS4q Estamos a…
# RT @SedecoCDMX: Compartimos la entrevista que realizó @laprensaoem a nuestro Secretario @FadlalaAkabani respecto a la estrategia #CiudadSol…
# RT @id_Mou77: @SOYAPANGOalcald atentamente denuncio que en las orillas del cerro San Jacinto se hace quema de "rastrojo" en horas de la tar…
# ¿Y todos los trapitos de crochet que recicló Naviband? Tan concienciados con el medio ambiente 😍#barquitodekiev
# @xeunoticias A ver si no contaminan a los peces y despues regresa al comerce el pescado el CORONAVIRUS,se deberian… https://t.co/jAmIGRqSc4
# RT @juralde: Eh! Que #lacafetera de @radiocable sigue!! Y los martes hablamos de medio ambiente. Mañana vamos a tocar los aspectos ambienta…
# RT @Antonio1Moreno: En definitiva, la creación en la que estamos insertos es un proceso dinámico, no estático. No somos figuritas de un Bel…
# RT @EdgarNewsTX: El puerto de Tuxpan será transformados en el recinto absolutamente sustentable y amigable con el medio ambiente, luego de…
# @criticaenlinea Esto está sirviendo para aliviar un poco al medio ambiente del caos al que lo hemos sometido por décadas.
# RT @elANTIMILI: Vea, ¿Quién responde por estos daños al medio ambiente @AlcaldiadeMed @Areametropol @QuinteroCalle @ISAZULETA?
#
# Está quebr…
# RT @ballenablanca_: Estamos a 19€ de llegar al 70% del objetivo mínimo para sacar el especial sobre publicidad engañosa en medio ambiente h…
# RT @PeoplesFather1: @geropm @funadospodcast @AXELKAISER Si lo que hay es problema de oferta. China la fabrica del mundo ha cerrado. Esas me…
# RT @urbasanatur: @pablom_m @bmolinaicortes Esto quiere decir que si se ponen las medidas adecuadas el Medio Ambiente en general, la flora,…
# RT @RevistaSemana: A las 7 p.m. de este lunes, los defensores del agua y de los ecosistemas del páramo de Santurbán harán escuchar sus voce…
# RT @saydabulneshn: CARACTERÍSTICAS DE LOS SERES DE LUZ ENCARNADOS EN El PLANETA 💥 Parte 2
# Consciente o inconscientemente llevan MEMORIAS DE…
# #RÍOBRAVO
# Aportará Conafor RB 10 mil árboles.
# https://t.co/3hOaxHwZ06 https://t.co/LYMnWYDhud
# #RÍOBRAVO
# Aportará Conafor RB 10 mil árboles.
# https://t.co/y6wmsdcklJ https://t.co/4EZKeAv9AD
# RT @PresidenciaCuba: Comienza en la tarde de #Hoy 16 de Marzo, el Balance anual perteneciente al @citmacuba, Ministerio de Ciencia, Tecnolo…
# RT @EdgarNewsTX: El puerto de Tuxpan será transformados en el recinto absolutamente sustentable y amigable con el medio ambiente, luego de…
# RT @RevistaSemana: A las 7 p.m. de este lunes, los defensores del agua y de los ecosistemas del páramo de Santurbán harán escuchar sus voce…
# RT @PresidenciaCuba: Comienza en la tarde de #Hoy 16 de Marzo, el Balance anual perteneciente al @citmacuba, Ministerio de Ciencia, Tecnolo…
# RT @Lirdenis995: COVID-19 y su impacto al medio ambiente,
#
# La madre naturaleza siendo paciente https://t.co/J7fkbNYo9H
# RT @Ernesto20831379: @DiazCanelB @Granma_Digital Nueva inyección de energía limpia al pueblo de #Cuba, el mayor beneficiado en el uso de la…
# RT @unlp: #TrenUniversitario @tauberfernando: "La finalidad es que la #UNLP llegue al sudoeste de nuestra ciudad y que miles de estudiantes…
# ----------------------------------------------------------------------------
# Positive

# %% [markdown]
# Otra perspectiva:
#
# Obtengamos las últimas 100 publicaciones para el usuario de Twitter Bill Gates y mostremos sólo los primeros 5 tweets más recientes.
# Fuente:https://medium.com/@randerson112358/twitter-sentiment-analysis-15d8892c0082

# %%
# Extract 100 tweets from the twitter user
posts = api.user_timeline(screen_name="carmen_hertz", 
                          count = 100, lang ="en", tweet_mode="extended")

#  Print the last 5 tweets
print("Show the 5 recent tweets:\n")
i=1
for tweet in posts[:5]:
    print(str(i) +') '+ tweet.full_text + '\n')
    i= i+1
# Out:
# Show the 5 recent tweets:
#
# 1) RT @PCdeChile: ¡Propuestas de las y los comunistas para enfrentar el Coronavirus!
#
# ✅Gratuidad en la cobertura del examen.
# ✅Especial vigilan…
#
# 2) Directora Escuela de Salud Pública U. de Chile: “Las próximas tres semanas son críticas para lograr un quiebre en la proyección de nuevos casos de COVID-19 y evitar que colapse la red de salud” https://t.co/x1dPTsGhNk
#
# 3) RT @AlvarezMalebran: 🔴🦠Izkia Siches, Presidenta del Colegio Médico, explica que la Fase 4 es igual distanciamiento social: No misas, reunio…
#
# 4) RT @danieljadue: Hago un llamado respetuoso al gobierno a decretar estado de emergencia y fijar o controlar los precios de los productos bá…
#
# 5) RT @elchascas: La Unesco ha subido a internet el acceso a la Biblioteca Digital Mundial. Pego aquí el enlace para que padres e hijos puedan…

# %% [markdown]
# Creemos un dataframe con una columna llamada "Tweets" que contendrá las publicaciones del usuario de Twitter y que luego muestre las primeras 5 filas.

# %%
# Cree un marco de datos con una columna llamada Tweets:
df = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
# Mostrar las primeras 5 filas de datos:
df.head()
# Out:
#                                               Tweets
# 0  RT @PCdeChile: ¡Propuestas de las y los comuni...
# 1  Directora Escuela de Salud Pública U. de Chile...
# 2  RT @AlvarezMalebran: 🔴🦠Izkia Siches, President...
# 3  RT @danieljadue: Hago un llamado respetuoso al...
# 4  RT @elchascas: La Unesco ha subido a internet ...

# %% [markdown]
# Los datos están un poco sucios porque contienen el símbolo "@", hipervínculos, RT y pueden contener etiquetas hash "#", por lo que los limpiaremos creando una función para eliminar estos símbolos de los tweets. Luego aplicaremos esa función a los Tweets y mostraré los resultados.

# %%
# Creamos una función para limpiar los tweets
import re
def cleanTxt(text):
     text = re.sub('@[A-Za-z0–9]+', '', text) #Removing @mentions
     text = re.sub('#', '', text) # Removing '#' hash tag
     text = re.sub('RT[\s]+', '', text) # Removing RT
     text = re.sub('https?:\/\/\S+', '', text) # Removing hyperlink
     return text

# Limpiamos los tweets
df['Tweets'] = df['Tweets'].apply(cleanTxt)

# Mostramos los tweets limpios
df
# Out:
#                                                Tweets
# 0   : ¡Propuestas de las y los comunistas para enf...
# 1   Directora Escuela de Salud Pública U. de Chile...
# 2   : 🔴🦠Izkia Siches, Presidenta del Colegio Médic...
# 3   : Hago un llamado respetuoso al gobierno a dec...
# 4   : La Unesco ha subido a internet el acceso a l...
# ..                                                ...
# 95  _valdes La crítica política a los 30 años de t...
# 96  : Como cristianas y cristianos, comprometidos ...
# 97  : La diputada  fue ratificada por la Bancada _...
# 98                                               🌷🌷🌷😊
# 99  : VIDEO| Presidente del Colegio de Profesores ...
#
# [100 rows x 1 columns]

# %% [markdown]
# Queremos agregar la subjetividad y polaridad de los tweets al dataframe.
# Para hacer esto, crearemos dos funciones:
# 1. Una para obtener los tweets llamados subjetividad (cuán subjetivo u obstinado es el texto, un puntaje de 0 es un hecho y un puntaje de +1 es en gran medida una opinión) y
# 2. Otra para obtener el tweets llamados Polarity (qué tan positivo o negativo es el texto, un puntaje de -1 es el puntaje negativo más alto y un puntaje de +1 es el puntaje positivo más alto).
# A continuación, almacenaremos los resultados en dos columnas, una llamada "Subjetividad" y la otra llamada "Polaridad" y mostraremos los resultados.

# %%
from textblob import TextBlob

# Create a function to get the subjectivity
def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
   return  TextBlob(text).sentiment.polarity


# Create two new columns 'Subjectivity' & 'Polarity'
df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] = df['Tweets'].apply(getPolarity)

# Show the new dataframe with columns 'Subjectivity' & 'Polarity'
df
# Out:
#                                                Tweets  Subjectivity  Polarity
# 0   : ¡Propuestas de las y los comunistas para enf...      0.000000  0.000000
# 1   Directora Escuela de Salud Pública U. de Chile...      0.000000  0.000000
# 2   : 🔴🦠Izkia Siches, Presidenta del Colegio Médic...      0.066667  0.033333
# 3   : Hago un llamado respetuoso al gobierno a dec...      0.000000  0.000000
# 4   : La Unesco ha subido a internet el acceso a l...      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  _valdes La crítica política a los 30 años de t...      0.000000  0.000000
# 96  : Como cristianas y cristianos, comprometidos ...      0.000000  0.000000
# 97  : La diputada  fue ratificada por la Bancada _...      0.000000  0.000000
# 98                                               🌷🌷🌷😊      0.000000  0.000000
# 99  : VIDEO| Presidente del Colegio de Profesores ...      0.000000  0.000000
#
# [100 rows x 3 columns]

# %% [markdown]
# Veamos qué tan bien se distribuyen los sentimientos.
# Una buena manera de lograr esta tarea es entender las palabras comunes trazando
# nubes de palabras. Una nube de palabras (también conocida como nubes de texto o
# nubes de etiquetas) es una visualización, cuanto más aparece una palabra específica en el texto, más grande y más audaz aparece en la nube de palabras. Visualicemos todas las palabras en los datos usando el diagrama de nube de palabras. Parece que la palabra "salud" aparece mucho en los últimos 100 tweets de Bill Gates.

# %%
# visualización de la nube de palabras
from wordcloud import WordCloud
allWords = ' '.join([twts for twts in df['Tweets']])
wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size=110).generate(allWords)
plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Crearemos una función para calcular el análisis negativo (-1), neutral (0) y positivo (+1) y agregue la información a una nueva columna llamada Análisis, luego muestre los resultados.

# %%
# Create a function to compute negative (-1), neutral (0) and positive (+1) analysis
def getAnalysis(score):
 if score < 0:
  return 'Negative'
 elif score == 0:
  return 'Neutral'
 else:
  return 'Positive'


df['Analysis'] = df['Polarity'].apply(getAnalysis)

# Show the dataframe
df
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   : ¡Propuestas de las y los comunistas para enf...      0.000000  0.000000
# 1   Directora Escuela de Salud Pública U. de Chile...      0.000000  0.000000
# 2   : 🔴🦠Izkia Siches, Presidenta del Colegio Médic...      0.066667  0.033333
# 3   : Hago un llamado respetuoso al gobierno a dec...      0.000000  0.000000
# 4   : La Unesco ha subido a internet el acceso a l...      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  _valdes La crítica política a los 30 años de t...      0.000000  0.000000
# 96  : Como cristianas y cristianos, comprometidos ...      0.000000  0.000000
# 97  : La diputada  fue ratificada por la Bancada _...      0.000000  0.000000
# 98                                               🌷🌷🌷😊      0.000000  0.000000
# 99  : VIDEO| Presidente del Colegio de Profesores ...      0.000000  0.000000
#
#     Analysis
# 0    Neutral
# 1    Neutral
# 2   Positive
# 3    Neutral
# 4    Neutral
# ..       ...
# 95   Neutral
# 96   Neutral
# 97   Neutral
# 98   Neutral
# 99   Neutral
#
# [100 rows x 4 columns]

# %% [markdown]
# Imprimamos los tweets positivos en orden ascendente. El tuit más positivo es el tuit # 1.

# %%
# Imprimimos los tweets positivos: 
print('Desplegamos los tweets positivos:\n')
j=1
sortedDF = df.sort_values(by=['Polarity']) # Ordenamos los tweets
for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Analysis'][i] == 'Positive'):
    print(str(j) + ') '+ sortedDF['Tweets'][i])
    print()
    j= j+1
# Out:
# Desplegamos los tweets positivos:
#
# 1) : 🔴🦠Izkia Siches, Presidenta del Colegio Médico, explica que la Fase 4 es igual distanciamiento social: No misas, reunio…
#
# 2) : Para el estallido social no les costó nada cerrar los malls. Para una pandemia ni ahí, siguen obligando a sus trabajadores…
#
# 3) : 3. No podré matar a todos...
#
# En realidad a ~80% de ustedes sólo les provocaré un resfrío. A ~15% lo hospitalizaré. Y sólo a ~5%…

# %% [markdown]
# Imprimimos los tweets negativos en orden descendente. El tuit más negativo es el tuit # 1.

# %%
# Impresión de los tweets negativos
  
print('Impresión de los tweets negativos:\n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False) #Sort the tweets
for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Analysis'][i] == 'Negative'):
    print(str(j) + ') '+sortedDF['Tweets'][i])
    print()
    j=j+1
# Out:
# Impresión de los tweets negativos:
#
# 1) : Carta abierta a Mariano Puga, de la Comunidad Cristiana de Base José Aldunate. (Por favor - difundir)
#
# 2) : [DENUNCIA]
# Ayer Patrick Carvajal (29) fue impactado x 1 lacrimógena es su cabeza. Hoy está grave con riesgo vital.Entubado y c…

# %% [markdown]
# Trace la polaridad y la subjetividad como un diagrama de dispersión. Parece que la mayoría de los tweets son positivos, ya que muchos de los puntos están en el lado derecho de la polaridad en el valor 0.00.

# %%
# Plotting 
plt.figure(figsize=(8,6)) 
for i in range(0, df.shape[0]):
  plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color='Blue') # plt.scatter(x,y,color)   
plt.title('Sentiment Analysis') 
plt.xlabel('Polarity') 
plt.ylabel('Subjectivity') 
plt.show()

# %% [markdown]
# Imprimimos el porcentaje de tweets positivos. Alrededor de 81/100 de los tweets se consideran tweets positivos.

# %%
# Print the percentage of positive tweets
ptweets = df[df.Analysis == 'Positive']
ptweets = ptweets['Tweets']
ptweets

round( (ptweets.shape[0] / df.shape[0]) * 100 , 1)
# Out:
# 3.0

# %% [markdown]
# Imprime el porcentaje de tweets negativos. Alrededor de 9/100 tweets se consideran tweets negativos.

# %%
# Print the percentage of negative tweets
ntweets = df[df.Analysis == 'Negative']
ntweets = ntweets['Tweets']
ntweets

round( (ntweets.shape[0] / df.shape[0]) * 100, 1)
# Out:
# 2.0

# %% [markdown]
# Mostrar el valor cuenta. Ahora podemos ver que 81 tweets son positivos, 10 son neutrales y 9 son negativos.

# %%
# Show the value counts
df['Analysis'].value_counts()
# Out:
# Neutral     95
# Positive     3
# Negative     2
# Name: Analysis, dtype: int64

# %% [markdown]
# Muestra visualmente el valor cuenta.

# %%
# Trazar y visualizar los recuentos
plt.title('Análisis de sentimientos')
plt.xlabel('Sentimiento')
plt.ylabel('Recuentos')
df['Analysis'].value_counts().plot(kind = 'bar')
plt.show()
