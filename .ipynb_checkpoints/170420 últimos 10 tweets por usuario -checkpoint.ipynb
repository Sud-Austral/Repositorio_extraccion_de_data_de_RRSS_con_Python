# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @ministeriosalud: Subsecretaria @pdazan: “todas las semanas se toman las medidas y si es necesario se evalúan cierres de nuevas comunas…
#
# RT @ministeriosalud: Subsecretaria @pdazan hace llamado a seguir con las medidas de prevención y respetar las cuarentenas.
# De forma paulati…
#
# RT @ministeriosalud: Subsecretaria @pdazan | Exámenes #COVID_19
# -400 exámenes diarios
# -Positividad del 8%
# -Más de 50 laboratorios de todo…
#
# RT @ministeriosalud: Subsecretaria @pdazan | Reporte diario #COVID_19
# -358 casos nuevos
# -10.088 casos totales
# -7 personas fallecidas (133 e…
#
# RT @ministeriosalud: [EN VIVO] Subsecretaria @pdazan entrega balance diario de #COVID_19 en nuestro país. https://t.co/29fl6gzZMQ
#
# Donar sangre es donar vida.
# Si vas a salir, haz que valga la pena. Si tu comuna está en cuarentena puedes pedir tu… https://t.co/Ee12wVPhKH
#
# Si estás en aislamiento domiciliario, es muy importante mantener las medidas de prevención en el hogar.
#
# - Lávate l… https://t.co/2nuW2lIAqv
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/rqCNm8WoJb
#
# Si tienes a un miembro del hogar diagnosticado con COVID 19, es muy importante que adoptes las siguientes medidas:… https://t.co/QUzUbue8SK
#
# RT @ministeriosalud: ¿Sabes qué es una Residencia Sanitaria?
# El subsecretario @arturozunigaj nos cuenta todo sobre ellas.
# Dale▶️ al video y…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @ministeriosalud: Subsecretaria @pdazan: “t...
# 1  RT @ministeriosalud: Subsecretaria @pdazan hac...
# 2  RT @ministeriosalud: Subsecretaria @pdazan | E...
# 3  RT @ministeriosalud: Subsecretaria @pdazan | R...
# 4  RT @ministeriosalud: [EN VIVO] Subsecretaria @...
# 5  Donar sangre es donar vida.\nSi vas a salir, h...
# 6  Si estás en aislamiento domiciliario, es muy i...
# 7  El uso correcto de la mascarilla es clave para...
# 8  Si tienes a un miembro del hogar diagnosticado...
# 9  RT @ministeriosalud: ¿Sabes qué es una Residen...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251897824171745282
# 2020-04-19 15:37:55
# Twitter for iPhone
# 0
# 8
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ministeriosalud', 'name': 'Ministerio de Salud', 'id': 153825949, 'id_str': '153825949', 'indices': [3, 19]}, {'screen_name': 'pdazan', 'name': 'Paula Daza', 'id': 2496588486, 'id_str': '2496588486', 'indices': [35, 42]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @ministeriosalud: Subsecretaria @pdazan: “t...  1251897824171745282
# 1  RT @ministeriosalud: Subsecretaria @pdazan hac...  1251897809915260930
# 2  RT @ministeriosalud: Subsecretaria @pdazan | E...  1251897799752536065
# 3  RT @ministeriosalud: Subsecretaria @pdazan | R...  1251897788079788035
# 4  RT @ministeriosalud: [EN VIVO] Subsecretaria @...  1251897773366087680
# 5  Donar sangre es donar vida.\nSi vas a salir, h...  1251888286278258689
# 6  Si estás en aislamiento domiciliario, es muy i...  1251873184187465728
# 7  El uso correcto de la mascarilla es clave para...  1251858085754187777
# 8  Si tienes a un miembro del hogar diagnosticado...  1251842986088030208
# 9  RT @ministeriosalud: ¿Sabes qué es una Residen...  1251713405515444225
#
#                  Date              Source  Likes  RTs
# 0 2020-04-19 15:37:55  Twitter for iPhone      0    8
# 1 2020-04-19 15:37:51  Twitter for iPhone      0   31
# 2 2020-04-19 15:37:49  Twitter for iPhone      0   31
# 3 2020-04-19 15:37:46  Twitter for iPhone      0   97
# 4 2020-04-19 15:37:42  Twitter for iPhone      0   99
# 5 2020-04-19 15:00:01           TweetDeck      1    2
# 6 2020-04-19 14:00:00           TweetDeck      2    4
# 7 2020-04-19 13:00:00           TweetDeck      1    1
# 8 2020-04-19 12:00:00           TweetDeck      3    1
# 9 2020-04-19 03:25:06  Twitter for iPhone      0   47

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @ministeriosalud: Subsecretaria @pdazan: “t...
# 1  RT @ministeriosalud: Subsecretaria @pdazan hac...
# 2  RT @ministeriosalud: Subsecretaria @pdazan | E...
# 3  RT @ministeriosalud: Subsecretaria @pdazan | R...
# 4  RT @ministeriosalud: [EN VIVO] Subsecretaria @...
# 5  Donar sangre es donar vida.\nSi vas a salir, h...
# 6  Si estás en aislamiento domiciliario, es muy i...
# 7  El uso correcto de la mascarilla es clave para...
# 8  Si tienes a un miembro del hogar diagnosticado...
# 9  RT @ministeriosalud: ¿Sabes qué es una Residen...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1251897824171... 2020-04-19 15:37:55
# 1  https://twitter.com/ispch/status/1251897809915... 2020-04-19 15:37:51
# 2  https://twitter.com/ispch/status/1251897799752... 2020-04-19 15:37:49
# 3  https://twitter.com/ispch/status/1251897788079... 2020-04-19 15:37:46
# 4  https://twitter.com/ispch/status/1251897773366... 2020-04-19 15:37:42
# 5  https://twitter.com/ispch/status/1251888286278... 2020-04-19 15:00:01
# 6  https://twitter.com/ispch/status/1251873184187... 2020-04-19 14:00:00
# 7  https://twitter.com/ispch/status/1251858085754... 2020-04-19 13:00:00
# 8  https://twitter.com/ispch/status/1251842986088... 2020-04-19 12:00:00
# 9  https://twitter.com/ispch/status/1251713405515... 2020-04-19 03:25:06
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0    8
# 1  Twitter for iPhone      0   31
# 2  Twitter for iPhone      0   31
# 3  Twitter for iPhone      0   97
# 4  Twitter for iPhone      0   99
# 5           TweetDeck      1    2
# 6           TweetDeck      2    4
# 7           TweetDeck      1    1
# 8           TweetDeck      3    1
# 9  Twitter for iPhone      0   47

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
