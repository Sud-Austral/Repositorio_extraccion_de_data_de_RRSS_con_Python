# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @ministeriosalud: Ministro @jmanalich| Recursos hospitalarios
# -588 ventiladores disponibles
# -360 pacientes en tratamiento intensivo htt…
#
# RT @ministeriosalud: Ministro @jmanalich| Reporte diario #COVID_19
# 478 casos nuevos
# 9730 casos totales
# 10 personas fallecidas (126 en tota…
#
# RT @arturozunigaj: 🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑
#
# En caravana!!!!
#
# Llegando los primeros pacientes al nuevo Hospital Felix Bulnes!!!
#
# Felicitaciones a todos…
#
# RT @ministeriosalud: [EN VIVO] Ministro @jmanalich entrega balance diario de #COVID_19 en nuestro país. https://t.co/9brtTDNUPR
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/eAwXErxEyP
#
# Prefiere medicamentos #bioequivalentes.
# El @ispch garantiza su calidad, seguridad y eficacia.
# #ExigeElAmarillo https://t.co/W0LdhA9lMC
#
# RT @seremisalud14: ✅Iniciamos la jornada en la costanera de #Valdiviacl vacunando a personas en situación de calle. El equipo de Seremi de…
#
# Inicio de uso obligatorio de mascarillas | ¿En qué lugares?
#
# Conoce más sobre esta nueva medida y encuentra más inf… https://t.co/DSrWgDhvop
#
# Inicio de uso obligatorio de mascarillas.
#
# Conoce más sobre esta nueva medida y encuentra más información en… https://t.co/rjLBTqIg4t
#
# Prefiere medicamentos #bioequivalentes.
# El @ispch garantiza su calidad, seguridad y eficacia.
# #ExigeElAmarillo https://t.co/vPQ1j4OBVj

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @ministeriosalud: Ministro @jmanalich| Recu...
# 1  RT @ministeriosalud: Ministro @jmanalich| Repo...
# 2  RT @arturozunigaj: 🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑 \n\nEn caravana!...
# 3  RT @ministeriosalud: [EN VIVO] Ministro @jmana...
# 4  El uso correcto de la mascarilla es clave para...
# 5  Prefiere medicamentos #bioequivalentes. \nEl @...
# 6  RT @seremisalud14: ✅Iniciamos la jornada en la...
# 7  Inicio de uso obligatorio de mascarillas | ¿En...
# 8  Inicio de uso obligatorio de mascarillas.\n\nC...
# 9  Prefiere medicamentos #bioequivalentes. \nEl @...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251528401657008129
# 2020-04-18 15:09:57
# Twitter for iPhone
# 0
# 17
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ministeriosalud', 'name': 'Ministerio de Salud', 'id': 153825949, 'id_str': '153825949', 'indices': [3, 19]}, {'screen_name': 'jmanalich', 'name': 'Jaime Mañalich', 'id': 114834301, 'id_str': '114834301', 'indices': [30, 40]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @ministeriosalud: Ministro @jmanalich| Recu...  1251528401657008129
# 1  RT @ministeriosalud: Ministro @jmanalich| Repo...  1251528383906877440
# 2  RT @arturozunigaj: 🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑 \n\nEn caravana!...  1251526977108029442
# 3  RT @ministeriosalud: [EN VIVO] Ministro @jmana...  1251526934430978048
# 4  El uso correcto de la mascarilla es clave para...  1251525899381547008
# 5  Prefiere medicamentos #bioequivalentes. \nEl @...  1251510799081897984
# 6  RT @seremisalud14: ✅Iniciamos la jornada en la...  1251509784974671873
# 7  Inicio de uso obligatorio de mascarillas | ¿En...  1251495699927101441
# 8  Inicio de uso obligatorio de mascarillas.\n\nC...  1251480598230646785
# 9  Prefiere medicamentos #bioequivalentes. \nEl @...  1251329602275823616
#
#                  Date              Source  Likes  RTs
# 0 2020-04-18 15:09:57  Twitter for iPhone      0   17
# 1 2020-04-18 15:09:53  Twitter for iPhone      0   86
# 2 2020-04-18 15:04:18  Twitter for iPhone      0   40
# 3 2020-04-18 15:04:08  Twitter for iPhone      0   96
# 4 2020-04-18 15:00:01           TweetDeck      2    1
# 5 2020-04-18 14:00:01           TweetDeck      2    1
# 6 2020-04-18 13:55:59  Twitter for iPhone      0   15
# 7 2020-04-18 13:00:01           TweetDeck      0    0
# 8 2020-04-18 12:00:00           TweetDeck      0    1
# 9 2020-04-18 02:00:00           TweetDeck      1    2

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @ministeriosalud: Ministro @jmanalich| Recu...
# 1  RT @ministeriosalud: Ministro @jmanalich| Repo...
# 2  RT @arturozunigaj: 🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑 \n\nEn caravana!...
# 3  RT @ministeriosalud: [EN VIVO] Ministro @jmana...
# 4  El uso correcto de la mascarilla es clave para...
# 5  Prefiere medicamentos #bioequivalentes. \nEl @...
# 6  RT @seremisalud14: ✅Iniciamos la jornada en la...
# 7  Inicio de uso obligatorio de mascarillas | ¿En...
# 8  Inicio de uso obligatorio de mascarillas.\n\nC...
# 9  Prefiere medicamentos #bioequivalentes. \nEl @...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1251528401657... 2020-04-18 15:09:57
# 1  https://twitter.com/ispch/status/1251528383906... 2020-04-18 15:09:53
# 2  https://twitter.com/ispch/status/1251526977108... 2020-04-18 15:04:18
# 3  https://twitter.com/ispch/status/1251526934430... 2020-04-18 15:04:08
# 4  https://twitter.com/ispch/status/1251525899381... 2020-04-18 15:00:01
# 5  https://twitter.com/ispch/status/1251510799081... 2020-04-18 14:00:01
# 6  https://twitter.com/ispch/status/1251509784974... 2020-04-18 13:55:59
# 7  https://twitter.com/ispch/status/1251495699927... 2020-04-18 13:00:01
# 8  https://twitter.com/ispch/status/1251480598230... 2020-04-18 12:00:00
# 9  https://twitter.com/ispch/status/1251329602275... 2020-04-18 02:00:00
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0   17
# 1  Twitter for iPhone      0   86
# 2  Twitter for iPhone      0   40
# 3  Twitter for iPhone      0   96
# 4           TweetDeck      2    1
# 5           TweetDeck      2    1
# 6  Twitter for iPhone      0   15
# 7           TweetDeck      0    0
# 8           TweetDeck      0    1
# 9           TweetDeck      1    2

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
