# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-16
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
prompt = '> '
tweet=''
print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = input(prompt)

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @jmanalich: ¿Cuál es el sentido esencial de...
# 1  Recuerda que desde hoy 𝘀𝗲 𝗮𝗺𝗽𝗹𝗶𝗼́ el uso oblig...
# 2  RT @latercera: 🔴 Paula Labra asume como nueva ...
# 3  RT @sebastianpinera: [EN VIVO] Iniciamos entre...
# 4  El ISP publica nuevo listado de exámenes de an...
# 5  [Actualización] Ministerio de Salud informa 9....
# 6  RT @arturozunigaj: Como cada día en el reporte...
# 7  RT @pdazan: Desde hoy comienza a regir la medi...
# 8  "Examen de anticuerpo será gratuito por indaga...
# 9  Ministro @jmanalich | Testeo\n\nExisten 3 tipo...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'quoted_status_id', 'quoted_status_id_str', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1251181129849114624
# 2020-04-17 16:10:01
# Twitter Web App
# 0
# 194
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'jmanalich', 'name': 'Jaime Mañalich', 'id': 114834301, 'id_str': '114834301', 'indices': [3, 13]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @jmanalich: ¿Cuál es el sentido esencial de...  1251181129849114624
# 1  Recuerda que desde hoy 𝘀𝗲 𝗮𝗺𝗽𝗹𝗶𝗼́ el uso oblig...  1251180230191923200
# 2  RT @latercera: 🔴 Paula Labra asume como nueva ...  1251176022550016000
# 3  RT @sebastianpinera: [EN VIVO] Iniciamos entre...  1251174350981525505
# 4  El ISP publica nuevo listado de exámenes de an...  1251173889389944832
# 5  [Actualización] Ministerio de Salud informa 9....  1251166802261884931
# 6  RT @arturozunigaj: Como cada día en el reporte...  1251164512385822720
# 7  RT @pdazan: Desde hoy comienza a regir la medi...  1251164430831742976
# 8  "Examen de anticuerpo será gratuito por indaga...  1251157610952183811
# 9  Ministro @jmanalich | Testeo\n\nExisten 3 tipo...  1251157608859230217
#
#                  Date                Source  Likes  RTs
# 0 2020-04-17 16:10:01       Twitter Web App      0  194
# 1 2020-04-17 16:06:27       Twitter Web App     46   53
# 2 2020-04-17 15:49:44       Twitter Web App      0   17
# 3 2020-04-17 15:43:05       Twitter Web App      0  214
# 4 2020-04-17 15:41:15             TweetDeck      6    7
# 5 2020-04-17 15:13:05  Twitter Media Studio     11   32
# 6 2020-04-17 15:03:59    Twitter for iPhone      0   31
# 7 2020-04-17 15:03:40    Twitter for iPhone      0   45
# 8 2020-04-17 14:36:34       Twitter Web App     25   29
# 9 2020-04-17 14:36:33       Twitter Web App     44   50

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @jmanalich: ¿Cuál es el sentido esencial de...
# 1  Recuerda que desde hoy 𝘀𝗲 𝗮𝗺𝗽𝗹𝗶𝗼́ el uso oblig...
# 2  RT @latercera: 🔴 Paula Labra asume como nueva ...
# 3  RT @sebastianpinera: [EN VIVO] Iniciamos entre...
# 4  El ISP publica nuevo listado de exámenes de an...
# 5  [Actualización] Ministerio de Salud informa 9....
# 6  RT @arturozunigaj: Como cada día en el reporte...
# 7  RT @pdazan: Desde hoy comienza a regir la medi...
# 8  "Examen de anticuerpo será gratuito por indaga...
# 9  Ministro @jmanalich | Testeo\n\nExisten 3 tipo...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ministeriosalud/status/125... 2020-04-17 16:10:01
# 1  https://twitter.com/ministeriosalud/status/125... 2020-04-17 16:06:27
# 2  https://twitter.com/ministeriosalud/status/125... 2020-04-17 15:49:44
# 3  https://twitter.com/ministeriosalud/status/125... 2020-04-17 15:43:05
# 4  https://twitter.com/ministeriosalud/status/125... 2020-04-17 15:41:15
# 5  https://twitter.com/ministeriosalud/status/125... 2020-04-17 15:13:05
# 6  https://twitter.com/ministeriosalud/status/125... 2020-04-17 15:03:59
# 7  https://twitter.com/ministeriosalud/status/125... 2020-04-17 15:03:40
# 8  https://twitter.com/ministeriosalud/status/125... 2020-04-17 14:36:34
# 9  https://twitter.com/ministeriosalud/status/125... 2020-04-17 14:36:33
#
#                  Source  Likes  RTs
# 0       Twitter Web App      0  194
# 1       Twitter Web App     46   53
# 2       Twitter Web App      0   17
# 3       Twitter Web App      0  214
# 4             TweetDeck      6    7
# 5  Twitter Media Studio     11   32
# 6    Twitter for iPhone      0   31
# 7    Twitter for iPhone      0   45
# 8       Twitter Web App     25   29
# 9       Twitter Web App     44   50

# %%
import csv
data.to_csv(r'tweets_opsoms.csv', index = False)
