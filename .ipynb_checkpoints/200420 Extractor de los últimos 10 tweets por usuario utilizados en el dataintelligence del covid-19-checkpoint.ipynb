# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# "La decisión de corte de asistencia a clases se tomó consultando y con los argumentos sobre la m…
#
# RT @ministeriosalud: Subsec @arturozunigaj | Red Asistencial #COVID_19
#
# ▪️ 6.365 exámenes realizados
# ▪️ 128.722 exámenes totales
# ▪️ Tasa de…
#
# RT @ministeriosalud: Subsec @arturozunigaj | Reporte diario #COVID_19
#
# ▪️ 464 casos nuevos
# ▪️ 11.296 casos totales
# ▪️ 5.386 recuperados
# ▪️…
#
# RT @ministeriosalud: Subsec @arturozunigaj | Nuevo @FelixHfb
#
# "Ayer se trasladó el último paciente al nuevo H. Félix Bulnes y que es uno d…
#
# RT @ministeriosalud: [AHORA] Autoridades de Salud entregan balance diario de #COVID_19 en nuestro país. https://t.co/2mWUzdU5hQ
#
# Si tienes a un miembro del hogar  diagnosticado con COVID 19, es muy importante que adoptes las siguientes medidas:… https://t.co/5ZoRG4W1kt
#
# RT @pdazan: No te olvides de las zonas que mañana continúan o entran a cuarentena en la RM. https://t.co/wF42BycIUL
#
# Si tienes un pañuelo en tu hogar, puedes convertirlo en una mascarilla.
#
# Sigue estos pasos y #CuidémonosEntreTodos https://t.co/mN0xNUkn9K
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/V5UrUce0hj
#
# Conoce más sobre esta nueva medida que comienza a implementarse y encuentra más información en… https://t.co/jg9GrACQwf

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 1  RT @ministeriosalud: Subsec @arturozunigaj | R...
# 2  RT @ministeriosalud: Subsec @arturozunigaj | R...
# 3  RT @ministeriosalud: Subsec @arturozunigaj | N...
# 4  RT @ministeriosalud: [AHORA] Autoridades de Sa...
# 5  Si tienes a un miembro del hogar  diagnosticad...
# 6  RT @pdazan: No te olvides de las zonas que mañ...
# 7  Si tienes un pañuelo en tu hogar, puedes conve...
# 8  Temperatura actual, pronóstico del tiempo y ra...
# 9  Conoce más sobre esta nueva medida que comienz...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252980392895877120
# 2020-04-22 15:19:39
# Twitter for iPhone
# 0
# 13
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ministeriosalud', 'name': 'Ministerio de Salud', 'id': 153825949, 'id_str': '153825949', 'indices': [3, 19]}, {'screen_name': 'jmanalich', 'name': 'Jaime Mañalich', 'id': 114834301, 'id_str': '114834301', 'indices': [30, 40]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...  1252980392895877120
# 1  RT @ministeriosalud: Subsec @arturozunigaj | R...  1252980381634134016
# 2  RT @ministeriosalud: Subsec @arturozunigaj | R...  1252980370481569792
# 3  RT @ministeriosalud: Subsec @arturozunigaj | N...  1252978280514404353
# 4  RT @ministeriosalud: [AHORA] Autoridades de Sa...  1252977062496866304
# 5  Si tienes a un miembro del hogar  diagnosticad...  1252975449539522560
# 6  RT @pdazan: No te olvides de las zonas que mañ...  1252965935536840704
# 7  Si tienes un pañuelo en tu hogar, puedes conve...  1252960348027719681
# 8  Temperatura actual, pronóstico del tiempo y ra...  1252946192201383936
# 9  Conoce más sobre esta nueva medida que comienz...  1252945251343273984
#
#                  Date              Source  Likes  RTs
# 0 2020-04-22 15:19:39  Twitter for iPhone      0   13
# 1 2020-04-22 15:19:36  Twitter for iPhone      0   44
# 2 2020-04-22 15:19:34  Twitter for iPhone      0  138
# 3 2020-04-22 15:11:15  Twitter for iPhone      0   16
# 4 2020-04-22 15:06:25  Twitter for iPhone      0  131
# 5 2020-04-22 15:00:00           TweetDeck      0    0
# 6 2020-04-22 14:22:12  Twitter for iPhone      0   57
# 7 2020-04-22 14:00:00           TweetDeck      0    1
# 8 2020-04-22 13:03:45  Twitter for iPhone      0    0
# 9 2020-04-22 13:00:01           TweetDeck      0    0

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 1  RT @ministeriosalud: Subsec @arturozunigaj | R...
# 2  RT @ministeriosalud: Subsec @arturozunigaj | R...
# 3  RT @ministeriosalud: Subsec @arturozunigaj | N...
# 4  RT @ministeriosalud: [AHORA] Autoridades de Sa...
# 5  Si tienes a un miembro del hogar  diagnosticad...
# 6  RT @pdazan: No te olvides de las zonas que mañ...
# 7  Si tienes un pañuelo en tu hogar, puedes conve...
# 8  Temperatura actual, pronóstico del tiempo y ra...
# 9  Conoce más sobre esta nueva medida que comienz...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1252980392895... 2020-04-22 15:19:39
# 1  https://twitter.com/ispch/status/1252980381634... 2020-04-22 15:19:36
# 2  https://twitter.com/ispch/status/1252980370481... 2020-04-22 15:19:34
# 3  https://twitter.com/ispch/status/1252978280514... 2020-04-22 15:11:15
# 4  https://twitter.com/ispch/status/1252977062496... 2020-04-22 15:06:25
# 5  https://twitter.com/ispch/status/1252975449539... 2020-04-22 15:00:00
# 6  https://twitter.com/ispch/status/1252965935536... 2020-04-22 14:22:12
# 7  https://twitter.com/ispch/status/1252960348027... 2020-04-22 14:00:00
# 8  https://twitter.com/ispch/status/1252946192201... 2020-04-22 13:03:45
# 9  https://twitter.com/ispch/status/1252945251343... 2020-04-22 13:00:01
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0   13
# 1  Twitter for iPhone      0   44
# 2  Twitter for iPhone      0  138
# 3  Twitter for iPhone      0   16
# 4  Twitter for iPhone      0  131
# 5           TweetDeck      0    0
# 6  Twitter for iPhone      0   57
# 7           TweetDeck      0    1
# 8  Twitter for iPhone      0    0
# 9           TweetDeck      0    0

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
