# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Recuerda que la vacuna contra la influenza es gratuita para personas mayores de 65 años, niños y niñas desde los 6… https://t.co/kDFGfnZOb7
#
# Donar sangre es donar vida.
# Si vas a salir, haz que valga la pena. Si tu comuna está en cuarentena puedes pedir tu… https://t.co/FrnXVQLKEe
#
# Si tienes a un miembro del hogar diagnosticado con COVID 19, es muy importante que adoptes las siguientes medidas:… https://t.co/p10gM6qj7W
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/LF0CJGv9I2
#
# RT @ministeriosalud: Ministro @jmanalich | Prevención al regreso de clases
#
# "Se considera hacer un muestro en los colegios cuando se defina…
#
# RT @ministeriosalud: Todas las medidas anunciadas de zonas que se suman y mantienen cuarentenas, tienen una duración de 𝟳 𝗱𝗶́𝗮𝘀, a partir d…
#
# Si no tienes mascarillas, crea la tuya en simples pasos con una polera.
# #CuidémonosEntreTodos https://t.co/bHy5EgYp4P
#
# RT @ministeriosalud: Ministro @jmanalich | Nuevas comunas en Cuarentena
#
# - Quinta Normal
# - Pedro Aguirre Cerda
# - Independencia (desde Av. G…
#
# RT @ministeriosalud: Ministro @jmanalich | Anuncios
#
# ▪️ Salen de cuarentena:
# - Chillán y Chillán viejo, pero se mantiene cordón sanitario…
#
# RT @ministeriosalud: Ministro @jmanalich | Mantienen medidas
#
# - Radio Urbano Arica
# - Temuco
# - Osorno
# - Punta Arenas
# - Chiloé
# - Zona norte d…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Recuerda que la vacuna contra la influenza es ...
# 1  Donar sangre es donar vida.\nSi vas a salir, h...
# 2  Si tienes a un miembro del hogar diagnosticado...
# 3  El uso correcto de la mascarilla es clave para...
# 4  RT @ministeriosalud: Ministro @jmanalich | Pre...
# 5  RT @ministeriosalud: Todas las medidas anuncia...
# 6  Si no tienes mascarillas, crea la tuya en simp...
# 7  RT @ministeriosalud: Ministro @jmanalich | Nue...
# 8  RT @ministeriosalud: Ministro @jmanalich | Anu...
# 9  RT @ministeriosalud: Ministro @jmanalich | Man...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252673459810942979
# 2020-04-21 19:00:01
# TweetDeck
# 1
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kDFGfnZOb7', 'expanded_url': 'https://twitter.com/i/web/status/1252673459810942979', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Recuerda que la vacuna contra la influenza es ...  1252673459810942979
# 1  Donar sangre es donar vida.\nSi vas a salir, h...  1252658359217594368
# 2  Si tienes a un miembro del hogar diagnosticado...  1252643262000533504
# 3  El uso correcto de la mascarilla es clave para...  1252628163558912002
# 4  RT @ministeriosalud: Ministro @jmanalich | Pre...  1252613523945000966
# 5  RT @ministeriosalud: Todas las medidas anuncia...  1252613500591104006
# 6  Si no tienes mascarillas, crea la tuya en simp...  1252613061828964353
# 7  RT @ministeriosalud: Ministro @jmanalich | Nue...  1252611730347343872
# 8  RT @ministeriosalud: Ministro @jmanalich | Anu...  1252611708222398465
# 9  RT @ministeriosalud: Ministro @jmanalich | Man...  1252611682079309824
#
#                  Date              Source  Likes  RTs
# 0 2020-04-21 19:00:01           TweetDeck      1    0
# 1 2020-04-21 18:00:00           TweetDeck      2    3
# 2 2020-04-21 17:00:01           TweetDeck      1    1
# 3 2020-04-21 16:00:01           TweetDeck      1    5
# 4 2020-04-21 15:01:51  Twitter for iPhone      0   41
# 5 2020-04-21 15:01:45  Twitter for iPhone      0   54
# 6 2020-04-21 15:00:01           TweetDeck      0    0
# 7 2020-04-21 14:54:43  Twitter for iPhone      0  143
# 8 2020-04-21 14:54:38  Twitter for iPhone      0   87
# 9 2020-04-21 14:54:32  Twitter for iPhone      0  140

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Recuerda que la vacuna contra la influenza es ...
# 1  Donar sangre es donar vida.\nSi vas a salir, h...
# 2  Si tienes a un miembro del hogar diagnosticado...
# 3  El uso correcto de la mascarilla es clave para...
# 4  RT @ministeriosalud: Ministro @jmanalich | Pre...
# 5  RT @ministeriosalud: Todas las medidas anuncia...
# 6  Si no tienes mascarillas, crea la tuya en simp...
# 7  RT @ministeriosalud: Ministro @jmanalich | Nue...
# 8  RT @ministeriosalud: Ministro @jmanalich | Anu...
# 9  RT @ministeriosalud: Ministro @jmanalich | Man...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1252673459810... 2020-04-21 19:00:01
# 1  https://twitter.com/ispch/status/1252658359217... 2020-04-21 18:00:00
# 2  https://twitter.com/ispch/status/1252643262000... 2020-04-21 17:00:01
# 3  https://twitter.com/ispch/status/1252628163558... 2020-04-21 16:00:01
# 4  https://twitter.com/ispch/status/1252613523945... 2020-04-21 15:01:51
# 5  https://twitter.com/ispch/status/1252613500591... 2020-04-21 15:01:45
# 6  https://twitter.com/ispch/status/1252613061828... 2020-04-21 15:00:01
# 7  https://twitter.com/ispch/status/1252611730347... 2020-04-21 14:54:43
# 8  https://twitter.com/ispch/status/1252611708222... 2020-04-21 14:54:38
# 9  https://twitter.com/ispch/status/1252611682079... 2020-04-21 14:54:32
#
#                Source  Likes  RTs
# 0           TweetDeck      1    0
# 1           TweetDeck      2    3
# 2           TweetDeck      1    1
# 3           TweetDeck      1    5
# 4  Twitter for iPhone      0   41
# 5  Twitter for iPhone      0   54
# 6           TweetDeck      0    0
# 7  Twitter for iPhone      0  143
# 8  Twitter for iPhone      0   87
# 9  Twitter for iPhone      0  140

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
