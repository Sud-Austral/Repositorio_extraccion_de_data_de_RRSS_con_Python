# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Si estás en aislamiento domiciliario, es muy importante mantener las medidas de prevención en el hogar.
#
# - Lávate l… https://t.co/gXIrCQM76M
#
# Si no tienes mascarillas, crea la tuya en simples pasos con una polera.
# #CuidémonosEntreTodos https://t.co/pEDCBn7rCk
#
# RT @ministeriosalud: "El Pdte nos ha invitado a una reunión que fue muy franca y cordial. Nos dio a conocer los aspectos que él está consid…
#
# RT @ministeriosalud: “Apoyamos plenamente el reintegro gradual de las funciones públicas en cuanto prime la condición de salud e indicacion…
#
# RT @Cenabast: Atención Proveedores: Revise esta importante información sobre Entrega y Recepción de Instrumentos de Garantía y Entrega y Re…
#
# Si tienes a un miembro del hogar diagnosticado con COVID 19, es muy importante que adoptes las medidas adecuadas.… https://t.co/0QMIpUtImo
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/b4s6mOJAeB
#
# RT @ministeriosalud: [Actualización] Ministerio de Salud informa 10.507 casos confirmados de #COVID_19 en Chile.
#
# Revisa el detalle complet…
#
# RT @ministeriosalud: "Además, en trabajo conjunto con @min_ciencia estamos coordinando la fabricación de ventiladores", señala subsec @artu…
#
# RT @ministeriosalud: "Han llegado a los lugares donde se ha necesitado. Desde la Subsecretaría, contamos con 538 ventiladores disponibles y…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Si estás en aislamiento domiciliario, es muy i...
# 1  Si no tienes mascarillas, crea la tuya en simp...
# 2  RT @ministeriosalud: "El Pdte nos ha invitado ...
# 3  RT @ministeriosalud: “Apoyamos plenamente el r...
# 4  RT @Cenabast: Atención Proveedores: Revise est...
# 5  Si tienes a un miembro del hogar diagnosticado...
# 6  El uso correcto de la mascarilla es clave para...
# 7  RT @ministeriosalud: [Actualización] Ministeri...
# 8  RT @ministeriosalud: "Además, en trabajo conju...
# 9  RT @ministeriosalud: "Han llegado a los lugare...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252341268870361088
# 2020-04-20 21:00:00
# TweetDeck
# 1
# 1
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/gXIrCQM76M', 'expanded_url': 'https://twitter.com/i/web/status/1252341268870361088', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Si estás en aislamiento domiciliario, es muy i...  1252341268870361088
# 1  Si no tienes mascarillas, crea la tuya en simp...  1252326172039319552
# 2  RT @ministeriosalud: "El Pdte nos ha invitado ...  1252320351100559360
# 3  RT @ministeriosalud: “Apoyamos plenamente el r...  1252320341289992194
# 4  RT @Cenabast: Atención Proveedores: Revise est...  1252320281449947137
# 5  Si tienes a un miembro del hogar diagnosticado...  1252311070590418944
# 6  El uso correcto de la mascarilla es clave para...  1252280872801308674
# 7  RT @ministeriosalud: [Actualización] Ministeri...  1252269062119440389
# 8  RT @ministeriosalud: "Además, en trabajo conju...  1252269046214656000
# 9  RT @ministeriosalud: "Han llegado a los lugare...  1252269036714561536
#
#                  Date              Source  Likes  RTs
# 0 2020-04-20 21:00:00           TweetDeck      1    1
# 1 2020-04-20 20:00:01           TweetDeck      1    2
# 2 2020-04-20 19:36:53  Twitter for iPhone      0   26
# 3 2020-04-20 19:36:51  Twitter for iPhone      0   15
# 4 2020-04-20 19:36:36  Twitter for iPhone      0    3
# 5 2020-04-20 19:00:00           TweetDeck      1    0
# 6 2020-04-20 17:00:00           TweetDeck      3    2
# 7 2020-04-20 16:13:05  Twitter for iPhone      0   30
# 8 2020-04-20 16:13:01  Twitter for iPhone      0   17
# 9 2020-04-20 16:12:59  Twitter for iPhone      0   17

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Si estás en aislamiento domiciliario, es muy i...
# 1  Si no tienes mascarillas, crea la tuya en simp...
# 2  RT @ministeriosalud: "El Pdte nos ha invitado ...
# 3  RT @ministeriosalud: “Apoyamos plenamente el r...
# 4  RT @Cenabast: Atención Proveedores: Revise est...
# 5  Si tienes a un miembro del hogar diagnosticado...
# 6  El uso correcto de la mascarilla es clave para...
# 7  RT @ministeriosalud: [Actualización] Ministeri...
# 8  RT @ministeriosalud: "Además, en trabajo conju...
# 9  RT @ministeriosalud: "Han llegado a los lugare...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1252341268870... 2020-04-20 21:00:00
# 1  https://twitter.com/ispch/status/1252326172039... 2020-04-20 20:00:01
# 2  https://twitter.com/ispch/status/1252320351100... 2020-04-20 19:36:53
# 3  https://twitter.com/ispch/status/1252320341289... 2020-04-20 19:36:51
# 4  https://twitter.com/ispch/status/1252320281449... 2020-04-20 19:36:36
# 5  https://twitter.com/ispch/status/1252311070590... 2020-04-20 19:00:00
# 6  https://twitter.com/ispch/status/1252280872801... 2020-04-20 17:00:00
# 7  https://twitter.com/ispch/status/1252269062119... 2020-04-20 16:13:05
# 8  https://twitter.com/ispch/status/1252269046214... 2020-04-20 16:13:01
# 9  https://twitter.com/ispch/status/1252269036714... 2020-04-20 16:12:59
#
#                Source  Likes  RTs
# 0           TweetDeck      1    1
# 1           TweetDeck      1    2
# 2  Twitter for iPhone      0   26
# 3  Twitter for iPhone      0   15
# 4  Twitter for iPhone      0    3
# 5           TweetDeck      1    0
# 6           TweetDeck      3    2
# 7  Twitter for iPhone      0   30
# 8  Twitter for iPhone      0   17
# 9  Twitter for iPhone      0   17

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
