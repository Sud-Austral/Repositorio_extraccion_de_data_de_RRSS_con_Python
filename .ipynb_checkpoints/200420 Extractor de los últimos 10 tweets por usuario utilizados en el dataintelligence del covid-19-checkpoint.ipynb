# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Si tienes un pañuelo en tu hogar, puedes convertirlo en una mascarilla.
#
# Sigue estos pasos y #CuidémonosEntreTodos https://t.co/n2yujZYpr7
#
# Recuerda que la vacuna contra la influenza es gratuita para personas mayores de 65 años, niños y niñas desde los 6… https://t.co/eA3XFvFNNl
#
# Si tienes a un miembro del hogar  diagnosticado con COVID 19, es muy importante que adoptes las siguientes medidas:… https://t.co/VwJDWuutzz
#
# RT @ministeriosalud: Embajador Xu Bu:
#
# “Siento mucha admiración por ministro @jmanalich y los colegas del Min. de Salud, por su sentido de…
#
# RT @ministeriosalud: Ministro @jmanalich y director de @Cenabast Valentín Díaz, reciben donación de 11 mil elementos de protección personal…
#
# RT @ministeriosalud: La donación adicional de la Embajada de China en Chile, consiste en 6.750 mascarillas, que fueron entregados por el em…
#
# RT @ministeriosalud: Ministro @jmanalich | Donación de insumos
#
# "A nombre del Pdte. @sebastianpinera quiero manifestar nuestro agradecimien…
#
# RT @ministeriosalud: Embajador de China en Chile, Xu Bu:
#
# "China y Chile han trabajado en conjunto y ambos jefes de estado llegaron a un a…
#
# RT @ministeriosalud: [AHORA] Ministro @jmanalich recibe donación del Gobierno Chino y Embajada de China en Chile de insumos y elementos de…
#
# RT @ministeriosalud: El @Ejercito_Chile hace entrega al @HSJ_Oficial la donación de mascarillas realizadas por funcionarios de la instituci…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Si tienes un pañuelo en tu hogar, puedes conve...
# 1  Recuerda que la vacuna contra la influenza es ...
# 2  Si tienes a un miembro del hogar  diagnosticad...
# 3  RT @ministeriosalud: Embajador Xu Bu:\n\n“Sien...
# 4  RT @ministeriosalud: Ministro @jmanalich y dir...
# 5  RT @ministeriosalud: La donación adicional de ...
# 6  RT @ministeriosalud: Ministro @jmanalich | Don...
# 7  RT @ministeriosalud: Embajador de China en Chi...
# 8  RT @ministeriosalud: [AHORA] Ministro @jmanali...
# 9  RT @ministeriosalud: El @Ejercito_Chile hace e...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'extended_entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1252764056152203264
# 2020-04-22 01:00:00
# TweetDeck
# 0
# 0
# None
# None
# {'hashtags': [{'text': 'CuidémonosEntreTodos', 'indices': [93, 114]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1252728199114612738, 'id_str': '1252728199114612738', 'indices': [115, 138], 'media_url': 'http://pbs.twimg.com/media/EWKVqOxXYAIox6o.png', 'media_url_https': 'https://pbs.twimg.com/media/EWKVqOxXYAIox6o.png', 'url': 'https://t.co/n2yujZYpr7', 'display_url': 'pic.twitter.com/n2yujZYpr7', 'expanded_url': 'https://twitter.com/ispch/status/1252764056152203264/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 672, 'resize': 'fit'}, 'small': {'w': 680, 'h': 381, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1147, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Si tienes un pañuelo en tu hogar, puedes conve...  1252764056152203264
# 1  Recuerda que la vacuna contra la influenza es ...  1252748956083224576
# 2  Si tienes a un miembro del hogar  diagnosticad...  1252733857129848832
# 3  RT @ministeriosalud: Embajador Xu Bu:\n\n“Sien...  1252719282141777922
# 4  RT @ministeriosalud: Ministro @jmanalich y dir...  1252719273136599040
# 5  RT @ministeriosalud: La donación adicional de ...  1252719262348779520
# 6  RT @ministeriosalud: Ministro @jmanalich | Don...  1252719249421996033
# 7  RT @ministeriosalud: Embajador de China en Chi...  1252719238667743233
# 8  RT @ministeriosalud: [AHORA] Ministro @jmanali...  1252719221030752257
# 9  RT @ministeriosalud: El @Ejercito_Chile hace e...  1252719209005670401
#
#                  Date              Source  Likes  RTs
# 0 2020-04-22 01:00:00           TweetDeck      0    0
# 1 2020-04-22 00:00:00           TweetDeck      0    0
# 2 2020-04-21 23:00:00           TweetDeck      0    1
# 3 2020-04-21 22:02:05  Twitter for iPhone      0  381
# 4 2020-04-21 22:02:03  Twitter for iPhone      0   72
# 5 2020-04-21 22:02:01  Twitter for iPhone      0   34
# 6 2020-04-21 22:01:58  Twitter for iPhone      0   61
# 7 2020-04-21 22:01:55  Twitter for iPhone      0  114
# 8 2020-04-21 22:01:51  Twitter for iPhone      0  225
# 9 2020-04-21 22:01:48  Twitter for iPhone      0   20

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Si tienes un pañuelo en tu hogar, puedes conve...
# 1  Recuerda que la vacuna contra la influenza es ...
# 2  Si tienes a un miembro del hogar  diagnosticad...
# 3  RT @ministeriosalud: Embajador Xu Bu:\n\n“Sien...
# 4  RT @ministeriosalud: Ministro @jmanalich y dir...
# 5  RT @ministeriosalud: La donación adicional de ...
# 6  RT @ministeriosalud: Ministro @jmanalich | Don...
# 7  RT @ministeriosalud: Embajador de China en Chi...
# 8  RT @ministeriosalud: [AHORA] Ministro @jmanali...
# 9  RT @ministeriosalud: El @Ejercito_Chile hace e...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1252764056152... 2020-04-22 01:00:00
# 1  https://twitter.com/ispch/status/1252748956083... 2020-04-22 00:00:00
# 2  https://twitter.com/ispch/status/1252733857129... 2020-04-21 23:00:00
# 3  https://twitter.com/ispch/status/1252719282141... 2020-04-21 22:02:05
# 4  https://twitter.com/ispch/status/1252719273136... 2020-04-21 22:02:03
# 5  https://twitter.com/ispch/status/1252719262348... 2020-04-21 22:02:01
# 6  https://twitter.com/ispch/status/1252719249421... 2020-04-21 22:01:58
# 7  https://twitter.com/ispch/status/1252719238667... 2020-04-21 22:01:55
# 8  https://twitter.com/ispch/status/1252719221030... 2020-04-21 22:01:51
# 9  https://twitter.com/ispch/status/1252719209005... 2020-04-21 22:01:48
#
#                Source  Likes  RTs
# 0           TweetDeck      0    0
# 1           TweetDeck      0    0
# 2           TweetDeck      0    1
# 3  Twitter for iPhone      0  381
# 4  Twitter for iPhone      0   72
# 5  Twitter for iPhone      0   34
# 6  Twitter for iPhone      0   61
# 7  Twitter for iPhone      0  114
# 8  Twitter for iPhone      0  225
# 9  Twitter for iPhone      0   20

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
