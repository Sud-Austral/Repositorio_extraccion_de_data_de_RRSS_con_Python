# %% [markdown]
# # 260320 Análisis de sentimientos de Twitter para la ciencia de datos usando Python
#
# #### Twitter Sentiment Analysis for Data Science Using Python
#
# http://aiforwomen.org/twitter-sentiment-analysis-for-data-science-using-python/

# %% [markdown]
# A principios de 2019, se dice que Twitter tiene alrededor de 126 millones de usuarios diarios. Esto significa que, al analizar los Tweets de todos estos usuarios sobre un tema en particular, podemos determinar la opinión general promedio de las personas sobre ese tema.
#
# Por ejemplo, durante la temporada de elecciones, al estudiar los Tweets de personas sobre un partido o candidato en particular, podemos predecir el posible resultado de la elección. Esto se puede hacer a través de algo llamado "Análisis de sentimientos".

# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud

# %%
consumer_key='koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret='3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'
access_token='1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_token_secret='6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
word = input("Enter the word here: ")
# Out:
# Enter the word here: covid

# %%
filtered='word -filter:retweets'


tweets = tweepy.Cursor(api.search,
              q=filtered,
              lang="en").items(100)

tweets

# %%
cleantweets = [remove_url(tweet.text) for tweet in tweets]

# %%
sentiment_objects = [TextBlob(tweet) for tweet in cleantweets]

sentiment_objects[0].polarity, sentiment_objects[0]
# Out:
# (-0.4, TextBlob("oytunkaradag0 Lan do you make us a word game"))

# %%
sentiment_values = [[tweet.sentiment.polarity, str(tweet)] for tweet in sentiment_objects]

sentiment_values[0]

sentiment_values[0:99]
# Out:
# [[-0.4, 'oytunkaradag0 Lan do you make us a word game'],
#  [-0.2833333333333333,
#   'GonzoXrp My HODL is STRONG Sir Looking into that nasty D word now though because of all this FUD Diversification'],
#  [0.0,
#   'The word reveal means to reveil that is to give one explanation and yet continue to maintain the mystery of t'],
#  [0.0, 'DHONIism Within one word ROARING LION OF CRICKET'],
#  [0.0,
#   'Ladies and gentleman we have some breaking news coming just inBy now all tributes are on their way to the Arena'],
#  [0.0,
#   'TaraWilcoxon CaptainQuint 88Wahoo beatles510 She say curse word I hang up'],
#  [0.0,
#   'thinkorswim TOS data and chatrooms freezing once again Lots of money being lost by their clients and no word out'],
#  [0.0,
#   'Word to providers If U refer a patient for Coronavirus testing U do not need to report the results to the Dpt of'],
#  [0.0,
#   'benyt Truth hurts realDonaldTrump Every word in the video was said by Trumpunedited'],
#  [0.0, 'katsukenma TWICE DIDNT ACTUALLY D WORD DID HE PLEASE SAY SIKE'],
#  [0.16,
#   'Daffins candy is at the high school now for seniors who need to pick up Spread the word classof2020'],
#  [0.0, 'like this for a 2 word indirect'],
#  [0.0, 'PolitiBunny TwitchyTeam I dont believe a word Kathy Griffin says'],
#  [0.125,
#   'Exactly this now is the time to discuss and create the future we wantThe Rword via weegingerdug'],
#  [0.7, 'CoachLavender theprogramorg JaxsonLavender Good word'],
#  [0.0, 'Teyiaraaa Ima take yo word'],
#  [0.25,
#   'LAUGHABLE that my uni has changed my exam to a 3000 word essay as they feel thats the best way to support us just'],
#  [0.0, 'Someone cheer me up Like for a gif starter Retweet spread word'],
#  [0.07499999999999998,
#   'Any time the word feet is in a tweet my delapitated abandoned cruise ship of a brain goes into full on search and destroy mode'],
#  [-0.2,
#   'elonmusk PPathole flcnhvy Tesla SE Michigan not doing well Vents not available nowCant get traction on'],
#  [0.4625,
#   'A LOVE WORDWhen its God Ordained Its OK to LOVE again And when youre true to yourself there is no reaso'],
#  [-0.15,
#   'Jebailey Word Hopping on Amazon now Thanks I was getting bored with my workouts some ngl'],
#  [0.0, 'Punjabi people heard the word hospital and named it haspatal'],
#  [0.0, 'Your word is SEFBD'],
#  [0.0,
#   'Word applausePart of Speech NounDefinition Approval or praise expressed by clapping'],
#  [0.0,
#   'TheRealTriscuit Im trademarking the word ElectriscuityGive me all your money'],
#  [0.0, 'DarkHorseComics Aaaaaany word yet'],
#  [0.0,
#   'RealTalkKim We perish without thePlan of GOD IN OUR FUTUREWISDOMKNOWLEDGEAND UNDERSTANDINGAND SPIRITUAL'],
#  [0.0,
#   'are you from Sabah Are u from Sabah cause i tak sabah nak jumpa uBecause I cant wait to see youjek play'],
#  [0.35,
#   'Absolutely howlin at my uni who thought it would be easier and more convenient to change a 10 min presentation'],
#  [-0.09999999999999999,
#   'agustdingus this now enough Im not going to waste more time answering a bunch of kids Namjoon would be shocked'],
#  [0.5,
#   'From my Bible Study this morning However in dire situations a sure word of counsel is needed We need to cons'],
#  [1.1102230246251566e-17,
#   'spicynoodsszn Failed is maybe a harsh word unproductive may be a better choice This sounds way more negative tha'],
#  [0.0,
#   'SundanceConstr1 NuniSasYu Israel is listed with Europe because the Arabs go apeshit if they see the word Israel'],
#  [0.0,
#   'Our local librarys online resources include Rosetta Stone Maybe yours does too Why not learn a language or brus'],
#  [0.1,
#   'xnolanjohnson Because negative stigma is still attention and thats a better nazis than nothing Arms also wasnt'],
#  [0.0, 'sayyeshaa hello sayyeshaa how is Arya sir one word about Arya sir'],
#  [-0.2,
#   'Yoongi gritted his teeth and wanted to say a few foul word or two but all he could do was looked away Tthen'],
#  [0.0, 'Word'],
#  [0.0, 'nosilenced realDonaldTrump Please dont say that word coughjkng'],
#  [0.0, 'wafflebooi describe u in one word GENDUT'],
#  [0.0,
#   'SamQari Its an abuse to the word Scholar when people refer to him as such All those with ghra for their Dn'],
#  [0.0,
#   'sayyeshaa One word about our director sir SanthoshAnand15 sayyeshaa AskSayyeshaa Yuvarathnaa'],
#  [0.09999999999999998,
#   'Lmaooooo what No I wont She would not be around when I hang with them If they arent good for me Ill find out'],
#  [0.8, 'ReggieAllGood Word lol Im on Oat Milk now'],
#  [0.17708333333333331, 'Thomberry the word mean exceptional me in arabic'],
#  [0.0, 'Key word YOURE'],
#  [0.05,
#   'The word Toxic Yall mfs barely learned it in 2019 and now use it for every damn thang Like anything that make yo'],
#  [0.0,
#   'curt71052579 ChrisJZullo realDonaldTrump I dont need to know Jesus His word is well documented Are you liv'],
#  [0.0, 'InevitableET Word brother'],
#  [0.13636363636363635,
#   'On my Wednesday Night I was blessed as I brought the Word of God at home on Facebook Live I was talking about on'],
#  [0.0,
#   'Dont let fear and disinformation contribute to the spread of Coronavirus Weve got to stand together Spread the'],
#  [0.0,
#   'food Help us spread the word by following us here or GrillUncle on Twitter or Uncle Chewies Grill on IG or Sn'],
#  [0.4,
#   'TheRynheart Actually I would be happy to see that Take them at their word'],
#  [0.0,
#   'Matt 8 the centurion The miracle didnt happen just by a man with faith coming but rather with that faith someo'],
#  [0.6,
#   'NeedleAndDead From me iam a rather blunt and honest person I do as I say I keep my word if I say I wont har'],
#  [0.0,
#   'jodiejporteous Im a college student and Ive been writing a 1400 word essay for the last 5 days'],
#  [0.7,
#   'KiriHerondale I think Amren would also be verypissy yes thats a good word because VeranI know I spelled it'],
#  [0.0,
#   'Per Rule 84 Judicial Misconduct of the American Bar Association KimFoxxforSA is in violation of Sections A B'],
#  [-0.1,
#   'All Im saying is if my mom dies because they refused to test her because shes not important enough even though sh'],
#  [0.8,
#   'fkeyamo Sir Great work you are doing what is the status of the rejigging of the Labour laws you embarked on a wh'],
#  [0.5, 'twenty 1 pilots is appropriating the word top from the gays'],
#  [0.0, 'Imma mute the word landlord Because yall r trying it tuday'],
#  [0.5,
#   'TheWainaina Glad to know you read the article sir Hope you understood every word of it'],
#  [0.5,
#   'billymooreAPBD Top man joekeep spreading the word mate your words and videos are an inspiration for a lot of peop'],
#  [0.15625,
#   'I love the way Ive never seen The Little Mermaid but Im still here singing along word for word'],
#  [0.03333333333333333,
#   'Is social distancing the correct wordDo we need social distancingI dont think we need to be socially distanced'],
#  [0.0,
#   'Either she is the fastest person in the history of the known universe or Britney Spears thinks one meter is a fancy'],
#  [0.10000000000000002,
#   'When God comes to a man who has clearly fallen to bring him his word command to change that man from wickedness an'],
#  [0.0, 'KataFarkas211 martinchanlab Bingo key word reported'],
#  [0.0, 'lalalalaiba in frst word bta'],
#  [-0.14166666666666666,
#   'Not only dumb science but DJT does not understand the math concept of proportionality Even the word is too long f'],
#  [-0.5999999999999999,
#   'Come on man We know youre always on the Shitter with Twitter Oh my bad I I was wrong to have used that one'],
#  [0.0,
#   'This pic for banpur market from khordha district its covid19 luckdown for humanless in market for such as supp'],
#  [0.0, 'OIceManni Them no dey hear wordWho send them advertisement'],
#  [0.0,
#   'TinkerSec I wonder if theyre defaulting to a schools version of British English that has the same timbre and cade'],
#  [0.1, 'I know what word yall was tryna get to about ending a marriage early'],
#  [0.43333333333333335,
#   'cyphertaetae95 BTSCHARTBULLlES lnnerchiIdtwt yall using that word too easily'],
#  [0.0,
#   'When the word Senator freaks people out amp becomes synonymous to coronavirus'],
#  [0.16666666666666666,
#   'stanateez idk whats complement so ill assume its a misspelled word of compliment OK ANYWAYS i love you account'],
#  [-0.8,
#   'Pluviophile Theres a word I really hate Its a phony I could puke every time I hear it'],
#  [0.0, 'knew required after the word news'],
#  [0.0, 'warmscenery describe u in one wordartistic'],
#  [0.0, 'zimzalabitchs no way thats correct thats literally a spanish word'],
#  [0.0,
#   'The psalmist says David shepherded them with integrity of heart with skillful hands he led them Ps 7872He g'],
#  [0.0,
#   'Daily Devotions with Brother SteveDay 4 Fixing Your Eyes Upon JesusHe replaces fear with peace hope and'],
#  [-0.06666666666666667,
#   'I mentioned how Ive been having dreams lately amp last night I was looking up homemade natural shampoos amp out of now'],
#  [0.05,
#   'celestialninii apparently he said the n word t slur and f slur i dont have proof i just heard it from somewher'],
#  [-0.6, 'Bud dont say that Thats a dirty word'],
#  [0.0,
#   'piersmorgan GMB Maybe people switched on because MartinSLewis was on I switched over afterwards What is the po'],
#  [0.0, 'This bounty hunter when someone uses the word draft in a sentence'],
#  [0.0,
#   'For those of you who havent seen it am reposting via JLC this message from Bill Gates i believe every word of'],
#  [0.8,
#   'realDonaldTrump Dont believe one word of itmake America great again Mr PresidentTrump2020'],
#  [0.425,
#   'Hope is a beautiful word Websters 1828 Dictionary defines hope as Confidence in a future event the highest deg'],
#  [0.0, 'Nays kaayong word ron Thank u Lord'],
#  [0.1,
#   'Guys if you know someone who is a healthcare professional Please check on them They may need an encouraging word'],
#  [0.4928571428571428,
#   'dabrooks661 CamMellor YUNGGURU You can word play all you want It is arguable right now that Sewell is as good'],
#  [0.78,
#   'Aditya80796590 AafaqOfficial RaviKum03422706 ANI Perseverance very nice wordNASAs rover to mars'],
#  [-0.1, 'Im not ready for whats coming after this comeback the e word']]

# %%
sentiment_df = pd.DataFrame(sentiment_values, columns=["polarity", "tweet"])

sentiment_df
# Out:
#     polarity                                              tweet
# 0  -0.400000       oytunkaradag0 Lan do you make us a word game
# 1  -0.283333  GonzoXrp My HODL is STRONG Sir Looking into th...
# 2   0.000000  The word reveal means to reveil that is to giv...
# 3   0.000000   DHONIism Within one word ROARING LION OF CRICKET
# 4   0.000000  Ladies and gentleman we have some breaking new...
# ..       ...                                                ...
# 95  0.100000  Guys if you know someone who is a healthcare p...
# 96  0.492857  dabrooks661 CamMellor YUNGGURU You can word pl...
# 97  0.780000  Aditya80796590 AafaqOfficial RaviKum03422706 A...
# 98 -0.100000  Im not ready for whats coming after this comeb...
# 99 -0.050000  Madusaholdings MyFriend004 uLeratopillay That ...
#
# [100 rows x 2 columns]

# %%
n=sentiment_df["polarity"]

m=pd.Series(n)

m
# Out:
# 0    -0.400000
# 1    -0.283333
# 2     0.000000
# 3     0.000000
# 4     0.000000
#         ...
# 95    0.100000
# 96    0.492857
# 97    0.780000
# 98   -0.100000
# 99   -0.050000
# Name: polarity, Length: 100, dtype: float64

# %%
pos=0
neg=0
neu=0

# %%
for items in m:
    if items>0:
        print("Positive")
        pos=pos+1
    elif items<0:
        print("Negative")
        neg=neg+1
    else:
        print("Neutral")
        neu=neu+1
        
print(pos,neg,neu)
# Out:
# Negative
# Negative
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Positive
# Neutral
# Positive
# Negative
# Positive
# Negative
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Negative
# Positive
# Positive
# Neutral
# Neutral
# Positive
# Neutral
# Negative
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Positive
# Neutral
# Positive
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Negative
# Positive
# Positive
# Neutral
# Positive
# Positive
# Positive
# Positive
# Neutral
# Positive
# Neutral
# Neutral
# Negative
# Negative
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Positive
# Negative
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Negative
# Positive
# Negative
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Positive
# Positive
# Positive
# Negative
# Negative
# 34 14 52

# %%
pieLabels=["Positive","Negative","Neutral"]

populationShare=[pos,neg,neu]

figureObject, axesObject = plt.subplots()

axesObject.pie(populationShare,labels=pieLabels,autopct='%1.2f',startangle=90)

axesObject.axis('equal')

plt.show()

# %%
print("%f percent twitter users feel positive about %s"%(pos,word))

print("%f percent twitter users feel negative about %s"%(neg,word))

print("%f percent twitter users feel neutral about %s"%(neu,word))
# Out:
# 34.000000 percent twitter users feel positive about covid
# 14.000000 percent twitter users feel negative about covid
# 52.000000 percent twitter users feel neutral about covid

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot histogram of the polarity values
sentiment_df.hist(bins=[-1, -0.75, -0.5, -0.25, 0.25, 0.5, 0.75, 1],
             ax=ax,
             color="purple")

plt.title("Sentiments from the Tweets")
plt.show()

# %%
all_words = ' '.join([text for text in cleantweets])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
