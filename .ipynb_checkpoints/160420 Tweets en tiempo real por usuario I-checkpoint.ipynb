# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-16
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
prompt = '> '
tweet=''
print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = input(prompt)

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:
# > ispch
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @Cenabast: Conoce el estado de nuestros servicios de atención en https://t.co/dxCjUVBT6X. #PlanCoronavirus #CuidémonosEntreTodos https:/…
#
# RT @ministeriosalud: El @FelixHfb implementó una serie de medidas para evitar aglomeraciones y esperas para la entrega de medicamentos en e…
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/Lt0d9kSzdM
#
# RT @ministeriosalud: Octavo informe epidemiológico #COVID_19  https://t.co/tITnUXmogM #PlanCoronavirus
#
# RT @ministeriosalud: Hoy, en @ucchristus fue dado de alta el primer paciente por #COVID_19 de ese establecimiento, tras permanecer 28 días…
#
# ¿Cómo se decretan las cuarentenas?
#
# Existe una serie de criterios para determinar esta medida en una zona, comuna,… https://t.co/opq1AIMWM8
#
# Conoce aquí las comunas y zonas donde se mantendrá la cuarentena total.
#
# #CuidémonosEntreTodos y encuentra más info… https://t.co/Qg1trQAq2w
#
# Fabrica tu propia mascarilla con una bandana.
# #CuidémonosEntreTodos https://t.co/S61uivxqYl
#
# Prefiere medicamentos #bioequivalentes.
# El @ispch garantiza su calidad, seguridad y eficacia.
# #ExigeElAmarillo https://t.co/Z4HAMogh6O
#
# Donar sangre es donar vida.
# Si vas a salir, haz que valga la pena. Si tu comuna está en cuarentena puedes pedir tu… https://t.co/mQjFeVHH6x

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @Cenabast: Conoce el estado de nuestros ser...
# 1  RT @ministeriosalud: El @FelixHfb implementó u...
# 2  Temperatura actual, pronóstico del tiempo y ra...
# 3  RT @ministeriosalud: Octavo informe epidemioló...
# 4  RT @ministeriosalud: Hoy, en @ucchristus fue d...
# 5  ¿Cómo se decretan las cuarentenas?\n\nExiste u...
# 6  Conoce aquí las comunas y zonas donde se mante...
# 7  Fabrica tu propia mascarilla con una bandana.\...
# 8  Prefiere medicamentos #bioequivalentes. \nEl @...
# 9  Donar sangre es donar vida.\nSi vas a salir, h...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1250777919477121025
# 2020-04-16 13:27:48
# Twitter for iPhone
# 0
# 1
# None
# None
# {'hashtags': [{'text': 'PlanCoronavirus', 'indices': [93, 109]}, {'text': 'CuidémonosEntreTodos', 'indices': [110, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Cenabast', 'name': 'Cenabast', 'id': 309847715, 'id_str': '309847715', 'indices': [3, 12]}], 'urls': [{'url': 'https://t.co/dxCjUVBT6X', 'expanded_url': 'http://cenabast.cl', 'display_url': 'cenabast.cl', 'indices': [68, 91]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @Cenabast: Conoce el estado de nuestros ser...  1250777919477121025
# 1  RT @ministeriosalud: El @FelixHfb implementó u...  1250777882072363015
# 2  Temperatura actual, pronóstico del tiempo y ra...  1250772898249351168
# 3  RT @ministeriosalud: Octavo informe epidemioló...  1250772478277955585
# 4  RT @ministeriosalud: Hoy, en @ucchristus fue d...  1250772269351284737
# 5  ¿Cómo se decretan las cuarentenas?\n\nExiste u...  1250770922308431879
# 6  Conoce aquí las comunas y zonas donde se mante...  1250755821698506753
# 7  Fabrica tu propia mascarilla con una bandana.\...  1250589727218163712
# 8  Prefiere medicamentos #bioequivalentes. \nEl @...  1250559529466556419
# 9  Donar sangre es donar vida.\nSi vas a salir, h...  1250529329815023616
#
#                  Date              Source  Likes   RTs
# 0 2020-04-16 13:27:48  Twitter for iPhone      0     1
# 1 2020-04-16 13:27:40  Twitter for iPhone      0     5
# 2 2020-04-16 13:07:51  Twitter for iPhone      0     1
# 3 2020-04-16 13:06:11  Twitter for iPhone      0    18
# 4 2020-04-16 13:05:21  Twitter for iPhone      0  1458
# 5 2020-04-16 13:00:00           TweetDeck      0     1
# 6 2020-04-16 12:00:00           TweetDeck      0     1
# 7 2020-04-16 01:00:00           TweetDeck      0     0
# 8 2020-04-15 23:00:00           TweetDeck      2     0
# 9 2020-04-15 21:00:00           TweetDeck      2     2

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @Cenabast: Conoce el estado de nuestros ser...
# 1  RT @ministeriosalud: El @FelixHfb implementó u...
# 2  Temperatura actual, pronóstico del tiempo y ra...
# 3  RT @ministeriosalud: Octavo informe epidemioló...
# 4  RT @ministeriosalud: Hoy, en @ucchristus fue d...
# 5  ¿Cómo se decretan las cuarentenas?\n\nExiste u...
# 6  Conoce aquí las comunas y zonas donde se mante...
# 7  Fabrica tu propia mascarilla con una bandana.\...
# 8  Prefiere medicamentos #bioequivalentes. \nEl @...
# 9  Donar sangre es donar vida.\nSi vas a salir, h...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1250777919477... 2020-04-16 13:27:48
# 1  https://twitter.com/ispch/status/1250777882072... 2020-04-16 13:27:40
# 2  https://twitter.com/ispch/status/1250772898249... 2020-04-16 13:07:51
# 3  https://twitter.com/ispch/status/1250772478277... 2020-04-16 13:06:11
# 4  https://twitter.com/ispch/status/1250772269351... 2020-04-16 13:05:21
# 5  https://twitter.com/ispch/status/1250770922308... 2020-04-16 13:00:00
# 6  https://twitter.com/ispch/status/1250755821698... 2020-04-16 12:00:00
# 7  https://twitter.com/ispch/status/1250589727218... 2020-04-16 01:00:00
# 8  https://twitter.com/ispch/status/1250559529466... 2020-04-15 23:00:00
# 9  https://twitter.com/ispch/status/1250529329815... 2020-04-15 21:00:00
#
#                Source  Likes   RTs
# 0  Twitter for iPhone      0     1
# 1  Twitter for iPhone      0     5
# 2  Twitter for iPhone      0     1
# 3  Twitter for iPhone      0    18
# 4  Twitter for iPhone      0  1458
# 5           TweetDeck      0     1
# 6           TweetDeck      0     1
# 7           TweetDeck      0     0
# 8           TweetDeck      2     0
# 9           TweetDeck      2     2

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
