# %% [markdown]
# https://onlinezhuanjia.com/python-facebook-page-scraper-tool/
# https://www.quintly.com/

# %%
import json
import datetime
import csv
import time
try:
    from urllib.request import urlopen, Request
except ImportError:
    from urllib2 import urlopen, Request
 
#app_id = "&amp;amp;amp;lt;FILL IN&amp;amp;amp;gt;"
#app_secret = "&amp;amp;amp;lt;FILL IN&amp;amp;amp;gt;"  # DO NOT SHARE WITH ANYONE!
page_id = "barackobama"
 
# input date formatted as YYYY-MM-DD
since_date = "2018-01-01"
until_date = "2018-04-30"
 
#access_token = app_id + "|" + app_secret
access_token = "EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD"
 
def request_until_succeed(url):
    req = Request(url)
    success = False
    while success is False:
        try:
            response = urlopen(req)
            if response.getcode() == 200:
                success = True
        except Exception as e:
            print(e)
            time.sleep(5)
 
            print("Error for URL {}: {}".format(url, datetime.datetime.now()))
            print("Retrying.")
 
    return response.read()
 
 
# Needed to write tricky unicode correctly to csv
def unicode_decode(text):
    try:
        return text.encode('utf-8').decode()
    except UnicodeDecodeError:
        return text.encode('utf-8')
 
 
def getFacebookPageFeedUrl(base_url):
 
    # Construct the URL string; see http://stackoverflow.com/a/37239851 for
    # Reactions parameters
    fields = "&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id," + \
        "comments.limit(0).summary(true),shares,reactions" + \
        ".limit(0).summary(true)"
 
    return base_url + fields
 
 
def getReactionsForStatuses(base_url):
 
    reaction_types = ['like', 'love', 'wow', 'haha', 'sad', 'angry']
    reactions_dict = {}   # dict of {status_id: tuple&amp;amp;amp;lt;6&amp;amp;amp;gt;}
 
    for reaction_type in reaction_types:
        fields = "&amp;amp;amp;amp;fields=reactions.type({}).limit(0).summary(total_count)".format(
            reaction_type.upper())
 
        url = base_url + fields
 
        data = json.loads(request_until_succeed(url))['data']
 
        data_processed = set()  # set() removes rare duplicates in statuses
        for status in data:
            id = status['id']
            count = status['reactions']['summary']['total_count']
            data_processed.add((id, count))
 
        for id, count in data_processed:
            if id in reactions_dict:
                reactions_dict[id] = reactions_dict[id] + (count,)
            else:
                reactions_dict[id] = (count,)
 
    return reactions_dict
 
 
def processFacebookPageFeedStatus(status):
 
    # The status is now a Python dictionary, so for top-level items,
    # we can simply call the key.
 
    # Additionally, some items may not always exist,
    # so must check for existence first
 
    status_id = status['id']
    status_type = status['type']
 
    status_message = '' if 'message' not in status else \
        unicode_decode(status['message'])
    link_name = '' if 'name' not in status else \
        unicode_decode(status['name'])
    status_link = '' if 'link' not in status else \
        unicode_decode(status['link'])
    status_permalink_url = '' if 'permalink_url' not in status.keys() else \
            unicode_decode(status['permalink_url'])
 
    # Time needs special care since a) it's in UTC and
    # b) it's not easy to use in statistical programs.
 
    status_published = datetime.datetime.strptime(
        status['created_time'], '%Y-%m-%dT%H:%M:%S+0000')
    status_published = status_published + \
        datetime.timedelta(hours=-5)  # EST
    status_published = status_published.strftime(
        '%Y-%m-%d %H:%M:%S')  # best time format for spreadsheet programs
 
    # Nested items require chaining dictionary keys.
 
    num_reactions = 0 if 'reactions' not in status else \
        status['reactions']['summary']['total_count']
    num_comments = 0 if 'comments' not in status else \
        status['comments']['summary']['total_count']
    num_shares = 0 if 'shares' not in status else status['shares']['count']
 
    return (status_id, status_message, link_name, status_type, status_link,status_permalink_url,
            status_published, num_reactions, num_comments, num_shares)
 
 
def scrapeFacebookPageFeedStatus(page_id, access_token, since_date, until_date):
    with open('{}_facebook_statuses.csv'.format(page_id), 'w',encoding="utf-8") as file:
        w = csv.writer(file)
        w.writerow(["status_id", "status_message", "link_name", "status_type",
                    "status_link","permalink_url", "status_published", "num_reactions",
                    "num_comments", "num_shares", "num_likes", "num_loves",
                    "num_wows", "num_hahas", "num_sads", "num_angrys",
                    "num_special"])
 
        has_next_page = True
        num_processed = 0
        scrape_starttime = datetime.datetime.now()
        after = ''
        base = "https://graph.facebook.com/v2.9"
        node = "/{}/posts".format(page_id)
        parameters = "/?limit={}&amp;amp;amp;amp;access_token={}".format(100, access_token)
        since = "&amp;amp;amp;amp;since={}".format(since_date) if since_date \
            is not '' else ''
        until = "&amp;amp;amp;amp;until={}".format(until_date) if until_date \
            is not '' else ''
 
        print("Scraping {} Facebook Page: {}\n".format(page_id, scrape_starttime))
 
        while has_next_page:
            after = '' if after is '' else "&amp;amp;amp;amp;after={}".format(after)
            base_url = base + node + parameters + after + since + until
 
            url = getFacebookPageFeedUrl(base_url)
            statuses = json.loads(request_until_succeed(url))
            reactions = getReactionsForStatuses(base_url)
 
            for status in statuses['data']:
 
                # Ensure it is a status with the expected metadata
                if 'reactions' in status:
                    status_data = processFacebookPageFeedStatus(status)
                    reactions_data = reactions[status_data[0]]
 
                    # calculate thankful/pride through algebra
                    num_special = status_data[7] - sum(reactions_data)
                    w.writerow(status_data + reactions_data + (num_special,))
 
                num_processed += 1
                if num_processed % 100 == 0:
                    print("{} Statuses Processed: {}".format
                          (num_processed, datetime.datetime.now()))
 
            # if there is no next page, we're done.
            if 'paging' in statuses:
                after = statuses['paging']['cursors']['after']
            else:
                has_next_page = False
 
        print("\nDone!\n{} Statuses Processed in {}".format(
              num_processed, datetime.datetime.now() - scrape_starttime))
 
 
if __name__ == '__main__':
    scrapeFacebookPageFeedStatus(page_id, access_token, since_date, until_date)
# Out:
# Scraping barackobama Facebook Page: 2020-03-02 15:46:16.655494
#
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:21.909109
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:27.145889
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:32.378588
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:37.651913
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:42.855951
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:48.072123
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:53.317128
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:46:58.544186
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:04.778917
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:10.033692
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:15.272376
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:20.487910
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:25.717755
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:30.950870
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:36.193930
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:41.416974
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:46.650634
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:51.891459
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:47:57.138513
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:02.384419
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:07.629045
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:12.886782
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:19.155719
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:24.377441
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:29.603010
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:34.844323
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:40.125978
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:45.359681
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:50.590564
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:48:55.837929
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:01.053383
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:06.284283
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:11.529656
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:16.780724
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:21.997764
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:27.246917
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:32.460378
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:37.684428
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:42.904505
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:48.147108
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:53.488862
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:49:58.725560
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:03.975378
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:09.212648
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:14.425939
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:19.668230
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:24.879189
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:30.106367
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:35.366509
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:40.591240
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:45.811619
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:51.039508
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:50:56.257352
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:01.479841
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:06.711778
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:11.932478
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:17.150194
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:22.366565
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:27.582461
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:32.838535
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:38.059179
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:43.273968
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:48.489639
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:53.708402
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:51:58.920324
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:04.141706
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:09.391345
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:14.611169
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:19.847907
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:25.059869
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:30.326857
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:35.574939
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:40.791815
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:45.991822
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:51.210368
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:52:56.426095
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:53:01.698826
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:53:06.944906
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:53:12.157344
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:53:17.382501
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:53:22.635727
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 15:53:27.871134
# Retrying.
# HTTP Error 400: Bad Request
# ...
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:10:29.567258
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:10:34.783960
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:10:40.046765
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:10:45.272444
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:10:50.520752
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:10:55.737255
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:00.976795
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:06.194985
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:11.421582
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:16.658957
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:21.911520
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:27.137748
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:32.377830
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:37.617869
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:42.848093
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:48.066800
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:53.278923
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:11:58.490892
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:03.744109
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:08.961174
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:14.206727
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:19.434879
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:24.654271
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:29.862986
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:35.099733
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:40.311665
# Retrying.
# HTTP Error 400: Bad Request
# Error for URL https://graph.facebook.com/v2.9/barackobama/posts/?limit=100&amp;amp;amp;amp;access_token=EAADfPdAMIXQBALanmEmEEgETIr01T7N7pZCMsxcQvLIkj3p6qhjaMEJXYFVfoNRIpIlUGZA0HZCQIuRWgkKO3KUykXLFWEq5d0BdTkeGwQiqX360vpp1Ah9Jrs3w0YYo7FMIJ8T7WVQtX2oyqYeDvGtdaRJNZCDXqaBCIuzHCeBSxJP4PI3JVVwaLCiSiagZD&amp;amp;amp;amp;since=2018-01-01&amp;amp;amp;amp;until=2018-04-30&amp;amp;amp;amp;fields=message,link,permalink_url,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true): 2020-03-02 16:12:45.609920
# Retrying.
# HTTP Error 400: Bad Request
