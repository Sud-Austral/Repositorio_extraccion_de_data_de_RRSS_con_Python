# %% [markdown]
# # Minería de datos sobre Twitter 3b
# ## Parte I: Extracción de datos.
# ### 1. Extracción por topico, lugar y fecha:
# 24 de Marzo
#
# Fuentes:
#
# https://medium.com/agatha-codes/0-to-280-getting-twitter-timeline-data-for-your-awesome-nlp-project-ff41b941ed6
#
# https://github.com/eleanorstrib/twitter_timeline_analysis_1/blob/master/twitter_timeline_to_csv.ipynb
#
# https://towardsdatascience.com/mining-twitter-data-ba4e44e6aecc
#
# https://github.com/owecodes/mining-twitter
#
# https://gist.github.com/mchirico/01ab321cb3533908cac5874f1705e45d

# %%
# Conexión a twitter:

import tweepy
from tweepy import OAuthHandler

api_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
api_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'
access_token = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
auth = OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
#api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
prompt = '> '
tweet=''

print("ingrese el tópico sobre el cual hacer la consulta: ")
topico = input(prompt)
print("ingrese fecha de inicio de los tweets")
fecha_de_inicio = input(prompt)
print("ingrese fecha de fin de los tweets")
fecha_de_fin = input(prompt)

# 2019-10-18
# 2020-03-18
# Out:
# ingrese el tópico sobre el cual hacer la consulta:
# > amor
# ingrese fecha de inicio de los tweets
# > 2019-10-18
# ingrese fecha de fin de los tweets
# > 2020-03-18

# %%
import datetime
import csv
j=1
for i in tweepy.Cursor(api.search, q = topico,  geocode="-33.433252,-70.606720,1km", tweet_mode='extended').items():
    
   # if(str(i.created_at) >= str(fecha_de_inicio) and str(i.created_at) <= str(fecha_de_fin)+str(1)):
    
    print (str(j) +') '+ 
        '\n' + 'Texto del tweet: '+ i.full_text +
        '\n' + 'Fecha de creación del tweet: ' + str(i.created_at)+' '+ '\n'+ '\n')
    j= j+1
# Out:
# 1)
# Texto del tweet: @theweeknd TE AMO MI AMOR ♥️
# Fecha de creación del tweet: 2020-03-25 00:43:31
#
#
# 2)
# Texto del tweet: @AlexRockStarGo Amor mío 😂
# Fecha de creación del tweet: 2020-03-25 00:14:27
#
#
# 3)
# Texto del tweet: Y diez más que duraban 1-2 jajajaj esto es amor verdadero https://t.co/mBwsb8SjZm
# Fecha de creación del tweet: 2020-03-25 00:00:37
#
#
# 4)
# Texto del tweet: @Amor_Animal2020 GRACIAS A DIOS LA GATITA FUE RESCATADA DE ESTA BESTIA AHORA @GobiernodeChile LE CORRESPONDE SABER SI ESTA APTA PARA TENER SUS HIJAS O LO QUE SEAN ..QUE LES ENSEÑAN A FUTURAS GENERACIONES
# Fecha de creación del tweet: 2020-03-24 17:46:01
#
#
# 5)
# Texto del tweet: @ma_azevedo94 @AndreRuoco Amor de mae é a primeira novela que vejo desde senhora do destino.
# Fecha de creación del tweet: 2020-03-24 02:14:51
#
#
# 6)
# Texto del tweet: @Blanquito_Amor Me indica el articulo del código ?
# Fecha de creación del tweet: 2020-03-24 01:26:07
#
#
# 7)
# Texto del tweet: @Blanquito_Amor Me das el art ?
# Fecha de creación del tweet: 2020-03-24 01:24:09
#
#
# 8)
# Texto del tweet: @Blanquito_Amor Si, pero tendría que estar esa actividad regulada en el decreto de estado de emergencia correspondiente 🤷🏻‍♀️
# Fecha de creación del tweet: 2020-03-24 01:22:52
#
#
# 9)
# Texto del tweet: @Claudiotter @timesnewrommy Merecidos los que comenzaron mal, triste para los que tenían futuro, creo que es una gran prueba de fuego, sobretodo para quienes se van a vivir juntos a lo loco, los que ya se conocen se dan espacio. Es extraño y justiciero el amor. 💔
# Fecha de creación del tweet: 2020-03-24 00:46:55
#
#
# 10)
# Texto del tweet: #NowPlaying️ Fuimos Amor by @estemanmusic
# https://t.co/NqttHWjxPR
# Fecha de creación del tweet: 2020-03-23 21:28:33
#
#
# 11)
# Texto del tweet: 🎶🎶 Ven y sana mi dolorrrrrrr...tienes la cura de éste amor oh oh oh...🎶🎶🎶
#
# #COVIDー19
# Fecha de creación del tweet: 2020-03-23 18:00:47
#
#
# 12)
# Texto del tweet: @Valle_Grande_ POR AMOR A DIOS @Carabdechile @PDI_CHILE @MMAChile @sotomayor_el Y EL QUE SE SUME A ESTA BESTIA PAGUE YA QUE TODA SU FAMILIA SERÁ IGUAL.
# Fecha de creación del tweet: 2020-03-23 17:57:27
#
#
# 13)
# Texto del tweet: @Ejercito_Chile @DeliaDG Gracias por su patriotismo y amor a Chile.
# No puedo decir lo mismo del maldito Congreso.
# Fecha de creación del tweet: 2020-03-23 17:28:46
#
#
# 14)
# Texto del tweet: @Yeyi79 O sea l@s sin pareja vamos a morir ???
# O incluye cualquier tipo de amor??
# #PreguntaSeria 😑🤔🤔
# Fecha de creación del tweet: 2020-03-23 14:25:05
#
#
# 15)
# Texto del tweet: Ayer @KarlaEnAccion se reía de las medidas tomadas en Argentina por "no ser efectivas". Pero al menos lo intentan y explican. Nada de discursos robados de un presidente melómano, nada de fotitos puestas, nada de "el amor es la mejor vacuna"... MEDIDAS Y MEDIDAS EFECTIVAS! https://t.co/mlkgx3Bzyx
# Fecha de creación del tweet: 2020-03-23 12:21:09
#
#
# 16)
# Texto del tweet: Debieran meterla presa
# Por habla tanta estupidez
# El amor no cura el Coronavirus tonta ignorante ! https://t.co/MKjkFgFkla
# Fecha de creación del tweet: 2020-03-23 12:03:55
#
#
# 17)
# Fecha de creación del tweet: 2020-03-21 03:23:52
#
#
# 29)
# Texto del tweet: @Sharonmijares Esta medio gafo amor
# Fecha de creación del tweet: 2020-03-20 19:52:11
#
#
# 30)
# Texto del tweet: Al fin una buena noticia. Que lo abracen, abracen a la madre y entreguen amor.
# A los weones mal hablados. Que se meten los csm como si fueran perfectos!!! https://t.co/brcvBUUNYO
# Fecha de creación del tweet: 2020-03-20 19:09:03
#
#
# 31)
# Texto del tweet: En tiempos donde el llamado es a quedarse en casa y hacer cuarentena, les queremos recomendar "Cuerdas", este conmovedor cortometraje español con un mensaje de respeto, inclusión y amor
# #CuarentenaChile
# #CoronaVirusEnChile
# .
# .
# .
# https://t.co/uhwZwsIkR6
# Fecha de creación del tweet: 2020-03-20 15:03:20
#
#
# 32)
# Texto del tweet: Se me apetece leer “El amor en los tiempos del cólera” de García Márquez, muy acorde a los tiempos que estamos viviendo.
#
# Quizás el coronavirus no es enfermedad sino síntomas de enamoramiento ✌🏻
#
# #soñemos
# Fecha de creación del tweet: 2020-03-20 13:24:48
#
#
# 33)
# Texto del tweet: Estaba escuchando "Un amor violento" y creo que esa canción siempre le va a pertenecer a una historia de mi vida. Reflexiones de cuarentena.
# Fecha de creación del tweet: 2020-03-20 01:08:47
#
#
# 34)
# Texto del tweet: @SexualSaludable Bien por el amor ♥️😍
# Fecha de creación del tweet: 2020-03-19 22:41:02
#
#
# 35)
# Texto del tweet: @JuFtn Gracias a ti por difundir y por el amor a los animales 😻
# Fecha de creación del tweet: 2020-03-19 21:04:06
#
#
# 36)
# Texto del tweet: Hola corazones ♥️ los quiero deleitar con esta hermosa piscina de forma corazón , para que les llegue alegría de creer que el amor entre los seres humanos, aún existe ... #BuenJueves #EstonoesPlazaItalia muchos abrazos virtuales a tod@s #GoodVibes ♥️🙏🏼😍🥰😘🤗 https://t.co/p7fVgVucO0
# Fecha de creación del tweet: 2020-03-19 16:43:31
#
#
# 37)
# Texto del tweet: Como dijo Juanes:
#
# "Y es que vale más, un año tardío que un siglo vacío amor"
#
# #QuedateEnCasa
# Fecha de creación del tweet: 2020-03-19 13:09:01
#
#
# 38)
# Texto del tweet: @Patri92RM Yo te visito amor
# Fecha de creación del tweet: 2020-03-18 22:31:00
#
#
# 39)
# Texto del tweet: @gonzalowinter @Camara_cl Excelente mi amor ❤️
# Fecha de creación del tweet: 2020-03-18 17:33:16
#
#
# 40)
# Texto del tweet: 🎶
# Como sufro al pensar
# Que en Venecia murió
# El amor que jurabas
# Eterno guardar
# Solo queda un adiós
# Que no puedo olvidar
# Hoy #Venecia sin ti
# Que triste y sola está
# 🎶
#
# (Quizá si Aznavour hubiese visto cómo está #Venecia hoy, la letra sería otra.♥️) https://t.co/KghwXshhr2
# Fecha de creación del tweet: 2020-03-18 11:57:37
#
#
# 41)
# Texto del tweet: Pensar salud mental de nuestr@s ni@ños, explicar encierro sin alarmas por responsabilidad, cuidado amor a los otr@s. Tener rutinas con ellos, no son vacaciones, sigamos las aulas virtuales, audio libros, creatividad y flexibilidad @rafa_cavada @patriciavenegas #sonarinformativo
# Fecha de creación del tweet: 2020-03-18 10:43:42
#
#
# 42)
# Texto del tweet: @Davoxs @biobio Y a ti también te pagan por idiota? O es por amor al arte?
# Fecha de creación del tweet: 2020-03-17 15:18:30
#
#
# 43)
# Texto del tweet: En el Evangelio de hoy Jesús insiste en la compasión y la Misericordia para perdonar a quien nos hace daño. Sólo desde el Amor y la presencia del Espíritu Santo en nuestra vida es posible lograr perdonarse y perdonar a otros 💝🙏🏻🙇🏻‍♀ Danos Señor humildad de corazón para lograrlo https://t.co/Q27bZac4wD
# Fecha de creación del tweet: 2020-03-17 12:36:12
#
#
# 44)
# Texto del tweet: Hola gente linda!
#
# Tengan un lindo martes, llenito de amor y cuidados personales
# Fecha de creación del tweet: 2020-03-17 11:59:48
#
#
# 45)
# Texto del tweet: Dios llévatelo por el amor de tu Hijo. https://t.co/AcyvAHfnwx
# Fecha de creación del tweet: 2020-03-17 11:00:21
#
#
# 46)
# Texto del tweet: @mvacarezza Maldito,  ojalá Dios te envíe su castigo, llamas a la gente a protestar sabiendo  que aceleras el contagio, ¿ quieres  en vez de un país un cementerio  ? Aquí se nota tu amor a la patria y a sus hijos, ojalá  te escuchen y razonen tus seguidores
# Fecha de creación del tweet: 2020-03-17 09:32:07
#
#
# 47)
# Texto del tweet: Con el onvre nos guardamos y se prendieron las cosas con natalia oreiro de fondo y sonó mil veces "cambio amor" en todas sus versiones. Sabían que ella es jevy famosa en Rusia?
# Fecha de creación del tweet: 2020-03-17 04:47:29
#
#
# 48)
# Texto del tweet: @JA_ERNAU Gracias José , no lo digo por mi familia ... a veces son los cercanos ! En fin si es por amor ♥️ Vamos!!!
# Fecha de creación del tweet: 2020-03-17 03:12:29

# %%
# codigo para guardar en CSV:
tweet=''
import datetime
import csv
csvFile = open('tweet.csv', 'a')

filename = 'alcalde001_'+(datetime.datetime.now().strftime("%Y-%m-%d-%H"))+'.csv'

with open (filename, 'a+', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    for tweet in tweepy.Cursor(api.search , 
                   since='2019-10-18', q = 'Carlos Adasme, carlos adasme',
                               geocode="-33.746827,-70.900098,0.5km").items():
        print ([tweet.created_at, tweet.text.encode('utf-8'), tweet.id, tweet.place])
        
        csvWriter.writerow([tweet.created_at, 
                            tweet.text.encode('utf-8'), 
                            tweet.id, 
                            tweet.place])
    if tweet == '':
        print('No hay nada que mostrar')
