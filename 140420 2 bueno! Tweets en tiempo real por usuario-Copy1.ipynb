# %% [markdown]
# # 140420 Tweets por usuario
#
# código excelente!

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-11
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
# https://twitter.com/colmedchile/status/1249754648476516352
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
prompt = '> '
tweet=''
print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = input(prompt)

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
    
# realDonaldTrump
# Out:
# ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:
# > ispch
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOl5Grx… https://t.co/lawLxqwmj6
#
# RT @arturozunigaj: El equipamiento y la infraestructura para enfrentar esta pandemia #Covid_19 la iremos disponiendo donde se requiera! dos…
#
# RT @arturozunigaj: Una cuarentena con estrellas: Cómo funcionan las 2.479 camas de las residencias sanitarias, habilitadas en hoteles https…
#
# RT @SaludMagallanes: Hoy arribaron a #Puq dos ventiladores mecánicos adquiridos por @SaludMagallanes destinados a reforzar la Unidad de Pac…
#
# RT @ministeriosalud: El Bosque y parte de San Bernardo y Arica entrarán en cuarentena este jueves  https://t.co/wxXW27i9fK #PlanCoronavirus
#
# Si tienes un pañuelo en tu hogar, puedes convertirlo en una mascarilla.
#
# Sigue estos pasos y #CuidémonosEntreTodos https://t.co/SsyAP2YcLz
#
# RT @arturozunigaj: Esta mañana en @Cenabast prepararon como habitualmente los despachos de #ElementosProtecciónPersonal para nuestros  reci…
#
# RT @ministeriosalud: Ministro @jmanalich | Medidas
#
# - Cierre de fronteras se mantiene hasta el 22 de abril (puede ser extendible)
# - Nueva I…
#
# RT @arturozunigaj: Excelente demostración de la Provincia del BioBio sobre cómo debemos trabajar para enfrentar esta Pandemia.
# Alcaldes, S…
#
# #VacúnateAhora contra la influenza. Recuerda que es además gratuita para personas mayores de 65 años, niños y niñas… https://t.co/7zBRgWMRs0

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Protégete contra el nuevo Coronavirus COVID-19...
# 1  RT @arturozunigaj: El equipamiento y la infrae...
# 2  RT @arturozunigaj: Una cuarentena con estrella...
# 3  RT @SaludMagallanes: Hoy arribaron a #Puq dos ...
# 4  RT @ministeriosalud: El Bosque y parte de San ...
# 5  Si tienes un pañuelo en tu hogar, puedes conve...
# 6  RT @arturozunigaj: Esta mañana en @Cenabast pr...
# 7  RT @ministeriosalud: Ministro @jmanalich | Med...
# 8  RT @arturozunigaj: Excelente demostración de l...
# 9  #VacúnateAhora contra la influenza. Recuerda q...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1250166943190929409
# 2020-04-14 21:00:00
# TweetDeck
# 0
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/YdvmOl5Grx', 'expanded_url': 'http://gob.cl/coronavirus', 'display_url': 'gob.cl/coronavirus', 'indices': [87, 110]}, {'url': 'https://t.co/lawLxqwmj6', 'expanded_url': 'https://twitter.com/i/web/status/1250166943190929409', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [112, 135]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Protégete contra el nuevo Coronavirus COVID-19...  1250166943190929409
# 1  RT @arturozunigaj: El equipamiento y la infrae...  1250156080493142017
# 2  RT @arturozunigaj: Una cuarentena con estrella...  1250156022024548352
# 3  RT @SaludMagallanes: Hoy arribaron a #Puq dos ...  1250155981406900224
# 4  RT @ministeriosalud: El Bosque y parte de San ...  1250139699638829056
# 5  Si tienes un pañuelo en tu hogar, puedes conve...  1250136743946436608
# 6  RT @arturozunigaj: Esta mañana en @Cenabast pr...  1250110146526752768
# 7  RT @ministeriosalud: Ministro @jmanalich | Med...  1250110101249241088
# 8  RT @arturozunigaj: Excelente demostración de l...  1250109200979693570
# 9  #VacúnateAhora contra la influenza. Recuerda q...  1250106543845990403
#
#                  Date              Source  Likes  RTs
# 0 2020-04-14 21:00:00           TweetDeck      0    0
# 1 2020-04-14 20:16:51  Twitter for iPhone      0   16
# 2 2020-04-14 20:16:37  Twitter for iPhone      0   17
# 3 2020-04-14 20:16:27  Twitter for iPhone      0   50
# 4 2020-04-14 19:11:45  Twitter for iPhone      0   10
# 5 2020-04-14 19:00:00           TweetDeck      3    6
# 6 2020-04-14 17:14:19  Twitter for iPhone      0   54
# 7 2020-04-14 17:14:08  Twitter for iPhone      0   49
# 8 2020-04-14 17:10:34  Twitter for iPhone      0   36
# 9 2020-04-14 17:00:00           TweetDeck      3    1

# %% [markdown]
# ahora agregemos un string a la columna ID

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Protégete contra el nuevo Coronavirus COVID-19...
# 1  RT @arturozunigaj: El equipamiento y la infrae...
# 2  RT @arturozunigaj: Una cuarentena con estrella...
# 3  RT @SaludMagallanes: Hoy arribaron a #Puq dos ...
# 4  RT @ministeriosalud: El Bosque y parte de San ...
# 5  Si tienes un pañuelo en tu hogar, puedes conve...
# 6  RT @arturozunigaj: Esta mañana en @Cenabast pr...
# 7  RT @ministeriosalud: Ministro @jmanalich | Med...
# 8  RT @arturozunigaj: Excelente demostración de l...
# 9  #VacúnateAhora contra la influenza. Recuerda q...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1250166943190... 2020-04-14 21:00:00
# 1  https://twitter.com/ispch/status/1250156080493... 2020-04-14 20:16:51
# 2  https://twitter.com/ispch/status/1250156022024... 2020-04-14 20:16:37
# 3  https://twitter.com/ispch/status/1250155981406... 2020-04-14 20:16:27
# 4  https://twitter.com/ispch/status/1250139699638... 2020-04-14 19:11:45
# 5  https://twitter.com/ispch/status/1250136743946... 2020-04-14 19:00:00
# 6  https://twitter.com/ispch/status/1250110146526... 2020-04-14 17:14:19
# 7  https://twitter.com/ispch/status/1250110101249... 2020-04-14 17:14:08
# 8  https://twitter.com/ispch/status/1250109200979... 2020-04-14 17:10:34
# 9  https://twitter.com/ispch/status/1250106543845... 2020-04-14 17:00:00
#
#                Source  Likes  RTs
# 0           TweetDeck      0    0
# 1  Twitter for iPhone      0   16
# 2  Twitter for iPhone      0   17
# 3  Twitter for iPhone      0   50
# 4  Twitter for iPhone      0   10
# 5           TweetDeck      3    6
# 6  Twitter for iPhone      0   54
# 7  Twitter for iPhone      0   49
# 8  Twitter for iPhone      0   36
# 9           TweetDeck      3    1

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)

# %% [markdown]
# #### Ahora se debe borrar el contenido del txt:
