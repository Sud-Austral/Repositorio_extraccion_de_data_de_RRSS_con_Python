# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# #VacúnateAhora contra la influenza. Recuerda que es además gratuita para personas mayores de 65 años, niños y niñas… https://t.co/OOEVDjXDHi
#
# RT @SaludNuble: ¡Grande Quirihue!👏🏻Tomando todas las medidas preventivas y siguiendo las recomendaciones de la autoridad sanitaria, 24 pers…
#
# RT @ministeriosalud: Salud dio a conocer el primer nacimiento del nuevo Hospital @FelixHfb https://t.co/44KYcvLtRh #PlanCoronavirus
#
# Es obligatorio el uso de mascarillas en medios de transporte públicos y privados remunerados.
#
# Si no cuentas con un… https://t.co/e6xCB6ZODq
#
# Conoce más sobre esta nueva medida que comienza a implementarse y encuentra más información en… https://t.co/6jNZKeVr6z
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOlnhQ7… https://t.co/gbyppQyqj1
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/IX07CbpjgE
#
# Donar sangre es donar vida.
# Si vas a salir, haz que valga la pena. Si tu comuna está en cuarentena puedes pedir tu… https://t.co/S6ZEB7n58a
#
# RT @ministeriosalud: "Estamos sacando adelante a nuestro país (del #COVID_19), y así ha sido reconocido internacionalmente".
#
# - Ministro @j…
#
# RT @ministeriosalud: Ministro @jmanalich | Grupos de importancia vacunación
#
# - Embarazadas, en cualquier momento de la edad gestacional
# - N…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  #VacúnateAhora contra la influenza. Recuerda q...
# 1  RT @SaludNuble: ¡Grande Quirihue!👏🏻Tomando tod...
# 2  RT @ministeriosalud: Salud dio a conocer el pr...
# 3  Es obligatorio el uso de mascarillas en medios...
# 4  Conoce más sobre esta nueva medida que comienz...
# 5  Protégete contra el nuevo Coronavirus COVID-19...
# 6  El uso correcto de la mascarilla es clave para...
# 7  Donar sangre es donar vida.\nSi vas a salir, h...
# 8  RT @ministeriosalud: "Estamos sacando adelante...
# 9  RT @ministeriosalud: Ministro @jmanalich | Gru...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1253066046497419266
# 2020-04-22 21:00:00
# TweetDeck
# 4
# 3
# None
# None
# {'hashtags': [{'text': 'VacúnateAhora', 'indices': [0, 14]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OOEVDjXDHi', 'expanded_url': 'https://twitter.com/i/web/status/1253066046497419266', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  #VacúnateAhora contra la influenza. Recuerda q...  1253066046497419266
# 1  RT @SaludNuble: ¡Grande Quirihue!👏🏻Tomando tod...  1253054726712758272
# 2  RT @ministeriosalud: Salud dio a conocer el pr...  1253054678566346763
# 3  Es obligatorio el uso de mascarillas en medios...  1253050947850260481
# 4  Conoce más sobre esta nueva medida que comienz...  1253035845721833477
# 5  Protégete contra el nuevo Coronavirus COVID-19...  1253020748555452416
# 6  El uso correcto de la mascarilla es clave para...  1253005649216262146
# 7  Donar sangre es donar vida.\nSi vas a salir, h...  1252990547331088385
# 8  RT @ministeriosalud: "Estamos sacando adelante...  1252983767603580932
# 9  RT @ministeriosalud: Ministro @jmanalich | Gru...  1252983756551524355
#
#                  Date              Source  Likes  RTs
# 0 2020-04-22 21:00:00           TweetDeck      4    3
# 1 2020-04-22 20:15:02  Twitter for iPhone      0   10
# 2 2020-04-22 20:14:50  Twitter for iPhone      0    9
# 3 2020-04-22 20:00:01           TweetDeck      1    1
# 4 2020-04-22 19:00:00           TweetDeck      2    3
# 5 2020-04-22 18:00:01           TweetDeck      0    1
# 6 2020-04-22 17:00:01           TweetDeck      1    1
# 7 2020-04-22 16:00:00           TweetDeck      2    3
# 8 2020-04-22 15:33:04  Twitter for iPhone      0  227
# 9 2020-04-22 15:33:01  Twitter for iPhone      0   19

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  #VacúnateAhora contra la influenza. Recuerda q...
# 1  RT @SaludNuble: ¡Grande Quirihue!👏🏻Tomando tod...
# 2  RT @ministeriosalud: Salud dio a conocer el pr...
# 3  Es obligatorio el uso de mascarillas en medios...
# 4  Conoce más sobre esta nueva medida que comienz...
# 5  Protégete contra el nuevo Coronavirus COVID-19...
# 6  El uso correcto de la mascarilla es clave para...
# 7  Donar sangre es donar vida.\nSi vas a salir, h...
# 8  RT @ministeriosalud: "Estamos sacando adelante...
# 9  RT @ministeriosalud: Ministro @jmanalich | Gru...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1253066046497... 2020-04-22 21:00:00
# 1  https://twitter.com/ispch/status/1253054726712... 2020-04-22 20:15:02
# 2  https://twitter.com/ispch/status/1253054678566... 2020-04-22 20:14:50
# 3  https://twitter.com/ispch/status/1253050947850... 2020-04-22 20:00:01
# 4  https://twitter.com/ispch/status/1253035845721... 2020-04-22 19:00:00
# 5  https://twitter.com/ispch/status/1253020748555... 2020-04-22 18:00:01
# 6  https://twitter.com/ispch/status/1253005649216... 2020-04-22 17:00:01
# 7  https://twitter.com/ispch/status/1252990547331... 2020-04-22 16:00:00
# 8  https://twitter.com/ispch/status/1252983767603... 2020-04-22 15:33:04
# 9  https://twitter.com/ispch/status/1252983756551... 2020-04-22 15:33:01
#
#                Source  Likes  RTs
# 0           TweetDeck      4    3
# 1  Twitter for iPhone      0   10
# 2  Twitter for iPhone      0    9
# 3           TweetDeck      1    1
# 4           TweetDeck      2    3
# 5           TweetDeck      0    1
# 6           TweetDeck      1    1
# 7           TweetDeck      2    3
# 8  Twitter for iPhone      0  227
# 9  Twitter for iPhone      0   19

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
