# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# "Como salud no podemos anticipar la situación del segundo semestre, nuestra respuesta dependerá…
#
# RT @ministeriosalud: "La fase de contención se va a prolongar por muchos meses, y cada paso que se dé, tiene que realizarse con mucho cuida…
#
# RT @ministeriosalud: Subsec @arturozunigaj:
#
# "Como Minsal, estamos poniendo todo nuestro #PlanCoronavirus en implementación"
#
# "La llegada d…
#
# RT @ministeriosalud: Subsec @arturozunigaj  | Red Asistencial #COVID_19
#
# 🔹 426 hospitalizados
# 🔹 325 con ventilación mecánica
# 🔹 5.260 exáme…
#
# RT @ministeriosalud: Subsec @pdazan | Balance diario #COVID_19
#
# 🔹 482 casos nuevos
# 🔹 13.813 casos totales
# 🔹 9 fallecidos (198 en total)
# 🔹…
#
# RT @ministeriosalud: Ministro @jmanalich | Consejo Asesor
#
# Nuestro Consejo Asesor acaba de publicar unos lineamientos, que son:
#
# - Nueva d…
#
# RT @ministeriosalud: "Todo lo que está haciendo el Minsal es con la asesoría de expertos, consejeros de la OMS, consejo asesor, para tomar…
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# "Agradecemos el trabajo de los funcionarios de la salud, porque han permitido que hasta esta fec…
#
# RT @ministeriosalud: [EN VIVO] Autoridades de Salud entregan balance diario de #COVID_19 en nuestro país. https://t.co/yeeO5BBPGG
#
# El uso correcto de la mascarilla es clave para proteger tu salud y la de los demás.
#
# ¿Cómo usarla y retirarla? Sig… https://t.co/AtCNEVXkDo

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 1  RT @ministeriosalud: "La fase de contención se...
# 2  RT @ministeriosalud: Subsec @arturozunigaj:\n\...
# 3  RT @ministeriosalud: Subsec @arturozunigaj  | ...
# 4  RT @ministeriosalud: Subsec @pdazan | Balance ...
# 5  RT @ministeriosalud: Ministro @jmanalich | Con...
# 6  RT @ministeriosalud: "Todo lo que está haciend...
# 7  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 8  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 9  El uso correcto de la mascarilla es clave para...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1254782617624301571
# 2020-04-27 14:41:03
# Twitter for iPhone
# 0
# 14
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ministeriosalud', 'name': 'Ministerio de Salud', 'id': 153825949, 'id_str': '153825949', 'indices': [3, 19]}, {'screen_name': 'jmanalich', 'name': 'Jaime Mañalich', 'id': 114834301, 'id_str': '114834301', 'indices': [30, 40]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...  1254782617624301571
# 1  RT @ministeriosalud: "La fase de contención se...  1254782594429804545
# 2  RT @ministeriosalud: Subsec @arturozunigaj:\n\...  1254780610058440706
# 3  RT @ministeriosalud: Subsec @arturozunigaj  | ...  1254780211729534980
# 4  RT @ministeriosalud: Subsec @pdazan | Balance ...  1254780008498737153
# 5  RT @ministeriosalud: Ministro @jmanalich | Con...  1254778591411228675
# 6  RT @ministeriosalud: "Todo lo que está haciend...  1254778578429816833
# 7  RT @ministeriosalud: Ministro @jmanalich:\n\n"...  1254778561551953924
# 8  RT @ministeriosalud: [EN VIVO] Autoridades de ...  1254775997578088455
# 9  El uso correcto de la mascarilla es clave para...  1254772291231072271
#
#                  Date              Source  Likes  RTs
# 0 2020-04-27 14:41:03  Twitter for iPhone      0   14
# 1 2020-04-27 14:40:57  Twitter for iPhone      0    6
# 2 2020-04-27 14:33:04  Twitter for iPhone      0    8
# 3 2020-04-27 14:31:29  Twitter for iPhone      0   25
# 4 2020-04-27 14:30:41  Twitter for iPhone      0   50
# 5 2020-04-27 14:25:03  Twitter for iPhone      0   26
# 6 2020-04-27 14:25:00  Twitter for iPhone      0   24
# 7 2020-04-27 14:24:56  Twitter for iPhone      0   59
# 8 2020-04-27 14:14:45  Twitter for iPhone      0  118
# 9 2020-04-27 14:00:01           TweetDeck      0    0

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 1  RT @ministeriosalud: "La fase de contención se...
# 2  RT @ministeriosalud: Subsec @arturozunigaj:\n\...
# 3  RT @ministeriosalud: Subsec @arturozunigaj  | ...
# 4  RT @ministeriosalud: Subsec @pdazan | Balance ...
# 5  RT @ministeriosalud: Ministro @jmanalich | Con...
# 6  RT @ministeriosalud: "Todo lo que está haciend...
# 7  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 8  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 9  El uso correcto de la mascarilla es clave para...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1254782617624... 2020-04-27 14:41:03
# 1  https://twitter.com/ispch/status/1254782594429... 2020-04-27 14:40:57
# 2  https://twitter.com/ispch/status/1254780610058... 2020-04-27 14:33:04
# 3  https://twitter.com/ispch/status/1254780211729... 2020-04-27 14:31:29
# 4  https://twitter.com/ispch/status/1254780008498... 2020-04-27 14:30:41
# 5  https://twitter.com/ispch/status/1254778591411... 2020-04-27 14:25:03
# 6  https://twitter.com/ispch/status/1254778578429... 2020-04-27 14:25:00
# 7  https://twitter.com/ispch/status/1254778561551... 2020-04-27 14:24:56
# 8  https://twitter.com/ispch/status/1254775997578... 2020-04-27 14:14:45
# 9  https://twitter.com/ispch/status/1254772291231... 2020-04-27 14:00:01
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0   14
# 1  Twitter for iPhone      0    6
# 2  Twitter for iPhone      0    8
# 3  Twitter for iPhone      0   25
# 4  Twitter for iPhone      0   50
# 5  Twitter for iPhone      0   26
# 6  Twitter for iPhone      0   24
# 7  Twitter for iPhone      0   59
# 8  Twitter for iPhone      0  118
# 9           TweetDeck      0    0

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
