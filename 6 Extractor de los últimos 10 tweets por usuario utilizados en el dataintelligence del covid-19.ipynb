# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
#   File "<ipython-input-39-de7cab2bb03e>", line 4
#     usuario_de_consulta = 'ispch
#                                 ^
# SyntaxError: EOL while scanning string literal

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @sebastianpinera: [VIVO] Desde aeropuerto A...
# 1  RT @ministeriosalud: "El Presidente @sebastian...
# 2  RT @ministeriosalud: "El retorno debe ser grad...
# 3  RT @ministeriosalud: Subsec @arturozunigaj | B...
# 4  RT @ministeriosalud: Ministro @jmanalich \n\n"...
# 5  RT @ministeriosalud: 🔴📺AHORA | Punta Arenas  M...
# 6  RT @ministeriosalud: Subsec @arturozunigaj \n\...
# 7  RT @ministeriosalud: "Desde el @HCMagallanes y...
# 8  RT @ministeriosalud: "Agradecemos y felicitamo...
# 9  RT @ministeriosalud: Ministro @jmanalich:\n\n"...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1254068012614856707
# 2020-04-25 15:21:28
# Twitter for iPhone
# 0
# 181
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'sebastianpinera', 'name': 'Sebastian Piñera', 'id': 13623532, 'id_str': '13623532', 'indices': [3, 19]}], 'urls': [{'url': 'https://t.co/XIjKG0A1Gb', 'expanded_url': 'https://www.pscp.tv/w/cXL5eDFNV0V3TUxndldES2J8MWRSSlpRTG9wRGdHQqD2vGXqJ2gGzfeItsdDR_5rkgJOToixMtbDOiygGyQM', 'display_url': 'pscp.tv/w/cXL5eDFNV0V3…', 'indices': [117, 140]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @sebastianpinera: [VIVO] Desde aeropuerto A...  1254068012614856707
# 1  RT @ministeriosalud: "El Presidente @sebastian...  1254061944929222657
# 2  RT @ministeriosalud: "El retorno debe ser grad...  1254061917750116354
# 3  RT @ministeriosalud: Subsec @arturozunigaj | B...  1254061887542767618
# 4  RT @ministeriosalud: Ministro @jmanalich \n\n"...  1254061845348069376
# 5  RT @ministeriosalud: 🔴📺AHORA | Punta Arenas  M...  1254061823319564288
# 6  RT @ministeriosalud: Subsec @arturozunigaj \n\...  1254052553584717824
# 7  RT @ministeriosalud: "Desde el @HCMagallanes y...  1254052499545341953
# 8  RT @ministeriosalud: "Agradecemos y felicitamo...  1254048806276149255
# 9  RT @ministeriosalud: Ministro @jmanalich:\n\n"...  1254048773870882819
#
#                  Date              Source  Likes  RTs
# 0 2020-04-25 15:21:28  Twitter for iPhone      0  181
# 1 2020-04-25 14:57:21  Twitter for iPhone      0   39
# 2 2020-04-25 14:57:15  Twitter for iPhone      0   24
# 3 2020-04-25 14:57:07  Twitter for iPhone      0   91
# 4 2020-04-25 14:56:57  Twitter for iPhone      0   43
# 5 2020-04-25 14:56:52  Twitter for iPhone      0  112
# 6 2020-04-25 14:20:02  Twitter for iPhone      0   12
# 7 2020-04-25 14:19:49  Twitter for iPhone      0    8
# 8 2020-04-25 14:05:09  Twitter for iPhone      0   17
# 9 2020-04-25 14:05:01  Twitter for iPhone      0   27

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @sebastianpinera: [VIVO] Desde aeropuerto A...
# 1  RT @ministeriosalud: "El Presidente @sebastian...
# 2  RT @ministeriosalud: "El retorno debe ser grad...
# 3  RT @ministeriosalud: Subsec @arturozunigaj | B...
# 4  RT @ministeriosalud: Ministro @jmanalich \n\n"...
# 5  RT @ministeriosalud: 🔴📺AHORA | Punta Arenas  M...
# 6  RT @ministeriosalud: Subsec @arturozunigaj \n\...
# 7  RT @ministeriosalud: "Desde el @HCMagallanes y...
# 8  RT @ministeriosalud: "Agradecemos y felicitamo...
# 9  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125406... 2020-04-25 15:21:28
# 1  https://twitter.com/SuperDeSalud/status/125406... 2020-04-25 14:57:21
# 2  https://twitter.com/SuperDeSalud/status/125406... 2020-04-25 14:57:15
# 3  https://twitter.com/SuperDeSalud/status/125406... 2020-04-25 14:57:07
# 4  https://twitter.com/SuperDeSalud/status/125406... 2020-04-25 14:56:57
# 5  https://twitter.com/SuperDeSalud/status/125406... 2020-04-25 14:56:52
# 6  https://twitter.com/SuperDeSalud/status/125405... 2020-04-25 14:20:02
# 7  https://twitter.com/SuperDeSalud/status/125405... 2020-04-25 14:19:49
# 8  https://twitter.com/SuperDeSalud/status/125404... 2020-04-25 14:05:09
# 9  https://twitter.com/SuperDeSalud/status/125404... 2020-04-25 14:05:01
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0  181
# 1  Twitter for iPhone      0   39
# 2  Twitter for iPhone      0   24
# 3  Twitter for iPhone      0   91
# 4  Twitter for iPhone      0   43
# 5  Twitter for iPhone      0  112
# 6  Twitter for iPhone      0   12
# 7  Twitter for iPhone      0    8
# 8  Twitter for iPhone      0   17
# 9  Twitter for iPhone      0   27

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
