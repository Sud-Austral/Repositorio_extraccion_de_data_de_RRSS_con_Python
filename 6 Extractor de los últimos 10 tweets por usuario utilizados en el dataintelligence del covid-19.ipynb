# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# "Tenemos 3 menores hospitalizados, 2 en Antofagasta y 1 en Santiago, por situaciones asociadas a…
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# Exceso de permisos: "El aislamiento físico es la medida esencial para combatir #COVID_19".
#
# Bro…
#
# RT @ministeriosalud: [EN VIVO] Autoridades de Salud entregan balance diario de #COVID_19 en nuestro país. https://t.co/cfZas0FfwG
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/bJdIH6rpP8
#
# Si estás en aislamiento domiciliario, es muy importante mantener las medidas de prevención en el hogar.
#
# - Lávate l… https://t.co/Q6d7wLlPLw
#
# Fabrica tu propia mascarilla con una bandana.
# #CuidémonosEntreTodos https://t.co/oxR4wSCR1X
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOl5Grx… https://t.co/PSBppRhQNq
#
# Si no tienes mascarillas, crea la tuya en simples pasos con una polera.
# #CuidémonosEntreTodos https://t.co/Wqe4iFrreV
#
# Es obligatorio el uso de mascarillas en medios de transporte públicos y privados remunerados.
#
# Si no cuentas con un… https://t.co/wj9PaG5XAf
#
# La versión web de @PublimetroChile entrega información sobre la NO autorización del Clorito de Sodio y Dióxido de C… https://t.co/PBx1s4NwqX

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 1  RT @ministeriosalud: Ministro @jmanalich:\n\nE...
# 2  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 3  Temperatura actual, pronóstico del tiempo y ra...
# 4  Si estás en aislamiento domiciliario, es muy i...
# 5  Fabrica tu propia mascarilla con una bandana.\...
# 6  Protégete contra el nuevo Coronavirus COVID-19...
# 7  Si no tienes mascarillas, crea la tuya en simp...
# 8  Es obligatorio el uso de mascarillas en medios...
# 9  La versión web de @PublimetroChile entrega inf...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1253696130090754054
# 2020-04-24 14:43:44
# Twitter for iPhone
# 0
# 10
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ministeriosalud', 'name': 'Ministerio de Salud', 'id': 153825949, 'id_str': '153825949', 'indices': [3, 19]}, {'screen_name': 'jmanalich', 'name': 'Jaime Mañalich', 'id': 114834301, 'id_str': '114834301', 'indices': [30, 40]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...  1253696130090754054
# 1  RT @ministeriosalud: Ministro @jmanalich:\n\nE...  1253695837827403782
# 2  RT @ministeriosalud: [EN VIVO] Autoridades de ...  1253693902214889476
# 3  Temperatura actual, pronóstico del tiempo y ra...  1253674222599188482
# 4  Si estás en aislamiento domiciliario, es muy i...  1253670027980607488
# 5  Fabrica tu propia mascarilla con una bandana.\...  1253503928626376705
# 6  Protégete contra el nuevo Coronavirus COVID-19...  1253473729570459649
# 7  Si no tienes mascarillas, crea la tuya en simp...  1253458632043159552
# 8  Es obligatorio el uso de mascarillas en medios...  1253443530971701252
# 9  La versión web de @PublimetroChile entrega inf...  1253435982776397825
#
#                  Date              Source  Likes  RTs
# 0 2020-04-24 14:43:44  Twitter for iPhone      0   10
# 1 2020-04-24 14:42:34  Twitter for iPhone      0   13
# 2 2020-04-24 14:34:53  Twitter for iPhone      0   91
# 3 2020-04-24 13:16:41  Twitter for iPhone      0    0
# 4 2020-04-24 13:00:01           TweetDeck      0    0
# 5 2020-04-24 02:00:00           TweetDeck      3    4
# 6 2020-04-24 00:00:00           TweetDeck      0    0
# 7 2020-04-23 23:00:00           TweetDeck      1    1
# 8 2020-04-23 22:00:00           TweetDeck      0    2
# 9 2020-04-23 21:30:00           TweetDeck      1    5

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 1  RT @ministeriosalud: Ministro @jmanalich:\n\nE...
# 2  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 3  Temperatura actual, pronóstico del tiempo y ra...
# 4  Si estás en aislamiento domiciliario, es muy i...
# 5  Fabrica tu propia mascarilla con una bandana.\...
# 6  Protégete contra el nuevo Coronavirus COVID-19...
# 7  Si no tienes mascarillas, crea la tuya en simp...
# 8  Es obligatorio el uso de mascarillas en medios...
# 9  La versión web de @PublimetroChile entrega inf...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1253696130090... 2020-04-24 14:43:44
# 1  https://twitter.com/ispch/status/1253695837827... 2020-04-24 14:42:34
# 2  https://twitter.com/ispch/status/1253693902214... 2020-04-24 14:34:53
# 3  https://twitter.com/ispch/status/1253674222599... 2020-04-24 13:16:41
# 4  https://twitter.com/ispch/status/1253670027980... 2020-04-24 13:00:01
# 5  https://twitter.com/ispch/status/1253503928626... 2020-04-24 02:00:00
# 6  https://twitter.com/ispch/status/1253473729570... 2020-04-24 00:00:00
# 7  https://twitter.com/ispch/status/1253458632043... 2020-04-23 23:00:00
# 8  https://twitter.com/ispch/status/1253443530971... 2020-04-23 22:00:00
# 9  https://twitter.com/ispch/status/1253435982776... 2020-04-23 21:30:00
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0   10
# 1  Twitter for iPhone      0   13
# 2  Twitter for iPhone      0   91
# 3  Twitter for iPhone      0    0
# 4           TweetDeck      0    0
# 5           TweetDeck      3    4
# 6           TweetDeck      0    0
# 7           TweetDeck      1    1
# 8           TweetDeck      0    2
# 9           TweetDeck      1    5

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
