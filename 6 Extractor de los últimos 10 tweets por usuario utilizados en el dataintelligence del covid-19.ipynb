# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'ispch'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOlnhQ7… https://t.co/YDQthqFnMu
#
# Conoce más sobre esta nueva medida que comienza a implementarse y encuentra más información en… https://t.co/RNyGCwzIdv
#
# Temperatura actual, pronóstico del tiempo y rayos UV para Santiago - Dirección Meteorológica de Chile https://t.co/xaRnMwAbQO
#
# RT @ministeriosalud: Chile presenta ante @WHO, a través del ministro @jmanalich, las medidas que se han tomado en el país. Entre ellas, el…
#
# RT @ministeriosalud: "El 30% de personas no tienen síntomas y tienen PCR positivo a #COVID_19. Examen de IGG a población asintomática para…
#
# RT @ministeriosalud: Ministro @jmanalich | Meeting @WHO
#
# "Los países hemos respondido con mucho sacrificio y esfuerzo y nos hemos concentr…
#
# RT @ministeriosalud: AHORA: Min. @jmanalich participa en meeting organizado por @WHO por situación mundial de #COVID_19.
#
# "A nombre de Chi…
#
# Prefiere medicamentos #bioequivalentes.
#
# El @ispch garantiza su calidad, seguridad y eficacia.
#
# #ExigeElAmarillo https://t.co/vaB6Sq1tDp
#
# Fabrica tu propia mascarilla con una bandana.
# #CuidémonosEntreTodos https://t.co/dGbEZ5oTpN
#
# Protégete contra el nuevo Coronavirus COVID-19.
# Entérate más sobre cómo prevenirlo en: https://t.co/YdvmOlnhQ7… https://t.co/ABzY4mIEoc

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  Protégete contra el nuevo Coronavirus COVID-19...
# 1  Conoce más sobre esta nueva medida que comienz...
# 2  Temperatura actual, pronóstico del tiempo y ra...
# 3  RT @ministeriosalud: Chile presenta ante @WHO,...
# 4  RT @ministeriosalud: "El 30% de personas no ti...
# 5  RT @ministeriosalud: Ministro @jmanalich | Mee...
# 6  RT @ministeriosalud: AHORA: Min. @jmanalich pa...
# 7  Prefiere medicamentos #bioequivalentes. \n\nEl...
# 8  Fabrica tu propia mascarilla con una bandana.\...
# 9  Protégete contra el nuevo Coronavirus COVID-19...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1253322740402212864
# 2020-04-23 14:00:01
# TweetDeck
# 0
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/YdvmOlnhQ7', 'expanded_url': 'http://gob.cl/coronavirus', 'display_url': 'gob.cl/coronavirus', 'indices': [87, 110]}, {'url': 'https://t.co/YDQthqFnMu', 'expanded_url': 'https://twitter.com/i/web/status/1253322740402212864', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [112, 135]}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  Protégete contra el nuevo Coronavirus COVID-19...  1253322740402212864
# 1  Conoce más sobre esta nueva medida que comienz...  1253307637715927040
# 2  Temperatura actual, pronóstico del tiempo y ra...  1253307269409882112
# 3  RT @ministeriosalud: Chile presenta ante @WHO,...  1253306771491389440
# 4  RT @ministeriosalud: "El 30% de personas no ti...  1253306758417862657
# 5  RT @ministeriosalud: Ministro @jmanalich | Mee...  1253306748959670272
# 6  RT @ministeriosalud: AHORA: Min. @jmanalich pa...  1253306736213098496
# 7  Prefiere medicamentos #bioequivalentes. \n\nEl...  1253292539530141698
# 8  Fabrica tu propia mascarilla con una bandana.\...  1253141542237134853
# 9  Protégete contra el nuevo Coronavirus COVID-19...  1253111342497742848
#
#                  Date              Source  Likes  RTs
# 0 2020-04-23 14:00:01           TweetDeck      0    0
# 1 2020-04-23 13:00:00           TweetDeck      0    0
# 2 2020-04-23 12:58:33  Twitter for iPhone      0    0
# 3 2020-04-23 12:56:34  Twitter for iPhone      0   32
# 4 2020-04-23 12:56:31  Twitter for iPhone      0   23
# 5 2020-04-23 12:56:28  Twitter for iPhone      0   12
# 6 2020-04-23 12:56:25  Twitter for iPhone      0   18
# 7 2020-04-23 12:00:01           TweetDeck      1    1
# 8 2020-04-23 02:00:00           TweetDeck      1    1
# 9 2020-04-23 00:00:00           TweetDeck      1    1

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  Protégete contra el nuevo Coronavirus COVID-19...
# 1  Conoce más sobre esta nueva medida que comienz...
# 2  Temperatura actual, pronóstico del tiempo y ra...
# 3  RT @ministeriosalud: Chile presenta ante @WHO,...
# 4  RT @ministeriosalud: "El 30% de personas no ti...
# 5  RT @ministeriosalud: Ministro @jmanalich | Mee...
# 6  RT @ministeriosalud: AHORA: Min. @jmanalich pa...
# 7  Prefiere medicamentos #bioequivalentes. \n\nEl...
# 8  Fabrica tu propia mascarilla con una bandana.\...
# 9  Protégete contra el nuevo Coronavirus COVID-19...
#
#                                                   ID                Date  \
# 0  https://twitter.com/ispch/status/1253322740402... 2020-04-23 14:00:01
# 1  https://twitter.com/ispch/status/1253307637715... 2020-04-23 13:00:00
# 2  https://twitter.com/ispch/status/1253307269409... 2020-04-23 12:58:33
# 3  https://twitter.com/ispch/status/1253306771491... 2020-04-23 12:56:34
# 4  https://twitter.com/ispch/status/1253306758417... 2020-04-23 12:56:31
# 5  https://twitter.com/ispch/status/1253306748959... 2020-04-23 12:56:28
# 6  https://twitter.com/ispch/status/1253306736213... 2020-04-23 12:56:25
# 7  https://twitter.com/ispch/status/1253292539530... 2020-04-23 12:00:01
# 8  https://twitter.com/ispch/status/1253141542237... 2020-04-23 02:00:00
# 9  https://twitter.com/ispch/status/1253111342497... 2020-04-23 00:00:00
#
#                Source  Likes  RTs
# 0           TweetDeck      0    0
# 1           TweetDeck      0    0
# 2  Twitter for iPhone      0    0
# 3  Twitter for iPhone      0   32
# 4  Twitter for iPhone      0   23
# 5  Twitter for iPhone      0   12
# 6  Twitter for iPhone      0   18
# 7           TweetDeck      1    1
# 8           TweetDeck      1    1
# 9           TweetDeck      1    1

# %%
import csv
data.to_csv(r'tweets_ispch.csv', index = False)
