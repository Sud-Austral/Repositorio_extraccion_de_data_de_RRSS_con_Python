# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'SuperDeSalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# [RECORDATORIO]
# Les dejamos nuestros canales de contacto, con las oficinas que están atendiendo público, sus horario… https://t.co/uPLn3oolsF
#
# Acá puedes revisar la nota sobre la devolución de excedentes, instruida por la Superintendencia, que benefició
#  a… https://t.co/WGd9kKvmPQ
#
# ¿Sabes qué comunas -o zonas- de la Región Metropolitana, tendrán implementada cuarentena a partir de hoy jueves, a… https://t.co/wTPYu2NfAy
#
# RT @ministeriosalud: Hasta minutos antes del inicio de la reunión interministerial por #COVID_19 en el Palacio de La Moneda, ministro @jman…
#
# RT @ministeriosalud: Chile presenta ante @WHO, a través del ministro @jmanalich, las medidas que se han tomado en el país. Entre ellas, el…
#
# RT @sebastianpinera: Hoy nos reunimos con Organizaciones de la Sociedad Civil que cumplen un gran rol social. Reafirmamos nuestro compromis…
#
# ¿Sabías que con un pañuelo puedes fabricar una mascarilla casera? ♻️ 😷
#
# ¡Así es!  Sigue el instructivo... y evita l… https://t.co/T1lzOxVHbi
#
# RT @ministeriosalud: Un buen uso de la red asistencial consiste en conocer los distintos tipos de establecimientos y tipos de atenciones. T…
#
# @esanmartin Hola, buenas tardes. Le dejamos un mensaje directo.
#
# Al salir de tu casa siempre mantén, como mínimo, un metro de distancia con los demás:
# 🚶‍♂️|----1mt-----|🚶‍♀️ |----1… https://t.co/U8jpIgA3vu

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  [RECORDATORIO]\nLes dejamos nuestros canales d...
# 1  Acá puedes revisar la nota sobre la devolución...
# 2  ¿Sabes qué comunas -o zonas- de la Región Metr...
# 3  RT @ministeriosalud: Hasta minutos antes del i...
# 4  RT @ministeriosalud: Chile presenta ante @WHO,...
# 5  RT @sebastianpinera: Hoy nos reunimos con Orga...
# 6  ¿Sabías que con un pañuelo puedes fabricar una...
# 7  RT @ministeriosalud: Un buen uso de la red asi...
# 8  @esanmartin Hola, buenas tardes. Le dejamos un...
# 9  Al salir de tu casa siempre mantén, como mínim...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1253318673688866817
# 2020-04-23 13:43:51
# Twitter for iPhone
# 0
# 19
# None
# None
# {'hashtags': [{'text': 'COVID19', 'indices': [72, 80]}], 'symbols': [], 'user_mentions': [{'screen_name': 'opsargentina', 'name': 'OPS/OMS Argentina', 'id': 1101368186, 'id_str': '1101368186', 'indices': [3, 16]}], 'urls': [], 'media': [{'id': 1253081362518675461, 'id_str': '1253081362518675461', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/EWPW3C-WkAU7sYr.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EWPW3C-WkAU7sYr.jpg', 'url': 'https://t.co/9wBQt0lI83', 'display_url': 'pic.twitter.com/9wBQt0lI83', 'expanded_url': 'https://twitter.com/opsargentina/status/1253081365756760064/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 800, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 1800, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1253081365756760064, 'source_status_id_str': '1253081365756760064', 'source_user_id': 1101368186, 'source_user_id_str': '1101368186'}]}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @opsargentina: 10 formas de protegerse si u...  1253318673688866817
# 1  RT @OPASOMSBrasil: Já chegaram ao 🇧🇷 500 mil t...  1253318621172023296
# 2  RT @opsomsels: 📢 Conoce 10 formas de ayudar a ...  1253318572853604352
# 3  RT @OPSOMSMexico: El distanciamiento físico no...  1253318540100349952
# 4  RT @OPSOMS_Col: Para mantener una salud óptima...  1253318526141636608
# 5  RT @OPSOMSPeru: #COVID19 La @opsoms  dona15 mi...  1253318353206366210
# 6  RT @opsomsels: #COVID19 👉🏽Mantente físicamente...  1253318208792203264
# 7  RT @opsargentina: 10 formas de ayudar a las pe...  1253318190706438145
# 8  RT @Ops_Paraguay: Fumar daña los pulmones y au...  1253317952763572224
# 9  RT @opsomsuruguay: Semana de Vacunación en las...  1253317766804897792
#
#                  Date              Source  Likes  RTs
# 0 2020-04-23 13:43:51  Twitter for iPhone      0   19
# 1 2020-04-23 13:43:39  Twitter for iPhone      0   10
# 2 2020-04-23 13:43:27  Twitter for iPhone      0   12
# 3 2020-04-23 13:43:20  Twitter for iPhone      0   29
# 4 2020-04-23 13:43:16  Twitter for iPhone      0   29
# 5 2020-04-23 13:42:35  Twitter for iPhone      0   20
# 6 2020-04-23 13:42:01  Twitter for iPhone      0   15
# 7 2020-04-23 13:41:56  Twitter for iPhone      0   13
# 8 2020-04-23 13:41:00  Twitter for iPhone      0   15
# 9 2020-04-23 13:40:15  Twitter for iPhone      0    4

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @opsargentina: 10 formas de protegerse si u...
# 1  RT @OPASOMSBrasil: Já chegaram ao 🇧🇷 500 mil t...
# 2  RT @opsomsels: 📢 Conoce 10 formas de ayudar a ...
# 3  RT @OPSOMSMexico: El distanciamiento físico no...
# 4  RT @OPSOMS_Col: Para mantener una salud óptima...
# 5  RT @OPSOMSPeru: #COVID19 La @opsoms  dona15 mi...
# 6  RT @opsomsels: #COVID19 👉🏽Mantente físicamente...
# 7  RT @opsargentina: 10 formas de ayudar a las pe...
# 8  RT @Ops_Paraguay: Fumar daña los pulmones y au...
# 9  RT @opsomsuruguay: Semana de Vacunación en las...
#
#                                                   ID                Date  \
# 0  https://twitter.com/opsoms/status/125331867368... 2020-04-23 13:43:51
# 1  https://twitter.com/opsoms/status/125331862117... 2020-04-23 13:43:39
# 2  https://twitter.com/opsoms/status/125331857285... 2020-04-23 13:43:27
# 3  https://twitter.com/opsoms/status/125331854010... 2020-04-23 13:43:20
# 4  https://twitter.com/opsoms/status/125331852614... 2020-04-23 13:43:16
# 5  https://twitter.com/opsoms/status/125331835320... 2020-04-23 13:42:35
# 6  https://twitter.com/opsoms/status/125331820879... 2020-04-23 13:42:01
# 7  https://twitter.com/opsoms/status/125331819070... 2020-04-23 13:41:56
# 8  https://twitter.com/opsoms/status/125331795276... 2020-04-23 13:41:00
# 9  https://twitter.com/opsoms/status/125331776680... 2020-04-23 13:40:15
#
#                Source  Likes  RTs
# 0  Twitter for iPhone      0   19
# 1  Twitter for iPhone      0   10
# 2  Twitter for iPhone      0   12
# 3  Twitter for iPhone      0   29
# 4  Twitter for iPhone      0   29
# 5  Twitter for iPhone      0   20
# 6  Twitter for iPhone      0   15
# 7  Twitter for iPhone      0   13
# 8  Twitter for iPhone      0   15
# 9  Twitter for iPhone      0    4

# %%
import csv
data.to_csv(r'tweets_super_de_salud.csv', index = False)
