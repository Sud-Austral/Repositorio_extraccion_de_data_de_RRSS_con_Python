# %% [markdown]
# # Extractor de los últimos 10 tweets por usuario utilizados en el dataintelligence del covid-19

# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-17
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

# %%
#prompt = '> '
#tweet=''
#print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = 'SuperDeSalud'

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# Exceso de permisos: "El aislamiento físico es la medida esencial para combatir #COVID_19".
#
# Bro…
#
# RT @ministeriosalud: Ministro @jmanalich:
#
# "Condenamos actos de discriminación contra inmigrantes, personal de salud y también contra perso…
#
# RT @ministeriosalud: [EN VIVO] Autoridades de Salud entregan balance diario de #COVID_19 en nuestro país. https://t.co/cfZas0FfwG
#
# RT @SeremiSaludRM: #DíaMundialdelaMeningitis te invitamos para que conozcas la enfermedad y el esfuerzo que hace día a día la @opsomschile…
#
# [RECORDATORIO]
# Les dejamos las medidas sanitarias que comenzaron a regir ayer a las 22:00 horas.… https://t.co/2u6GutQdED
#
# RT @ministeriosalud: Si estás en zonas con cuarentena total, respétala y no te expongas a multas o sanciones, y más importante, protege tu…
#
# Al salir de tu casa siempre conserva, como mínimo, un metro de distancia con los demás.
# 🚶‍♂️|----1mt-----|🚶‍♀️ |---… https://t.co/dAtLsq2gCW
#
# [RECORDATORIO]
# Acá 👇🏼 nuestros canales de contacto, con las oficinas que están atendiendo público, sus horarios y l… https://t.co/ZanO0WOwkR
#
# RT @jmanalich: Esto va mal.
#
# RT @jmanalich: La discriminación contra contagiados de COVID-19, sobretodo inmigrantes, pasó de ser una preocupación a una triste y repudia…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\nE...
# 1  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 2  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 3  RT @SeremiSaludRM: #DíaMundialdelaMeningitis t...
# 4  [RECORDATORIO]\nLes dejamos las medidas sanita...
# 5  RT @ministeriosalud: Si estás en zonas con cua...
# 6  Al salir de tu casa siempre conserva, como mín...
# 7  [RECORDATORIO]\nAcá 👇🏼 nuestros canales de con...
# 8                        RT @jmanalich: Esto va mal.
# 9  RT @jmanalich: La discriminación contra contag...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1253695924230148097
# 2020-04-24 14:42:55
# Twitter Web App
# 0
# 12
# None
# None
# {'hashtags': [{'text': 'COVID_19', 'indices': [122, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ministeriosalud', 'name': 'Ministerio de Salud', 'id': 153825949, 'id_str': '153825949', 'indices': [3, 19]}, {'screen_name': 'jmanalich', 'name': 'Jaime Mañalich', 'id': 114834301, 'id_str': '114834301', 'indices': [30, 40]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\nE...  1253695924230148097
# 1  RT @ministeriosalud: Ministro @jmanalich:\n\n"...  1253695889199239168
# 2  RT @ministeriosalud: [EN VIVO] Autoridades de ...  1253693953003737089
# 3  RT @SeremiSaludRM: #DíaMundialdelaMeningitis t...  1253691640465821696
# 4  [RECORDATORIO]\nLes dejamos las medidas sanita...  1253681281512214528
# 5  RT @ministeriosalud: Si estás en zonas con cua...  1253671938448334849
# 6  Al salir de tu casa siempre conserva, como mín...  1253658240837128193
# 7  [RECORDATORIO]\nAcá 👇🏼 nuestros canales de con...  1253507086794792960
# 8                        RT @jmanalich: Esto va mal.  1253493517642498048
# 9  RT @jmanalich: La discriminación contra contag...  1253479514614702086
#
#                  Date              Source  Likes  RTs
# 0 2020-04-24 14:42:55     Twitter Web App      0   12
# 1 2020-04-24 14:42:47     Twitter Web App      0   17
# 2 2020-04-24 14:35:05     Twitter Web App      0   89
# 3 2020-04-24 14:25:54     Twitter Web App      0    2
# 4 2020-04-24 13:44:44     Twitter Web App      0    0
# 5 2020-04-24 13:07:36     Twitter Web App      0   14
# 6 2020-04-24 12:13:11     Twitter Web App      1    0
# 7 2020-04-24 02:12:33  Twitter for iPhone      2    1
# 8 2020-04-24 01:18:38  Twitter for iPhone      0  705
# 9 2020-04-24 00:22:59  Twitter for iPhone      0  833

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @ministeriosalud: Ministro @jmanalich:\n\nE...
# 1  RT @ministeriosalud: Ministro @jmanalich:\n\n"...
# 2  RT @ministeriosalud: [EN VIVO] Autoridades de ...
# 3  RT @SeremiSaludRM: #DíaMundialdelaMeningitis t...
# 4  [RECORDATORIO]\nLes dejamos las medidas sanita...
# 5  RT @ministeriosalud: Si estás en zonas con cua...
# 6  Al salir de tu casa siempre conserva, como mín...
# 7  [RECORDATORIO]\nAcá 👇🏼 nuestros canales de con...
# 8                        RT @jmanalich: Esto va mal.
# 9  RT @jmanalich: La discriminación contra contag...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125369... 2020-04-24 14:42:55
# 1  https://twitter.com/SuperDeSalud/status/125369... 2020-04-24 14:42:47
# 2  https://twitter.com/SuperDeSalud/status/125369... 2020-04-24 14:35:05
# 3  https://twitter.com/SuperDeSalud/status/125369... 2020-04-24 14:25:54
# 4  https://twitter.com/SuperDeSalud/status/125368... 2020-04-24 13:44:44
# 5  https://twitter.com/SuperDeSalud/status/125367... 2020-04-24 13:07:36
# 6  https://twitter.com/SuperDeSalud/status/125365... 2020-04-24 12:13:11
# 7  https://twitter.com/SuperDeSalud/status/125350... 2020-04-24 02:12:33
# 8  https://twitter.com/SuperDeSalud/status/125349... 2020-04-24 01:18:38
# 9  https://twitter.com/SuperDeSalud/status/125347... 2020-04-24 00:22:59
#
#                Source  Likes  RTs
# 0     Twitter Web App      0   12
# 1     Twitter Web App      0   17
# 2     Twitter Web App      0   89
# 3     Twitter Web App      0    2
# 4     Twitter Web App      0    0
# 5     Twitter Web App      0   14
# 6     Twitter Web App      1    0
# 7  Twitter for iPhone      2    1
# 8  Twitter for iPhone      0  705
# 9  Twitter for iPhone      0  833

# %%
import csv
data.to_csv(r'tweets_super_de_salud.csv', index = False)
