# %% [markdown]
# # 080420 Extracción en tiempo real de tweets por usuario III
#
# https://www.storybench.org/how-to-collect-tweets-from-the-twitter-streaming-api-using-python/
#
#
# https://twitter.com/colmedchile
#
# Para obtener el id de un usuario:
#
# http://gettwitterid.com/
#
# Tweet objects:
#
# https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object

# %% [markdown]
# Filtros en Twitter:
#
# <img src="./filtros_en_tweeter.jpg" width="500" height="1000" >

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# Out:
# Christian Castro
# last updated: 2020-04-08
#
# numpy 1.18.2
# pandas 1.0.1
# matplotlib 3.1.3

# %%
import tweepy

# authorization tokens
consumer_key = 'koO4XqTuWFr5ADGcE8kjIkVoU'
consumer_secret = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'
access_key = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
access_secret = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'
 
    
# Paso 2: Crea la clase StreamListener. En el mismo
# archivo, vamos a crear una nueva clase llamada
# StreamListener que hereda de la clase
# StreamListener de tweepy y anula los métodos
# on_status y on_error para que podamos personalizar
# lo que queremos hacer con cada tweet que
# encontremos. 

# La siguiente función limpia nuestros tweets y los separa con la función .split():
def remove_url(txt):
    return ' '.join(re.sub('([^0-9A-Za-z-áéíóúÁÉÍÓÚñÑ \t])|(\w+:\/\/\S+)', '', txt).split())    
    
# StreamListener class inherits from tweepy.StreamListener and overrides on_status/on_error methods.
class StreamListener(tweepy.StreamListener):
    
    
    
    

    
    
    
    
    
    
    def on_status(self, status):
        #print('Tweet: '+status.text +' '+'\n' + 'Hora en la que fue emitido: '+ str(status.created_at))
        
        j=1
        
      
        print(str(j) +') '+ '\n' +
                'Texto del tweet: '+ status.text +' '+'\n' +
              
         
              
              
                'Creado en : '+str(status.created_at) +' '+'\n' +
                'Id del tweet: '+str(status.id) +' '+'\n' +
                'Número de favoritos: '+str(status.favorite_count) +' '+'\n' +
                'Número de retweets: '+str(status.retweet_count) +' '+'\n' +
                'Favoritos: '+str(status.favorited) +' '+'\n' +
                '¿Usuario autenticado?: '+str(status.retweeted) +' '+'\n' +
                'Idioma: '+str(status.lang) +' '+'\n' +
                'Lugar: '+str(status.place) +' '+'\n' +
                'Coordenadas: '+str(status.coordinates) +' '+'\n' +
                'Geolocalización: '+str(status.geo) +' '+'\n' +
                'Perfil completo del autor: '+str(status.user) +' '+ '\n'+ '\n')
        j= j+1    
        
        
        
        
        
        
        
        
        # si existe el atributo "retweeted_status", marque este tweet como un retweet:
        is_retweet = hasattr(status, "retweeted_status")

        # verificar si el texto ha sido truncado:
        if hasattr(status,"extended_tweet"):
            text = status.extended_tweet["full_text"]
        else:
            text = status.text

        # check if this is a quote tweet.
        is_quote = hasattr(status, "quoted_status")
        quoted_text = ""
        if is_quote:
            # check if quoted tweet's text has been truncated before recording it
            if hasattr(status.quoted_status,"extended_tweet"):
                quoted_text = status.quoted_status.extended_tweet["full_text"]
            else:
                quoted_text = status.quoted_status.text

        # remove characters that might cause problems with csv encoding
        remove_characters = [",","\n"]
        for c in remove_characters:
            text.replace(c," ")
            quoted_text.replace(c, " ")

        with open("out.csv", "a", encoding='utf-8') as f:
            f.write("%s,%s,%s,%s,%s,%s\n" % (status.created_at,status.user.screen_name,is_retweet,is_quote,text,quoted_text))

    def on_error(self, status_code):
        print("Encountered streaming error (", status_code, ")")
        sys.exit()

        
        


# Programa MAIN #  
        
if __name__ == "__main__":
    
    # Paso 1: Configuramos el endpoint API tweeter con las clave que obtuvimos como desarrollador:   
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    # Instanciamos la clase StreamListener:
    streamListener = StreamListener()
    stream = tweepy.Stream(auth=api.auth, listener=streamListener, count=5, tweet_mode='extended')
    

    
    
    with open("out.csv", "w", encoding='utf-8') as f:
        f.write("date,user, is_retweet, is_quote, full_text, quoted_text\n")
    
    # Paso 3: Inicializamos el streaming con filtros para seguir a un usuario específico:
    # id del usuario: colegio médico: 633098103
    # usuario = ['633098103']
    
    # id del usuario: WHO: 14499829
    usuario = ['14499829']
    

    
    
    stream.filter(follow=usuario)
# Out:
# 1)
# Texto del tweet: @WHO so... exactly when is support going to come to #Ecuador. Is it okay for them to die and be ignored? And how ab… https://t.co/hvah5lTGi4
# Creado en : 2020-04-08 18:40:28
# Id del tweet: 1247957501515087873
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: en
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000001992A135988>, _json={'id': 1220838916737183749, 'id_str': '1220838916737183749', 'name': 'Neil Moore', 'screen_name': 'NeilMoo42109003', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1, 'friends_count': 12, 'listed_count': 0, 'favourites_count': 23, 'statuses_count': 327, 'created_at': 'Fri Jan 24 22:41:02 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1220838916737183749, id_str='1220838916737183749', name='Neil Moore', screen_name='NeilMoo42109003', location=None, url=None, description=None, translator_type='none', protected=False, verified=False, followers_count=1, friends_count=12, listed_count=0, favourites_count=23, statuses_count=327, created_at=datetime.datetime(2020, 1, 24, 22, 41, 2), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='F5F8FA', profile_background_image_url='', profile_background_image_url_https='', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @WHO @Facebook @Google @instagram @LinkedIn @messenger @Pinterest @Snapchat @TencentGlobal @tiktok_uk @Twitter… https://t.co/ruHnJ2vF0M
# Creado en : 2020-04-08 18:40:30
# Id del tweet: 1247957506720026625
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: en
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000001992A135988>, _json={'id': 1040337955, 'id_str': '1040337955', 'name': 'Earl Farrow', 'screen_name': 'EarldfjrEarl', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 21, 'friends_count': 234, 'listed_count': 1, 'favourites_count': 749, 'statuses_count': 8412, 'created_at': 'Thu Dec 27 19:01:26 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1040337955, id_str='1040337955', name='Earl Farrow', screen_name='EarldfjrEarl', location=None, url=None, description=None, translator_type='none', protected=False, verified=False, followers_count=21, friends_count=234, listed_count=1, favourites_count=749, statuses_count=8412, created_at=datetime.datetime(2012, 12, 27, 19, 1, 26), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @WHO what about the few millions of hidden illegal immigrants and Covid-19 spread among them? How much will they co… https://t.co/cQvS5cbgta
# Creado en : 2020-04-08 18:40:30
# Id del tweet: 1247957508754456578
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: en
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000001992A135988>, _json={'id': 284530863, 'id_str': '284530863', 'name': 'Albert Vanneste', 'screen_name': 'alvamp003', 'location': 'North of Belgium', 'url': None, 'description': 'Pharma chemist. Longvity experiment with daily intake of exotic phyto anti-oxydants.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 111, 'friends_count': 434, 'listed_count': 1, 'favourites_count': 1066, 'statuses_count': 2839, 'created_at': 'Tue Apr 19 13:15:42 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/989440774063484928/42zOCF7A_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989440774063484928/42zOCF7A_normal.jpg', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=284530863, id_str='284530863', name='Albert Vanneste', screen_name='alvamp003', location='North of Belgium', url=None, description='Pharma chemist. Longvity experiment with daily intake of exotic phyto anti-oxydants.', translator_type='none', protected=False, verified=False, followers_count=111, friends_count=434, listed_count=1, favourites_count=1066, statuses_count=2839, created_at=datetime.datetime(2011, 4, 19, 13, 15, 42), utc_offset=None, time_zone=None, geo_enabled=True, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='000000', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='FAB81E', profile_sidebar_border_color='000000', profile_sidebar_fill_color='000000', profile_text_color='000000', profile_use_background_image=False, profile_image_url='http://pbs.twimg.com/profile_images/989440774063484928/42zOCF7A_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/989440774063484928/42zOCF7A_normal.jpg', default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# 1)
# Texto del tweet: RT @WHO: Did You Know❓
# ☑ 1 in 8 #nurses works in a country other than where they were born or trained
# ☑ &gt;80% of the world’s nurses work in…
# Creado en : 2020-04-08 18:40:32
# Id del tweet: 1247957515666698241
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: en
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000001992A135988>, _json={'id': 2159186131, 'id_str': '2159186131', 'name': 'Amol Bade', 'screen_name': 'being__AB', 'location': 'भारत India 🇮🇳 ', 'url': None, 'description': 'मराठी, English\n\nmostly RTs... informative! \nN.E.W.S. in, out, up, down', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 114, 'friends_count': 2474, 'listed_count': 1, 'favourites_count': 2688, 'statuses_count': 3312, 'created_at': 'Sun Oct 27 16:18:12 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000777192114/c8643bb212ee6035f05f3e40294a2bb1_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000777192114/c8643bb212ee6035f05f3e40294a2bb1_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2159186131/1486369350', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=2159186131, id_str='2159186131', name='Amol Bade', screen_name='being__AB', location='भारत India 🇮🇳 ', url=None, description='मराठी, English\n\nmostly RTs... informative! \nN.E.W.S. in, out, up, down', translator_type='none', protected=False, verified=False, followers_count=114, friends_count=2474, listed_count=1, favourites_count=2688, statuses_count=3312, created_at=datetime.datetime(2013, 10, 27, 16, 18, 12), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/378800000777192114/c8643bb212ee6035f05f3e40294a2bb1_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/378800000777192114/c8643bb212ee6035f05f3e40294a2bb1_normal.jpeg', profile_banner_url='https://pbs.twimg.com/profile_banners/2159186131/1486369350', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
#
#
# 1)
# Texto del tweet: @WHO @DrTedros The World Health Organization asked the United States and China for “honest leadership” on the coron… https://t.co/Y3Ly9ufe3e
# Creado en : 2020-04-08 18:40:35
# Id del tweet: 1247957527553134592
# Número de favoritos: 0
# Número de retweets: 0
# Favoritos: False
# ¿Usuario autenticado?: False
# Idioma: en
# Lugar: None
# Coordenadas: None
# Geolocalización: None
# Perfil completo del autor: User(_api=<tweepy.api.API object at 0x000001992A135988>, _json={'id': 1040337955, 'id_str': '1040337955', 'name': 'Earl Farrow', 'screen_name': 'EarldfjrEarl', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 21, 'friends_count': 234, 'listed_count': 1, 'favourites_count': 749, 'statuses_count': 8413, 'created_at': 'Thu Dec 27 19:01:26 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, id=1040337955, id_str='1040337955', name='Earl Farrow', screen_name='EarldfjrEarl', location=None, url=None, description=None, translator_type='none', protected=False, verified=False, followers_count=21, friends_count=234, listed_count=1, favourites_count=749, statuses_count=8413, created_at=datetime.datetime(2012, 12, 27, 19, 1, 26), utc_offset=None, time_zone=None, geo_enabled=False, lang=None, contributors_enabled=False, is_translator=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, profile_image_url='http://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/378800000710032531/da005cf98751b97db08d6f8db5a70068_normal.jpeg', default_profile=True, default_profile_image=False, following=False, follow_request_sent=None, notifications=None)
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-a31982cc37d9> in <module>
#     130
#     131
# --> 132     stream.filter(follow=usuario)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %% [markdown]
# #### la tarea es desplegar siempre los últimos 5 tweets siendo el último el primero de la lista
