# %%
import tweepy

# %%
# %load_ext watermark
# %watermark -a "Christian Castro" -u -d -p numpy,pandas,matplotlib
# %watermark -a "Propiedad de DataIntelligence"
# Out:
# Christian Castro
# last updated: 2020-04-16
#
# numpy 1.18.1
# pandas 1.0.1
# matplotlib 3.1.3
# Propiedad de DataIntelligence

# %% [markdown]
# 1
# @colmedchile
# tweets_colegio_medico.csv
#
# 2
# @ministeriosalud
# tweets_min_sal.csv
#
# 3
# @opsoms
# tweets_opsoms.csv
#
# 4
# @SuperDeSalud
# tweets_super_de_salud.csv
#
# 5
# @ispch
# tweets_ispch.csv
#
#
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_colegio_medico.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master/tweets_min_sal.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_opsoms.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_super_de_salud.csv
# https://raw.githubusercontent.com/Sud-Austral/Repositorio_extraccion_de_data_de_RRSS_con_Python/master
# /tweets_ispch.csv
#
# sochimu: no twitea nada:
#
# Fuente:
#
# https://github.com/RodolfoFerro/pandas_twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Declaramos nuestras Twitter API Keys:
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'koO4XqTuWFr5ADGcE8kjIkVoU'
CONSUMER_SECRET = '3F4sk9qU8zbKBROuLPUUj1uvE2YuhseXPe0ahMQoivg4icN5bL'

# Access:
ACCESS_TOKEN  = '1230251564616515586-2KqPsCG2mIJp3irRjENgHpCfQUxTUg'
ACCESS_SECRET = '6PJfMtYGY7w6csiIX9m1S5jFEKNZ3hE9PVkHKeN1S14iM'

# %%
# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
prompt = '> '
tweet=''
print("ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:")
usuario_de_consulta = input(prompt)

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name=usuario_de_consulta, count=10)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("10 recent tweets:\n")
for tweet in tweets[:10]:
    print(tweet.text)
    print()
# Out:
# ingrese el usuario de Twitter sobre el cual hacer la consulta sin comillas ni arroba:
# > SuperDeSalud
# Number of tweets extracted: 10.
#
# 10 recent tweets:
#
# RT @valenzuelagabi: @SuperDeSalud, Patricio Fernández: "Sacamos una circular donde obligamos a las #isapres aprobar a todas las licencias q…
#
# RT @valenzuelagabi: @SuperDeSalud, Patricio Fernández x licencias médicas por covid-19: "Todas estas licencias que fueron rechazadas por te…
#
# EL Superintendente, Patricio Fernández, en vivo por @Interactiva921  se refiere al pago de las licencias por… https://t.co/ufueo7jIlY
#
# [EN VIVO]
# El Superintendente, Patricio Fernández, en vivo, por @uchileradio se refiere a las Isapres en tiempos de… https://t.co/7vswI0GqRE
#
# RT @sebastianpinera: La tecnología nos permite, pese a la distancia, estar informados y cerca de nuestros seres queridos. Queremos entregar…
#
# RT @ElMercurio_cl: Superintendencia de Salud ordena a isapres aprobar toda licencia por coronavirus que hayan rechazado https://t.co/hJbr05…
#
# @FerdinandGac @CKumbre De nada!
#
# RT @SENAMAGOB: Recuerda que el aislamiento físico no puede convertirse en aislamiento social. Por eso, sigue estos consejos y podrás cuidar…
#
# @FerdinandGac @CKumbre Hola, buenas noches, no... transporte privado pagado.
# En auto, la recomendación dice que si… https://t.co/gOb71iGomI
#
# @omarmanuelg @jmanalich Estimado, la circular se emitió el jueves pasado, la notificación le debe haber llegado a l… https://t.co/03tX9xtivr

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @valenzuelagabi: @SuperDeSalud, Patricio Fe...
# 1  RT @valenzuelagabi: @SuperDeSalud, Patricio Fe...
# 2  EL Superintendente, Patricio Fernández, en viv...
# 3  [EN VIVO]\nEl Superintendente, Patricio Fernán...
# 4  RT @sebastianpinera: La tecnología nos permite...
# 5  RT @ElMercurio_cl: Superintendencia de Salud o...
# 6                    @FerdinandGac @CKumbre De nada!
# 7  RT @SENAMAGOB: Recuerda que el aislamiento fís...
# 8  @FerdinandGac @CKumbre Hola, buenas noches, no...
# 9  @omarmanuelg @jmanalich Estimado, la circular ...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1250771163342610432
# 2020-04-16 13:00:58
# Twitter Web App
# 0
# 5
# None
# None
# {'hashtags': [{'text': 'isapres', 'indices': [99, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'valenzuelagabi', 'name': 'Gabi Valenzuela', 'id': 133867430, 'id_str': '133867430', 'indices': [3, 18]}, {'screen_name': 'SuperDeSalud', 'name': 'Super de Salud Chile', 'id': 165797212, 'id_str': '165797212', 'indices': [20, 33]}], 'urls': []}

# %%
# We add relevant data:
#data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID'] = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

#And to display again the dataframe to see the changes we just...:

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets                   ID  \
# 0  RT @valenzuelagabi: @SuperDeSalud, Patricio Fe...  1250771163342610432
# 1  RT @valenzuelagabi: @SuperDeSalud, Patricio Fe...  1250769996868915200
# 2  EL Superintendente, Patricio Fernández, en viv...  1250769947464273921
# 3  [EN VIVO]\nEl Superintendente, Patricio Fernán...  1250761280690040833
# 4  RT @sebastianpinera: La tecnología nos permite...  1250759458076209152
# 5  RT @ElMercurio_cl: Superintendencia de Salud o...  1250759234528120838
# 6                    @FerdinandGac @CKumbre De nada!  1250603233283837953
# 7  RT @SENAMAGOB: Recuerda que el aislamiento fís...  1250600158016012288
# 8  @FerdinandGac @CKumbre Hola, buenas noches, no...  1250599912196145158
# 9  @omarmanuelg @jmanalich Estimado, la circular ...  1250592937156755463
#
#                  Date              Source  Likes  RTs
# 0 2020-04-16 13:00:58     Twitter Web App      0    5
# 1 2020-04-16 12:56:20     Twitter Web App      0    5
# 2 2020-04-16 12:56:08     Twitter Web App     11   10
# 3 2020-04-16 12:21:41     Twitter Web App      0    0
# 4 2020-04-16 12:14:27     Twitter Web App      0  209
# 5 2020-04-16 12:13:34     Twitter Web App      0   46
# 6 2020-04-16 01:53:40  Twitter for iPhone      1    0
# 7 2020-04-16 01:41:27  Twitter for iPhone      0   18
# 8 2020-04-16 01:40:28  Twitter for iPhone      1    0
# 9 2020-04-16 01:12:45  Twitter for iPhone      0    0

# %%
elstringid = 'https://twitter.com/'+usuario_de_consulta+'/status/'
data['ID'] = elstringid + data['ID'].astype(str)
display(data.head(10))
# Out:
#                                               Tweets  \
# 0  RT @valenzuelagabi: @SuperDeSalud, Patricio Fe...
# 1  RT @valenzuelagabi: @SuperDeSalud, Patricio Fe...
# 2  EL Superintendente, Patricio Fernández, en viv...
# 3  [EN VIVO]\nEl Superintendente, Patricio Fernán...
# 4  RT @sebastianpinera: La tecnología nos permite...
# 5  RT @ElMercurio_cl: Superintendencia de Salud o...
# 6                    @FerdinandGac @CKumbre De nada!
# 7  RT @SENAMAGOB: Recuerda que el aislamiento fís...
# 8  @FerdinandGac @CKumbre Hola, buenas noches, no...
# 9  @omarmanuelg @jmanalich Estimado, la circular ...
#
#                                                   ID                Date  \
# 0  https://twitter.com/SuperDeSalud/status/125077... 2020-04-16 13:00:58
# 1  https://twitter.com/SuperDeSalud/status/125076... 2020-04-16 12:56:20
# 2  https://twitter.com/SuperDeSalud/status/125076... 2020-04-16 12:56:08
# 3  https://twitter.com/SuperDeSalud/status/125076... 2020-04-16 12:21:41
# 4  https://twitter.com/SuperDeSalud/status/125075... 2020-04-16 12:14:27
# 5  https://twitter.com/SuperDeSalud/status/125075... 2020-04-16 12:13:34
# 6  https://twitter.com/SuperDeSalud/status/125060... 2020-04-16 01:53:40
# 7  https://twitter.com/SuperDeSalud/status/125060... 2020-04-16 01:41:27
# 8  https://twitter.com/SuperDeSalud/status/125059... 2020-04-16 01:40:28
# 9  https://twitter.com/SuperDeSalud/status/125059... 2020-04-16 01:12:45
#
#                Source  Likes  RTs
# 0     Twitter Web App      0    5
# 1     Twitter Web App      0    5
# 2     Twitter Web App     11   10
# 3     Twitter Web App      0    0
# 4     Twitter Web App      0  209
# 5     Twitter Web App      0   46
# 6  Twitter for iPhone      1    0
# 7  Twitter for iPhone      0   18
# 8  Twitter for iPhone      1    0
# 9  Twitter for iPhone      0    0

# %%
import csv
data.to_csv(r'tweets_super_de_salud.csv', index = False)
